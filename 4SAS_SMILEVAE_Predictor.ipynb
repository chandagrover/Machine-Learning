# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SAS_SMILEVAE_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# !sudo apt-get install software-pro`perties-common
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test
# !sudo apt-get update
# !sudo apt-get install gcc-4.9
# !sudo apt-get upgrade libstdc++6
# !pip install keras==2.2.4
# %tensorflow_version 1.x
import keras
import tensorflow as tf
print("Keras: %s"%keras.__version__)
print("Tensorflow: %s"%tf.__version__)

# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# RDKIT Imports
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# FOR VAE Architecture 
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import mse, binary_crossentropy
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
print("RDKit: %s"%rdkit.__version__)

from rdkit import RDLogger  

# Checking if GPU is enabled or not
tf.test.gpu_device_name()
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching ``'
# /bin/bash: -c: line 1: syntax error: unexpected end of file
#  Toolchain test builds; see https://wiki.ubuntu.com/ToolChain
#
#  More info: https://launchpad.net/~ubuntu-toolchain-r/+archive/ubuntu/test
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic InRelease
# Reading package lists... Done
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package gcc-4.9 is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'gcc-4.9' has no installation candidate
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libstdc++6 is already the newest version (10.1.0-2ubuntu1~18.04).
# Calculating upgrade... Done
# The following packages have been kept back:
#   lib32gcc1 lib32stdc++6 libcublas-dev libcublas10 libcudnn7 libcudnn7-dev
#   libnccl-dev libnccl2 linux-headers-generic
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Keras: 2.3.1
# Tensorflow: 1.15.2
# --2021-01-07 12:14:51--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2021-01-07 12:14:51--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libgcc-ng conflicts for:
# pandas -> libgcc-ng[version='>=9.3.0']
# pixman -> libgcc-ng[version='>=7.5.0']
# boost-cpp -> libgcc-ng[version='>=7.5.0']
# tornado -> libgcc-ng[version='>=7.5.0']
# python_abi -> python=3.7 -> libgcc-ng[version='>=7.3.0']
# pycairo -> libgcc-ng[version='>=7.5.0']
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=9.3.0']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0']
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.5.0']
# icu -> libgcc-ng[version='>=7.5.0']
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0']
# pycparser==2.20=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# pthread-stubs -> libgcc-ng[version='>=7.5.0']
# matplotlib-base -> libgcc-ng[version='>=7.3.0']
# xorg-xproto -> libgcc-ng[version='>=9.3.0']
# xorg-libsm -> libgcc-ng[version='>=7.3.0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0'] -> libgcc-ng[version='>=7.2.0']
# idna==2.9=py_1 -> python -> libgcc-ng[version='>=7.3.0']
# lcms2 -> libgcc-ng[version='>=7.5.0']
# libopenblas -> libgcc-ng[version='>=9.3.0']
# xorg-libxext -> libgcc-ng[version='>=7.3.0']
# kiwisolver -> libgcc-ng[version='>=7.5.0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# pcre -> libgcc-ng[version='>=7.3.0']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> libgcc-ng[version='>=7.3.0']
# reportlab -> libgcc-ng[version='>=9.3.0']
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# zstd -> libgcc-ng[version='>=9.3.0']
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0']
# pytz -> python[version='>=3'] -> libgcc-ng[version='>=7.3.0']
# lz4-c -> libgcc-ng[version='>=9.3.0']
# pillow -> libgcc-ng[version='>=7.3.0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# reportlab -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# cairo -> libgcc-ng[version='>=9.3.0']
# cycler -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libxau -> libgcc-ng[version='>=7.3.0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# libglib -> libgcc-ng[version='>=9.3.0']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0']
# xorg-libxext -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# libiconv -> libgcc-ng[version='>=7.5.0']
# sqlalchemy -> libgcc-ng[version='>=9.3.0']
# libtiff -> jpeg[version='>=9d,<10a'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libxml2 -> libgcc-ng[version='>=9.3.0']
# pyparsing -> python -> libgcc-ng[version='>=7.3.0']
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0']
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# fontconfig -> libgcc-ng[version='>=9.3.0']
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# olefile -> python -> libgcc-ng[version='>=7.3.0']
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0']
# libxml2 -> icu[version='>=68.1,<69.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libgcc-ng==9.1.0=hdf63c60_0
# libwebp-base -> libgcc-ng[version='>=7.5.0']
# libtiff -> libgcc-ng[version='>=9.3.0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# freetype -> libgcc-ng[version='>=7.5.0']
# xorg-libx11 -> libxcb=1 -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# libuuid -> libgcc-ng[version='>=9.3.0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# xorg-libxrender -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# libglib -> libffi[version='>=3.3,<3.4.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# xorg-renderproto -> libgcc-ng[version='>=7.3.0']
# bzip2 -> libgcc-ng[version='>=9.3.0']
# libxcb -> pthread-stubs -> libgcc-ng[version='>=7.5.0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# numpy -> libgcc-ng[version='>=9.3.0']
# rdkit -> libgcc-ng[version='>=9.3.0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# cairo -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libpng -> libgcc-ng[version='>=7.5.0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# xorg-libxrender -> libgcc-ng[version='>=7.3.0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# pillow -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# libxcb -> libgcc-ng[version='>=7.3.0']
# gettext -> libgcc-ng[version='>=9.3.0']
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> libgcc-ng[version='>=7.3.0']
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=9.3.0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# tqdm==4.46.0=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libice -> libgcc-ng[version='>=7.3.0']
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgcc-ng[version='>=9.3.0']
# boost -> libgcc-ng[version='>=7.5.0']
# python-dateutil -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0']
# xorg-libsm -> libuuid[version='>=2.32.1,<3.0a0'] -> libgcc-ng[version='>=9.3.0']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> libgcc-ng[version='>=7.3.0']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# boost-cpp -> bzip2[version='>=1.0.8,<2.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# zstd -> xz[version='>=5.2.5,<5.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# jpeg -> libgcc-ng[version='>=7.5.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libgcc-ng[version='>=9.3.0']
# gettext -> libffi[version='>=3.3,<3.4.0a0'] -> libgcc-ng[version='>=7.3.0']
#
# Package tk conflicts for:
# boost -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# tqdm==4.46.0=py_0 -> python -> tk[version='>=8.6.8,<8.7.0a0']
# python_abi -> python=3.7 -> tk[version='>=8.6.8,<8.7.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# cycler -> python -> tk[version='>=8.6.8,<8.7.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# python-dateutil -> python -> tk[version='>=8.6.8,<8.7.0a0']
# python==3.7.7=hcff3b4d_5 -> tk[version='>=8.6.8,<8.7.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pycparser==2.20=py_0 -> python -> tk[version='>=8.6.8,<8.7.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# tk==8.6.8=hbc83047_0
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pillow -> tk
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# reportlab -> pillow[version='>=2.4.0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pyparsing -> python -> tk[version='>=8.6.8,<8.7.0a0']
# idna==2.9=py_1 -> python -> tk[version='>=8.6.8,<8.7.0a0']
# rdkit -> matplotlib-base -> tk[version='>=8.6.8,<8.7.0a0']
# matplotlib-base -> tk
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pytz -> python[version='>=3'] -> tk[version='>=8.6.8,<8.7.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# olefile -> python -> tk[version='>=8.6.8,<8.7.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
#
# Package sqlite conflicts for:
# numpy -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# python==3.7.7=hcff3b4d_5 -> sqlite[version='>=3.31.1,<4.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# cycler -> python -> sqlite[version='>=3.31.1,<4.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# idna==2.9=py_1 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# pycparser==2.20=py_0 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pyparsing -> python -> sqlite[version='>=3.31.1,<4.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# sqlite==3.31.1=h62c20be_1
# pytz -> python[version='>=3'] -> sqlite[version='>=3.31.1,<4.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# python-dateutil -> python -> sqlite[version='>=3.31.1,<4.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# tqdm==4.46.0=py_0 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# olefile -> python -> sqlite[version='>=3.31.1,<4.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# python_abi -> python=3.7 -> sqlite[version='>=3.31.1,<4.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
#
# Package _openmp_mutex conflicts for:
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pycairo -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# lz4-c -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# cairo -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-xproto -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# kiwisolver -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# matplotlib-base -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxext -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pthread-stubs -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libsm -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# zstd -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxrender -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pandas -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-renderproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxau -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libiconv -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# _openmp_mutex
# pillow -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# lcms2 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# boost -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pixman -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# rdkit -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# bzip2 -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libxcb -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libopenblas -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# libuuid -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# gettext -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# fontconfig -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# libpng -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# jpeg -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# freetype -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# boost-cpp -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libtiff -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# pcre -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libxml2 -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# icu -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# reportlab -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# tornado -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libice -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libwebp-base -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libglib -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# numpy -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
#
# Package idna conflicts for:
# idna==2.9=py_1
# urllib3==1.25.8=py37_0 -> idna[version='>=2.0.0']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> idna
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> idna[version='>=2.0.0']
# requests==2.23.0=py37_0 -> idna[version='>=2.5,<3']
# cryptography==2.9.2=py37h1ba5d50_0 -> idna
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> idna[version='>=2.5,<3']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> idna
#
# Package ncurses conflicts for:
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python-dateutil -> python -> ncurses[version='>=6.2,<7.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# tqdm==4.46.0=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.7.7=hcff3b4d_5 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# python_abi -> python=3.7 -> ncurses[version='>=6.2,<7.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# libedit==3.1.20181209=hc058e9b_0 -> ncurses[version='>=6.1,<7.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.7.7=hcff3b4d_5 -> ncurses[version='>=6.2,<7.0a0']
# pycparser==2.20=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.31.1=h62c20be_1 -> ncurses[version='>=6.2,<7.0a0']
# idna==2.9=py_1 -> python -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.31.1=h62c20be_1 -> libedit[version='>=3.1.20181209,<3.2.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# pytz -> python[version='>=3'] -> ncurses[version='>=6.2,<7.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ncurses==6.2=he6710b0_1
# cycler -> python -> ncurses[version='>=6.2,<7.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# olefile -> python -> ncurses[version='>=6.2,<7.0a0']
# pyparsing -> python -> ncurses[version='>=6.2,<7.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
#
# Package python conflicts for:
# cycler -> python
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0']
# boost -> python[version='>=3.7,<3.8.0a0']
# tornado -> python_abi=3.7[build=*_cp37m] -> python=3.7
# numpy -> python[version='>=3.7,<3.8.0a0']
# pycparser==2.20=py_0 -> python
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0']
# python_abi -> python=3.7
# cycler -> six -> python[version='>=3.7,<3.8.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0']
# pandas -> python-dateutil[version='>=2.7.3'] -> python[version='3.7.*|>=3']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0']
# python-dateutil -> python
# sqlalchemy -> python_abi=3.7[build=*_cp37m] -> python=3.7
# python==3.7.7=hcff3b4d_5
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
# matplotlib-base -> cycler[version='>=0.10'] -> python
# numpy -> python_abi=3.7[build=*_cp37m] -> python=3.7
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# requests==2.23.0=py37_0 -> idna[version='>=2.5,<3'] -> python
# urllib3==1.25.8=py37_0 -> idna[version='>=2.0.0'] -> python
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0']
# tqdm==4.46.0=py_0 -> python
# pyparsing -> python
# idna==2.9=py_1 -> python
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0']
# boost -> python_abi=3.7[build=*_cp37m] -> python=3.7
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0']
# rdkit -> python_abi=3.7[build=*_cp37m] -> python=3.7
# olefile -> python
# kiwisolver -> python_abi=3.7[build=*_cp37m] -> python=3.7
# pandas -> python[version='>=3.7,<3.8.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> idna -> python
# conda-package-handling==1.6.1=py37h7b6447c_0 -> tqdm -> python
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0']
# reportlab -> python_abi=3.7[build=*_cp37m] -> python=3.7
# pillow -> olefile -> python
# cffi==1.14.0=py37he30daa8_1 -> pycparser -> python
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0']
# python-dateutil -> six -> python[version='>=3.7,<3.8.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# pytz -> python[version='>=3']
# pycairo -> python_abi=3.7[build=*_cp37m] -> python=3.7
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
#
# Package jpeg conflicts for:
# jpeg
# matplotlib-base -> pillow[version='>=6.2.0'] -> jpeg
# pillow -> lcms2[version='>=2.11,<3.0a0'] -> jpeg[version='>=9d,<10a']
# lcms2 -> jpeg[version='>=9d,<10a']
# pillow -> jpeg
# reportlab -> pillow[version='>=2.4.0'] -> jpeg
# libtiff -> jpeg[version='>=9d,<10a']
# rdkit -> pillow -> jpeg
#
# Package _libgcc_mutex conflicts for:
# libglib -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# numpy -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# boost-cpp -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# kiwisolver -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libiconv -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# tornado -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-libxext -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# lz4-c -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# cairo -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# xorg-renderproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-libsm -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# _openmp_mutex -> _libgcc_mutex==0.1=conda_forge
# xorg-libxrender -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-libxau -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pixman -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pillow -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# lcms2 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pandas -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libgcc-ng==9.1.0=hdf63c60_0 -> _libgcc_mutex=[build=main]
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# matplotlib-base -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# xorg-libx11 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-xproto -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# freetype -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libpng -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# jpeg -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# _libgcc_mutex==0.1=main
# boost -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libuuid -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# gettext -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# fontconfig -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# zstd -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# pcre -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libgomp -> _libgcc_mutex==0.1=conda_forge
# xorg-libice -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# icu -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libxcb -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libtiff -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# libxml2 -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# rdkit -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# libwebp-base -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pthread-stubs -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# bzip2 -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# reportlab -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# libopenblas -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
# pycairo -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main']
#
# Package icu conflicts for:
# cairo -> icu[version='>=68.1,<69.0a0']
# icu
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> icu[version='>=68.1,<69.0a0']
# libxml2 -> icu[version='>=68.1,<69.0a0']
# boost -> boost-cpp=1.74.0 -> icu[version='>=68.1,<69.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> icu[version='>=68.1,<69.0a0']
# boost-cpp -> icu[version='>=68.1,<69.0a0']
# fontconfig -> icu[version='>=68.1,<69.0a0']
#
# Package xz conflicts for:
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> xz[version='>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# cycler -> python -> xz[version='>=5.2.5,<6.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# libxml2 -> xz[version='>=5.2.5,<5.3.0a0']
# pyparsing -> python -> xz[version='>=5.2.5,<6.0a0']
# pycparser==2.20=py_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# idna==2.9=py_1 -> python -> xz[version='>=5.2.5,<6.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# boost-cpp -> xz[version='>=5.2.5,<5.3.0a0']
# libtiff -> xz[version='>=5.2.5,<5.3.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pytz -> python[version='>=3'] -> xz[version='>=5.2.5,<6.0a0']
# olefile -> python -> xz[version='>=5.2.5,<6.0a0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0'] -> xz[version='>=5.2.5,<5.3.0a0']
# tqdm==4.46.0=py_0 -> python -> xz[version='>=5.2.5,<6.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# python-dateutil -> python -> xz[version='>=5.2.5,<6.0a0']
# python==3.7.7=hcff3b4d_5 -> xz[version='>=5.2.5,<6.0a0']
# boost -> boost-cpp=1.74.0 -> xz[version='>=5.2.5,<5.3.0a0|>=5.2.5,<6.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# zstd -> xz[version='>=5.2.5,<5.3.0a0']
# python_abi -> python=3.7 -> xz[version='>=5.2.5,<6.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> xz[version='>=5.2.5,<5.3.0a0']
# xz==5.2.5=h7b6447c_0
# numpy -> python[version='>=3.7,<3.8.0a0'] -> xz[version='>=5.2.5,<6.0a0']
#
# Package conda-package-handling conflicts for:
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0']
# conda-package-handling==1.6.1=py37h7b6447c_0
#
# Package pyopenssl conflicts for:
# urllib3==1.25.8=py37_0 -> pyopenssl[version='>=0.14']
# pyopenssl==19.1.0=py37_0
# conda==4.8.3=py37_0 -> pyopenssl[version='>=16.2.0']
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pyopenssl[version='>=0.14']
#
# Package libffi conflicts for:
# libffi==3.3=he6710b0_1
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# olefile -> python -> libffi[version='>=3.3,<3.4.0a0']
# pytz -> python[version='>=3'] -> libffi[version='>=3.3,<3.4.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# python-dateutil -> python -> libffi[version='>=3.3,<3.4.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# tqdm==4.46.0=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# python_abi -> python=3.7 -> libffi[version='>=3.3,<3.4.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# cycler -> python -> libffi[version='>=3.3,<3.4.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# libglib -> libffi[version='>=3.3,<3.4.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# python==3.7.7=hcff3b4d_5 -> libffi[version='>=3.3,<3.4.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> cffi -> libffi[version='>=3.3,<3.4.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# gettext -> libffi[version='>=3.3,<3.4.0a0']
# idna==2.9=py_1 -> python -> libffi[version='>=3.3,<3.4.0a0']
# pyparsing -> python -> libffi[version='>=3.3,<3.4.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pycparser==2.20=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# cffi==1.14.0=py37he30daa8_1 -> libffi[version='>=3.3,<3.4.0a0']
#
# Package libblas conflicts for:
# liblapack -> libblas==3.9.0=7_openblas
# libblas
# matplotlib-base -> numpy[version='>=1.15.4,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# numpy -> libblas[version='>=3.8.0,<4.0a0']
# libcblas -> libblas==3.9.0=7_openblas
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# numpy -> libcblas[version='>=3.8.0,<4.0a0'] -> libblas==3.9.0=7_openblas
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
#
# Package readline conflicts for:
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# readline==8.0=h7b6447c_0
# tqdm==4.46.0=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python_abi -> python=3.7 -> readline[version='>=8.0,<9.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python-dateutil -> python -> readline[version='>=8.0,<9.0a0']
# python==3.7.7=hcff3b4d_5 -> readline[version='>=8.0,<9.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cycler -> python -> readline[version='>=8.0,<9.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycparser==2.20=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# idna==2.9=py_1 -> python -> readline[version='>=8.0,<9.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pytz -> python[version='>=3'] -> readline[version='>=8.0,<9.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyparsing -> python -> readline[version='>=8.0,<9.0a0']
# olefile -> python -> readline[version='>=8.0,<9.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
#
# Package freetype conflicts for:
# fontconfig -> freetype[version='>=2.10.4,<3.0a0']
# freetype
# pillow -> freetype[version='>=2.10.4,<3.0a0']
# rdkit -> freetype[version='>=2.10.4,<3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> freetype[version='>=2.10.4,<3.0a0']
# reportlab -> freetype[version='>=2.10.4,<3.0a0']
# cairo -> freetype[version='>=2.10.4,<3.0a0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0']
#
# Package xorg-libice conflicts for:
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libice
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libice
# cairo -> xorg-libsm -> xorg-libice=1.0
# xorg-libsm -> xorg-libice=1.0
# xorg-libice
# cairo -> xorg-libice
#
# Package six conflicts for:
# matplotlib-base -> cycler[version='>=0.10'] -> six
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> six
# python-dateutil -> six
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> six[version='>=1.5.2']
# cryptography==2.9.2=py37h1ba5d50_0 -> six
# pyopenssl==19.1.0=py37_0 -> six[version='>=1.5.2']
# cycler -> six
# pandas -> python-dateutil[version='>=2.7.3'] -> six
# ...
# pillow -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# olefile -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# pytz -> python[version='>=3'] -> openssl[version='>=1.1.1g,<1.1.2a']
# tqdm==4.46.0=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# python-dateutil -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a']
# pycparser==2.20=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# python_abi -> python=3.7 -> openssl[version='>=1.1.1g,<1.1.2a']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> openssl[version='>=1.1.1g,<1.1.2a']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# cycler -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# openssl==1.1.1g=h7b6447c_0
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pyparsing -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
#
# Package boost conflicts for:
# boost
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0']
#
# Package liblapack conflicts for:
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# matplotlib-base -> numpy[version='>=1.15.4,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# numpy -> liblapack[version='>=3.8.0,<4.0a0']
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# liblapack
#
# Package tqdm conflicts for:
# conda-package-handling==1.6.1=py37h7b6447c_0 -> tqdm
# tqdm==4.46.0=py_0
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> tqdm
#
# Package libxml2 conflicts for:
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0']
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0']
# libxml2
#
# Package xorg-renderproto conflicts for:
# xorg-libxrender -> xorg-renderproto
# cairo -> xorg-libxrender -> xorg-renderproto
# xorg-renderproto
#
# Package urllib3 conflicts for:
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
# urllib3==1.25.8=py37_0
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
#
# Package wheel conflicts for:
# wheel==0.34.2=py37_0
# pip==20.0.2=py37_3 -> wheel
#
# Package cffi conflicts for:
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> cffi
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> cffi
# cryptography==2.9.2=py37h1ba5d50_0 -> cffi
# cffi==1.14.0=py37he30daa8_1
#
# Package pycparser conflicts for:
# cryptography==2.9.2=py37h1ba5d50_0 -> cffi -> pycparser
# cffi==1.14.0=py37he30daa8_1 -> pycparser
# pycparser==2.20=py_0
#
# Package cryptography conflicts for:
# cryptography==2.9.2=py37h1ba5d50_0
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> cryptography[version='>=1.3.4']
# urllib3==1.25.8=py37_0 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=2.8']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4']
# conda==4.8.3=py37_0 -> pyopenssl[version='>=16.2.0'] -> cryptography[version='>=2.8']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8']
#
# Package cairo conflicts for:
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0']
# cairo
#
# Package xorg-libsm conflicts for:
# xorg-libsm
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libsm
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libsm
# cairo -> xorg-libsm
#
# Package xorg-libxrender conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxrender
# xorg-libxrender
# cairo -> xorg-libxrender
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxrender
#
# Package libxcb conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> libxcb
# xorg-libxrender -> xorg-libx11=1.6 -> libxcb=1
# xorg-libxext -> xorg-libx11=1.6 -> libxcb=1
# libxcb
# xorg-libx11 -> libxcb=1
# cairo -> libxcb
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libxcb
# cairo -> xorg-libx11 -> libxcb=1
#
# Package xorg-libxext conflicts for:
# xorg-libxext
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxext
# cairo -> xorg-libxext
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxext
#
# Package libgfortran5 conflicts for:
# libgfortran5
# libopenblas -> libgfortran-ng -> libgfortran5=9.3.0
# libopenblas -> libgfortran5[version='>=9.3.0']
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgfortran5[version='>=9.3.0']
# libgfortran-ng -> libgfortran5=9.3.0
#
# Package reportlab conflicts for:
# rdkit -> reportlab
# reportlab
#
# Package libstdcxx-ng conflicts for:
# libglib -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# sqlite==3.31.1=h62c20be_1 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ncurses==6.2=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# lz4-c -> libstdcxx-ng[version='>=9.3.0']
# fontconfig -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# pandas -> libstdcxx-ng[version='>=9.3.0']
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# rdkit -> libstdcxx-ng[version='>=9.3.0']
# gettext -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libffi==3.3=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# libxml2 -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# kiwisolver -> libstdcxx-ng[version='>=7.5.0']
# libstdcxx-ng==9.1.0=hdf63c60_0
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# zstd -> libstdcxx-ng[version='>=9.3.0']
# boost -> libstdcxx-ng[version='>=7.5.0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# python==3.7.7=hcff3b4d_5 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libglib -> libstdcxx-ng[version='>=9.3.0']
# cairo -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0|>=9.3.0']
# pcre -> libstdcxx-ng[version='>=7.3.0']
# cffi==1.14.0=py37he30daa8_1 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# boost-cpp -> libstdcxx-ng[version='>=7.5.0']
# libedit==3.1.20181209=hc058e9b_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libtiff -> libstdcxx-ng[version='>=9.3.0']
# matplotlib-base -> kiwisolver[version='>=1.0.1'] -> libstdcxx-ng[version='>=7.5.0']
# icu -> libstdcxx-ng[version='>=7.5.0']
#
# Package cycler conflicts for:
# rdkit -> matplotlib-base -> cycler[version='>=0.10']
# matplotlib-base -> cycler[version='>=0.10']
# cycler
#
# Package yaml conflicts for:
# yaml==0.1.7=had09818_2
# conda==4.8.3=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16'] -> yaml[version='>=0.1.7,<0.2.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0']
#
# Package chardet conflicts for:
# requests==2.23.0=py37_0 -> chardet[version='>=3.0.2,<4']
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> chardet[version='>=3.0.2,<4']
# chardet==3.0.4=py37_1003
#
# Package zstd conflicts for:
# boost -> boost-cpp=1.74.0 -> zstd[version='>=1.4.5,<1.5.0a0']
# zstd
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.4.5,<1.5.0a0']
# libtiff -> zstd[version='>=1.4.5,<1.5.0a0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.4.5,<1.5.0a0']
#
# Package libglib conflicts for:
# cairo -> libglib[version='>=2.66.4,<3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libglib[version='>=2.66.4,<3.0a0']
# libglib
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> libglib[version='>=2.66.4,<3.0a0']
#
# Package xorg-libx11 conflicts for:
# xorg-libxrender -> xorg-libx11=1.6
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libx11
# cairo -> xorg-libx11
# cairo -> xorg-libxext -> xorg-libx11=1.6
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libx11
# xorg-libx11
# xorg-libxext -> xorg-libx11=1.6
#
# Package bzip2 conflicts for:
# boost -> boost-cpp=1.74.0 -> bzip2[version='>=1.0.8,<2.0a0']
# boost-cpp -> bzip2[version='>=1.0.8,<2.0a0']
# bzip2
#
# Package gettext conflicts for:
# gettext
# libglib -> gettext[version='>=0.19.8.1,<1.0a0']
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> gettext[version='>=0.19.8.1,<1.0a0']
#
# Package lcms2 conflicts for:
# rdkit -> pillow -> lcms2[version='>=2.11,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.11,<3.0a0']
# pillow -> lcms2[version='>=2.11,<3.0a0']
# reportlab -> pillow[version='>=2.4.0'] -> lcms2[version='>=2.11,<3.0a0']
# lcms2
#
# Package xorg-xproto conflicts for:
# xorg-libxrender -> xorg-libx11=1.6 -> xorg-xproto
# xorg-xproto
# xorg-libxext -> xorg-libx11=1.6 -> xorg-xproto
# xorg-libx11 -> xorg-xproto
# cairo -> xorg-libx11 -> xorg-xproto
#
# Package fontconfig conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> fontconfig[version='>=2.13.1,<3.0a0']
# cairo -> fontconfig[version='>=2.13.1,<3.0a0']
# fontconfig
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> fontconfig[version='>=2.13.1,<3.0a0']
#
# Package tornado conflicts for:
# rdkit -> matplotlib-base -> tornado
# matplotlib-base -> tornado
# tornado
#
# Package olefile conflicts for:
# olefile
# rdkit -> pillow -> olefile
# pillow -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
# reportlab -> pillow[version='>=2.4.0'] -> olefile
#
# Package libtiff conflicts for:
# matplotlib-base -> pillow[version='>=6.2.0'] -> libtiff[version='>=4.1.0,<5.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0']
# reportlab -> pillow[version='>=2.4.0'] -> libtiff[version='>=4.1.0,<5.0a0']
# libtiff
# rdkit -> pillow -> libtiff[version='>=4.1.0,<5.0a0']
#
# Package pillow conflicts for:
# reportlab -> pillow[version='>=2.4.0']
# rdkit -> pillow
# matplotlib-base -> pillow[version='>=6.2.0']
# rdkit -> matplotlib-base -> pillow[version='>=2.4.0|>=6.2.0']
# pillow
#
# Package xorg-libxau conflicts for:
# xorg-libxau
# cairo -> libxcb -> xorg-libxau
# xorg-libx11 -> libxcb=1 -> xorg-libxau
# libxcb -> xorg-libxau
#
# Package ca-certificates conflicts for:
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a'] -> ca-certificates
# ca-certificates==2020.1.1=0
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> ca-certificates
# openssl==1.1.1g=h7b6447c_0 -> ca-certificates
#
# Package setuptools conflicts for:
# rdkit -> matplotlib-base -> setuptools
# matplotlib-base -> setuptools
# pip==20.0.2=py37_3 -> setuptools
# conda==4.8.3=py37_0 -> setuptools[version='>=31.0.1']
# setuptools==46.4.0=py37_0
# wheel==0.34.2=py37_0 -> setuptools
#
# Package pycairo conflicts for:
# rdkit -> pycairo
# pycairo
#
# Package requests conflicts for:
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3']
# requests==2.23.0=py37_0
#
# Package pysocks conflicts for:
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks==1.7.1=py37_0
# urllib3==1.25.8=py37_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package numpy conflicts for:
# numpy
# rdkit -> numpy[version='>=1.16.5,<2.0a0']
# pandas -> numpy[version='>=1.16.6,<2.0a0']
# rdkit -> matplotlib-base -> numpy[version='>=1.15.4,<2.0a0|>=1.16.6,<2.0a0']
# matplotlib-base -> numpy[version='>=1.15.4,<2.0a0']
# boost -> numpy[version='>=1.16.5,<2.0a0']
#
# Package kiwisolver conflicts for:
# rdkit -> matplotlib-base -> kiwisolver[version='>=1.0.1']
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# kiwisolver
#
# Package pcre conflicts for:
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> pcre[version='>=8.44,<9.0a0']
# pcre
# libglib -> pcre[version='>=8.44,<9.0a0']
#
# Package libcblas conflicts for:
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# libcblas
# numpy -> libcblas[version='>=3.8.0,<4.0a0']
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# matplotlib-base -> numpy[version='>=1.15.4,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
#
# Package libgfortran-ng conflicts for:
# libopenblas -> libgfortran-ng
# libgfortran-ng
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgfortran-ng
#
# Package lz4-c conflicts for:
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0'] -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# zstd -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# libtiff -> zstd[version='>=1.4.5,<1.5.0a0'] -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# lz4-c
#
# Package pixman conflicts for:
# cairo -> pixman[version='>=0.40.0,<1.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> pixman[version='>=0.40.0,<1.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> pixman[version='>=0.40.0,<1.0a0']
# pixman
#
# Package pycosat conflicts for:
# pycosat==0.6.3=py37h7b6447c_0
# conda==4.8.3=py37_0 -> pycosat[version='>=0.6.3']
#
# Package boost-cpp conflicts for:
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0'] -> boost-cpp=1.74.0
# boost-cpp
# boost -> boost-cpp=1.74.0
#
# Package sqlalchemy conflicts for:
# sqlalchemy
# rdkit -> sqlalchemy
#
# Package xorg-xextproto conflicts for:
# cairo -> xorg-libxext -> xorg-xextproto
# xorg-libxext -> xorg-xextproto
# xorg-xextproto
#
# Package pytz conflicts for:
# pandas -> pytz[version='>=2017.2']
# rdkit -> pandas -> pytz[version='>=2017.2']
# pytz
#
# Package libuuid conflicts for:
# fontconfig -> libuuid[version='>=2.32.1,<3.0a0']
# xorg-libsm -> libuuid[version='>=2.32.1,<3.0a0']
# libuuid
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libuuid[version='>=2.32.1,<3.0a0']
#
# Package pyparsing conflicts for:
# pyparsing
# matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
# rdkit -> matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
#
# Package libedit conflicts for:
# python==3.7.7=hcff3b4d_5 -> sqlite[version='>=3.31.1,<4.0a0'] -> libedit[version='>=3.1.20181209,<3.2.0a0']
# libedit==3.1.20181209=hc058e9b_0
# sqlite==3.31.1=h62c20be_1 -> libedit[version='>=3.1.20181209,<3.2.0a0']
#
# Package ruamel_yaml conflicts for:
# ruamel_yaml==0.15.87=py37h7b6447c_0
# conda==4.8.3=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16']
#
# Package matplotlib-base conflicts for:
# rdkit -> matplotlib-base
# matplotlib-base
#
# Package libgomp conflicts for:
# _openmp_mutex -> libgomp[version='>=7.5.0']
# libgomp
#
# Package pandas conflicts for:
# rdkit -> pandas
# pandasThe following specifications were found to be incompatible with your CUDA driver:
#
#   - feature:/linux-64::__cuda==11.2=0
#   - feature:|@/linux-64::__cuda==11.2=0
#
# Your installed CUDA driver is: 11.2
#
#
#
# real	0m37.065s
# user	0m45.756s
# sys	0m6.028s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# real	0m9.898s
# user	0m9.011s
# sys	0m0.951s
# RDKit: 2020.09.3
# '/device:GPU:0'

# %% [markdown]
# # **Data Fetching**

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/drive')
WEIGHTS_FOLDER = 'sample_data/weights/'
import csv
smifile ='/drive/My Drive/ZINC/Data/ZINC_Data/SMILEWithProp.csv'      #"sample_data/SMILEWithoutProp.csv"
df = pd.read_csv(smifile, delimiter = ",", header='infer', encoding='utf-8')
# smifile ='/drive/My Drive/ZINC/Data/ZINC_Data/AAAA.smi'      
# df = pd.read_csv(smifile, delimiter = " ", header='infer', encoding='utf-8')
df.smiles = df.smiles.replace('\n','', regex=True)
data= pd.DataFrame(df[df['smiles'].str.len()<60])
data=data.reset_index(drop=True)
NUM_SMILES = len(data)
print("\nSmiles having Length less than Sixty is", NUM_SMILES)
data.head()
# Out:
# Mounted at /drive
#
# Smiles having Length less than Sixty is 7732
#                                               smiles  ...       SAS
# 0            CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1  ...  2.084095
# 1       C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print("Training data shape", smiles_train.shape)
print("Testing Data shape", smiles_test.shape)
print("Total Data Points", NUM_SMILES)
# logP_train = smiles_train['logP']
# logP_test = smiles_test['logP']

# qed_train=smiles_train['qed']
# qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([SAS_train])   #logP_train, qed_train, SAS_train
test= np.array([SAS_test])             #logP_test, qed_test, SAS_test
y_train_property=train.transpose()
y_test_property=test.transpose()
#Labels for the Smiles String. We will deal with three properties values.
print("Training Data Property shape", y_train_property.shape)
print("Testing Data Property Shape", y_test_property.shape)
# Out:
# Training data shape (6185, 4)
# Testing Data shape (1547, 4)
# Total Data Points 7732
# Training Data Property shape (6185, 1)
# Testing Data Property Shape (1547, 1)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(int_to_char)
print(len(charset), embed)
# print(embed)
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        # print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
print("Vectorised shape of Training Input", X_train.shape)
print("Vectorised shape of Testing Input",X_test.shape)
# Out:
# {0: 'I', 1: 'o', 2: '#', 3: '5', 4: 'B', 5: 'n', 6: '[', 7: 'P', 8: 'N', 9: 'c', 10: '/', 11: 'O', 12: 'C', 13: '(', 14: '+', 15: 'r', 16: '=', 17: '\\', 18: 'S', 19: 'l', 20: ')', 21: 's', 22: '-', 23: '1', 24: '@', 25: 'H', 26: ']', 27: '2', 28: '3', 29: '4', 30: '!', 31: 'E', 32: 'F'}
# 33 61
# Vectorised shape of Training Input (6185, 61, 33)
# Vectorised shape of Testing Input (1547, 61, 33)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=4532
print("Molecule Index=", idx,"\tLength =",len(smiles_train['smiles'][idx]),"\tSmile=", (smiles_train['smiles'][idx]))
mol = Chem.MolFromSmiles(smiles_train['smiles'][idx])
mol
# Out:
# Molecule Index= 4532 	Length = 49 	Smile= O=C(CCC(F)(F)F)N1CCC[C@H](c2[nH+]ccn2Cc2ccccn2)C1

# %%
# Going back from vectorized form back to a readable string
smi="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
smi = re.sub('[!E]', '', smi)
print(len(smi))
print(smi)
mol = Chem.MolFromSmiles(smi)
mol
# Out:
# 49
# O=C(CCC(F)(F)F)N1CCC[C@H](c2[nH+]ccn2Cc2ccccn2)C1

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print("Input dimension", orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# Input dimension 2013

# %% [markdown]
# # **VAE**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=50# Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(1, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# ### **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input

  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  vae_output = vae_decoder(vae_encoder_output)

  # # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE_with_Predictor')
# VAE Model without Property Predictor
  # vae_with_predictor = Model(vae_input, vae_output, name='VAE_without_Predictor')



  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### **VAE Loss Function**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
  kl_weight=0.5
  reconst_weight=0.5
    
  # vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  vae_loss_val=kl_weight * kl_loss + reconst_weight * reconstruction_loss
  return vae_loss_val

# %% [markdown]
# **Plotting all models**

# %%
# Plot the Encoder Model
plot_model(encoder, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# #Plot the Predictor Model
plot_model(predictor, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/smilesvae_with_SAS_predictor.png', show_shapes=True, show_layer_names=True, expand_nested=True)   #, expand_nested=False

# %% [markdown]
# **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "/drive/My Drive/ZINC/Models/OnlySAS/Weights/train_ckpt/cp.ckpt"
new_check_path="/drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor{epoch:02d}-{val_loss:.2f}.h5"           #'VAE_Predictor{epoch:02d}.h5'
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=new_check_path, verbose=1, save_weights_only=False, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(new_check_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **Training or Loading the VAE Model**

# %%
pre_trained=False
epochs=100
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[0.10, 0.5]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )  
      vae_predictor.save(new_check_path)
    else:
      vae_predictor.load_weights(new_check_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback]) 
      vae_predictor.save(new_check_path)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 6185 samples, validate on 1547 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 8.90317, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor01-8.90.h5
# 6185/6185 - 3s - loss: 12.2651 - decoder_loss: 117.8865 - predictor_loss: 0.9253 - val_loss: 8.9032 - val_decoder_loss: 87.6574 - val_predictor_loss: 0.2552
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 8.90317 to 8.25805, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor02-8.26.h5
# 6185/6185 - 1s - loss: 8.5026 - decoder_loss: 84.0937 - predictor_loss: 0.1844 - val_loss: 8.2581 - val_decoder_loss: 81.7447 - val_predictor_loss: 0.1629
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 8.25805 to 7.89556, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor03-7.90.h5
# 6185/6185 - 1s - loss: 8.0081 - decoder_loss: 79.4839 - predictor_loss: 0.1205 - val_loss: 7.8956 - val_decoder_loss: 78.1134 - val_predictor_loss: 0.1736
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 7.89556 to 7.56477, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor04-7.56.h5
# 6185/6185 - 1s - loss: 7.6105 - decoder_loss: 75.6187 - predictor_loss: 0.0935 - val_loss: 7.5648 - val_decoder_loss: 74.7433 - val_predictor_loss: 0.1795
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 7.56477 to 7.28326, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor05-7.28.h5
# 6185/6185 - 1s - loss: 7.2626 - decoder_loss: 72.2658 - predictor_loss: 0.0791 - val_loss: 7.2833 - val_decoder_loss: 72.0453 - val_predictor_loss: 0.1668
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 7.28326 to 7.09388, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor06-7.09.h5
# 6185/6185 - 1s - loss: 6.9846 - decoder_loss: 69.4531 - predictor_loss: 0.0766 - val_loss: 7.0939 - val_decoder_loss: 70.0666 - val_predictor_loss: 0.1584
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 7.09388 to 6.92727, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor07-6.93.h5
# 6185/6185 - 1s - loss: 6.7523 - decoder_loss: 67.2245 - predictor_loss: 0.0592 - val_loss: 6.9273 - val_decoder_loss: 68.5011 - val_predictor_loss: 0.1548
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 6.92727 to 6.85124, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor08-6.85.h5
# 6185/6185 - 1s - loss: 6.5917 - decoder_loss: 65.6429 - predictor_loss: 0.0557 - val_loss: 6.8512 - val_decoder_loss: 67.2395 - val_predictor_loss: 0.2486
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 6.85124 to 6.77851, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor09-6.78.h5
# 6185/6185 - 1s - loss: 6.4456 - decoder_loss: 64.1973 - predictor_loss: 0.0516 - val_loss: 6.7785 - val_decoder_loss: 66.5598 - val_predictor_loss: 0.2448
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 6.77851 to 6.65114, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor10-6.65.h5
# 6185/6185 - 1s - loss: 6.3138 - decoder_loss: 62.9292 - predictor_loss: 0.0432 - val_loss: 6.6511 - val_decoder_loss: 65.8854 - val_predictor_loss: 0.1418
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 6.65114 to 6.59084, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor11-6.59.h5
# 6185/6185 - 1s - loss: 6.2065 - decoder_loss: 61.8625 - predictor_loss: 0.0484 - val_loss: 6.5908 - val_decoder_loss: 65.0805 - val_predictor_loss: 0.1575
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 6.59084 to 6.51563, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor12-6.52.h5
# 6185/6185 - 1s - loss: 6.1129 - decoder_loss: 60.8365 - predictor_loss: 0.0586 - val_loss: 6.5156 - val_decoder_loss: 64.4003 - val_predictor_loss: 0.1476
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 6.51563 to 6.48781, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor13-6.49.h5
# 6185/6185 - 1s - loss: 6.0203 - decoder_loss: 59.9090 - predictor_loss: 0.0548 - val_loss: 6.4878 - val_decoder_loss: 64.1486 - val_predictor_loss: 0.1442
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 6.48781 to 6.46792, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor14-6.47.h5
# 6185/6185 - 1s - loss: 5.9212 - decoder_loss: 58.9990 - predictor_loss: 0.0411 - val_loss: 6.4679 - val_decoder_loss: 63.8962 - val_predictor_loss: 0.1484
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 6.46792
# 6185/6185 - 1s - loss: 5.8531 - decoder_loss: 58.3354 - predictor_loss: 0.0373 - val_loss: 6.4720 - val_decoder_loss: 63.6466 - val_predictor_loss: 0.2133
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 6.46792 to 6.35956, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor16-6.36.h5
# 6185/6185 - 1s - loss: 5.7713 - decoder_loss: 57.5170 - predictor_loss: 0.0402 - val_loss: 6.3596 - val_decoder_loss: 62.8737 - val_predictor_loss: 0.1483
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 6.35956
# 6185/6185 - 1s - loss: 5.7000 - decoder_loss: 56.8196 - predictor_loss: 0.0366 - val_loss: 6.3654 - val_decoder_loss: 62.6568 - val_predictor_loss: 0.1937
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 6.35956 to 6.35319, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor18-6.35.h5
# 6185/6185 - 1s - loss: 5.6340 - decoder_loss: 56.1058 - predictor_loss: 0.0479 - val_loss: 6.3532 - val_decoder_loss: 62.6921 - val_predictor_loss: 0.1665
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 6.35319 to 6.32550, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor19-6.33.h5
# 6185/6185 - 1s - loss: 5.5661 - decoder_loss: 55.4566 - predictor_loss: 0.0416 - val_loss: 6.3255 - val_decoder_loss: 62.4184 - val_predictor_loss: 0.1673
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 6.32550 to 6.31729, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor20-6.32.h5
# 6185/6185 - 1s - loss: 5.5033 - decoder_loss: 54.8173 - predictor_loss: 0.0410 - val_loss: 6.3173 - val_decoder_loss: 62.3593 - val_predictor_loss: 0.1670
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 6.31729 to 6.29393, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor21-6.29.h5
# 6185/6185 - 1s - loss: 5.4531 - decoder_loss: 54.3206 - predictor_loss: 0.0430 - val_loss: 6.2939 - val_decoder_loss: 62.1752 - val_predictor_loss: 0.1462
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 6.29393
# 6185/6185 - 1s - loss: 5.3832 - decoder_loss: 53.5992 - predictor_loss: 0.0429 - val_loss: 6.2971 - val_decoder_loss: 62.1692 - val_predictor_loss: 0.1728
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 6.29393 to 6.27685, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor23-6.28.h5
# 6185/6185 - 1s - loss: 5.3292 - decoder_loss: 53.1303 - predictor_loss: 0.0317 - val_loss: 6.2768 - val_decoder_loss: 62.1375 - val_predictor_loss: 0.1495
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 6.27685 to 6.24988, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor24-6.25.h5
# 6185/6185 - 1s - loss: 5.2716 - decoder_loss: 52.5581 - predictor_loss: 0.0354 - val_loss: 6.2499 - val_decoder_loss: 61.7934 - val_predictor_loss: 0.1435
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 6.24988
# 6185/6185 - 1s - loss: 5.2263 - decoder_loss: 52.0874 - predictor_loss: 0.0357 - val_loss: 6.2623 - val_decoder_loss: 61.8017 - val_predictor_loss: 0.1550
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 6.24988 to 6.24309, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor26-6.24.h5
# 6185/6185 - 1s - loss: 5.1872 - decoder_loss: 51.6992 - predictor_loss: 0.0318 - val_loss: 6.2431 - val_decoder_loss: 61.7226 - val_predictor_loss: 0.1444
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 6.24309
# 6185/6185 - 1s - loss: 5.1334 - decoder_loss: 51.1884 - predictor_loss: 0.0303 - val_loss: 6.2620 - val_decoder_loss: 61.8902 - val_predictor_loss: 0.1568
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 6.24309 to 6.24262, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor28-6.24.h5
# 6185/6185 - 1s - loss: 5.1135 - decoder_loss: 50.9761 - predictor_loss: 0.0356 - val_loss: 6.2426 - val_decoder_loss: 61.7955 - val_predictor_loss: 0.1470
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 6.24262 to 6.23949, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor29-6.24.h5
# 6185/6185 - 1s - loss: 5.0626 - decoder_loss: 50.4595 - predictor_loss: 0.0359 - val_loss: 6.2395 - val_decoder_loss: 61.4667 - val_predictor_loss: 0.1865
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 6.23949 to 6.23572, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SAS_Predictor30-6.24.h5
# 6185/6185 - 1s - loss: 5.0213 - decoder_loss: 50.0649 - predictor_loss: 0.0275 - val_loss: 6.2357 - val_decoder_loss: 61.6863 - val_predictor_loss: 0.1580
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.9799 - decoder_loss: 49.6514 - predictor_loss: 0.0269 - val_loss: 6.2734 - val_decoder_loss: 61.9838 - val_predictor_loss: 0.1506
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.9552 - decoder_loss: 49.4444 - predictor_loss: 0.0270 - val_loss: 6.2451 - val_decoder_loss: 61.7192 - val_predictor_loss: 0.1445
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.9154 - decoder_loss: 49.0365 - predictor_loss: 0.0249 - val_loss: 6.2820 - val_decoder_loss: 61.8924 - val_predictor_loss: 0.1753
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.8772 - decoder_loss: 48.6341 - predictor_loss: 0.0265 - val_loss: 6.3066 - val_decoder_loss: 61.9510 - val_predictor_loss: 0.2284
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.8571 - decoder_loss: 48.4349 - predictor_loss: 0.0284 - val_loss: 6.2684 - val_decoder_loss: 62.0076 - val_predictor_loss: 0.1623
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.8233 - decoder_loss: 48.0686 - predictor_loss: 0.0307 - val_loss: 6.3005 - val_decoder_loss: 62.2027 - val_predictor_loss: 0.1582
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.7953 - decoder_loss: 47.8398 - predictor_loss: 0.0256 - val_loss: 6.2772 - val_decoder_loss: 61.8759 - val_predictor_loss: 0.1628
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.7732 - decoder_loss: 47.5900 - predictor_loss: 0.0252 - val_loss: 6.3176 - val_decoder_loss: 62.4072 - val_predictor_loss: 0.1536
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.7497 - decoder_loss: 47.3897 - predictor_loss: 0.0232 - val_loss: 6.3309 - val_decoder_loss: 62.3741 - val_predictor_loss: 0.1575
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.7219 - decoder_loss: 47.0928 - predictor_loss: 0.0254 - val_loss: 6.3466 - val_decoder_loss: 62.6382 - val_predictor_loss: 0.1573
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.6968 - decoder_loss: 46.8422 - predictor_loss: 0.0257 - val_loss: 6.3310 - val_decoder_loss: 62.5164 - val_predictor_loss: 0.1502
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.6819 - decoder_loss: 46.6786 - predictor_loss: 0.0260 - val_loss: 6.3426 - val_decoder_loss: 62.6594 - val_predictor_loss: 0.1528
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.6569 - decoder_loss: 46.4773 - predictor_loss: 0.0221 - val_loss: 6.3747 - val_decoder_loss: 62.8882 - val_predictor_loss: 0.1526
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.6221 - decoder_loss: 46.1192 - predictor_loss: 0.0206 - val_loss: 6.4099 - val_decoder_loss: 63.3865 - val_predictor_loss: 0.1526
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.6133 - decoder_loss: 46.0292 - predictor_loss: 0.0242 - val_loss: 6.3855 - val_decoder_loss: 63.0787 - val_predictor_loss: 0.1594
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.5993 - decoder_loss: 45.8637 - predictor_loss: 0.0250 - val_loss: 6.4319 - val_decoder_loss: 63.4754 - val_predictor_loss: 0.1642
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.5741 - decoder_loss: 45.6351 - predictor_loss: 0.0232 - val_loss: 6.4253 - val_decoder_loss: 63.5292 - val_predictor_loss: 0.1597
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.5546 - decoder_loss: 45.4605 - predictor_loss: 0.0197 - val_loss: 6.4531 - val_decoder_loss: 63.5810 - val_predictor_loss: 0.1814
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.5402 - decoder_loss: 45.3056 - predictor_loss: 0.0214 - val_loss: 6.4343 - val_decoder_loss: 63.5247 - val_predictor_loss: 0.1661
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.5140 - decoder_loss: 45.0538 - predictor_loss: 0.0187 - val_loss: 6.4732 - val_decoder_loss: 63.9551 - val_predictor_loss: 0.1529
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4916 - decoder_loss: 44.8319 - predictor_loss: 0.0177 - val_loss: 6.5024 - val_decoder_loss: 64.2696 - val_predictor_loss: 0.1574
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4897 - decoder_loss: 44.8156 - predictor_loss: 0.0172 - val_loss: 6.4894 - val_decoder_loss: 64.0237 - val_predictor_loss: 0.1569
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4736 - decoder_loss: 44.6405 - predictor_loss: 0.0183 - val_loss: 6.5447 - val_decoder_loss: 64.4445 - val_predictor_loss: 0.1785
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4586 - decoder_loss: 44.4980 - predictor_loss: 0.0195 - val_loss: 6.5709 - val_decoder_loss: 64.8772 - val_predictor_loss: 0.1754
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4476 - decoder_loss: 44.3686 - predictor_loss: 0.0203 - val_loss: 6.5540 - val_decoder_loss: 64.5482 - val_predictor_loss: 0.1844
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4345 - decoder_loss: 44.2350 - predictor_loss: 0.0211 - val_loss: 6.5847 - val_decoder_loss: 64.9371 - val_predictor_loss: 0.1724
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4196 - decoder_loss: 44.1069 - predictor_loss: 0.0180 - val_loss: 6.5671 - val_decoder_loss: 64.9853 - val_predictor_loss: 0.1601
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.4080 - decoder_loss: 44.0002 - predictor_loss: 0.0177 - val_loss: 6.5709 - val_decoder_loss: 64.7507 - val_predictor_loss: 0.1619
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3996 - decoder_loss: 43.9194 - predictor_loss: 0.0179 - val_loss: 6.6137 - val_decoder_loss: 65.3707 - val_predictor_loss: 0.1550
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3686 - decoder_loss: 43.6294 - predictor_loss: 0.0173 - val_loss: 6.6537 - val_decoder_loss: 65.7878 - val_predictor_loss: 0.1597
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3598 - decoder_loss: 43.5276 - predictor_loss: 0.0175 - val_loss: 6.6546 - val_decoder_loss: 65.7769 - val_predictor_loss: 0.1554
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3560 - decoder_loss: 43.4699 - predictor_loss: 0.0169 - val_loss: 6.6565 - val_decoder_loss: 65.8305 - val_predictor_loss: 0.1579
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3380 - decoder_loss: 43.2896 - predictor_loss: 0.0193 - val_loss: 6.6945 - val_decoder_loss: 66.0339 - val_predictor_loss: 0.1597
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3289 - decoder_loss: 43.1992 - predictor_loss: 0.0182 - val_loss: 6.6722 - val_decoder_loss: 65.8298 - val_predictor_loss: 0.1550
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3183 - decoder_loss: 43.1212 - predictor_loss: 0.0151 - val_loss: 6.6983 - val_decoder_loss: 66.0903 - val_predictor_loss: 0.1570
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.3114 - decoder_loss: 43.0293 - predictor_loss: 0.0163 - val_loss: 6.7118 - val_decoder_loss: 66.1540 - val_predictor_loss: 0.1704
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2997 - decoder_loss: 42.9064 - predictor_loss: 0.0167 - val_loss: 6.7450 - val_decoder_loss: 66.7228 - val_predictor_loss: 0.1527
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2926 - decoder_loss: 42.8594 - predictor_loss: 0.0172 - val_loss: 6.7751 - val_decoder_loss: 66.9143 - val_predictor_loss: 0.1670
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2798 - decoder_loss: 42.7015 - predictor_loss: 0.0186 - val_loss: 6.7494 - val_decoder_loss: 66.5991 - val_predictor_loss: 0.1590
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2628 - decoder_loss: 42.5432 - predictor_loss: 0.0189 - val_loss: 6.8201 - val_decoder_loss: 67.0544 - val_predictor_loss: 0.2273
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2649 - decoder_loss: 42.5655 - predictor_loss: 0.0170 - val_loss: 6.8203 - val_decoder_loss: 67.2459 - val_predictor_loss: 0.1727
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2569 - decoder_loss: 42.4715 - predictor_loss: 0.0158 - val_loss: 6.8147 - val_decoder_loss: 67.3929 - val_predictor_loss: 0.1565
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2319 - decoder_loss: 42.2540 - predictor_loss: 0.0150 - val_loss: 6.8449 - val_decoder_loss: 67.6032 - val_predictor_loss: 0.1638
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2411 - decoder_loss: 42.3169 - predictor_loss: 0.0165 - val_loss: 6.8637 - val_decoder_loss: 67.9295 - val_predictor_loss: 0.1732
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2100 - decoder_loss: 42.0265 - predictor_loss: 0.0162 - val_loss: 6.8717 - val_decoder_loss: 67.9763 - val_predictor_loss: 0.1626
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2103 - decoder_loss: 42.0383 - predictor_loss: 0.0156 - val_loss: 6.9058 - val_decoder_loss: 68.2420 - val_predictor_loss: 0.1558
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2151 - decoder_loss: 42.0786 - predictor_loss: 0.0144 - val_loss: 6.8947 - val_decoder_loss: 68.1532 - val_predictor_loss: 0.1754
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.2023 - decoder_loss: 41.9357 - predictor_loss: 0.0149 - val_loss: 6.9119 - val_decoder_loss: 68.3569 - val_predictor_loss: 0.1606
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1904 - decoder_loss: 41.8317 - predictor_loss: 0.0148 - val_loss: 6.9077 - val_decoder_loss: 68.2730 - val_predictor_loss: 0.1572
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1822 - decoder_loss: 41.7534 - predictor_loss: 0.0155 - val_loss: 6.9162 - val_decoder_loss: 68.4769 - val_predictor_loss: 0.1606
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1772 - decoder_loss: 41.6911 - predictor_loss: 0.0153 - val_loss: 6.9256 - val_decoder_loss: 68.4735 - val_predictor_loss: 0.1598
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1733 - decoder_loss: 41.6571 - predictor_loss: 0.0161 - val_loss: 6.9892 - val_decoder_loss: 68.8953 - val_predictor_loss: 0.1715
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1630 - decoder_loss: 41.5576 - predictor_loss: 0.0149 - val_loss: 6.9647 - val_decoder_loss: 68.8991 - val_predictor_loss: 0.1602
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1603 - decoder_loss: 41.5401 - predictor_loss: 0.0142 - val_loss: 7.0286 - val_decoder_loss: 69.4402 - val_predictor_loss: 0.1792
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1536 - decoder_loss: 41.4640 - predictor_loss: 0.0155 - val_loss: 7.0067 - val_decoder_loss: 69.3177 - val_predictor_loss: 0.1567
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1457 - decoder_loss: 41.3700 - predictor_loss: 0.0174 - val_loss: 7.0315 - val_decoder_loss: 69.4187 - val_predictor_loss: 0.1905
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1358 - decoder_loss: 41.2936 - predictor_loss: 0.0140 - val_loss: 7.0403 - val_decoder_loss: 69.7042 - val_predictor_loss: 0.1593
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1232 - decoder_loss: 41.1620 - predictor_loss: 0.0136 - val_loss: 7.0734 - val_decoder_loss: 69.8398 - val_predictor_loss: 0.1619
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1292 - decoder_loss: 41.2073 - predictor_loss: 0.0172 - val_loss: 7.0882 - val_decoder_loss: 70.0674 - val_predictor_loss: 0.1741
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1123 - decoder_loss: 41.0447 - predictor_loss: 0.0159 - val_loss: 7.0754 - val_decoder_loss: 69.9313 - val_predictor_loss: 0.1624
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1050 - decoder_loss: 40.9917 - predictor_loss: 0.0136 - val_loss: 7.1263 - val_decoder_loss: 70.3182 - val_predictor_loss: 0.1696
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1080 - decoder_loss: 41.0127 - predictor_loss: 0.0136 - val_loss: 7.1251 - val_decoder_loss: 70.4078 - val_predictor_loss: 0.1657
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1048 - decoder_loss: 41.0060 - predictor_loss: 0.0139 - val_loss: 7.1346 - val_decoder_loss: 70.4036 - val_predictor_loss: 0.1610
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.1005 - decoder_loss: 40.9350 - predictor_loss: 0.0132 - val_loss: 7.1571 - val_decoder_loss: 70.8348 - val_predictor_loss: 0.1630
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0796 - decoder_loss: 40.7271 - predictor_loss: 0.0149 - val_loss: 7.1598 - val_decoder_loss: 70.7843 - val_predictor_loss: 0.1749
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0829 - decoder_loss: 40.7690 - predictor_loss: 0.0138 - val_loss: 7.1955 - val_decoder_loss: 71.0480 - val_predictor_loss: 0.1658
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0822 - decoder_loss: 40.7497 - predictor_loss: 0.0130 - val_loss: 7.2095 - val_decoder_loss: 71.2131 - val_predictor_loss: 0.1826
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0638 - decoder_loss: 40.5684 - predictor_loss: 0.0151 - val_loss: 7.2154 - val_decoder_loss: 71.4353 - val_predictor_loss: 0.1656
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0716 - decoder_loss: 40.6499 - predictor_loss: 0.0136 - val_loss: 7.2092 - val_decoder_loss: 71.2668 - val_predictor_loss: 0.1648
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 6.23572
# 6185/6185 - 1s - loss: 4.0541 - decoder_loss: 40.4861 - predictor_loss: 0.0130 - val_loss: 7.2859 - val_decoder_loss: 71.8654 - val_predictor_loss: 0.1722

# %%
# print(type(history))
# print(type(history.history))
print(history.history.keys())
# Out:
# dict_keys(['loss', 'decoder_loss', 'predictor_loss', 'val_loss', 'val_decoder_loss', 'val_predictor_loss'])

# %%
# summarize history for loss
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,7))
fig.suptitle('Various Losses')


ax1.plot(history.history['loss'])
ax1.plot( history.history['val_loss'])
ax1.set_title('Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(['train', 'Validation'], loc='lower left')


ax2.plot(history.history['decoder_loss'])
ax2.plot(history.history['val_decoder_loss'])
ax2.set_title('Decoder Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Decoder Loss')
ax2.legend(['train', 'Validation'], loc='lower left')

ax3.plot(history.history['predictor_loss']) 
ax3.plot(history.history['val_predictor_loss'])
ax3.set_title('Predictor Loss')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('Predictor Loss')
ax3.legend(['train', 'Validation'], loc='lower left')

# %% [markdown]
# # **Latent Space Visualization**

# %% [markdown]
# ### **Each Component of latent space**

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 30)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %% [markdown]
# ## **Latent Space Values of SAS Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "VAESMILES_SASLatent_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# encoded, decoded and predicted data on test dataset
encoded_xtest=encoder.predict(X_test)
allProp_pred_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print("Encoded data shape",encoded_xtest.shape)
print("Decoded Test data Shape", decoded_xtest.shape)

allProp_orig_xtest= y_test_property

# print("\nPredicted Property Data Shape",allProp_pred_xtest.shape)
# print("Properties of Test Data Shape", allProp_orig_xtest.shape)
print(type(allProp_orig_xtest))
# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)

print("\nOriginal Test Data Dimension",orig_test.shape)
print("Reconstructed Test Data Dimension", reconst_test.shape)

### **Original and Reconstructed test data set**
# Going back from vectorized form back to a readable string on original test data
IPythonConsole.ipython_useSVG=True 
mols_orig_test= []
smi_orig_test=[]
syntax_val={0:[], 1:[]}

for id in range(len(X_test)):
  smi="".join([int_to_char[idx] for idx in np.argmax(orig_test[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_orig_test.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_orig_test.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid SMiles" ,sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)
      # print(mol)
    except:
      print('Mol {} {}'.format(id+1, mol)) 


smi_orig_test_valid=[]
mols_orig_test_valid=[]
for item in syntax_val[1]:
  smi_orig_test_valid.append(smi_orig_test[item])
  mols_orig_test_valid.append(mols_orig_test[item])
# smi_orig_test_valid


print(len(mols_orig_test_valid), "Original Valid Test Samples")
# Draw.MolsToGridImage(mols_orig_test_valid, molsPerRow=4,subImgSize=(200,200))



### **Reconstruction on test data**


RDLogger.DisableLog('rdApp.*') 
# Going back from vectorized form back to a readable string on original test data
#Reconstruction
syntax_val={0:[], 1:[]}
mols_reconst_test= []
smi_reconst_test=[]

 

for id in range(len(X_test)):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_test[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_reconst_test.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_test.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Reconstructed Smile", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol, kekulize=False)
    except:
      # print('Mol {} {}'.format(id+1, mol)) 
      continue


smi_reconst_test_valid=[]
mols_reconst_test_valid=[]
allProp_pred_xtest_valid=[]

smi_orig_test_valid=[]
mols_orig_test_valid=[]
allProp_orig_xtest_valid=[]




print(len(syntax_val[1]), "Reconstructed Valid Test Molecules")
for item in syntax_val[1]:
  smi_reconst_test_valid.append(smi_reconst_test[item])
  smi_orig_test_valid.append(smi_orig_test[item])


  mols_reconst_test_valid.append(mols_reconst_test[item])
  mols_orig_test_valid.append(mols_orig_test[item])

  allProp_pred_xtest_valid.append(allProp_pred_xtest[item])
  allProp_orig_xtest_valid.append(allProp_orig_xtest[item])

  print("\nMolecule", item, "Original Valid Molecule", smi_orig_test[item], "Original Property=", allProp_orig_xtest[item] )
  print("Molecule", item, "Reconstructed Valid molecule", smi_reconst_test[item],"Predicted Property=", allProp_pred_xtest[item] )


Draw.MolsToGridImage(mols_reconst_test_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# Encoded data shape (1547, 50)
# Decoded Test data Shape (1547, 2013)
# <class 'numpy.ndarray'>
#
# Original Test Data Dimension (1547, 61, 33)
# Reconstructed Test Data Dimension (1547, 61, 33)
# 1547 Original Valid Test Samples
# 5 Reconstructed Valid Test Molecules
#
# Molecule 77 Original Valid Molecule Cc1ccc(N2CCN(CC(=O)NCCCO)C2=O)cc1 Original Property= [2.08559512]
# Molecule 77 Reconstructed Valid molecule Cc1ccc(CN=C(NOC(=O)NCCCC)CC=O)o1 Predicted Property= [3.2923524]
#
# Molecule 143 Original Valid Molecule C[C@@H]1CN(C(=O)c2csc(-c3ccsc3)n2)C(C)(C)CO1 Original Property= [3.37956442]
# Molecule 143 Reconstructed Valid molecule C[C@@H]1CN(C(=O)c2ccc(-c3cc(c3)C2)CCCCCC)C1 Predicted Property= [3.2641523]
#
# Molecule 665 Original Valid Molecule CC(=O)NCCNC(=O)N(C)[C@@H](C)C1CC1 Original Property= [2.79848232]
# Molecule 665 Reconstructed Valid molecule CC(=O)NCCCC(=O)N(C)[C@@H](C)CO Predicted Property= [2.4013798]
#
# Molecule 986 Original Valid Molecule COCCNC(=O)NC[C@@H](OC)c1cccc(Cl)c1 Original Property= [2.5871137]
# Molecule 986 Reconstructed Valid molecule C=CCNC(=O)NC[C@@H](C)Sc1cccc(OO)c1F Predicted Property= [2.0696476]
#
# Molecule 1109 Original Valid Molecule COc1ccc(CNC(=O)Cc2csc(C)n2)cc1OC Original Property= [1.8947693]
# Molecule 1109 Reconstructed Valid molecule COc1ccc(CNC(=O)Nc2ccc(C)nc2)cc1 Predicted Property= [2.136889]

# %% [markdown]
# ## **Reconstruction on Training data**

# %%
# encoded, decoded and predicted data on Training dataset

# encoded, decoded and predicted data on Training dataset
encoded_xtrain=encoder.predict(X_train)
allProp_pred_xtrain=predictor.predict(encoded_xtrain)
decoded_xtrain=decoder.predict(encoded_xtrain)
print("Encoded data shape",encoded_xtrain.shape)
print("Decoded Training data Shape", decoded_xtrain.shape)

allProp_orig_xtrain= y_train_property

# print("\nPredicted Property Data Shape",allProp_pred_xtrain.shape)
# print("Properties of Training Data Shape", allProp_orig_xtrain.shape)
print(type(allProp_orig_xtrain))
# Reshaping the original and reconstructed training data
orig_train=X_train.reshape(len(X_train), mol_size_x, mol_size_y)
reconst_train = decoded_xtrain.reshape(len(X_train), mol_size_x,mol_size_y)

print("\nOriginal Training Data Dimension",orig_train.shape)
print("Reconstructed Training Data Dimension", reconst_train.shape)


# Going back from vectorized form back to a readable string on original training data

syntax_val={0:[], 1:[]}

smi_orig_train=[]
mols_orig_train= []

for id in range(len(X_train)):
  smi="".join([int_to_char[idx] for idx in np.argmax(orig_train[id,:,:], axis=1)])
  smi = re.sub('!|E',"", smi)
  smi_orig_train.append(smi)

  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_orig_train.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(mol), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)
    except:
      print('Mol {} {}'.format(id+1, mol)) 

smi_orig_train_valid=[]
mols_orig_train_valid=[]

for item in syntax_val[1]:
  smi_orig_train_valid.append(smi_orig_train[item].rstrip('\n'))
  mols_orig_train_valid.append(mols_orig_train[item])


print(len(mols_orig_train_valid), "Original Valid Training Samples")
# Draw.MolsToGridImage(mols_orig_train_valid, molsPerRow=4,subImgSize=(200,200))

# Going back from vectorized form back to a readable string on Reconstructed training data
#Reconstruction

syntax_val={0:[], 1:[]}

smi_reconst_train=[]
mols_reconst_train= []

for id in range(len(X_train)):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_train[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_reconst_train.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_train.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol, kekulize=True)      
    except:
      # print('Mol {} {}'.format(id+1, mol)) 
      continue

smi_reconst_train_valid=[]
mols_reconst_train_valid=[]
allProp_pred_xtrain_valid=[]

smi_orig_train_valid=[]
mols_orig_train_valid=[]
allProp_orig_xtrain_valid=[]

print(len(syntax_val[1]), "Reconstructed Valid Training Samples")
for item in syntax_val[1]:
  smi_reconst_train_valid.append(smi_reconst_train[item].rstrip('\n'))
  smi_orig_train_valid.append(smi_orig_train[item].rstrip('\n'))

  mols_reconst_train_valid.append(mols_reconst_train[item])
  mols_orig_train_valid.append(mols_orig_train[item])

  allProp_pred_xtrain_valid.append(allProp_pred_xtrain[item])
  allProp_orig_xtrain_valid.append(allProp_orig_xtrain[item])

  print("\nMolecule", item, "Original Valid Molecule", smi_orig_train[item], "Original Property=", allProp_orig_xtrain[item] )
  print("Molecule", item, "Reconstructed Valid molecule", smi_reconst_train[item],"Predicted Property=", allProp_pred_xtrain[item] )

Draw.MolsToGridImage(mols_reconst_train_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# Encoded data shape (6185, 50)
# Decoded Training data Shape (6185, 2013)
# <class 'numpy.ndarray'>
#
# Original Training Data Dimension (6185, 61, 33)
# Reconstructed Training Data Dimension (6185, 61, 33)
# 6185 Original Valid Training Samples
# 249 Reconstructed Valid Training Samples
#
# Molecule 22 Original Valid Molecule Cc1ccc(N2CC[C@@H](NS(=O)(=O)c3ccccc3C)C2=O)cc1C Original Property= [2.5956212]
# Molecule 22 Reconstructed Valid molecule Cc1ccc(N2CC[C@@H](NS(=O)(=O)ccccccc3C)C2=3)cc1C Predicted Property= [1.5346229]
#
# Molecule 90 Original Valid Molecule O=C1NC(=S)NC(=O)C1=CNc1ccc([N+](=O)[O-])cc1O Original Property= [2.70393269]
# Molecule 90 Reconstructed Valid molecule O=C1NC(=C)NC(=O)C1CCNc1ccc([N+](=O)[O-])cc1O Predicted Property= [3.4461627]
#
# Molecule 96 Original Valid Molecule Cc1ccc([C@@H](C)NC(=O)N[C@@H](CCO)c2cccs2)cc1 Original Property= [2.86082152]
# Molecule 96 Reconstructed Valid molecule Cc1ccc([C@@H](C)NC(=O)N[C@@H](CC)Cc2cccs2)cc1 Predicted Property= [3.9961672]
#
# Molecule 109 Original Valid Molecule O=C(NCCCc1nc(-c2ccc(Br)o2)no1)C1CC1 Original Property= [2.36262106]
# Molecule 109 Reconstructed Valid molecule O=C(NCCCc1nc(-c2ccc(Br)o2)no1)C1CC1 Predicted Property= [3.7955635]
#
# Molecule 110 Original Valid Molecule CCOc1cccc(NC(=O)CCc2ccc(N)cc2)c1 Original Property= [1.65855208]
# Molecule 110 Reconstructed Valid molecule CCOc1cccc(NC(=O)NCc2ccc(N)cc2)c1 Predicted Property= [2.7752104]
#
# Molecule 116 Original Valid Molecule O=C(Cn1nnn(-c2cccs2)c1=O)OC1CCCCC1 Original Property= [2.65942975]
# Molecule 116 Reconstructed Valid molecule O=C(Nn1nnn(-c2cccs2)c1=O)OC1CCCCC1 Predicted Property= [1.681875]
#
# Molecule 131 Original Valid Molecule CC[C@@H](CC(=O)NC1(C(=O)OC)CCSCC1)c1ccccc1 Original Property= [3.02742415]
# Molecule 131 Reconstructed Valid molecule CC[C@@H](NC(=O)NC1(C(=O)OC)CNSCC1)c1ccccc1 Predicted Property= [4.068885]
#
# Molecule 203 Original Valid Molecule C[C@H](NC(=O)Cc1ccc[nH]1)C(=O)N1CCCC[C@H]1C Original Property= [3.17083231]
# Molecule 203 Reconstructed Valid molecule C[C@H](NC(=O)Oc1ccc[nH]1)C(=O)N1CCCC[C@H]1C Predicted Property= [4.59476]
#
# Molecule 241 Original Valid Molecule Cc1cc(C)cc(NC(=O)CC(C)C)c1 Original Property= [1.71999966]
# Molecule 241 Reconstructed Valid molecule Cc1cc(C)nc(NC(=O)CC(C)C)c1 Predicted Property= [2.3763313]
#
# Molecule 243 Original Valid Molecule CCn1ccnc(N2CCCC[C@@H](N3CC[NH+](C)CC3)C2)c1=O Original Property= [3.95367152]
# Molecule 243 Reconstructed Valid molecule CCn1ccnc(N2CCCN[C@@H](N3CC[NH+](C)CC3)C2)C1=O Predicted Property= [2.7274308]
#
# Molecule 270 Original Valid Molecule CC(C)OC(=O)CCNC(=O)c1cnn(-c2ccc(F)cc2)n1 Original Property= [2.29166021]
# Molecule 270 Reconstructed Valid molecule CC(C)OC(=O)CCNC(=O)c1cnn(-c2ccc(F)cc2)n1 Predicted Property= [2.7457411]
#
# Molecule 332 Original Valid Molecule Cc1nccn1CC(=O)N1CCCC[C@@H]1CCNC(=O)c1ccccc1 Original Property= [2.63519041]
# Molecule 332 Reconstructed Valid molecule Cc1nccnc1C(=O)N2CCCC[C@@H]2CCNC(=O)c1ccccc1 Predicted Property= [5.12927]
#
# Molecule 370 Original Valid Molecule CCNC(=O)c1cccc(NC(=O)NCCCSC)c1 Original Property= [1.9210886]
# Molecule 370 Reconstructed Valid molecule CCNC(=O)c1cccc(NC(=O)NCCCCC)c1 Predicted Property= [2.6664991]
#
# Molecule 416 Original Valid Molecule CCc1nn(C)cc1CNC(=O)C1(CC)CCC1 Original Property= [2.70713693]
# Molecule 416 Reconstructed Valid molecule CCc1nn(C)cc1CNC(=O)C1(CC)CC1 Predicted Property= [2.0801396]
#
# Molecule 446 Original Valid Molecule CCCCc1nnc(NC(=O)C2CCN(S(=O)(=O)c3ccc(C)cc3)CC2)s1 Original Property= [2.17814055]
# Molecule 446 Reconstructed Valid molecule COCCc1cnc(NC(=O)C2CCN(S(=O)(=O)c3ccc(C)cc3)CC2)s1 Predicted Property= [4.2152023]
#
# Molecule 473 Original Valid Molecule COC[C@@H](C)NC(=O)C(=O)Nc1cc(-c2ccccc2)nn1C(C)C Original Property= [2.80281585]
# Molecule 473 Reconstructed Valid molecule COC[C@@H](C)NC(=O)C(=O)Nc1cc(-c2ccccc2)nn1C(O) Predicted Property= [2.7043266]
#
# Molecule 488 Original Valid Molecule COc1ccc(-c2csc(NC(=O)c3ccc(S(C)(=O)=O)cc3)n2)cc1OC Original Property= [1.9639253]
# Molecule 488 Reconstructed Valid molecule COc1ccc(-c2csc(NC(=O)c3ccc(S(C)(=O)=O)cc3)n2)cc1 Predicted Property= [1.421709]
#
# Molecule 494 Original Valid Molecule CCC(=O)N1CCCC[C@@H]1C(=O)NCCc1ccc(F)cc1C Original Property= [2.50749621]
# Molecule 494 Reconstructed Valid molecule CCC(=O)N1CCCC[C@@H]1C(=O)NCCc1ccc(F)cc1C Predicted Property= [1.5643547]
#
# Molecule 503 Original Valid Molecule CCO[C@@H]1C[C@@H]([NH3+])[C@@H]1Nc1ncc(Cl)cc1F Original Property= [4.35034506]
# Molecule 503 Reconstructed Valid molecule CCO[C@@H]1C[C@@H]([NH3+])[C@@H]1Nc1ncc(Cl)cc1F Predicted Property= [4.838748]
#
# Molecule 505 Original Valid Molecule COCCOC[C@H]1CC[NH+](C2C[C@@H](C)O[C@H](C)C2)C1 Original Property= [5.03277664]
# Molecule 505 Reconstructed Valid molecule COCCOC[C@H]1CC[NH+](C2C[C@@H](C)O[C@H](C)C2)C1 Predicted Property= [6.2952056]
#
# Molecule 514 Original Valid Molecule N#CCC[NH2+]C1(C(=O)[O-])CC1 Original Property= [5.04666771]
# Molecule 514 Reconstructed Valid molecule N=CCC[NH2+]CC(C(=O)[O-])CCC Predicted Property= [9.422672]
#
# Molecule 518 Original Valid Molecule CC(C)Cn1cc[nH+]c1CN[C@@H](c1ccccc1)C(C)C Original Property= [3.69652166]
# Molecule 518 Reconstructed Valid molecule CC(C)Cn1cc[nH+]1CCC[C@@H](c1ccccc1)C(C)C Predicted Property= [4.8206835]
#
# Molecule 527 Original Valid Molecule COC1=CC2=NC(SCc3cc(-c4ccccc4)on3)=NC2=CC1 Original Property= [3.3599301]
# Molecule 527 Reconstructed Valid molecule COC1=CC2=NC(SCc3cc(-c4ccccc4)on3)CCC2=CC1 Predicted Property= [5.0128727]
#
# Molecule 552 Original Valid Molecule CCN(CC(C)(C)O)C(=O)COCc1ccccc1Cl Original Property= [2.33662092]
# Molecule 552 Reconstructed Valid molecule CCN(CC(C)(C)C)C(=O)COCc1ccccc1C Predicted Property= [5.5121474]
#
# Molecule 578 Original Valid Molecule CCCOC(=O)c1ccc(NC(=O)c2ccc[n+]([O-])c2)cc1 Original Property= [2.12864767]
# Molecule 578 Reconstructed Valid molecule CCCOC(=O)c1ccc(NC(=O)c2ccc[n+]([O-])c2)cc1 Predicted Property= [2.5191908]
#
# Molecule 668 Original Valid Molecule Cc1nsnc1Cn1nnc(C(=O)NC(C)C)c1C Original Property= [2.79488977]
# Molecule 668 Reconstructed Valid molecule Cc1nsnc1Cn1ncc(C(NO)NCCCOC)c1 Predicted Property= [1.4753318]
#
# Molecule 675 Original Valid Molecule COc1ccc([C@@H](CNC(=O)c2ccc([N+](=O)[O-])o2)[NH+](C)C)cc1 Original Property= [3.51828762]
# Molecule 675 Reconstructed Valid molecule COc1ccc([C@@H](CNC(=O)c2ccc([N+](=O)[O-])o2)[NH+](C)C)C1 Predicted Property= [2.702411]
#
# Molecule 769 Original Valid Molecule O[C@H](CSc1nnc(-c2c[nH]c3ccccc23)n1C1CC1)CN1CCOCC1 Original Property= [3.03750611]
# Molecule 769 Reconstructed Valid molecule O[C@H](CSc1nnc(-c2c[nH]c3ccccc23)n1C1CC1)CN1CCOcc1 Predicted Property= [3.5306823]
#
# Molecule 786 Original Valid Molecule CS(=O)(=O)c1ccc(C(=O)Nc2ccc(F)c(F)c2F)cc1 Original Property= [1.86030849]
# Molecule 786 Reconstructed Valid molecule CS(=O)(=O)c1ccc(C(=O)Nc2ccc(F)c(F)c2F)cc1 Predicted Property= [1.682286]
#
# Molecule 823 Original Valid Molecule CC(C)(C)[S@](=O)CCNC(=O)c1cccc(F)c1Cl Original Property= [3.00003694]
# Molecule 823 Reconstructed Valid molecule CC(C)(C)[S@](=O)CCCC(=O)c1cccc(F)c1C Predicted Property= [3.2172127]
#
# Molecule 847 Original Valid Molecule O=C(C/C(=N\Nc1nc(-c2ccccc2)cs1)c1ccccc1)C(F)(F)F Original Property= [2.41511437]
# Molecule 847 Reconstructed Valid molecule O=C(C/C(=N\Nc1nc(-c2ccccc2)cs1)c1ccccc1)C(F)(F)F Predicted Property= [1.8729846]
#
# Molecule 929 Original Valid Molecule NC(=O)COc1cccc(CNC(=O)c2cc3cc(Cl)ccc3[nH]2)c1 Original Property= [2.08430064]
# Molecule 929 Reconstructed Valid molecule NC(=O)CCc1cccc(CNC(=O)c2cc3cc(Cl)ccc3[nH]2)c1 Predicted Property= [3.0929735]
#
# Molecule 953 Original Valid Molecule O=C(CSc1nnc(-c2ccco2)n1-c1ccccc1)c1ccc[nH]1 Original Property= [2.37251007]
# Molecule 953 Reconstructed Valid molecule O=C(CSc1nnc(-c2ccco2)n1-c1ccccc1)c1ccc[nH]1 Predicted Property= [1.7039974]
#
# Molecule 997 Original Valid Molecule C[C@H](SCC[NH3+])c1ccc(C(=O)[O-])o1 Original Property= [4.72266584]
# Molecule 997 Reconstructed Valid molecule C[C@H](SCC[NH3+])c1ccc(C(=O)[O-])o1 Predicted Property= [5.4724727]
#
# Molecule 1001 Original Valid Molecule O=C([O-])CCNC(=O)N[C@@H]1CCOC1 Original Property= [3.34827951]
# Molecule 1001 Reconstructed Valid molecule O=C([O-])CCNC(=O)N[C@@H]1CCOC1OC Predicted Property= [2.1890156]
#
# Molecule 1026 Original Valid Molecule C[C@@H](c1ccccc1)N(C)C(=O)Nc1cccc(C[NH+](C)C)c1 Original Property= [3.22346784]
# Molecule 1026 Reconstructed Valid molecule C[C@@H](c1ccccc1)N(C)C(=O)Nc1cccc(C[NH+](C)C)c1 Predicted Property= [1.3411384]
#
# Molecule 1045 Original Valid Molecule CC(C)NS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)cc2)cc1 Original Property= [1.67107164]
# Molecule 1045 Reconstructed Valid molecule CC(C)NS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)cc2)cc1C Predicted Property= [3.4258766]
#
# Molecule 1051 Original Valid Molecule COc1cccc(N[C@@H]2CCS(=O)(=O)C2)c1 Original Property= [2.47100539]
# Molecule 1051 Reconstructed Valid molecule COc1cccc(C[C@@H]2NCS(=O)(=O)c2)c1 Predicted Property= [2.1450028]
#
# Molecule 1060 Original Valid Molecule Cc1ccc(F)c(Br)n1 Original Property= [2.44105108]
# Molecule 1060 Reconstructed Valid molecule Cc1ccc(F)c(Br)c1 Predicted Property= [1.6713333]
#
# Molecule 1061 Original Valid Molecule Cc1ccc([N+](=O)[O-])cc1C(=O)Nc1cnc(-c2ccccc2)s1 Original Property= [2.19853258]
# Molecule 1061 Reconstructed Valid molecule Cc1ccc([N+](=O)[C-])cc1C(=O)Nc1ccc(-c2ccccc2)s1 Predicted Property= [1.1985431]
#
# Molecule 1118 Original Valid Molecule Cc1cnn(CCCNC(=O)N2CCCC[C@H](N3CC[NH+](C)CC3)C2)c1 Original Property= [3.84409994]
# Molecule 1118 Reconstructed Valid molecule Cc1cnn(CCCNC(=O)N2CCCC[C@H](N3CC[NH+](C)CC3)C2)c1 Predicted Property= [3.7760649]
#
# Molecule 1132 Original Valid Molecule Cc1ccc2nc(NC(=O)c3ccc(N4CCCC4)c([N+](=O)[O-])c3)sc2c1 Original Property= [2.11431657]
# Molecule 1132 Reconstructed Valid molecule Cc1ccc2nc(NC(=O)c3ccc(N4CCCC4)c([N+](=O)[O-])c3)sc2c1 Predicted Property= [2.0952559]
#
# Molecule 1207 Original Valid Molecule Clc1ccc(C2([NH2+]C3CCCC3)CCOCC2)cc1 Original Property= [3.45280004]
# Molecule 1207 Reconstructed Valid molecule Clc1ccc(C2C[CH2+]cCCCCC(CCC)CC2)cc1 Predicted Property= [1.6764076]
#
# Molecule 1214 Original Valid Molecule O=C(Cc1cc(F)ccc1F)N1CCO[C@@H](c2ccc(Cl)cc2)C1 Original Property= [2.5746947]
# Molecule 1214 Reconstructed Valid molecule O=C(Cc1cc(F)ccc1F)N1CCC[C@@H](c2ccc(Cl)cc2)c1 Predicted Property= [5.2778764]
#
# Molecule 1221 Original Valid Molecule Cc1ccccc1Cc1noc(CSc2ncnc3nc[nH]c23)n1 Original Property= [2.64954245]
# Molecule 1221 Reconstructed Valid molecule Cc1ccccc1Cc1noc(CSc2nccc3cc[nH]c23)c1 Predicted Property= [4.2738333]
#
# Molecule 1243 Original Valid Molecule O=C(Nc1ccccc1)N1CCCC[C@@H]1[C@H]1CCC[C@@H]1O Original Property= [2.98103867]
# Molecule 1243 Reconstructed Valid molecule O=C(Nc1ccccc1)N1CCCC[C@@H]1[C@H]1CCC[C@@H]1O Predicted Property= [4.768511]
#
# Molecule 1339 Original Valid Molecule Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)/N=C(\[O-])[C@H](C)OCC(C)C Original Property= [3.45493515]
# Molecule 1339 Reconstructed Valid molecule Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)/N=C(\[O-])[C@H](C)OCC(C)C Predicted Property= [3.5870075]
#
# Molecule 1417 Original Valid Molecule C/C(=C(\C#N)C(=O)NN)c1ccc(F)cc1 Original Property= [2.53748908]
# Molecule 1417 Reconstructed Valid molecule C/C(=C(\C#N)C(=O)NC)c1ccc(F)cc1 Predicted Property= [2.9298532]
#
# Molecule 1434 Original Valid Molecule CCc1ccc(N)cc1S(=O)(=O)N(C)CC(=O)NC Original Property= [2.28294464]
# Molecule 1434 Reconstructed Valid molecule CCc1ccc(N)cc1S(=O)(=O)N(C)NC(=O)N Predicted Property= [1.7318892]
#
# Molecule 1518 Original Valid Molecule CCOc1ccc(F)c(C(=O)NCc2ccnc(OC(C)(C)C)c2)c1F Original Property= [2.41500262]
# Molecule 1518 Reconstructed Valid molecule CCOc1ccc(F)c(C(=O)NCc2ccnc(OC(C)(C)C)c2)c1 Predicted Property= [4.7499504]
#
# Molecule 1533 Original Valid Molecule CCn1nnnc1NCc1c(Cl)cccc1Cl Original Property= [2.33238485]
# Molecule 1533 Reconstructed Valid molecule CCn1nnnc1NCc1c(Cl)cccc1Cl Predicted Property= [1.8718604]
#
# Molecule 1539 Original Valid Molecule CC[NH+](CC)C[C@H]1CC[NH2+]C1 Original Property= [6.46115701]
# Molecule 1539 Reconstructed Valid molecule CC[C@H](CC)C[C@H]1CC[NH2+]C1 Predicted Property= [6.3918004]
#
# Molecule 1686 Original Valid Molecule Clc1cccc(-c2ccc(C[NH2+]Cc3ccc4c(c3)OCO4)o2)c1 Original Property= [2.97031298]
# Molecule 1686 Reconstructed Valid molecule Clc1cccc(-c2ccc(C[NH2+]Cc3ccc4c(c3)CCO4)o2)c1 Predicted Property= [1.3181434]
#
# Molecule 1744 Original Valid Molecule COc1ccc([C@H](NS(=O)(=O)c2cccc(C(C)=O)c2)c2ccccc2)cc1 Original Property= [2.34403097]
# Molecule 1744 Reconstructed Valid molecule COc1ccc([C@H](NS(=O)(=O)c2cccc(C(C)=O)c2)c2ccccc2)cc1 Predicted Property= [2.3721669]
#
# Molecule 1747 Original Valid Molecule CCn1nccc1[C@H](F)C(=O)[O-] Original Property= [3.83411531]
# Molecule 1747 Reconstructed Valid molecule CCC1cccc1[C@H](F)C(=O)[O-] Predicted Property= [1.9613601]
#
# Molecule 1772 Original Valid Molecule Cc1nc(-c2ccccc2F)sc1CNC(=O)NC(C)(C)C Original Property= [2.29641951]
# Molecule 1772 Reconstructed Valid molecule Cc1cc(-c2ccccc2F)(C1CNC(=O)N1-C)(C)C1 Predicted Property= [3.6347756]
#
# Molecule 1804 Original Valid Molecule O=C(CSc1cccc(C(F)(F)F)c1)N1CCN(S(=O)(=O)c2cccs2)CC1 Original Property= [2.31984778]
# Molecule 1804 Reconstructed Valid molecule O=C(CSc1cccc(C(F)(F)F)c1)N1CCN(S(=O)(=O)c2cccs2)Cc1 Predicted Property= [4.4913883]
#
# Molecule 1811 Original Valid Molecule CNC(=O)c1cccc(CNC(=O)Nc2c[nH]nc2-c2ccccn2)c1 Original Property= [2.5014061]
# Molecule 1811 Reconstructed Valid molecule COC(=O)c1cccc(CNC(=O)Nc2ccnnnnc2-c2ccccc2)c1 Predicted Property= [4.1373034]
#
# Molecule 1905 Original Valid Molecule COc1ccc(N2CCN(C(=O)COC(=O)c3ccc(C)c(C)c3)CC2)cc1 Original Property= [1.86619898]
# Molecule 1905 Reconstructed Valid molecule COc1ccc(N2CCN(C(=O)NNC(=O)c3ccc(C)c(C)c3)Cc2)cc1 Predicted Property= [2.3487043]
#
# Molecule 1928 Original Valid Molecule C[C@H](SC(C)(C)C)C(=O)N1CCN(c2ccc(F)cc2)CC1 Original Property= [2.66879566]
# Molecule 1928 Reconstructed Valid molecule C[C@H]1SC(C)(C)COC(=O)NCCCN(c2ccc(F)cc2)CC1 Predicted Property= [3.1845338]
#
# Molecule 1931 Original Valid Molecule CC(C)C[C@@H]1C(=N)NC(=O)N1CC1CC1 Original Property= [3.66405157]
# Molecule 1931 Reconstructed Valid molecule CC(C)C[C@@H](CCCCCCC(=O)N1CC)CC1 Predicted Property= [2.5564194]
#
# Molecule 1935 Original Valid Molecule Cc1ccccc1CS(=O)(=O)Nc1ccc(F)c(F)c1 Original Property= [1.90944978]
# Molecule 1935 Reconstructed Valid molecule Cc1ccccc1NS(=O)(=O)Cc1ccc(F)c(F)c1 Predicted Property= [2.8493972]
#
# Molecule 1949 Original Valid Molecule CCN(CC)S(=O)(=O)c1ccc(F)c(C(=O)Nc2ccc(C(C)=O)cc2)c1 Original Property= [1.96935209]
# Molecule 1949 Reconstructed Valid molecule CCN(CC)S(=O)(=O)c1ccc(F)c(C(=O)Nc2ccc(C(C)=O)cc2)c1 Predicted Property= [3.8093777]
#
# Molecule 1979 Original Valid Molecule CC[C@]1(c2ccc(F)cc2)NC(=O)N(CC(=O)NCCc2ccc(Cl)cc2)C1=O Original Property= [2.62748252]
# Molecule 1979 Reconstructed Valid molecule CC[C@]1(c2ccc(F)cc2)NC(=O)N(CC(=O)NCCc2ccc(Cl)cc2)C1=O Predicted Property= [1.6914665]
#
# Molecule 1981 Original Valid Molecule COC(=O)CCC(=O)Nc1ccc(N)cc1 Original Property= [1.65009113]
# Molecule 1981 Reconstructed Valid molecule CCC(=O)CNC(=O)Nc1ccc(N)cc1 Predicted Property= [4.853591]
#
# Molecule 2021 Original Valid Molecule Cc1cn2c(=O)c(C(=O)Nc3cnn(-c4ccccc4)c3)cnc2s1 Original Property= [2.46822239]
# Molecule 2021 Reconstructed Valid molecule Cc1cn2c(=O)c(C(=O)Nc3cnn(-c4ccccc4)c3)ccc2s1 Predicted Property= [2.0411568]
#
# Molecule 2023 Original Valid Molecule Brc1cn2ccnc2c(N[C@H]2CCCOC2)n1 Original Property= [3.34041981]
# Molecule 2023 Reconstructed Valid molecule Brc1cn2ccnc2c(N[C@H]2CCCSC2)n1 Predicted Property= [1.8456076]
#
# Molecule 2044 Original Valid Molecule CNS(=O)(=O)c1cccc([C@@H](C)[NH2+]C[C@H](C)SC)c1 Original Property= [4.11203584]
# Molecule 2044 Reconstructed Valid molecule CNS(=O)(=O)c1cccc([C@@H](C)[NH2+]C[C@H](C)SC)c1 Predicted Property= [8.284019]
#
# Molecule 2064 Original Valid Molecule CN(Cc1ccccc1N1CCOCC1)c1ccc(Cl)cn1 Original Property= [2.1757849]
# Molecule 2064 Reconstructed Valid molecule CN(Cc1ccccc(N1)CCCCC)c1ccc(Cl)cn1 Predicted Property= [1.733563]
#
# Molecule 2093 Original Valid Molecule COc1ccc(OC)c(CNC(=O)c2sccc2C)c1 Original Property= [1.90563283]
# Molecule 2093 Reconstructed Valid molecule COc1ccc(OC)c(CNC(=O)c2sccc2C)c1 Predicted Property= [1.9799504]
#
# Molecule 2098 Original Valid Molecule COc1ccc(CCNC(=O)c2ccncc2)cc1 Original Property= [1.5885351]
# Molecule 2098 Reconstructed Valid molecule COc1ccc(CCNC(=O)c2ccccc2)cc1 Predicted Property= [1.4803349]
#
# Molecule 2104 Original Valid Molecule Cc1cc(NC(=O)CCS(=O)(=O)[C@H](C)c2ccccc2)no1 Original Property= [2.77750083]
# Molecule 2104 Reconstructed Valid molecule Cc1cc(NC(=O)CCS(=O)(=O)[C@H](C)c2ccccc2)no1 Predicted Property= [4.5136814]
#
# Molecule 2111 Original Valid Molecule C[C@@H]1CCCN(C(=O)C2CC[NH+](Cc3ccoc3)CC2)C1 Original Property= [4.11923042]
# Molecule 2111 Reconstructed Valid molecule C[C@@H]1CCCN(C(=O)C2CC[NH+](Cc3ccoc3)CC2)C1 Predicted Property= [3.220402]
#
# Molecule 2123 Original Valid Molecule Cc1noc(C)c1[C@@H](C)NC(=O)Nc1ccc(NC(=O)[C@H]2CCCO2)cc1 Original Property= [3.08604972]
# Molecule 2123 Reconstructed Valid molecule Cc1noc(C)c1[C@@H](C)NC(=O)Nc1ccc(NC(=O)[C@H]2CCCO2)cc1 Predicted Property= [2.445889]
#
# Molecule 2145 Original Valid Molecule CCC[C@H](C#N)[C@@H](O)c1ccc(C(F)(F)F)cc1 Original Property= [3.20405543]
# Molecule 2145 Reconstructed Valid molecule CCC[C@H](C#N)[C@@H](C)c1ccc(C(F)(F)F)cc1 Predicted Property= [4.475945]
#
# Molecule 2211 Original Valid Molecule CCOC(=O)[C@H]1CCCN(C(=O)c2ccco2)C1 Original Property= [2.41965696]
# Molecule 2211 Reconstructed Valid molecule CCOC(=O)[C@H]1CCCN(C(=O)c2ccco2)C1 Predicted Property= [5.1047144]
#
# Molecule 2271 Original Valid Molecule C[C@H](Sc1nnc(-c2ccccc2)o1)C(=O)NC12CC3CC(CC(C3)C1)C2 Original Property= [3.98928078]
# Molecule 2271 Reconstructed Valid molecule C[C@@](Sc1cnc(-c2ccccc2)o1)C(=O)NC1C2C3CC(CC(C3)C1)C2 Predicted Property= [3.808438]
#
# Molecule 2305 Original Valid Molecule COc1ccc(OC)c([C@H](c2nnnn2C2CCCC2)N2CCc3ccccc3C2)c1 Original Property= [2.89805749]
# Molecule 2305 Reconstructed Valid molecule COc1ccc(OC)c([C@H](c2nnnn2C)CCCCO)N2CCc3ccccc3C2Cc1 Predicted Property= [1.6345248]
#
# Molecule 2337 Original Valid Molecule Cc1cc(F)cc(S(=O)(=O)N(C)CC[NH+](C)C)c1 Original Property= [3.38029791]
# Molecule 2337 Reconstructed Valid molecule Cc1cc(F)cc(S(=O)(=O)N(C)CC[NH+](C)C)c1 Predicted Property= [6.1020317]
#
# Molecule 2377 Original Valid Molecule CC(C)(C)OC(=O)N1CCc2cccc(C[NH+]3CC[C@H]([N+]4=CCCC4)C3)c21 Original Property= [4.87647207]
# Molecule 2377 Reconstructed Valid molecule CC(C)(C)OC(=O)N1CCc2cccc(C[NH+]3CC[C@H]([N+]4=CCCC4)C3)c21 Predicted Property= [6.9283633]
#
# Molecule 2398 Original Valid Molecule C=CCN(CC=C)C[C@@H]1CCC(C)(C)[C@H]1[NH2+]C Original Property= [4.75563079]
# Molecule 2398 Reconstructed Valid molecule CCCCN(CC=C)C[C@@H]1CCC(C)(C)[C@H]1[CH2+] Predicted Property= [4.2921004]
#
# Molecule 2401 Original Valid Molecule O=C([O-])COCCNC(=O)[C@@H]1CCCCO1 Original Property= [3.23692232]
# Molecule 2401 Reconstructed Valid molecule O=C([C-])CCCCNC(=O)[C@@H]1CCOCO1 Predicted Property= [1.419251]
#
# Molecule 2415 Original Valid Molecule Cc1ccc(NC(=O)Cc2ccc(NC3=N[C@H]4CS(=O)(=O)C[C@H]4S3)cc2)cc1 Original Property= [3.15508813]
# Molecule 2415 Reconstructed Valid molecule Cc1ccc(NC(=O)Cc2ccc(NC3=N[C@H]4CS(=O)(=O)C[C@H]4S3)cc2)cc1 Predicted Property= [3.0729423]
#
# Molecule 2438 Original Valid Molecule COc1cccc(CN(C)C(=O)C(=O)Nc2cccc3cccnc23)c1 Original Property= [2.12101119]
# Molecule 2438 Reconstructed Valid molecule COc1cccc(CN(C)C(=O)C(=O)Nc2cccc3ccccc23)c1 Predicted Property= [1.9613991]
#
# Molecule 2441 Original Valid Molecule CCc1cccc2c(/C=N/n3c(C)nnc3C)c[nH]c12 Original Property= [2.76367126]
# Molecule 2441 Reconstructed Valid molecule COc1cccc2c(CCCC/n3c(C)ncc3C)c[nH]c12 Predicted Property= [3.9601836]
#
# Molecule 2452 Original Valid Molecule Cc1nn(C)c(CO[C@@H]2CCC[C@@H]([NH3+])C2)c1Cl Original Property= [4.06780632]
# Molecule 2452 Reconstructed Valid molecule Cc1nn(C)c(COC[C@H]2CCC[C@@H]([NH3+])C2)c1Cl Predicted Property= [4.0796785]
#
# Molecule 2455 Original Valid Molecule CCn1cnnc1CNC(=O)NC[C@H](O)c1ccccc1OC Original Property= [2.80683148]
# Molecule 2455 Reconstructed Valid molecule CCn1cnnc1CNC(=O)NC[C@H](O)c1ccccc1OC Predicted Property= [2.5136974]
#
# Molecule 2462 Original Valid Molecule COC(=O)NCCCC(=O)N1CCC(c2ccc(C(F)(F)F)cc2)CC1 Original Property= [2.16421026]
# Molecule 2462 Reconstructed Valid molecule COC(=O)NCCCC(=O)N1CCC(c2ccc(C(F)(F)F)cc2)cc1 Predicted Property= [2.6481738]
#
# Molecule 2494 Original Valid Molecule Cc1cc([N+](=O)[O-])cnc1Oc1ccccc1[N+](=O)[O-] Original Property= [2.24728335]
# Molecule 2494 Reconstructed Valid molecule Cc1cc([N+](=O)[O-])cnc1Oc1ccccc1[N+](=O)[O-] Predicted Property= [3.19977]
#
# Molecule 2502 Original Valid Molecule C#Cc1cccc(N(Cc2cccs2)S(=O)(=O)c2cn[nH]c2)c1 Original Property= [2.74244816]
# Molecule 2502 Reconstructed Valid molecule C#Cc1cccc(C(Cc2cccs2)S(=O)(=O)c2cn[nH]c2)n1 Predicted Property= [5.015279]
#
# Molecule 2507 Original Valid Molecule CC(C)CN1CCO[C@@H](CNC(=O)[C@]23CC[C@H](C[C@@H]2Br)C3)C1 Original Property= [4.76956833]
# Molecule 2507 Reconstructed Valid molecule CC(C)CN1CCO[C@@H](CNC(=O)[C@]23CC[C@H](C[C@@H]2Br)C3)C1 Predicted Property= [5.146602]
#
# Molecule 2568 Original Valid Molecule NC(=O)N1CCC[C@H](C(=O)N2CCC(C(=O)[O-])CC2)C1 Original Property= [3.04646698]
# Molecule 2568 Reconstructed Valid molecule NC(=O)N1CCC[C@H](C(=O)N2CCC(C(=O)[O-])C2)CC1 Predicted Property= [2.0595255]
#
# Molecule 2575 Original Valid Molecule Cn1cnc(C[NH2+]Cc2ccc(C(C)(C)C)cc2)n1 Original Property= [3.42430206]
# Molecule 2575 Reconstructed Valid molecule CC1cnc(C[NH2+]Cc2ccc(C(C)(F)C)cc2)n1 Predicted Property= [2.7625499]
#
# Molecule 2580 Original Valid Molecule C[C@@H](C[NH2+]Cc1cc[nH]c1)c1ccc(F)c(F)c1 Original Property= [3.96876737]
# Molecule 2580 Reconstructed Valid molecule C[C@@H](C[CH2+]Cc1cn[nH]c1)c1ccc(F)c(F)c1 Predicted Property= [6.24859]
#
# Molecule 2663 Original Valid Molecule COc1ccc(CNC(=O)NC[C@H](C)c2ccsc2)cc1NC(C)=O Original Property= [2.6898398]
# Molecule 2663 Reconstructed Valid molecule COc1ccc(CNC(=O)NC[C@H](C)c2ccsc2)cc1NC(C)=O Predicted Property= [2.589406]
#
# Molecule 2680 Original Valid Molecule Cc1ccc(CN2CCN(C(=O)c3cc(NC(=O)C(C)C)n(-c4ccccc4)n3)CC2)cc1 Original Property= [2.20018818]
# Molecule 2680 Reconstructed Valid molecule Cc1ccc(CN2CCN(C(=O)c3cc(CC(=O)C(C)C)n(-c4ccccc4)n3)CC2)cc1 Predicted Property= [2.0734732]
#
# Molecule 2702 Original Valid Molecule Cc1cccc(OC[C@H](C)NC(=O)C(=O)Nc2cccc(C#N)c2)c1 Original Property= [2.53403101]
# Molecule 2702 Reconstructed Valid molecule Cc1cccc(CC[C@H](C)CC(=O)C(=O)Nc2cccc(C#N)c2)c1 Predicted Property= [3.025351]
#
# Molecule 2721 Original Valid Molecule Cc1ccc(Cl)cc1NS(=O)(=O)c1ccc(Br)cc1 Original Property= [1.69410723]
# Molecule 2721 Reconstructed Valid molecule Cc1ccc(Cl)cc1NS(=O)(=O)c1ccc(Br)cc1 Predicted Property= [1.4613982]
#
# Molecule 2726 Original Valid Molecule C[C@H]1CN(CC(=O)Nc2ccc(OC(F)F)cc2)C[C@H](C)O1 Original Property= [2.76396035]
# Molecule 2726 Reconstructed Valid molecule C[C@H]1CN(CC(=O)Nc2ccc(OC(F)F)cc2)C[C@H](C)C1 Predicted Property= [4.771185]
#
# Molecule 2729 Original Valid Molecule COc1ccc(NC(=O)[C@H]2C[C@H]3CC[C@@H]2O3)cn1 Original Property= [4.09290958]
# Molecule 2729 Reconstructed Valid molecule COc1ccc(NC(=O)[C@H]2C[C@H]3CC[C@@H]2O3)cc1 Predicted Property= [5.735038]
#
# Molecule 2747 Original Valid Molecule Cc1nn(C)c2ncc(NC(=O)NC[C@H](c3ccccc3)[NH+](C)C)cc12 Original Property= [3.5008746]
# Molecule 2747 Reconstructed Valid molecule Cc1nn(C)c2ncc(CC(=O)NC[C@H](c3ccccc3)[NH+](C)C)cc12 Predicted Property= [3.838622]
#
# Molecule 2760 Original Valid Molecule CC[C@@H](C)c1noc([C@@H]2CCCN(C(=O)C3CCCC3)C2)n1 Original Property= [3.13529564]
# Molecule 2760 Reconstructed Valid molecule CC[C@@H](C)c1noc([C@@H]2CCCN(C(=O)C3CCCC3)c2)n1 Predicted Property= [4.12003]
#
# Molecule 2775 Original Valid Molecule C[C@H]1CC[C@H]([NH3+])[C@H](N2CC[NH+]3CCC[C@@H]3C2)C1 Original Property= [6.09192624]
# Molecule 2775 Reconstructed Valid molecule C[C@H]1CC[C@H]([NH3+])[C@H](C2CC[NH+]3CCC[C@@H]3C2)C1 Predicted Property= [8.212818]
#
# Molecule 2817 Original Valid Molecule COc1cc(Br)c(C[NH2+]C[C@H](C)O)cc1OC Original Property= [3.72110644]
# Molecule 2817 Reconstructed Valid molecule COc1cc(Br)c(C[NH2+]C[C@H](C)O)cc1OC Predicted Property= [2.087528]
#
# Molecule 2818 Original Valid Molecule C[C@H](CNC(=O)c1cccc(C(F)(F)F)c1F)c1ccncc1 Original Property= [2.69499889]
# Molecule 2818 Reconstructed Valid molecule C[C@H](CNC(=O)c1cccc(C(F)(F)F)c1F)c1ccncc1 Predicted Property= [3.514249]
#
# Molecule 2819 Original Valid Molecule C[C@H]([NH2+][C@@H]1CC(=O)N(C(C)(C)C)C1)c1ccc(Br)s1 Original Property= [4.49115439]
# Molecule 2819 Reconstructed Valid molecule C[C@H]([NH2+][C@@H]1CC(=O)N(C(N)(C)C)N1)c1ccc(Br)s1 Predicted Property= [6.1051455]
#
# Molecule 2821 Original Valid Molecule COc1ccc(S(=O)(=O)N[C@H]2CCC[C@@H](C)C2)cc1N Original Property= [2.82659809]
# Molecule 2821 Reconstructed Valid molecule COc1ccc(S(=O)(=O)N[C@H]2CCC[C@@H](C)C2)cc1N Predicted Property= [3.6862516]
#
# Molecule 2848 Original Valid Molecule C#CCN(C(=O)Nc1ccc(Cl)cc1F)[C@H]1CCS(=O)(=O)C1 Original Property= [3.0416772]
# Molecule 2848 Reconstructed Valid molecule C#CCN(C(=O)Nc1ccc(Cl)cc1F)[n@H]1CCS(=O)(=O)C1 Predicted Property= [2.65134]
#
# Molecule 2856 Original Valid Molecule N[C@H]1C(=O)Nc2cc(SCc3ccccc3)c(Br)cc21 Original Property= [2.98698567]
# Molecule 2856 Reconstructed Valid molecule C[C@H]1C(=O)cc2cc(S2c3ccccc3)c(Br)ccc1 Predicted Property= [3.9972942]
#
# Molecule 2862 Original Valid Molecule Cc1ccc(C(=O)[O-])cc1NC(=O)c1ccc(-c2cccc([N+](=O)[O-])c2)o1 Original Property= [2.43527919]
# Molecule 2862 Reconstructed Valid molecule Cc1ccc(C(=O)[O-])cc1NC(=O)c1ccc(-c2cccc([N+](=C)[O-])c2)o1 Predicted Property= [2.5974202]
#
# Molecule 2867 Original Valid Molecule O=C1c2ccccc2O[C@@H](c2ccccc2)N1CCO Original Property= [2.59078836]
# Molecule 2867 Reconstructed Valid molecule C=C1c2ccccc2C[C@@H](c2ccccc2)N1CCO Predicted Property= [2.101068]
#
# Molecule 2902 Original Valid Molecule CCc1ccc(-c2csc(NC(=O)[C@H]3CCC(=O)NC3)n2)cc1 Original Property= [2.65253585]
# Molecule 2902 Reconstructed Valid molecule CCc1ccc(-c2csc(NC(=O)[C@H]3CCC(=O)NC3)n2)cc1 Predicted Property= [1.2409561]
#
# Molecule 3017 Original Valid Molecule C[C@H](Cc1ccc(C2CC2)cc1)C(=O)[O-] Original Property= [2.82283356]
# Molecule 3017 Reconstructed Valid molecule C[C@H](Cc1ccc(C2CC2)cc1)C(=O)[O-] Predicted Property= [5.6336226]
#
# Molecule 3032 Original Valid Molecule COc1ccc([C@H]2CCCN2C(=O)/C=C/c2ccc(Cl)c([N+](=O)[O-])c2)cc1 Original Property= [2.6371677]
# Molecule 3032 Reconstructed Valid molecule COc1ccc([C@H]2CCCN2C(=O)/C=C/c2ccc(Cl)c([N+](=O)[O-])c2)cc1 Predicted Property= [3.4626284]
#
# Molecule 3035 Original Valid Molecule c1cncc(-c2ncc(C[NH+]3C[C@H]4CCCC[C@@H]4C3)s2)c1 Original Property= [4.30621591]
# Molecule 3035 Reconstructed Valid molecule c1cncc(-c2ncc(C[NH+]3C[C@H]4CCCC[C@@H]4C3)s2)c1 Predicted Property= [3.3170624]
#
# Molecule 3046 Original Valid Molecule COc1ccc(NC(=O)N[C@@H](C)c2ccc(C)o2)cn1 Original Property= [2.62411667]
# Molecule 3046 Reconstructed Valid molecule COc1ccc(NC(=O)N[C@@H](C)c2ccc(C)o2)nn1 Predicted Property= [1.4566988]
#
# Molecule 3054 Original Valid Molecule CCNS(=O)(=O)c1ccc(Cl)c(N)c1 Original Property= [1.98339784]
# Molecule 3054 Reconstructed Valid molecule CCNS(=O)(=O)c1ccc(Cl)c(F)c1 Predicted Property= [4.1981335]
#
# Molecule 3068 Original Valid Molecule CC(C)[C@H](NC(=O)Cc1ccccc1)C(=O)Nc1nc(-c2cccnc2)cs1 Original Property= [2.50993869]
# Molecule 3068 Reconstructed Valid molecule CCCCC[C@H](NC(=O)Cc1ccccc1)C(=O)Nc1cc(-c2ccccc2)cs1 Predicted Property= [4.8135653]
#
# Molecule 3088 Original Valid Molecule NC(=O)CC[C@H]1CCCN(S(=O)(=O)c2ccccc2Cl)C1 Original Property= [2.50992574]
# Molecule 3088 Reconstructed Valid molecule CC(=O)CC[C@H]1CCCN(S(=O)(=O)c2ccccc2Cl)C1 Predicted Property= [1.8844309]
#
# Molecule 3092 Original Valid Molecule COC[C@@H](C)NC(=O)Cc1ccc(F)cc1F Original Property= [2.39157467]
# Molecule 3092 Reconstructed Valid molecule C=C[C@@H](C)NC(=O)Cc1ccc(F)cc1F Predicted Property= [4.555748]
#
# Molecule 3105 Original Valid Molecule COc1ccc(-c2nc(CSc3nc4ccccc4[nH]3)n[nH]2)cc1 Original Property= [2.35719553]
# Molecule 3105 Reconstructed Valid molecule COc1ccc(Cc2nc(CSc3cc4ccccc4[nH]3)n[nH]2)cc1 Predicted Property= [5.3769813]
#
# Molecule 3109 Original Valid Molecule O=C(COc1ccccc1C(=O)Nc1ccccc1)Nc1ccc(Br)cc1 Original Property= [1.64895377]
# Molecule 3109 Reconstructed Valid molecule O=C(COc1ccccc1C(CO)Nc1ccccc1)Nc1ccc(Br)cc1 Predicted Property= [2.7941513]
#
# Molecule 3114 Original Valid Molecule CC(C)[C@@H](NC(=O)[C@H]1CCCO1)C(=O)[O-] Original Property= [3.46753139]
# Molecule 3114 Reconstructed Valid molecule CC(C)[C@@H](NC(=O)[C@H]1CCCO1)C(=O)[O-] Predicted Property= [6.4169507]
#
# Molecule 3126 Original Valid Molecule CCc1ccsc1CNC(=O)C(=O)Nc1cc(F)cc(F)c1 Original Property= [2.44642046]
# Molecule 3126 Reconstructed Valid molecule CCc1ccsc1CCC(=O)C(=O)Nc1cc(F)cc(F)c1 Predicted Property= [1.6800497]
#
# Molecule 3157 Original Valid Molecule COCCNC(=S)N1c2ccccc2C[C@H]1C Original Property= [2.67045138]
# Molecule 3157 Reconstructed Valid molecule CNCCNC(=O)NCc2cccc12C[C@H]1C Predicted Property= [5.9730344]
#
# Molecule 3179 Original Valid Molecule C[C@@H](c1ccco1)N(C)C(=O)c1cn(CC2CCCCC2)nn1 Original Property= [2.98886732]
# Molecule 3179 Reconstructed Valid molecule C[C@@H](c1ccco1)N(C)C(=O)c1cC(CC2CCCCC2)nn1 Predicted Property= [2.6857615]
#
# Molecule 3204 Original Valid Molecule C=CCNC(=O)NNC(=O)Cc1ccc(Cl)cc1 Original Property= [2.05534896]
# Molecule 3204 Reconstructed Valid molecule C=CCNC(=O)NNC(=O)Cc1ccc(Cl)cc1 Predicted Property= [2.5947309]
#
# Molecule 3236 Original Valid Molecule O=C([O-])c1ccc(CNC(=O)c2cnns2)o1 Original Property= [3.08543677]
# Molecule 3236 Reconstructed Valid molecule O=C([O-])c1ccc(CNC(=O)c2cnns2)o1 Predicted Property= [1.2869602]
#
# Molecule 3244 Original Valid Molecule Cc1ccc(C(=O)N[C@@H](C)c2ccccc2)cc1S(=O)(=O)N1CCOCC1 Original Property= [2.37749583]
# Molecule 3244 Reconstructed Valid molecule Cc1ccc(C(=O)N[C@@H](O)c2ccccc2)cc1S(=O)(=O)c1CCOCC1 Predicted Property= [2.3854015]
#
# Molecule 3313 Original Valid Molecule Cc1cc(C)nc([C@H](C#N)C(=O)c2cc(C)sc2C)n1 Original Property= [3.20284707]
# Molecule 3313 Reconstructed Valid molecule Cc1cc(C)nc([C@H](C#N)C(=O)c2cc(F)sc2C)n1 Predicted Property= [4.1810117]
#
# Molecule 3328 Original Valid Molecule CN(C(=O)c1sccc1N)C1CCC(C)(C)CC1 Original Property= [2.68003238]
# Molecule 3328 Reconstructed Valid molecule CN(C(=O)c1sccc1N)C1CCC(C)(C)CC1 Predicted Property= [3.31455]
#
# Molecule 3338 Original Valid Molecule CCOC(=O)N1CCC[C@H](C(=O)Nc2c(C)cccc2CC)C1 Original Property= [2.44195631]
# Molecule 3338 Reconstructed Valid molecule CCOC(=O)c1cCC[C@H](C(=O)Nc2c(C)cccc2OC)C1 Predicted Property= [1.7424345]
#
# Molecule 3349 Original Valid Molecule O=C(CNC(=O)c1cccc(Br)c1)NCC1(c2ccccc2)CCCC1 Original Property= [2.11910826]
# Molecule 3349 Reconstructed Valid molecule O=C(COC(=O)c1cccc(Br)c1)NCC1(c2ccccc2)CCCC1 Predicted Property= [2.698]
#
# Molecule 3356 Original Valid Molecule Cn1cc(N2CC[C@H](NC(=O)CCSc3ccccn3)C2=O)cn1 Original Property= [3.06497868]
# Molecule 3356 Reconstructed Valid molecule Cn1cc(N2CC[C@H](NC(=O)CCSc3ccccn3)C2=O)cc1 Predicted Property= [3.4212923]
#
# Molecule 3364 Original Valid Molecule COC(=O)C1=C(C(=O)OC)[C@@](O)(c2ccccc2)[C@@H](c2ccccc2)O1 Original Property= [3.29863279]
# Molecule 3364 Reconstructed Valid molecule COC(=O)C1=C(C(=O)OC)[C@@](C)(c2ccccc2)[C@@H](c2ccccc2)O1 Predicted Property= [4.258813]
#
# Molecule 3369 Original Valid Molecule CCOCCCc1cnc(C[NH2+]C)o1 Original Property= [3.65995059]
# Molecule 3369 Reconstructed Valid molecule CC(CO)c1ccc(C[NH2+]C)o1 Predicted Property= [5.1564264]
#
# Molecule 3370 Original Valid Molecule Cc1ccsc1CN(C)S(=O)(=O)c1cccc(F)c1 Original Property= [2.14607498]
# Molecule 3370 Reconstructed Valid molecule Cc1ccsc1CN(C)S(=O)(=O)c1cccc(F)c1 Predicted Property= [1.4260206]
#
# Molecule 3428 Original Valid Molecule COc1ccc(CN(C)C(=O)NCc2ccc(C)s2)cc1O Original Property= [2.2058197]
# Molecule 3428 Reconstructed Valid molecule COc1ccc(CN(C)C(=O)NCc2ccc(C)s2)cc1 Predicted Property= [1.635453]
#
# Molecule 3460 Original Valid Molecule Cc1ccc([C@H](O)CNC(=O)C(=O)Nc2ccc(C)c(F)c2)o1 Original Property= [2.68575054]
# Molecule 3460 Reconstructed Valid molecule Cc1ccc([C@H](O)CNC(=O)C(=O)Nc2ccc(C)c(F)c2)o1 Predicted Property= [1.4929812]
#
# Molecule 3461 Original Valid Molecule C[C@@H](CO)[C@@H](C)NC(=O)C(=O)Nc1cnc(-c2ccccc2)s1 Original Property= [3.29141439]
# Molecule 3461 Reconstructed Valid molecule C[C@@H](CO)[C@@H](C)NC(=O)C(=O)Nc1cnc(-c2ccccc2)s1 Predicted Property= [1.957721]
#
# Molecule 3497 Original Valid Molecule COc1ccccc1[C@@H](C)CC(=O)NC[C@H](C)c1cccc(C)c1 Original Property= [2.72434122]
# Molecule 3497 Reconstructed Valid molecule COc1ccccc1[C@@H](C)CC(=O)CC[C@H](C)c1cccc(C)c1 Predicted Property= [2.6649885]
#
# Molecule 3537 Original Valid Molecule CCC([NH3+])(CC)CN1CCN(c2ccccc2)CC1 Original Property= [2.69506689]
# Molecule 3537 Reconstructed Valid molecule CCC([NH3+])(c1)CNCCCN(c2ccccc2)CC1 Predicted Property= [2.7839537]
#
# Molecule 3558 Original Valid Molecule COC(=O)[C@@H](C)CNC(=O)Nc1ccc(C)cc1C Original Property= [2.34099726]
# Molecule 3558 Reconstructed Valid molecule COC(=O)[C@@H](C)CNC(=O)Nc1ccc(C)cc1 Predicted Property= [1.0424838]
#
# Molecule 3572 Original Valid Molecule COc1ccc(CC[NH2+][C@H](C)c2ccc(C)cc2)cc1S(N)(=O)=O Original Property= [3.32802678]
# Molecule 3572 Reconstructed Valid molecule COc1ccc(CC[NH2+][C@H](C)c2ccc(C)cc2)cc1S(N)(=O)=O Predicted Property= [4.996043]
#
# Molecule 3594 Original Valid Molecule Cc1ccccc1CC[NH+]1CCC[C@@H](C[NH3+])C1 Original Property= [4.81726995]
# Molecule 3594 Reconstructed Valid molecule Cc1ccccc1CC[NH+]1CCC[C@@H](C[NH2+])C1 Predicted Property= [4.772377]
#
# Molecule 3603 Original Valid Molecule N#Cc1c(F)ccc(NC(=O)Nc2ccc(Cl)cc2)c1F Original Property= [2.03692346]
# Molecule 3603 Reconstructed Valid molecule N#Cc1c(F)ccc(NC(=O)Nc2ccc(Cl)cc2)c1F Predicted Property= [3.6455395]
#
# Molecule 3629 Original Valid Molecule COc1ccc(F)cc1S(=O)(=O)N1CCC(C(=O)NCCN2CCOCC2)CC1 Original Property= [2.18347993]
# Molecule 3629 Reconstructed Valid molecule COc1ccc(F)cc1S(=O)(=O)N1CCC(C(=O)NCCN2CCOCC2)cC1 Predicted Property= [3.5785134]
#
# Molecule 3631 Original Valid Molecule C[NH+](Cc1ccsc1)Cc1ccc(C(N)=O)cc1[N+](=O)[O-] Original Property= [3.79689709]
# Molecule 3631 Reconstructed Valid molecule C[NH+](Cc1ccsc1)Cc1ccc(C(N)=O)cc1[N+](=O)[O-] Predicted Property= [3.8892162]
#
# Molecule 3718 Original Valid Molecule Cc1nc(C[NH+](C)[C@H](C)c2ccc(C(=O)[O-])o2)cs1 Original Property= [4.80219612]
# Molecule 3718 Reconstructed Valid molecule Cc1nc(C[NH+](C)[C@H](C)c2ccc(C(=O)[O-])o2)cs1 Predicted Property= [3.6173344]
#
# Molecule 3757 Original Valid Molecule O=C1C[C@H]([NH+]2CCN(c3ccc(Cl)c(Cl)c3)CC2)C(=O)N1c1ccccc1 Original Property= [3.6491629]
# Molecule 3757 Reconstructed Valid molecule O=C1C[C@H]([CH+]2CCN(c3ccc(Cl)c(Cl)c3)CC2)C(=O)N1c1ccccc1 Predicted Property= [4.013135]
#
# Molecule 3824 Original Valid Molecule CC1(C)CCC[C@@H](C[NH+](CCO)C2CCCCC2)C1=O Original Property= [4.67750896]
# Molecule 3824 Reconstructed Valid molecule CC1(C)CCC[C@@H](C[CH+](CCO)C2CCCCC2)C1 Predicted Property= [4.8489275]
#
# Molecule 3868 Original Valid Molecule CCc1nn(C)c(OC)c1CNC(=O)c1cc(SC)ccc1C Original Property= [2.52612659]
# Molecule 3868 Reconstructed Valid molecule CCc1nn(C)c(OC)c1CNC(=O)c1cc(SC)ccc1C Predicted Property= [4.072425]
#
# Molecule 3870 Original Valid Molecule COCCOc1cccc(NC(=O)c2ccc(NC=O)cc2)c1 Original Property= [1.88678733]
# Molecule 3870 Reconstructed Valid molecule C=CCOc1cccc(NC(=O)c2ccc(CC=O)cc2)c1 Predicted Property= [1.9667888]
#
# Molecule 3891 Original Valid Molecule Cc1noc(CCCC(=O)N2CC(C)(C)[C@H]2c2ccccc2)n1 Original Property= [2.99994273]
# Molecule 3891 Reconstructed Valid molecule Cc1coc(CCCC(=O)N2CC(C)(C)[C@H]2c2ccccc2)n1 Predicted Property= [3.5982609]
#
# Molecule 3922 Original Valid Molecule Cc1ccc(NC(=O)C2=NO[C@@H](c3ccccc3)C2)c(Cl)c1 Original Property= [2.60759566]
# Molecule 3922 Reconstructed Valid molecule Cc1ccc(NC(=O)C2=NC[C@@H](c3ccccc3)n2)c(Cl)c1 Predicted Property= [4.646226]
#
# Molecule 3946 Original Valid Molecule COc1ccc(C)cc1N[C@@H](C)C(=O)NC1CCCCC1 Original Property= [2.35203431]
# Molecule 3946 Reconstructed Valid molecule COc1ccc(C)cc1O[C@@H](C)C(=O)NC1CCCCC1 Predicted Property= [3.5183647]
#
# Molecule 3966 Original Valid Molecule CC(=O)Nc1ccc(S(=O)(=O)NCCOc2ccccc2)cc1 Original Property= [1.70138332]
# Molecule 3966 Reconstructed Valid molecule CC(=O)Nc1ccc(S(COC(=O)NCC)c2ccccc2)cc1 Predicted Property= [1.4280839]
#
# Molecule 4002 Original Valid Molecule O=[N+]([O-])c1cccc(NC(=S)Nc2ccc(F)c(F)c2)c1 Original Property= [1.90397651]
# Molecule 4002 Reconstructed Valid molecule C=[N+]([N-])c1cccc(NC(=S)Nc2ccc(F)c(F)c2)c1 Predicted Property= [1.3032938]
#
# Molecule 4006 Original Valid Molecule Cc1ccccc1OCCCNC(=O)c1cc(F)ccc1F Original Property= [1.7562442]
# Molecule 4006 Reconstructed Valid molecule Cc1ccccc1CCCCNC(=O)c1cc(F)ccc1 Predicted Property= [3.1750278]
#
# Molecule 4019 Original Valid Molecule CCONC(=O)CN(C)c1ccccc1[N+](=O)[O-] Original Property= [2.41414667]
# Molecule 4019 Reconstructed Valid molecule CCONC(=O)CN(C)c1ccccc1[N+](=O)[O-] Predicted Property= [6.1854]
#
# Molecule 4041 Original Valid Molecule Cc1ccc(F)cc1S(=O)(=O)N(C)CC(=O)N1CCCC1 Original Property= [2.04481447]
# Molecule 4041 Reconstructed Valid molecule Cc1ccc(F)cc1S(=O)(=O)N1CCCC(=O)N1CCCC Predicted Property= [3.7365334]
#
# Molecule 4070 Original Valid Molecule Cc1noc(CCC(=O)NC[C@@H]2C[C@]23CCc2ccccc23)n1 Original Property= [3.78783783]
# Molecule 4070 Reconstructed Valid molecule Cc1coc(CCC(=O)NC[C@@H]2C[C@]23CCc2ccccc23)n1 Predicted Property= [3.3280945]
#
# Molecule 4094 Original Valid Molecule O=C(Nc1cccc(-n2ccnc2)c1)c1cc(-c2ccco2)on1 Original Property= [2.35991211]
# Molecule 4094 Reconstructed Valid molecule O=C(Nc1cccc(-C2ccnc2)c1)c1cc(-c2ccco2)oc1 Predicted Property= [2.9449964]
#
# Molecule 4103 Original Valid Molecule O=C(c1ccc[nH]c1=O)N1CCC[C@H](CCc2ccc(F)cc2)C1 Original Property= [2.57140945]
# Molecule 4103 Reconstructed Valid molecule O=C(c1ccc[nH]c1=O)C1CCC[C@H](CCc2ccc(F)cc2)C1 Predicted Property= [1.8421956]
#
# Molecule 4185 Original Valid Molecule Cc1nnc(-c2ccc(C(=O)N3CC[C@H](C[NH+]4CCCCC4)C3)cc2)o1 Original Property= [3.76090098]
# Molecule 4185 Reconstructed Valid molecule Cc1nnc(-c2ccc(C(=O)N3CC[C@H](C[NH+]4CCCCC4)C3)cc2)o1 Predicted Property= [3.4945753]
#
# Molecule 4202 Original Valid Molecule CN(C)C(=O)Nc1cccc(CNS(=O)(=O)CC2CCC2)c1 Original Property= [2.23703797]
# Molecule 4202 Reconstructed Valid molecule CC(C)C(=O)Nc1cccc(CNS(=O)(=O)CC)C(Cl)c1 Predicted Property= [1.8355157]
#
# Molecule 4214 Original Valid Molecule COc1ccccc1CC(=O)N1C[C@H]2CC[C@@H]1CN(S(C)(=O)=O)C2 Original Property= [3.78079293]
# Molecule 4214 Reconstructed Valid molecule COc1ccccc1CC(=O)N1C[C@H]2CC[C@@H]1CN(S(C)(=O)=O)C2 Predicted Property= [4.7140884]
#
# Molecule 4218 Original Valid Molecule Cc1nn(C)c2nc(NC[C@H](c3ccncc3)N3CCOCC3)sc12 Original Property= [3.18551658]
# Molecule 4218 Reconstructed Valid molecule Cc1nn(C)c2nc(NC[C@H](c3ccccc3)N3CCCCC3)sc12 Predicted Property= [3.0971131]
#
# Molecule 4226 Original Valid Molecule Cc1ccc(SC(=O)[C@@H](C)Oc2ccc(F)cc2)cc1 Original Property= [2.47672931]
# Molecule 4226 Reconstructed Valid molecule Cc1ccc(SC(=O)[C@@H](C)Oc2ccc(B)cc2)cc1 Predicted Property= [2.4097192]
#
# Molecule 4283 Original Valid Molecule CN1CCN(C(=O)c2cccc(S(C)(=O)=O)c2)[C@H](CNC(=O)OC(C)(C)C)C1 Original Property= [2.82630323]
# Molecule 4283 Reconstructed Valid molecule CN1CCN(C(=O)c2cccc(S(C)(=C)=O)c2)[C@H](CNC(=O)OC(C)(C)C)C1 Predicted Property= [2.7876422]
#
# Molecule 4291 Original Valid Molecule CCCCCN1C(=O)CSC1=S Original Property= [2.39710799]
# Molecule 4291 Reconstructed Valid molecule CCCCCC1C(=O)CSC1CS Predicted Property= [1.980846]
#
# Molecule 4308 Original Valid Molecule C[C@@H](C#N)Sc1nc2ccccc2c(=O)n1-c1ccccc1 Original Property= [2.47633192]
# Molecule 4308 Reconstructed Valid molecule C[C@@H](C#N)Sc1nc2ccccc2c(=O)n1-c1ccccc1 Predicted Property= [3.841761]
#
# Molecule 4309 Original Valid Molecule O=C(Nc1ccccc1)[C@H]1CCCN(C(=O)c2cccs2)C1 Original Property= [2.24647426]
# Molecule 4309 Reconstructed Valid molecule O=C(Nc1ccccc1)[C@H]1CCCN(C(=O)c2cccs2)C1 Predicted Property= [2.3786035]
#
# Molecule 4319 Original Valid Molecule Cc1cc(C)c(CNC(=O)CC2CC[NH+](C(C)C)CC2)cn1 Original Property= [3.56416825]
# Molecule 4319 Reconstructed Valid molecule Cc1cc(C)c(CNC(=O)CC2CC[NH+](C(C)C)CC2)cn1 Predicted Property= [4.663638]
#
# Molecule 4322 Original Valid Molecule CC(C)(CBr)CN1C(=O)C(C)(C)S1(=O)=O Original Property= [3.69103998]
# Molecule 4322 Reconstructed Valid molecule CC(C)(CBr)C1CC(=O)C(C)(C)S1(=O)=O Predicted Property= [2.776608]
#
# Molecule 4334 Original Valid Molecule Cc1ccc(C(=O)[C@H]2CSCCS2)cc1C Original Property= [3.05685462]
# Molecule 4334 Reconstructed Valid molecule Cc1ccc(C(=O)[C@@]2CSCCC2)cc1C Predicted Property= [2.1226554]
#
# Molecule 4346 Original Valid Molecule CC[C@H](C)[C@@H](NC(=O)N1CC(=O)Nc2ccccc21)C(=O)[O-] Original Property= [3.41948971]
# Molecule 4346 Reconstructed Valid molecule CC[C@H](C)[C@@H](NC(=O)N1CC(=O)Nc2ccccc21)C(=O)[O-] Predicted Property= [1.7386494]
#
# Molecule 4361 Original Valid Molecule CCn1cnnc1S[C@H]1C[C@@H](C)OC1=O Original Property= [3.70518233]
# Molecule 4361 Reconstructed Valid molecule CCn1cnnc1S[C@H]1C[C@@H](C)NC1CO Predicted Property= [1.0790766]
#
# Molecule 4454 Original Valid Molecule C#CCNCC(=O)N[C@@H](C)Cc1ccsc1 Original Property= [3.08253155]
# Molecule 4454 Reconstructed Valid molecule C=CCNCC(=O)N[C@@H](C)Cc1ccsc1 Predicted Property= [2.0083416]
#
# Molecule 4459 Original Valid Molecule Cc1ccc(NC(=O)CSc2nc3ncc(Cl)cc3[nH]2)cc1C Original Property= [2.24826806]
# Molecule 4459 Reconstructed Valid molecule Cc1ccc(NC(=O)CSc2nc3ncc(Cl)cc3[nH]2)cc1 Predicted Property= [2.7576842]
#
# Molecule 4477 Original Valid Molecule O=C1NCCS[C@@H]1Cc1ccccc1 Original Property= [2.71515101]
# Molecule 4477 Reconstructed Valid molecule O=C1NCCC[C@@H]1Cc1ccccc1 Predicted Property= [1.7666726]
#
# Molecule 4521 Original Valid Molecule COCC[NH+]1CC[C@H]2CCCC[C@@H]2C1 Original Property= [4.89019029]
# Molecule 4521 Reconstructed Valid molecule COCC[NH+]1CC[C@H]2CCCC[C@@H]2C1 Predicted Property= [4.4451237]
#
# Molecule 4531 Original Valid Molecule C[C@@H](NC(=O)Cc1ccc(-n2cccc2)cc1)c1ccccc1 Original Property= [2.28295467]
# Molecule 4531 Reconstructed Valid molecule C[C@@H](NC(=O)Cc1ccc(-n2cccn2)cc1)c1ccccc1 Predicted Property= [2.6256938]
#
# Molecule 4535 Original Valid Molecule COc1ccc(C[NH+]2C[C@@H](CO)CC[C@H]2C)cc1O Original Property= [4.42998165]
# Molecule 4535 Reconstructed Valid molecule COc1ccc(C[NH+]2C[C@@H](CC)CC[C@H]2C)cc1 Predicted Property= [6.5644817]
#
# Molecule 4580 Original Valid Molecule CCOC(=O)[C@H]1Nc2ncccc2Cc2ccccc21 Original Property= [2.92666263]
# Molecule 4580 Reconstructed Valid molecule CCOC(=O)[C@H]1NcCncccc2cccccc2co1 Predicted Property= [3.6901987]
#
# Molecule 4586 Original Valid Molecule CCC[NH2+]CC/C=C(/C)[C@@H]1CCOC2(CCSCC2)C1 Original Property= [5.20695324]
# Molecule 4586 Reconstructed Valid molecule CCC[NH2+]CC/C=C(/O)[C@@H](CCOC21CCCCC2)C1 Predicted Property= [3.4806123]
#
# Molecule 4596 Original Valid Molecule CN(Cc1ccccn1)C(=O)N[C@H]1CCC[C@H]1c1ccc(F)cc1 Original Property= [2.91780404]
# Molecule 4596 Reconstructed Valid molecule CN(Cc1ccccn1)C(=O)N[C@H]1CCC[C@H]1C1ccc(F)c1 Predicted Property= [3.6618013]
#
# Molecule 4602 Original Valid Molecule O=C(OC[C@@H]1CC(=O)N(c2ccccc2)C1)[C@@H]1CCC[NH+]1Cc1ccccc1 Original Property= [4.10118892]
# Molecule 4602 Reconstructed Valid molecule O=C(OC[C@@H]1CC(=O)N(c2ccccc2)C1)[C@@H]1CCC[NH+]1Cc1ccccc1 Predicted Property= [4.9203396]
#
# Molecule 4613 Original Valid Molecule CCOc1cc(C)ccc1NC(=O)c1cccnc1 Original Property= [1.70115151]
# Molecule 4613 Reconstructed Valid molecule CCOc1cc(C)ccc1NC(=O)c1ccccc1 Predicted Property= [3.6970584]
#
# Molecule 4619 Original Valid Molecule CCCn1c(C[NH2+]CC2CCC2)nc2ccccc21 Original Property= [3.06185146]
# Molecule 4619 Reconstructed Valid molecule C=Cn1c(C[NH2+]CCSCCC2)nc2ccccc1 Predicted Property= [4.0812716]
#
# Molecule 4636 Original Valid Molecule CC(C)CCC(=O)NNC(=O)NC[C@H](C)c1ccsc1 Original Property= [2.90435006]
# Molecule 4636 Reconstructed Valid molecule CC(C)CCC(=O)NNC(=O)NC[C@H](C)c1ccsc1 Predicted Property= [1.3882167]
#
# Molecule 4638 Original Valid Molecule Cc1cc([C@H](O)Cc2ccc(Br)s2)c2ccccc2n1 Original Property= [2.73871441]
# Molecule 4638 Reconstructed Valid molecule Cc1cc([C@H](O)Cc2ccc(Br)s2)c2ccccc2n1 Predicted Property= [1.3491212]
#
# Molecule 4646 Original Valid Molecule CCCOc1ccc(NC(=O)CNC(=O)c2ccoc2)cc1Cl Original Property= [2.05963445]
# Molecule 4646 Reconstructed Valid molecule CCCOc1ccc(NC(=O)CNC(=O)c2ccoc2)cc1Cl Predicted Property= [2.4953012]
#
# Molecule 4664 Original Valid Molecule CCSCc1ccc(C(=O)N2C[C@@H](C)OCC2(C)C)cc1 Original Property= [3.06489868]
# Molecule 4664 Reconstructed Valid molecule CCSCc1ccc(C(=O)NCC[C@@H](C)ONOC(C)O)cc1 Predicted Property= [5.879321]
#
# Molecule 4675 Original Valid Molecule C/C(=N\NC(=O)c1ccc(Cl)c([N+](=O)[O-])c1)c1ccc2ccccc2c1 Original Property= [2.06008386]
# Molecule 4675 Reconstructed Valid molecule C/C(=N\NC(=O)c1ccc(Cl)c([N+](=O)[O-])c1)c1ccc2ccccc2c1 Predicted Property= [2.2346475]
#
# Molecule 4701 Original Valid Molecule Cc1cc(C(=O)[O-])c([N+](=O)[O-])cc1[N+](=O)[O-] Original Property= [2.80267906]
# Molecule 4701 Reconstructed Valid molecule Cc1cc(C(=O)[O-])c([N+](=O)[C-])cc1[N+](=O)[O-] Predicted Property= [1.3546729]
#
# Molecule 4726 Original Valid Molecule CCN(CCC#N)Cc1ccc(C(=O)NC)cc1 Original Property= [2.00276404]
# Molecule 4726 Reconstructed Valid molecule CCC(NCC#N)Cc1ccc(C(=O)CC)cc1 Predicted Property= [1.9096148]
#
# Molecule 4808 Original Valid Molecule COc1ccccc1[C@@H](NCc1ccc(C)c([N+](=O)[O-])c1)c1[nH+]ccn1C Original Property= [3.55982802]
# Molecule 4808 Reconstructed Valid molecule COc1ccccc1[C@@H](NCc1ccc(C)c([N+](=O)[O-])c1)c1[nH+]ccn1C Predicted Property= [4.0493]
#
# Molecule 4859 Original Valid Molecule O=C([C@@H]1CCCN1C(=O)C[C@H](O)c1ccc(Cl)cc1)N1CCOCC1 Original Property= [2.93619031]
# Molecule 4859 Reconstructed Valid molecule O=C([C@@H]1CCCN1C(=O)C[C@H](O)c1ccc(Cl)cc1)N1OC1 Predicted Property= [5.3804054]
#
# Molecule 4888 Original Valid Molecule CCO[C@@H]1C[C@H]1C(=O)N1CCC(n2c(=O)[nH]c3ccccc32)CC1 Original Property= [3.19045488]
# Molecule 4888 Reconstructed Valid molecule CCO[C@@H]1C[n@H]1C(=O)N1CCC(n2c(=O)[nH]c3ccccc32)Cc1 Predicted Property= [2.568645]
#
# Molecule 4907 Original Valid Molecule CCn1c(=O)c(I)cn(C)c1=O Original Property= [2.65879814]
# Molecule 4907 Reconstructed Valid molecule CCn1c(=O)c(I)cc(C)n1=O Predicted Property= [1.7430028]
#
# Molecule 4911 Original Valid Molecule CC[C@@H]1C(=O)N2CCC[C@H]2C(=O)N1c1cc(F)cc(F)c1 Original Property= [3.20960515]
# Molecule 4911 Reconstructed Valid molecule CC[C@@H]1C(=O)N2CCC[C@H]2C(=O)N1c1cc(C)cc(F)c1 Predicted Property= [4.188701]
#
# Molecule 4935 Original Valid Molecule C[C@H](C(=O)N1CCC(n2cncn2)CC1)[NH+]1CCCCCC1 Original Property= [4.11711128]
# Molecule 4935 Reconstructed Valid molecule C[C@H](C(=O)NCCCCCC2cccn2)CCCC[NH+]1CCCOCC1 Predicted Property= [5.6836753]
#
# Molecule 4938 Original Valid Molecule Cc1ccc(CNC(=O)c2csc(Nc3cccnc3)n2)cc1 Original Property= [2.00620705]
# Molecule 4938 Reconstructed Valid molecule Cc1ccc(CNC(=O)c2csc(Nc3cccnc3)n2)cc1 Predicted Property= [1.1339054]
#
# Molecule 4950 Original Valid Molecule Cc1ccc2c(c1)N(Cc1ncc(C)o1)CC2 Original Property= [2.41356799]
# Molecule 4950 Reconstructed Valid molecule Cc1cnc2c(c1)C(Cc1Occ(C)c1)CC2 Predicted Property= [1.945071]
#
# Molecule 4951 Original Valid Molecule C[C@H](NC(=O)CCc1ccco1)c1ccc(-n2ccnc2)cc1 Original Property= [2.61562815]
# Molecule 4951 Reconstructed Valid molecule C[C@H](NC(=O)NCc1ccno1)c1ccc(-n2cccc2)cc1 Predicted Property= [1.3020222]
#
# Molecule 4966 Original Valid Molecule NC(=O)c1ccc(N2CCN(Cc3ccc(F)cc3F)CC2)cc1 Original Property= [1.86564253]
# Molecule 4966 Reconstructed Valid molecule NC(=O)c1ccc(N2CCN(Cc3ccc(F)cc3F)CC2)cc1 Predicted Property= [1.842971]
#
# Molecule 4972 Original Valid Molecule CCC[NH2+]C[C@@H](C)Oc1ccc(C(C)C)cc1 Original Property= [3.56013888]
# Molecule 4972 Reconstructed Valid molecule CCC[NH2+]C[C@@H](C)Oc1ccc(C(C)C)cc1 Predicted Property= [3.491994]
#
# Molecule 4975 Original Valid Molecule Cc1nnc(NC(=O)Cc2ccc(-n3cccn3)cc2)s1 Original Property= [2.13929104]
# Molecule 4975 Reconstructed Valid molecule Cc1ncc(NC(=O)Cc2ccc(-n3cccn3)cn2)s1 Predicted Property= [2.0380301]
#
# Molecule 4993 Original Valid Molecule c1ccc(COc2ccc(-c3ccnc4nc(-c5cccnc5)nn34)cc2)cc1 Original Property= [2.1899811]
# Molecule 4993 Reconstructed Valid molecule c1ccc(COc2ccc(-c3cccc4nc(-c5cccnc5)nn34)cc2)cc1 Predicted Property= [3.2541914]
#
# Molecule 4996 Original Valid Molecule O=C(COc1ccccc1[N+](=O)[O-])NC1CCC(c2ccccc2)CC1 Original Property= [1.97257903]
# Molecule 4996 Reconstructed Valid molecule O=C(NOc1ccccc1[N+](=O)[C-])NC1CCN(c2ccccc2)CC1 Predicted Property= [2.6700323]
#
# Molecule 5028 Original Valid Molecule Nc1cccnc1SCC(=O)N1CCc2ccccc2C1 Original Property= [2.16004892]
# Molecule 5028 Reconstructed Valid molecule Nc1cccnc1SCC(=O)N1CCc2ccccc2C1 Predicted Property= [3.2070198]
#
# Molecule 5096 Original Valid Molecule CC[C@@H](CNC(=O)NC1CCCC1)c1ccccc1 Original Property= [2.35093831]
# Molecule 5096 Reconstructed Valid molecule CC[C@@H](CNC(=O)NC1CCCC1)c1ccccc1 Predicted Property= [2.395485]
#
# Molecule 5098 Original Valid Molecule CC(C)Nc1nnc(SCc2cc(-c3cccs3)on2)s1 Original Property= [2.63948675]
# Molecule 5098 Reconstructed Valid molecule CC(C)Cc1cnc(CCc2cc(-c3cccs3)on2)s1 Predicted Property= [5.097839]
#
# Molecule 5140 Original Valid Molecule Cc1ccc(Cc2nc(C(=O)O[C@H](C)C(F)(F)F)cs2)cc1 Original Property= [2.79920797]
# Molecule 5140 Reconstructed Valid molecule Cc1ccc(Cc2nc(C(=O)C[C@H](C)C(F)(F)F)cs2)cc1 Predicted Property= [3.754897]
#
# Molecule 5164 Original Valid Molecule CCn1cc(S(=O)(=O)Nc2ncn(Cc3ccccc3C)n2)cn1 Original Property= [2.4568]
# Molecule 5164 Reconstructed Valid molecule CCn1cc(S(=O)(=O)Nc2ncn(Cc3ccccc3C)n2)cn1 Predicted Property= [1.8022108]
#
# Molecule 5201 Original Valid Molecule COc1cc(C(=O)Nc2cc(C)ccc2F)cc(NC(C)=O)c1OC Original Property= [1.95634196]
# Molecule 5201 Reconstructed Valid molecule COc1cc(C(=O)Nc2cc(C)ccc2C)cc(SC(C)=O)c1O Predicted Property= [1.8751855]
#
# Molecule 5209 Original Valid Molecule CCc1ccc(-c2ccc3nnc(SCC(=O)Nc4cccc(F)c4)n3n2)cc1 Original Property= [2.18637371]
# Molecule 5209 Reconstructed Valid molecule CCc1ccc(-c2ccc3ncc(SCC(=O)Nc4cccc(F)c4)n3n2)cc1 Predicted Property= [2.359677]
#
# Molecule 5229 Original Valid Molecule [NH3+][C@H](c1ccc(Cl)cn1)[C@H]1CCc2cccnc21 Original Property= [3.82838095]
# Molecule 5229 Reconstructed Valid molecule [NH3+][C@H](c1ccc(Cl)cn2)[C@H]1CCc1ccccc21 Predicted Property= [4.522441]
#
# Molecule 5260 Original Valid Molecule Cc1ccc(NC(=O)c2cccc(S(=O)(=O)[N-]c3ccccc3F)c2)cc1 Original Property= [2.64317657]
# Molecule 5260 Reconstructed Valid molecule Cc1ccc(NC(=O)c2cccc(S(=O)(=O)[N-]c3ccccc3F)c2)cc1 Predicted Property= [4.979202]
#
# Molecule 5298 Original Valid Molecule COc1ccc(F)c(N[C@H](C)C[NH3+])c1 Original Property= [3.17861928]
# Molecule 5298 Reconstructed Valid molecule COc1ccc(F)c(C[C@H](C)C[NH3+])c1 Predicted Property= [1.5924163]
#
# Molecule 5314 Original Valid Molecule O[C@H]1CCCC[C@@H]1Cc1ccccn1 Original Property= [2.81666499]
# Molecule 5314 Reconstructed Valid molecule O[C@H]1CCCC[C@@H]1Cc1ccccn1 Predicted Property= [3.0858593]
#
# Molecule 5358 Original Valid Molecule Cc1cc([N+](=O)[O-])nn1CC(=O)NC1CCCCC1 Original Property= [2.28389365]
# Molecule 5358 Reconstructed Valid molecule Cc1cc([N+](=O)[O-])nn1CC(=O)NC1CCCCC1 Predicted Property= [2.4939172]
#
# Molecule 5504 Original Valid Molecule Cc1ccc(C(=O)OCc2ccc(Br)cc2)cc1 Original Property= [1.46133398]
# Molecule 5504 Reconstructed Valid molecule Cc1ccc(C(=O)CCc2ccc(Br)cc2)cn1 Predicted Property= [2.56544]
#
# Molecule 5510 Original Valid Molecule C[C@H]1CN(C(=O)c2cc(Cl)cc3cccnc23)C[C@H](C)O1 Original Property= [2.95327618]
# Molecule 5510 Reconstructed Valid molecule C[C@H]1CN(C(=O)c2cc(Cl)cc3cccnc23)C[C@H](C)C1 Predicted Property= [1.9691799]
#
# Molecule 5529 Original Valid Molecule CNc1ccccc1C(=O)NCc1ccc(Cl)cc1 Original Property= [1.56746176]
# Molecule 5529 Reconstructed Valid molecule COc1ccccc1C(=O)NCc1ccc(Cl)cc1 Predicted Property= [2.1705623]
#
# Molecule 5567 Original Valid Molecule O=C([O-])[C@@H]1CSCN1C(=O)c1cccc(Cl)c1 Original Property= [3.11559486]
# Molecule 5567 Reconstructed Valid molecule O=C([O-])[C@@H]1CSCN1C(=O)c1cccc(Cl)c1 Predicted Property= [3.9186268]
#
# Molecule 5581 Original Valid Molecule CCOc1ccc(C(=S)NC[C@@H]2CCCO2)cc1 Original Property= [2.52885163]
# Molecule 5581 Reconstructed Valid molecule CCOc1ccc(C(=C)NS[C@@H]2CCCO2)cc1 Predicted Property= [1.7748163]
#
# Molecule 5615 Original Valid Molecule CC(C)SCC(=O)N[C@@H](C)c1ccco1 Original Property= [2.73939529]
# Molecule 5615 Reconstructed Valid molecule CC(C)CCC(=O)N[C@@H](C)c1ccco1 Predicted Property= [4.8820906]
#
# Molecule 5635 Original Valid Molecule O[C@H]1CCC[C@@H]1CC[NH+](CC1CC1)C1CC1 Original Property= [4.92493616]
# Molecule 5635 Reconstructed Valid molecule O[C@H]1CCC[C@@H]1CC[NH+](CC1CC1)C1CC1 Predicted Property= [4.6081405]
#
# Molecule 5650 Original Valid Molecule NC(=O)c1ccc(C(=O)Oc2cc(F)cc(Br)c2)cn1 Original Property= [2.23161202]
# Molecule 5650 Reconstructed Valid molecule CC(=O)c1ccc(C(=O)Oc2cc(F)cc(Br)c2)nc1 Predicted Property= [2.3445313]
#
# Molecule 5655 Original Valid Molecule Cc1cnc(C(=O)N2CCN(Cc3cccc(-c4noc(-c5cccnc5)n4)c3)CC2)cn1 Original Property= [2.4366826]
# Molecule 5655 Reconstructed Valid molecule Cc1ncc(C(=O)N2CCN(Cc3cccc(-c4coc(-c5cccnc5)n4)c3)Cc2)cn1 Predicted Property= [3.544532]
#
# Molecule 5679 Original Valid Molecule CCOC(=O)c1ccc(NS(=O)(=O)c2cc(Cl)ccc2Cl)cc1 Original Property= [1.78739911]
# Molecule 5679 Reconstructed Valid molecule CCOC(=O)c1ccc(NS(=O)(=O)c2cc(Cl)ccc2Cl)cc1 Predicted Property= [5.2876472]
#
# Molecule 5765 Original Valid Molecule Cn1cc(NC(=O)N2Cc3[nH+]c[nH]c3C[C@@H]2C(=O)[O-])cn1 Original Property= [4.6209965]
# Molecule 5765 Reconstructed Valid molecule Cn1cc(CC(=O)N2Cc3[nH+]c[nH]c3C[C@@H]2C(=O)[O-])cn1 Predicted Property= [2.9840586]
#
# Molecule 5771 Original Valid Molecule COc1ccc(CNC(=O)C2CC[NH+](Cc3ccc(C)s3)CC2)cc1 Original Property= [3.17453585]
# Molecule 5771 Reconstructed Valid molecule COc1ccc(CNC(=O)C2CC[NH+](Cc3ccc(C)s3)CC2)cc1 Predicted Property= [1.246048]
#
# Molecule 5784 Original Valid Molecule CC(C)OCCOC(=O)C=C1CCSCC1 Original Property= [3.05500078]
# Molecule 5784 Reconstructed Valid molecule CC(C)OCCNC(=O)CCCCCCSCCO Predicted Property= [3.0393054]
#
# Molecule 5801 Original Valid Molecule Cc1cc(NC(=O)CCSc2nnc(NC3CCCCC3)s2)no1 Original Property= [2.47482775]
# Molecule 5801 Reconstructed Valid molecule Cc1cc(NC(=O)CCSc2nnc(NC3CCCCC3)s2)co1 Predicted Property= [1.6926676]
#
# Molecule 5812 Original Valid Molecule C[NH2+][C@H](c1ccccc1C)[C@H](C)OC Original Property= [3.93196912]
# Molecule 5812 Reconstructed Valid molecule C[NH2+][C@H](c1ccccc1C)[C@H](C)CC Predicted Property= [4.49219]
#
# Molecule 5852 Original Valid Molecule COc1cc(C)c(C[NH+]2CCC(N3CCCC3=O)CC2)cc1OC Original Property= [3.43699977]
# Molecule 5852 Reconstructed Valid molecule COc1cc(C)c(C[NH+]2CCN(C)CCCC(=O)CC2)cc1 Predicted Property= [1.7731707]
#
# Molecule 5930 Original Valid Molecule C[C@@H]1CN(C)c2ccccc2CN1C(=O)N[C@@H]1CC[NH+]2CCCC[C@H]12 Original Property= [4.75388086]
# Molecule 5930 Reconstructed Valid molecule C[C@@H]1CN(C)c2ccccc2CN1C(=O)N[C@@H]1CC[NH+]2CCCC[C@H]12 Predicted Property= [6.1355276]
#
# Molecule 5950 Original Valid Molecule CN(C)c1ccc([C@H](O)CNC(=O)CC2CCCCC2)cc1 Original Property= [2.50549665]
# Molecule 5950 Reconstructed Valid molecule CN(C)c1ccc([C@H](C)CNC(=O)CC2CCCCC2)cc1 Predicted Property= [3.0063403]
#
# Molecule 5960 Original Valid Molecule CSCC[C@@H](C)NC(=O)Nc1ccc(Cl)nc1 Original Property= [2.68322661]
# Molecule 5960 Reconstructed Valid molecule C#CC[C@@H](C)NC(=O)Nc1ccc(Cl)nc1 Predicted Property= [5.2365327]
#
# Molecule 5961 Original Valid Molecule Cc1ncccc1NC(=O)C(=O)NCC[NH+]1CCC(C)CC1 Original Property= [3.59314197]
# Molecule 5961 Reconstructed Valid molecule Cc1ncccc1NC(=O)C(=O)NCC[NH+]1CCC(C)CC1 Predicted Property= [1.763451]
#
# Molecule 6013 Original Valid Molecule Cc1cnc(CNS(=O)(=O)c2cc(C(F)(F)F)ccc2F)o1 Original Property= [2.5134081]
# Molecule 6013 Reconstructed Valid molecule Cc1cnc(CNS(=O)(=O)c2cc(C(F)(F)F)ccc2F)o1 Predicted Property= [1.5377004]
#
# Molecule 6020 Original Valid Molecule CCOCC[NH2+][C@H]1CCO[C@]2(CCSC2)C1 Original Property= [5.50267738]
# Molecule 6020 Reconstructed Valid molecule CCOCC[NH2+][C@H]1CCC[C@]2(CCSC2)C1C Predicted Property= [6.7060623]
#
# Molecule 6036 Original Valid Molecule Cc1cc2sc(NC(=O)CC(C)C)nc2cc1Cl Original Property= [2.12909957]
# Molecule 6036 Reconstructed Valid molecule Cc1cc2sc(NC(=O)CCCCCC)nc2cc1Cl Predicted Property= [1.6095208]
#
# Molecule 6058 Original Valid Molecule CS[C@H](C)c1cccc(NC(=O)c2cc(F)ccc2F)c1 Original Property= [2.51075412]
# Molecule 6058 Reconstructed Valid molecule CS[C@H](C)c1cccc(NC(=O)c2cc(F)ccc2F)c1 Predicted Property= [2.5172682]
#
# Molecule 6075 Original Valid Molecule NOCc1ccc([N+](=O)[O-])cc1Cl Original Property= [2.27337997]
# Molecule 6075 Reconstructed Valid molecule N#Cc1ccc([N+](=C)[C-])cc1Cl Predicted Property= [3.1670976]
#
# Molecule 6175 Original Valid Molecule C#CCOc1ccccc1/C=N/NC(=O)[C@@H](OC)c1ccccc1 Original Property= [2.74347099]
# Molecule 6175 Reconstructed Valid molecule C#CCOc1ccccc1/C=N/NC(=O)[C@@H](CC)c1ccccc1 Predicted Property= [1.6594129]
# /usr/local/lib/python3.7/site-packages/rdkit/Chem/Draw/IPythonConsole.py:192: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   % (maxMols))

# %%
print("Validity Percentage of Training Reconstructed Molecules", (len(mols_reconst_train_valid)/len(mols_reconst_train))*100, "%")
print("Validity Percentage of Testing Reconstructed Molecules", (len(mols_reconst_test_valid)/len(mols_reconst_test))*100,"%")
# Out:
# Validity Percentage of Training Reconstructed Molecules 4.025869037995149 %
# Validity Percentage of Testing Reconstructed Molecules 0.3232062055591467 %

# %% [markdown]
# # **Generating New Valid Molecules from Normal Distribution**

# %%
syntax_val_new={0:[], 1:[]}


smi_reconst_new=[]
smi_reconst_new_valid=[]

mols_reconst_new= []
mols_reconst_new_valid=[]

n_mol=100000

latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))

#Passing it to Decoder
reconst_sample = decoder.predict(latent_samples)
reconst_smi=reconst_sample.reshape(n_mol, mol_size_x, mol_size_y) 

for id, latent_mol in enumerate(reconst_smi):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_smi[id,:,:], axis=1)])
  smi = re.sub('!|E',"", smi)
  smi_reconst_new.append(smi)

  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_new.append(mol)
  if mol is None:
    syntax_val_new[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val_new[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid New Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)      
    except:
      print('Mol {} {}'.format(id+1, mol)) 

i=1
for item in syntax_val_new[1]:
  smi_reconst_new_valid.append(smi_reconst_new[item].rstrip('\n'))
  mols_reconst_new_valid.append(mols_reconst_new[item])
  print("New valid Molecule", i, smi_reconst_new[item], "Index=", item)
  i=i+1

print(len(mols_reconst_new_valid), "New Valid Molecules")
Draw.MolsToGridImage(mols_reconst_new_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# Mol 30013 <rdkit.Chem.rdchem.Mol object at 0x7fd2937d0f80>
# New valid Molecule 1 CC(C)n1Cc(NC(NO(CO))C2CccccOnCCC(C2))C1 Index= 5171
# New valid Molecule 2 NC[C@@H](C)NC(=O)c1ccc(B)cc1O Index= 23629
# New valid Molecule 3 O=C(C1Ccccccc(CC)C(=O)c1(CC(=O)N1C)(C)Cl)c1 Index= 30012
# New valid Molecule 4 COC(ccccCS2ccc(C(=O)cc2)c1C)cc1O Index= 37985
# New valid Molecule 5 C[C@H](CCCC=O)Nc1ccc(NC(C))N(C(=O)C1O) Index= 39736
# New valid Molecule 6 COC(cCcccc1C(=O)NCCCNC)CSCc2ccc2C1 Index= 48947
# New valid Molecule 7 CCc1ccc(CCCC(=O)NCCCcc2ccCc1cs2)C Index= 51264
# New valid Molecule 8 COc1cc(NNCC(=O)CCC(NS(=O)C2ccc1C2CCCCCO)=C) Index= 56515
# New valid Molecule 9 CCc1ccc(NC(=O)cc2c1(CCCNCC(N))S2C) Index= 68420
# New valid Molecule 10 Cc1ccc(C(CO)[CH+]2CCCn2)c2Cc(CO)cc2cc1 Index= 76472
# New valid Molecule 11 COc1cc(=CCC(C)CCCC)CCCCCC1OOC Index= 81367
# New valid Molecule 12 CCC(C[C@@H](CC)C(=O)c1ccccccc1)C Index= 85850
# 12 New Valid Molecules

# %% [markdown]
# # **Property Acceptance of Newly Generated Valid Molecules**

# %%
# Calculating mean and standard deviation of all property values on test data

SAS_mean_test= np.mean(y_test_property, axis=0)
SAS_std_test = np.std(y_test_property, axis=0)
print("SAS Property Value Range = ", SAS_mean_test,"+-", SAS_std_test )

# Predicting Properties of New Valid Molecules

if len(syntax_val_new[1])!=0:
  predicted_prop_samples=predictor.predict(latent_samples[syntax_val_new[1]])
  for ((id,item), val_mol_id) in zip(enumerate(predicted_prop_samples), syntax_val_new[1]):
    # print(id)
    a=predicted_prop_samples[id][0]<(SAS_mean_test+SAS_std_test)
    b=predicted_prop_samples[id][0]>=(SAS_mean_test-SAS_std_test)
    print("SAS Predicted Properties of molecule having index ", val_mol_id,"is", predicted_prop_samples[id])
    if (a & b):
      print("Mol having index {}, Property Validated".format(val_mol_id))    
    else:    
      print("Mol having index {}, Property Invalidated".format(val_mol_id)) 
else:
  print("No Valid Molecule Generated")
# Out:
# SAS Property Value Range =  [3.03445567] +- [0.83916364]
# SAS Predicted Properties of molecule having index  5171 is [2.4956763]
# Mol having index 5171, Property Validated
# SAS Predicted Properties of molecule having index  23629 is [4.8450403]
# Mol having index 23629, Property Invalidated
# SAS Predicted Properties of molecule having index  30012 is [3.584551]
# Mol having index 30012, Property Validated
# SAS Predicted Properties of molecule having index  37985 is [4.3212233]
# Mol having index 37985, Property Invalidated
# SAS Predicted Properties of molecule having index  39736 is [5.303538]
# Mol having index 39736, Property Invalidated
# SAS Predicted Properties of molecule having index  48947 is [4.315686]
# Mol having index 48947, Property Invalidated
# SAS Predicted Properties of molecule having index  51264 is [3.749359]
# Mol having index 51264, Property Validated
# SAS Predicted Properties of molecule having index  56515 is [5.1803985]
# Mol having index 56515, Property Invalidated
# SAS Predicted Properties of molecule having index  68420 is [2.2170005]
# Mol having index 68420, Property Validated
# SAS Predicted Properties of molecule having index  76472 is [3.2463434]
# Mol having index 76472, Property Validated
# SAS Predicted Properties of molecule having index  81367 is [2.9992895]
# Mol having index 81367, Property Validated
# SAS Predicted Properties of molecule having index  85850 is [6.908894]
# Mol having index 85850, Property Invalidated

# %%
# print(syntax_val_new[1])
# print(predicted_prop_samples.shape)
# print(predicted_prop_samples)
# print(type(predicted_prop_samples))
