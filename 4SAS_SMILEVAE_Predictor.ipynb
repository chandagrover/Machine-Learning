# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SAS_SMILEVAE_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# 10 tricks for a better Google Colab experience
# https://towardsdatascience.com/10-tips-for-a-better-google-colab-experience-33f8fe721b82
# %load_ext google.colab.data_table

# %%
# !sudo apt-get install software-properties-common
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test
# !sudo apt-get update
# !sudo apt-get install gcc-4.9
# !sudo apt-get upgrade libstdc++6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# software-properties-common is already the newest version (0.96.24.32.14).
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
#  Toolchain test builds; see https://wiki.ubuntu.com/ToolChain
#
#  More info: https://launchpad.net/~ubuntu-toolchain-r/+archive/ubuntu/test
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic InRelease
# Reading package lists... Done
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package gcc-4.9 is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'gcc-4.9' has no installation candidate
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libstdc++6 is already the newest version (10.1.0-2ubuntu1~18.04).
# Calculating upgrade... Done
# The following packages have been kept back:
#   lib32gcc1 lib32stdc++6 libcublas-dev libcublas10 libcudnn7 libcudnn7-dev
#   libnccl-dev libnccl2 linux-headers-generic
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.

# %%
# !pip install keras==2.2.4
# %tensorflow_version 1.x
import keras
import tensorflow as tf
print("Keras: %s"%keras.__version__)
print("Tensorflow: %s"%tf.__version__)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Keras: 2.3.1
# Tensorflow: 1.15.2

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-01-07 08:31:04--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2021-01-07 08:31:04--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package tornado conflicts for:
# rdkit -> matplotlib-base -> tornado
# tornado
# matplotlib-base -> tornado
#
# Package libblas conflicts for:
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# libblas
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# numpy -> libblas[version='>=3.8.0,<4.0a0']
# libcblas -> libblas==3.9.0=7_openblas
# numpy -> libcblas[version='>=3.8.0,<4.0a0'] -> libblas==3.9.0=7_openblas
# matplotlib-base -> numpy[version='>=1.16.5,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
# liblapack -> libblas==3.9.0=7_openblas
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> libblas[version='>=3.8.0,<4.0a0']
#
# Package jpeg conflicts for:
# rdkit -> pillow -> jpeg[version='>=9d,<10a']
# libtiff -> jpeg[version='>=9d,<10a']
# reportlab -> pillow[version='>=2.4.0'] -> jpeg[version='>=9d,<10a']
# matplotlib-base -> pillow[version='>=6.2.0'] -> jpeg[version='>=9d,<10a']
# pillow -> jpeg[version='>=9d,<10a']
# lcms2 -> jpeg[version='>=9d,<10a']
# jpeg
#
# Package kiwisolver conflicts for:
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# kiwisolver
# rdkit -> matplotlib-base -> kiwisolver[version='>=1.0.1']
#
# Package python conflicts for:
# idna==2.9=py_1 -> python
# tornado -> python_abi=3.7[build=*_cp37m] -> python=3.7
# matplotlib-base -> cycler[version='>=0.10'] -> python=3.7
# python==3.7.7=hcff3b4d_5
# urllib3==1.25.8=py37_0 -> idna[version='>=2.0.0'] -> python
# tornado -> python[version='>=3.7,<3.8.0a0']
# boost -> python[version='>=3.7,<3.8.0a0']
# kiwisolver -> python_abi=3.7[build=*_cp37m] -> python=3.7
# rdkit -> python[version='>=3.7,<3.8.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0']
# sqlalchemy -> python_abi=3.7[build=*_cp37m] -> python=3.7
# pycparser==2.20=py_0 -> python
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> tqdm -> python
# numpy -> python[version='>=3.7,<3.8.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# pandas -> python-dateutil[version='>=2.7.3'] -> python[version='3.7.*|>=3']
# cycler -> six -> python[version='>=3.7,<3.8.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0']
# pytz -> python[version='>=3']
# cryptography==2.9.2=py37h1ba5d50_0 -> idna -> python
# pillow -> olefile -> python=3.7
# pyparsing -> python
# pycairo -> python[version='>=3.7,<3.8.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0']
# pycairo -> python_abi=3.7[build=*_cp37m] -> python=3.7
# tqdm==4.46.0=py_0 -> python
# rdkit -> python_abi=3.7[build=*_cp37m] -> python=3.7
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0']
# python-dateutil -> python
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0']
# olefile -> python
# sqlalchemy -> python[version='>=3.7,<3.8.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0']
# numpy -> python_abi=3.7[build=*_cp37m] -> python=3.7
# python-dateutil -> six -> python[version='>=3.7,<3.8.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0']
# requests==2.23.0=py37_0 -> idna[version='>=2.5,<3'] -> python
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0']
# python_abi -> python=3.7
# kiwisolver -> python[version='>=3.7,<3.8.0a0']
# reportlab -> python_abi=3.7[build=*_cp37m] -> python=3.7
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0']
# boost -> python_abi=3.7[build=*_cp37m] -> python=3.7
# cffi==1.14.0=py37he30daa8_1 -> pycparser -> python
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0']
# cycler -> python
#
# Package freetype conflicts for:
# rdkit -> freetype[version='>=2.10.4,<3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> freetype[version='>=2.10.4,<3.0a0']
# reportlab -> freetype[version='>=2.10.4,<3.0a0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0']
# cairo -> freetype[version='>=2.10.4,<3.0a0']
# pillow -> freetype[version='>=2.10.4,<3.0a0']
# freetype
#
# Package _openmp_mutex conflicts for:
# cairo -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# lcms2 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# pillow -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# pixman -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# yaml==0.1.7=had09818_2 -> libgcc-ng[version='>=7.2.0'] -> _openmp_mutex[version='>=4.5']
# boost-cpp -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# numpy -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# rdkit -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# libiconv -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# pcre -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pandas -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-xproto -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# boost -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# pthread-stubs -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libsm -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# matplotlib-base -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# tornado -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# _openmp_mutex
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# zstd -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxau -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libglib -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libopenblas -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# bzip2 -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libice -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# jpeg -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libpng -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# reportlab -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-renderproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# kiwisolver -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# lz4-c -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-libxext -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libtiff -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# fontconfig -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# pycairo -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# libuuid -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# libxml2 -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# libxcb -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# icu -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# freetype -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# gettext -> libgcc-ng[version='>=9.3.0'] -> _openmp_mutex[version='>=4.5']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# libwebp-base -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
#
# Package readline conflicts for:
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python-dateutil -> python -> readline[version='>=8.0,<9.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python_abi -> python=3.7 -> readline[version='>=8.0,<9.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycparser==2.20=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# readline==8.0=h7b6447c_0
# tqdm==4.46.0=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# pyparsing -> python -> readline[version='>=8.0,<9.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# python==3.7.7=hcff3b4d_5 -> readline[version='>=8.0,<9.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# cycler -> python -> readline[version='>=8.0,<9.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pytz -> python[version='>=3'] -> readline[version='>=8.0,<9.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# olefile -> python -> readline[version='>=8.0,<9.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> readline[version='>=8.0,<9.0a0']
# idna==2.9=py_1 -> python -> readline[version='>=8.0,<9.0a0']
#
# Package icu conflicts for:
# fontconfig -> icu[version='>=68.1,<69.0a0']
# libxml2 -> icu[version='>=68.1,<69.0a0']
# cairo -> icu[version='>=68.1,<69.0a0']
# boost-cpp -> icu[version='>=68.1,<69.0a0']
# boost -> boost-cpp=1.74.0 -> icu[version='>=68.1,<69.0a0']
# icu
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> icu[version='>=68.1,<69.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> icu[version='>=68.1,<69.0a0']
#
# Package pytz conflicts for:
# pandas -> pytz[version='>=2017.2']
# rdkit -> pandas -> pytz[version='>=2017.2']
# pytz
#
# Package certifi conflicts for:
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> certifi
# wheel==0.34.2=py37_0 -> setuptools -> certifi[version='>=2016.9.26']
# requests==2.23.0=py37_0 -> certifi[version='>=2017.4.17']
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> certifi[version='>=2016.9.26|>=2017.4.17']
# rdkit -> matplotlib-base -> certifi[version='>=2020.06.20']
# certifi==2020.4.5.1=py37_0
# matplotlib-base -> setuptools -> certifi[version='>=2016.9.26']
# matplotlib-base -> certifi[version='>=2020.06.20']
# urllib3==1.25.8=py37_0 -> certifi
# setuptools==46.4.0=py37_0 -> certifi[version='>=2016.9.26']
# pip==20.0.2=py37_3 -> setuptools -> certifi[version='>=2016.9.26']
#
# Package xorg-libx11 conflicts for:
# xorg-libx11
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libx11
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libx11
# xorg-libxext -> xorg-libx11=1.6
# cairo -> xorg-libxext -> xorg-libx11=1.6
# cairo -> xorg-libx11
#
# Package cycler conflicts for:
# matplotlib-base -> cycler[version='>=0.10']
# rdkit -> matplotlib-base -> cycler[version='>=0.10']
# cycler
#
# Package libgcc-ng conflicts for:
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0']
# libuuid -> libgcc-ng[version='>=9.3.0']
# libopenblas -> libgcc-ng[version='>=9.3.0']
# xorg-renderproto -> libgcc-ng[version='>=7.3.0']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0']
# pyparsing -> python -> libgcc-ng[version='>=7.3.0']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# matplotlib-base -> libgcc-ng[version='>=7.5.0']
# pcre -> libgcc-ng[version='>=7.3.0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> libgcc-ng[version='>=7.3.0']
# libtiff -> jpeg[version='>=9d,<10a'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0']
# libglib -> libffi[version='>=3.3,<3.4.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# xorg-libxext -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0']
# libxml2 -> libgcc-ng[version='>=9.3.0']
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0']
# tqdm==4.46.0=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libice -> libgcc-ng[version='>=7.3.0']
# kiwisolver -> libgcc-ng[version='>=7.5.0']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> libgcc-ng[version='>=7.3.0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# lz4-c -> libgcc-ng[version='>=9.3.0']
# xorg-libsm -> libgcc-ng[version='>=7.3.0']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0']
# xorg-xproto -> libgcc-ng[version='>=9.3.0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# boost-cpp -> bzip2[version='>=1.0.8,<2.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libxcb -> pthread-stubs -> libgcc-ng[version='>=7.5.0']
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# gettext -> libffi[version='>=3.3,<3.4.0a0'] -> libgcc-ng[version='>=7.3.0']
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgcc-ng[version='>=9.3.0']
# zstd -> xz[version='>=5.2.5,<5.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# olefile -> python -> libgcc-ng[version='>=7.3.0']
# matplotlib-base -> numpy[version='>=1.16.5,<2.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# cairo -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# pycparser==2.20=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libx11 -> libxcb=1 -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libglib -> libgcc-ng[version='>=9.3.0']
# tornado -> libgcc-ng[version='>=7.5.0']
# sqlalchemy -> libgcc-ng[version='>=9.3.0']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# zstd -> libgcc-ng[version='>=9.3.0']
# bzip2 -> libgcc-ng[version='>=9.3.0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.5.0']
# icu -> libgcc-ng[version='>=7.5.0']
# pixman -> libgcc-ng[version='>=7.5.0']
# boost -> libgcc-ng[version='>=7.5.0']
# xorg-libsm -> libuuid[version='>=2.32.1,<3.0a0'] -> libgcc-ng[version='>=9.3.0']
# pthread-stubs -> libgcc-ng[version='>=7.5.0']
# reportlab -> libgcc-ng[version='>=9.3.0']
# pillow -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# pytz -> python[version='>=3'] -> libgcc-ng[version='>=7.3.0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0']
# libwebp-base -> libgcc-ng[version='>=7.5.0']
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> libgcc-ng[version='>=7.3.0']
# libiconv -> libgcc-ng[version='>=7.5.0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# libxml2 -> icu[version='>=68.1,<69.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libgcc-ng==9.1.0=hdf63c60_0
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0']
# pandas -> libgcc-ng[version='>=9.3.0']
# libtiff -> libgcc-ng[version='>=9.3.0']
# fontconfig -> libgcc-ng[version='>=9.3.0']
# lcms2 -> libgcc-ng[version='>=7.5.0']
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# jpeg -> libgcc-ng[version='>=7.5.0']
# idna==2.9=py_1 -> python -> libgcc-ng[version='>=7.3.0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# xorg-libxext -> libgcc-ng[version='>=7.3.0']
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0']
# boost-cpp -> libgcc-ng[version='>=7.5.0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0'] -> libgcc-ng[version='>=7.2.0']
# libpng -> libgcc-ng[version='>=7.5.0']
# cycler -> python -> libgcc-ng[version='>=7.3.0']
# freetype -> libgcc-ng[version='>=7.5.0']
# cairo -> libgcc-ng[version='>=9.3.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libgcc-ng[version='>=9.3.0']
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# python-dateutil -> python -> libgcc-ng[version='>=7.3.0']
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0']
# reportlab -> freetype[version='>=2.10.4,<3.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# pillow -> libgcc-ng[version='>=9.3.0']
# rdkit -> libgcc-ng[version='>=9.3.0']
# libxcb -> libgcc-ng[version='>=7.3.0']
# python_abi -> python=3.7 -> libgcc-ng[version='>=7.3.0']
# yaml==0.1.7=had09818_2 -> libgcc-ng[version='>=7.2.0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=9.3.0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# gettext -> libgcc-ng[version='>=9.3.0']
# xorg-libxau -> libgcc-ng[version='>=7.3.0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.3.0']
# numpy -> libgcc-ng[version='>=9.3.0']
# pycairo -> libgcc-ng[version='>=7.5.0']
#
# Package six conflicts for:
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> six[version='>=1.5.2']
# cryptography==2.9.2=py37h1ba5d50_0 -> six
# six==1.14.0=py37_0
# python-dateutil -> six
# matplotlib-base -> cycler[version='>=0.10'] -> six
# cycler -> six
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> six[version='>=1.5.2']
# pyopenssl==19.1.0=py37_0 -> six[version='>=1.5.2']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> six
# conda-package-handling==1.6.1=py37h7b6447c_0 -> six
# pandas -> python-dateutil[version='>=2.7.3'] -> six
#
# Package ncurses conflicts for:
# pandas -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# tqdm==4.46.0=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycparser==2.20=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# python==3.7.7=hcff3b4d_5 -> ncurses[version='>=6.2,<7.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyparsing -> python -> ncurses[version='>=6.2,<7.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cycler -> python -> ncurses[version='>=6.2,<7.0a0']
# olefile -> python -> ncurses[version='>=6.2,<7.0a0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pytz -> python[version='>=3'] -> ncurses[version='>=6.2,<7.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.7.7=hcff3b4d_5 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# libedit==3.1.20181209=hc058e9b_0 -> ncurses[version='>=6.1,<7.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.31.1=h62c20be_1 -> ncurses[version='>=6.2,<7.0a0']
# idna==2.9=py_1 -> python -> ncurses[version='>=6.2,<7.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python-dateutil -> python -> ncurses[version='>=6.2,<7.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python_abi -> python=3.7 -> ncurses[version='>=6.2,<7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.31.1=h62c20be_1 -> libedit[version='>=3.1.20181209,<3.2.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# ncurses==6.2=he6710b0_1
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> ncurses[version='>=6.2,<7.0a0']
#
# Package zlib conflicts for:
# cairo -> zlib[version='>=1.2.11,<1.3.0a0']
# zlib==1.2.11=h7b6447c_3
# tqdm==4.46.0=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python-dateutil -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pycparser==2.20=py_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# olefile -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pytz -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# reportlab -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python==3.7.7=hcff3b4d_5 -> zlib[version='>=1.2.11,<1.3.0a0']
# pyparsing -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite==3.31.1=h62c20be_1 -> zlib[version='>=1.2.11,<1.3.0a0']
# idna==2.9=py_1 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# cycler -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libglib -> zlib[version='>=1.2.11,<1.3.0a0']
# python_abi -> python=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tk==8.6.8=hbc83047_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package python_abi conflicts for:
# kiwisolver -> python_abi=3.7[build=*_cp37m]
# matplotlib-base -> python_abi=3.7[build=*_cp37m]
# pandas -> python_abi=3.7[build=*_cp37m]
# boost -> python_abi=3.7[build=*_cp37m]
# rdkit -> python_abi=3.7[build=*_cp37m]
# pillow -> python_abi=3.7[build=*_cp37m]
# numpy -> python_abi=3.7[build=*_cp37m]
# urllib3==1.25.8=py37_0 -> certifi -> python_abi=3.7[build=*_cp37m]
# tornado -> python_abi=3.7[build=*_cp37m]
# python_abi
# sqlalchemy -> python_abi=3.7[build=*_cp37m]
# pycairo -> python_abi=3.7[build=*_cp37m]
# requests==2.23.0=py37_0 -> certifi[version='>=2017.4.17'] -> python_abi=3.7[build=*_cp37m]
# reportlab -> python_abi=3.7[build=*_cp37m]
# setuptools==46.4.0=py37_0 -> certifi[version='>=2016.9.26'] -> python_abi=3.7[build=*_cp37m]
#
# Package _libgcc_mutex conflicts for:
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xorg-libxau -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# python==3.7.7=hcff3b4d_5 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xorg-libsm -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libgomp -> _libgcc_mutex==0.1=conda_forge
# libiconv -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# icu -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# boost -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# matplotlib-base -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# rdkit -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# _openmp_mutex -> _libgcc_mutex==0.1=conda_forge
# libglib -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# sqlite==3.31.1=h62c20be_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# kiwisolver -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# cryptography==2.9.2=py37h1ba5d50_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# cairo -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# cffi==1.14.0=py37he30daa8_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libxcb -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# _libgcc_mutex==0.1=main
# jpeg -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libopenblas -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# zstd -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# xorg-libice -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# pillow -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# openssl==1.1.1g=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# bzip2 -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# pycosat==0.6.3=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libedit==3.1.20181209=hc058e9b_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# numpy -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# xorg-xextproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# pandas -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# xorg-xproto -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# tk==8.6.8=hbc83047_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xorg-libxext -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# lz4-c -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# libffi==3.3=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libxml2 -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# libgcc-ng==9.1.0=hdf63c60_0 -> _libgcc_mutex=[build=main]
# xorg-renderproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libwebp-base -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# freetype -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# fontconfig -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# libtiff -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# boost-cpp -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libpng -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# pcre -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# reportlab -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# tornado -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# libuuid -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# pixman -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# lcms2 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# gettext -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex==0.1=conda_forge
# pthread-stubs -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# yaml==0.1.7=had09818_2 -> libgcc-ng[version='>=7.2.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# pycairo -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|conda_forge']
#
# Package zstd conflicts for:
# zstd
# boost -> boost-cpp=1.74.0 -> zstd[version='>=1.4.5,<1.5.0a0']
# libtiff -> zstd[version='>=1.4.5,<1.5.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.4.5,<1.5.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.4.5,<1.5.0a0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0']
#
# Package libgfortran-ng conflicts for:
# libopenblas -> libgfortran-ng
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgfortran-ng
# libgfortran-ng
#
# Package tk conflicts for:
# python-dateutil -> python -> tk[version='>=8.6.8,<8.7.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# reportlab -> pillow[version='>=2.4.0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python_abi -> python=3.7 -> tk[version='>=8.6.8,<8.7.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pycparser==2.20=py_0 -> python -> tk[version='>=8.6.8,<8.7.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# tk==8.6.8=hbc83047_0
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pytz -> python[version='>=3'] -> tk[version='>=8.6.8,<8.7.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pyparsing -> python -> tk[version='>=8.6.8,<8.7.0a0']
# python==3.7.7=hcff3b4d_5 -> tk[version='>=8.6.8,<8.7.0a0']
# cycler -> python -> tk[version='>=8.6.8,<8.7.0a0']
# rdkit -> matplotlib-base -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# olefile -> python -> tk[version='>=8.6.8,<8.7.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# matplotlib-base -> tk[version='>=8.6.10,<8.7.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# pillow -> tk[version='>=8.6.10,<8.7.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# idna==2.9=py_1 -> python -> tk[version='>=8.6.8,<8.7.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> tk[version='>=8.6.8,<8.7.0a0']
# tqdm==4.46.0=py_0 -> python -> tk[version='>=8.6.8,<8.7.0a0']
#
# Package sqlite conflicts for:
# pycparser==2.20=py_0 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# sqlite==3.31.1=h62c20be_1
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pytz -> python[version='>=3'] -> sqlite[version='>=3.31.1,<4.0a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pyparsing -> python -> sqlite[version='>=3.31.1,<4.0a0']
# python==3.7.7=hcff3b4d_5 -> sqlite[version='>=3.31.1,<4.0a0']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# cycler -> python -> sqlite[version='>=3.31.1,<4.0a0']
# olefile -> python -> sqlite[version='>=3.31.1,<4.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# idna==2.9=py_1 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# tqdm==4.46.0=py_0 -> python -> sqlite[version='>=3.31.1,<4.0a0']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# boost -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# python_abi -> python=3.7 -> sqlite[version='>=3.31.1,<4.0a0']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# python-dateutil -> python -> sqlite[version='>=3.31.1,<4.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.31.1,<4.0a0']
#
# Package liblapack conflicts for:
# numpy -> liblapack[version='>=3.8.0,<4.0a0']
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# matplotlib-base -> numpy[version='>=1.16.5,<2.0a0'] -> liblapack[version='>=3.8.0,<4.0a0']
# liblapack
#
# Package openssl conflicts for:
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> openssl[version='>=1.1.1g,<1.1.2a']
# idna==2.9=py_1 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# tqdm==4.46.0=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a']
# boost -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> openssl[version='>=1.1.1g,<1.1.2a']
# python-dateutil -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# olefile -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# openssl==1.1.1g=h7b6447c_0
# pycparser==2.20=py_0 -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pyparsing -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pytz -> python[version='>=3'] -> openssl[version='>=1.1.1g,<1.1.2a']
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# tornado -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a']
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# cycler -> python -> openssl[version='>=1.1.1g,<1.1.2a']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# python_abi -> python=3.7 -> openssl[version='>=1.1.1g,<1.1.2a']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='>=1.1.1g,<1.1.2a']
#
# Package libcblas conflicts for:
# numpy -> libcblas[version='>=3.8.0,<4.0a0']
# boost -> numpy[version='>=1.16.5,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# pandas -> numpy[version='>=1.16.6,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# libcblas
# rdkit -> numpy[version='>=1.16.5,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
# matplotlib-base -> numpy[version='>=1.16.5,<2.0a0'] -> libcblas[version='>=3.8.0,<4.0a0']
#
# Package xorg-libxext conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxext
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libxext
# xorg-libxext
# cairo -> xorg-libxext
#
# Package libffi conflicts for:
# ...
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> cryptography[version='>=1.3.4']
# cryptography==2.9.2=py37h1ba5d50_0
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8']
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4']
#
# Package libwebp-base conflicts for:
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> libwebp-base
# libtiff -> libwebp-base
# libwebp-base
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libwebp-base
#
# Package libglib conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> libglib[version='>=2.66.4,<3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libglib[version='>=2.66.4,<3.0a0']
# cairo -> libglib[version='>=2.66.4,<3.0a0']
# libglib
#
# Package pyparsing conflicts for:
# rdkit -> matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
# matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
# pyparsing
#
# Package xorg-xproto conflicts for:
# xorg-libx11 -> xorg-xproto
# xorg-libxext -> xorg-libx11=1.6 -> xorg-xproto
# xorg-xproto
# cairo -> xorg-libx11 -> xorg-xproto
#
# Package xorg-xextproto conflicts for:
# xorg-xextproto
# cairo -> xorg-libxext -> xorg-xextproto
# xorg-libxext -> xorg-xextproto
#
# Package ld_impl_linux-64 conflicts for:
# requests==2.23.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pysocks==1.7.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# certifi==2020.4.5.1=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# conda==4.8.3=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# tqdm==4.46.0=py_0 -> python -> ld_impl_linux-64
# boost -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# chardet==3.0.4=py37_1003 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# python-dateutil -> python -> ld_impl_linux-64
# urllib3==1.25.8=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# ld_impl_linux-64==2.33.1=h53a641e_7
# pycparser==2.20=py_0 -> python -> ld_impl_linux-64
# six==1.14.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# setuptools==46.4.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# python==3.7.7=hcff3b4d_5 -> ld_impl_linux-64
# pytz -> python[version='>=3'] -> ld_impl_linux-64
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# cycler -> python -> ld_impl_linux-64
# olefile -> python -> ld_impl_linux-64
# pillow -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# rdkit -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# tornado -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pip==20.0.2=py37_3 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pyparsing -> python -> ld_impl_linux-64
# pycairo -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# conda-package-handling==1.6.1=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# reportlab -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# idna==2.9=py_1 -> python -> ld_impl_linux-64
# pyopenssl==19.1.0=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# cryptography==2.9.2=py37h1ba5d50_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# cffi==1.14.0=py37he30daa8_1 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# wheel==0.34.2=py37_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# python_abi -> python=3.7 -> ld_impl_linux-64
# numpy -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pycosat==0.6.3=py37h7b6447c_0 -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# pandas -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> ld_impl_linux-64
#
# Package xorg-libsm conflicts for:
# xorg-libsm
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libsm
# cairo -> xorg-libsm
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libsm
#
# Package setuptools conflicts for:
# rdkit -> matplotlib-base -> setuptools
# pip==20.0.2=py37_3 -> setuptools
# wheel==0.34.2=py37_0 -> setuptools
# matplotlib-base -> setuptools
# conda==4.8.3=py37_0 -> setuptools[version='>=31.0.1']
# setuptools==46.4.0=py37_0
#
# Package libstdcxx-ng conflicts for:
# zstd -> libstdcxx-ng[version='>=9.3.0']
# libstdcxx-ng==9.1.0=hdf63c60_0
# gettext -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# cairo -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0|>=9.3.0']
# fontconfig -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# icu -> libstdcxx-ng[version='>=7.5.0']
# pcre -> libstdcxx-ng[version='>=7.3.0']
# ncurses==6.2=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# libxml2 -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# lz4-c -> libstdcxx-ng[version='>=9.3.0']
# pandas -> libstdcxx-ng[version='>=9.3.0']
# libtiff -> libstdcxx-ng[version='>=9.3.0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# sqlite==3.31.1=h62c20be_1 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libglib -> libstdcxx-ng[version='>=9.3.0']
# libglib -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# boost-cpp -> libstdcxx-ng[version='>=7.5.0']
# python==3.7.7=hcff3b4d_5 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# kiwisolver -> libstdcxx-ng[version='>=7.5.0']
# cffi==1.14.0=py37he30daa8_1 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# libedit==3.1.20181209=hc058e9b_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# libffi==3.3=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# rdkit -> libstdcxx-ng[version='>=9.3.0']
# boost -> libstdcxx-ng[version='>=7.5.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.5.0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
#
# Package pillow conflicts for:
# pillow
# reportlab -> pillow[version='>=2.4.0']
# rdkit -> matplotlib-base -> pillow[version='>=2.4.0|>=6.2.0']
# rdkit -> pillow
# matplotlib-base -> pillow[version='>=6.2.0']
#
# Package numpy conflicts for:
# pandas -> numpy[version='>=1.16.6,<2.0a0']
# rdkit -> numpy[version='>=1.16.5,<2.0a0']
# rdkit -> pandas -> numpy[version='>=1.16.6,<2.0a0']
# numpy
# boost -> numpy[version='>=1.16.5,<2.0a0']
# matplotlib-base -> numpy[version='>=1.16.5,<2.0a0']
#
# Package libedit conflicts for:
# libedit==3.1.20181209=hc058e9b_0
# python==3.7.7=hcff3b4d_5 -> sqlite[version='>=3.31.1,<4.0a0'] -> libedit[version='>=3.1.20181209,<3.2.0a0']
# sqlite==3.31.1=h62c20be_1 -> libedit[version='>=3.1.20181209,<3.2.0a0']
#
# Package pysocks conflicts for:
# pysocks==1.7.1=py37_0
# urllib3==1.25.8=py37_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package pycparser conflicts for:
# cryptography==2.9.2=py37h1ba5d50_0 -> cffi -> pycparser
# cffi==1.14.0=py37he30daa8_1 -> pycparser
# pycparser==2.20=py_0
#
# Package libgfortran5 conflicts for:
# libgfortran5
# libopenblas -> libgfortran5[version='>=9.3.0']
# libopenblas -> libgfortran-ng -> libgfortran5=9.3.0
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgfortran5[version='>=9.3.0']
# libgfortran-ng -> libgfortran5=9.3.0
#
# Package reportlab conflicts for:
# rdkit -> reportlab
# reportlab
#
# Package pcre conflicts for:
# libglib -> pcre[version='>=8.44,<9.0a0']
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> pcre[version='>=8.44,<9.0a0']
# pcre
#
# Package gettext conflicts for:
# gettext
# libglib -> gettext[version='>=0.19.8.1,<1.0a0']
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> gettext[version='>=0.19.8.1,<1.0a0']
#
# Package wheel conflicts for:
# pip==20.0.2=py37_3 -> wheel
# wheel==0.34.2=py37_0
#
# Package cairo conflicts for:
# cairo
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0']
#
# Package libpng conflicts for:
# fontconfig -> libpng[version='>=1.6.37,<1.7.0a0']
# pillow -> freetype[version='>=2.10.4,<3.0a0'] -> libpng[version='>=1.6.37,<1.7.0a0']
# cairo -> libpng[version='>=1.6.37,<1.7.0a0']
# libpng
# reportlab -> freetype[version='>=2.10.4,<3.0a0'] -> libpng[version='>=1.6.37,<1.7.0a0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0'] -> libpng[version='>=1.6.37,<1.7.0a0']
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> libpng[version='>=1.6.37,<1.7.0a0']
# freetype -> libpng[version='>=1.6.37,<1.7.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> libpng[version='>=1.6.37,<1.7.0a0']
#
# Package xorg-kbproto conflicts for:
# xorg-kbproto
# xorg-libx11 -> xorg-kbproto
# cairo -> xorg-libx11 -> xorg-kbproto
# xorg-libxext -> xorg-libx11=1.6 -> xorg-kbproto
#
# Package pandas conflicts for:
# pandas
# rdkit -> pandas
#
# Package idna conflicts for:
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> idna
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> idna
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> idna[version='>=2.0.0']
# cryptography==2.9.2=py37h1ba5d50_0 -> idna
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> idna[version='>=2.5,<3']
# idna==2.9=py_1
# urllib3==1.25.8=py37_0 -> idna[version='>=2.0.0']
# requests==2.23.0=py37_0 -> idna[version='>=2.5,<3']
#
# Package conda-package-handling conflicts for:
# conda-package-handling==1.6.1=py37h7b6447c_0
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0']
#
# Package requests conflicts for:
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3']
# requests==2.23.0=py37_0
#
# Package pthread-stubs conflicts for:
# libxcb -> pthread-stubs
# pthread-stubs
# xorg-libx11 -> libxcb=1 -> pthread-stubs
# cairo -> libxcb -> pthread-stubs
#
# Package libgomp conflicts for:
# _openmp_mutex -> libgomp[version='>=7.5.0']
# libgomp
#
# Package bzip2 conflicts for:
# boost-cpp -> bzip2[version='>=1.0.8,<2.0a0']
# boost -> boost-cpp=1.74.0 -> bzip2[version='>=1.0.8,<2.0a0']
# bzip2
#
# Package pycosat conflicts for:
# conda==4.8.3=py37_0 -> pycosat[version='>=0.6.3']
# pycosat==0.6.3=py37h7b6447c_0
#
# Package libopenblas conflicts for:
# libopenblas
# numpy -> libblas[version='>=3.8.0,<4.0a0'] -> libopenblas[version='>=0.3.12,<0.3.13.0a0|>=0.3.12,<1.0a0']
# liblapack -> libblas==3.9.0=7_openblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0|>=0.3.12,<1.0a0']
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0|>=0.3.12,<1.0a0']
# libcblas -> libblas==3.9.0=7_openblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0|>=0.3.12,<1.0a0']
#
# Package pixman conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> pixman[version='>=0.40.0,<1.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> pixman[version='>=0.40.0,<1.0a0']
# cairo -> pixman[version='>=0.40.0,<1.0a0']
# pixman
#
# Package yaml conflicts for:
# ruamel_yaml==0.15.87=py37h7b6447c_0 -> yaml[version='>=0.1.7,<0.2.0a0']
# conda==4.8.3=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16'] -> yaml[version='>=0.1.7,<0.2.0a0']
# yaml==0.1.7=had09818_2
#
# Package lcms2 conflicts for:
# reportlab -> pillow[version='>=2.4.0'] -> lcms2[version='>=2.11,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.11,<3.0a0']
# pillow -> lcms2[version='>=2.11,<3.0a0']
# rdkit -> pillow -> lcms2[version='>=2.11,<3.0a0']
# lcms2
#
# Package libtiff conflicts for:
# reportlab -> pillow[version='>=2.4.0'] -> libtiff[version='>=4.1.0,<5.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0']
# rdkit -> pillow -> libtiff[version='>=4.1.0,<5.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> libtiff[version='>=4.1.0,<5.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0']
# libtiff
#
# Package urllib3 conflicts for:
# requests==2.23.0=py37_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
# urllib3==1.25.8=py37_0
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
#
# Package libiconv conflicts for:
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libiconv[version='>=1.16,<1.17.0a0']
# libglib -> libiconv[version='>=1.16,<1.17.0a0']
# libiconv
# cairo -> libglib[version='>=2.66.4,<3.0a0'] -> libiconv[version='>=1.16,<1.17.0a0']
# libxml2 -> libiconv[version='>=1.16,<1.17.0a0']
#
# Package ca-certificates conflicts for:
# ca-certificates==2020.1.1=0
# openssl==1.1.1g=h7b6447c_0 -> ca-certificates
# python==3.7.7=hcff3b4d_5 -> openssl[version='>=1.1.1g,<1.1.2a'] -> ca-certificates
# cryptography==2.9.2=py37h1ba5d50_0 -> openssl[version='>=1.1.1g,<1.1.2a'] -> ca-certificates
#
# Package boost conflicts for:
# rdkit -> boost[version='>=1.74.0,<1.74.1.0a0']
# boost
#
# Package libuuid conflicts for:
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libuuid[version='>=2.32.1,<3.0a0']
# fontconfig -> libuuid[version='>=2.32.1,<3.0a0']
# libuuid
# xorg-libsm -> libuuid[version='>=2.32.1,<3.0a0']
#
# Package cffi conflicts for:
# cffi==1.14.0=py37he30daa8_1
# urllib3==1.25.8=py37_0 -> cryptography[version='>=1.3.4'] -> cffi
# pyopenssl==19.1.0=py37_0 -> cryptography[version='>=2.8'] -> cffi
# cryptography==2.9.2=py37h1ba5d50_0 -> cffi
#
# Package xorg-libice conflicts for:
# xorg-libice
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libice
# xorg-libsm -> xorg-libice=1.0
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> xorg-libice
# cairo -> xorg-libice
# cairo -> xorg-libsm -> xorg-libice=1.0
#
# Package xorg-renderproto conflicts for:
# cairo -> xorg-libxrender -> xorg-renderproto
# xorg-renderproto
#
# Package python-dateutil conflicts for:
# python-dateutil
# pandas -> python-dateutil[version='>=2.7.3']
# matplotlib-base -> python-dateutil[version='>=2.1']
# rdkit -> matplotlib-base -> python-dateutil[version='>=2.1|>=2.7.3']
#
# Package fontconfig conflicts for:
# rdkit -> cairo[version='>=1.16.0,<1.17.0a0'] -> fontconfig[version='>=2.13.1,<3.0a0']
# pycairo -> cairo[version='>=1.16.0,<1.17.0a0'] -> fontconfig[version='>=2.13.1,<3.0a0']
# fontconfig
# cairo -> fontconfig[version='>=2.13.1,<3.0a0']
#
# Package ruamel_yaml conflicts for:
# conda==4.8.3=py37_0 -> ruamel_yaml[version='>=0.11.14,<0.16']
# ruamel_yaml==0.15.87=py37h7b6447c_0
#
# Package xorg-libxau conflicts for:
# xorg-libxau
# xorg-libx11 -> libxcb=1 -> xorg-libxau
# cairo -> libxcb -> xorg-libxau
# libxcb -> xorg-libxau
#
# Package olefile conflicts for:
# pillow -> olefile
# reportlab -> pillow[version='>=2.4.0'] -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
# rdkit -> pillow -> olefile
# olefile
#
# Package xorg-libxdmcp conflicts for:
# libxcb -> xorg-libxdmcp
# xorg-libx11 -> libxcb=1 -> xorg-libxdmcp
# cairo -> libxcb -> xorg-libxdmcp
# xorg-libxdmcp
#
# Package chardet conflicts for:
# chardet==3.0.4=py37_1003
# conda==4.8.3=py37_0 -> requests[version='>=2.18.4,<3'] -> chardet[version='>=3.0.2,<4']
# requests==2.23.0=py37_0 -> chardet[version='>=3.0.2,<4']
#
# Package sqlalchemy conflicts for:
# rdkit -> sqlalchemy
# sqlalchemy
#
# Package lz4-c conflicts for:
# zstd -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# lz4-c
# libtiff -> zstd[version='>=1.4.5,<1.5.0a0'] -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
# boost-cpp -> zstd[version='>=1.4.5,<1.5.0a0'] -> lz4-c[version='>=1.9.3,<1.9.4.0a0']
#
# Package tqdm conflicts for:
# tqdm==4.46.0=py_0
# conda==4.8.3=py37_0 -> conda-package-handling[version='>=1.3.0'] -> tqdm
# conda-package-handling==1.6.1=py37h7b6447c_0 -> tqdm
#
# Package libxml2 conflicts for:
# libxml2
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0']
#
# Package matplotlib-base conflicts for:
# rdkit -> matplotlib-base
# matplotlib-base
#
# Package pycairo conflicts for:
# pycairo
# rdkit -> pycairoThe following specifications were found to be incompatible with your CUDA driver:
#
#   - feature:/linux-64::__cuda==11.2=0
#   - feature:|@/linux-64::__cuda==11.2=0
#
# Your installed CUDA driver is: 11.2
#
#
#
# real	0m32.377s
# user	0m40.099s
# sys	0m5.334s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# real	0m8.527s
# user	0m7.710s
# sys	0m0.871s

# %%
# !strings /usr/lib/x86_64-linux-gnu/libstdc++.so.6 | grep GLIBCXX

# %%
# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# RDKIT Imports
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# FOR VAE Architecture 
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import mse, binary_crossentropy
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
print("RDKit: %s"%rdkit.__version__)
# Checking if GPU is enabled or not
tf.test.gpu_device_name()
# Out:
# RDKit: 2020.09.3
# '/device:GPU:0'

# %% [markdown]
# # **Data Fetching**

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/drive')
WEIGHTS_FOLDER = 'sample_data/weights/'
import csv
smifile ='/drive/My Drive/ZINC/Data/ZINC_Data/SMILEWithProp.csv'      #"sample_data/SMILEWithoutProp.csv"
df = pd.read_csv(smifile, delimiter = ",", header='infer', encoding='utf-8')
# smifile ='/drive/My Drive/ZINC/Data/ZINC_Data/AAAA.smi'      
# df = pd.read_csv(smifile, delimiter = " ", header='infer', encoding='utf-8')
df.smiles = df.smiles.replace('\n','', regex=True)
data= pd.DataFrame(df[df['smiles'].str.len()<60])
data=data.reset_index(drop=True)
NUM_SMILES = len(data)
print(NUM_SMILES)
data.head()
# Out:
# Mounted at /drive
# 7732
#                                               smiles  ...       SAS
# 0            CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1  ...  2.084095
# 1       C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
# print(type(data.smiles.items))
# data= data[data['smiles'].str.len()<60]
# print(data.smiles.count())
print(len(data))
# Out:
# 7732

# %%
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print("Training data shape", smiles_train.shape)
print("Testing Data shape", smiles_test.shape)
print("Total Data Points", NUM_SMILES)
# Out:
# Training data shape (6185, 4)
# Testing Data shape (1547, 4)
# Total Data Points 7732

# %%
# logP_train = smiles_train['logP']
# logP_test = smiles_test['logP']

# qed_train=smiles_train['qed']
# qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([SAS_train])   #logP_train, qed_train, SAS_train
test= np.array([SAS_test])             #logP_test, qed_test, SAS_test

y_train_property=train.transpose()
y_test_property=test.transpose()
#Labels for the Smiles String. We will deal with three properties values.
print("Training Data Property shape", y_train_property.shape)
print("Testing Data Property Shape", y_test_property.shape)
# print(SAS_train[1])
# Out:
# Training Data Property shape (6185, 1)
# Testing Data Property Shape (1547, 1)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(int_to_char)
print(len(charset), embed)
# print(embed)
# Out:
# {0: '#', 1: '5', 2: 'P', 3: 'l', 4: '=', 5: '+', 6: '4', 7: '-', 8: 'B', 9: 'F', 10: 'O', 11: 'o', 12: 'H', 13: '3', 14: '\\', 15: 'c', 16: 'N', 17: 'r', 18: 'C', 19: '2', 20: ')', 21: '[', 22: '1', 23: 's', 24: 'E', 25: '(', 26: 'S', 27: '!', 28: '/', 29: 'I', 30: ']', 31: 'n', 32: '@'}
# 33 61

# %%
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        # print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
print(X_train.shape)
print(X_test.shape)
# Out:
# (6185, 61, 33)
# (1547, 61, 33)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=600
print("Molecule Index=", idx,"\tLength =",len(smiles_train['smiles'][idx]),"\tSmile=", (smiles_train['smiles'][idx]))
mol = Chem.MolFromSmiles(smiles_train['smiles'][idx])
mol
# Out:
# Molecule Index= 600 	Length = 48 	Smile= CN(C)C(=O)[C@@H](Sc1nnc2n(C)c3ccccc3n12)c1ccccc1

# %%
# Going back from vectorized form back to a readable string
smi="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
smi = re.sub('[!E]', '', smi)
print(len(smi))
print(smi)
mol = Chem.MolFromSmiles(smi)
mol
# Out:
# 48
# CN(C)C(=O)[C@@H](Sc1nnc2n(C)c3ccccc3n12)c1ccccc1

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print(orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# 2013

# %% [markdown]
# # **VAE**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=50# Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(1, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# ### **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input

  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  vae_output = vae_decoder(vae_encoder_output)

  # # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE_with_Predictor')
# VAE Model without Property Predictor
  # vae_with_predictor = Model(vae_input, vae_output, name='VAE_without_Predictor')



  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### **VAE Loss Function**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
  kl_weight=0.5
  reconst_weight=0.5
    
  # vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  vae_loss_val=kl_weight * kl_loss + reconst_weight * reconstruction_loss
  return vae_loss_val

# %% [markdown]
# **Plotting all models**

# %%
# Plot the Encoder Model
plot_model(encoder, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# #Plot the Predictor Model
plot_model(predictor, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='/drive/My Drive/ZINC/Models/OnlySAS/Diagram/smilesvae_with_SASpredictor.png', show_shapes=True, show_layer_names=True, expand_nested=True)   #, expand_nested=False

# %% [markdown]
# **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "/drive/My Drive/ZINC/Models/OnlySAS/Weights/train_ckpt/cp.ckpt"
new_check_path="/drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor{epoch:02d}-{val_loss:.2f}.h5"           #'VAE_Predictor{epoch:02d}.h5'
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=new_check_path, verbose=1, save_weights_only=False, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(new_check_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **Training or Loading the VAE Model**

# %%
pre_trained=False
epochs=100
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[3.0, 1.0]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )  
      vae_predictor.save(new_check_path)
    else:
      vae_predictor.load_weights(new_check_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback]) 
      vae_predictor.save(new_check_path)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 6185 samples, validate on 1547 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 259.01575, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor01-259.02.h5
# 6185/6185 - 3s - loss: 343.1476 - decoder_loss: 113.7362 - predictor_loss: 1.6177 - val_loss: 259.0157 - val_decoder_loss: 86.2136 - val_predictor_loss: 0.5118
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 259.01575 to 243.86508, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor02-243.87.h5
# 6185/6185 - 1s - loss: 250.4736 - decoder_loss: 83.3481 - predictor_loss: 0.3914 - val_loss: 243.8651 - val_decoder_loss: 81.2861 - val_predictor_loss: 0.3783
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 243.86508 to 230.53189, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor03-230.53.h5
# 6185/6185 - 1s - loss: 235.6951 - decoder_loss: 78.4466 - predictor_loss: 0.3330 - val_loss: 230.5319 - val_decoder_loss: 76.7037 - val_predictor_loss: 0.3112
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 230.53189 to 221.42500, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor04-221.43.h5
# 6185/6185 - 1s - loss: 224.0633 - decoder_loss: 74.5685 - predictor_loss: 0.2885 - val_loss: 221.4250 - val_decoder_loss: 73.6787 - val_predictor_loss: 0.2832
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 221.42500 to 215.03632, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor05-215.04.h5
# 6185/6185 - 1s - loss: 214.7810 - decoder_loss: 71.5043 - predictor_loss: 0.2500 - val_loss: 215.0363 - val_decoder_loss: 71.4521 - val_predictor_loss: 0.2742
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 215.03632 to 209.03790, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor06-209.04.h5
# 6185/6185 - 1s - loss: 207.1723 - decoder_loss: 68.9586 - predictor_loss: 0.2320 - val_loss: 209.0379 - val_decoder_loss: 69.5285 - val_predictor_loss: 0.2668
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 209.03790 to 204.61564, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor07-204.62.h5
# 6185/6185 - 1s - loss: 200.8274 - decoder_loss: 66.8941 - predictor_loss: 0.2145 - val_loss: 204.6156 - val_decoder_loss: 68.0977 - val_predictor_loss: 0.2547
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 204.61564 to 200.67624, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor08-200.68.h5
# 6185/6185 - 1s - loss: 195.6688 - decoder_loss: 65.1496 - predictor_loss: 0.1975 - val_loss: 200.6762 - val_decoder_loss: 66.7743 - val_predictor_loss: 0.2594
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 200.67624 to 198.30014, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor09-198.30.h5
# 6185/6185 - 1s - loss: 191.2912 - decoder_loss: 63.6949 - predictor_loss: 0.1829 - val_loss: 198.3001 - val_decoder_loss: 65.9577 - val_predictor_loss: 0.2497
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 198.30014 to 196.08796, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor10-196.09.h5
# 6185/6185 - 1s - loss: 187.5342 - decoder_loss: 62.4590 - predictor_loss: 0.1797 - val_loss: 196.0880 - val_decoder_loss: 65.2483 - val_predictor_loss: 0.2414
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 196.08796 to 194.43484, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor11-194.43.h5
# 6185/6185 - 2s - loss: 184.4259 - decoder_loss: 61.4273 - predictor_loss: 0.1749 - val_loss: 194.4348 - val_decoder_loss: 64.7384 - val_predictor_loss: 0.2604
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 194.43484 to 193.11558, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor12-193.12.h5
# 6185/6185 - 1s - loss: 181.1336 - decoder_loss: 60.3480 - predictor_loss: 0.1652 - val_loss: 193.1156 - val_decoder_loss: 64.3023 - val_predictor_loss: 0.2496
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 193.11558 to 191.14350, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor13-191.14.h5
# 6185/6185 - 1s - loss: 178.3676 - decoder_loss: 59.4101 - predictor_loss: 0.1569 - val_loss: 191.1435 - val_decoder_loss: 63.6928 - val_predictor_loss: 0.2460
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 191.14350 to 190.93881, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor14-190.94.h5
# 6185/6185 - 1s - loss: 176.0349 - decoder_loss: 58.6274 - predictor_loss: 0.1469 - val_loss: 190.9388 - val_decoder_loss: 63.5283 - val_predictor_loss: 0.2427
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 190.93881 to 189.34948, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor15-189.35.h5
# 6185/6185 - 1s - loss: 173.5763 - decoder_loss: 57.8225 - predictor_loss: 0.1447 - val_loss: 189.3495 - val_decoder_loss: 63.1096 - val_predictor_loss: 0.2285
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 189.34948 to 189.27102, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor16-189.27.h5
# 6185/6185 - 1s - loss: 171.6670 - decoder_loss: 57.1785 - predictor_loss: 0.1410 - val_loss: 189.2710 - val_decoder_loss: 62.9922 - val_predictor_loss: 0.2475
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 189.27102 to 187.45967, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor17-187.46.h5
# 6185/6185 - 1s - loss: 169.6285 - decoder_loss: 56.4842 - predictor_loss: 0.1341 - val_loss: 187.4597 - val_decoder_loss: 62.4479 - val_predictor_loss: 0.2415
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 187.45967 to 186.69573, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor18-186.70.h5
# 6185/6185 - 1s - loss: 167.3810 - decoder_loss: 55.7552 - predictor_loss: 0.1356 - val_loss: 186.6957 - val_decoder_loss: 62.1653 - val_predictor_loss: 0.2446
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 186.69573 to 186.26237, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor19-186.26.h5
# 6185/6185 - 1s - loss: 165.5950 - decoder_loss: 55.1585 - predictor_loss: 0.1300 - val_loss: 186.2624 - val_decoder_loss: 61.9197 - val_predictor_loss: 0.2405
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 186.26237 to 185.22284, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor20-185.22.h5
# 6185/6185 - 1s - loss: 163.7558 - decoder_loss: 54.5131 - predictor_loss: 0.1292 - val_loss: 185.2228 - val_decoder_loss: 61.6757 - val_predictor_loss: 0.2193
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 185.22284 to 185.17334, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor21-185.17.h5
# 6185/6185 - 1s - loss: 161.9453 - decoder_loss: 53.9601 - predictor_loss: 0.1252 - val_loss: 185.1733 - val_decoder_loss: 61.6194 - val_predictor_loss: 0.2335
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 185.17334 to 184.84597, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor22-184.85.h5
# 6185/6185 - 1s - loss: 160.1580 - decoder_loss: 53.3619 - predictor_loss: 0.1223 - val_loss: 184.8460 - val_decoder_loss: 61.5112 - val_predictor_loss: 0.2185
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 184.84597 to 184.71551, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor23-184.72.h5
# 6185/6185 - 1s - loss: 158.8824 - decoder_loss: 52.9145 - predictor_loss: 0.1151 - val_loss: 184.7155 - val_decoder_loss: 61.4249 - val_predictor_loss: 0.2078
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 184.71551
# 6185/6185 - 1s - loss: 157.3368 - decoder_loss: 52.4071 - predictor_loss: 0.1117 - val_loss: 184.7676 - val_decoder_loss: 61.5935 - val_predictor_loss: 0.2081
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 184.71551
# 6185/6185 - 1s - loss: 156.0056 - decoder_loss: 51.9622 - predictor_loss: 0.1112 - val_loss: 185.5080 - val_decoder_loss: 61.7839 - val_predictor_loss: 0.2076
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 184.71551
# 6185/6185 - 1s - loss: 154.9042 - decoder_loss: 51.5823 - predictor_loss: 0.1113 - val_loss: 185.2089 - val_decoder_loss: 61.6033 - val_predictor_loss: 0.2125
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 184.71551
# 6185/6185 - 1s - loss: 153.4665 - decoder_loss: 51.1385 - predictor_loss: 0.1035 - val_loss: 184.7641 - val_decoder_loss: 61.5506 - val_predictor_loss: 0.1997
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 184.71551 to 184.68362, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor28-184.68.h5
# 6185/6185 - 1s - loss: 152.4212 - decoder_loss: 50.7768 - predictor_loss: 0.1035 - val_loss: 184.6836 - val_decoder_loss: 61.5309 - val_predictor_loss: 0.2035
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 184.68362
# 6185/6185 - 1s - loss: 151.1427 - decoder_loss: 50.3448 - predictor_loss: 0.1025 - val_loss: 184.8665 - val_decoder_loss: 61.4403 - val_predictor_loss: 0.2233
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 184.68362 to 184.55568, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor30-184.56.h5
# 6185/6185 - 1s - loss: 150.0336 - decoder_loss: 49.9632 - predictor_loss: 0.1045 - val_loss: 184.5557 - val_decoder_loss: 61.4209 - val_predictor_loss: 0.1994
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 184.55568 to 184.39804, saving model to /drive/My Drive/ZINC/Models/OnlySAS/Weights/VAE_With_SASPredictor31-184.40.h5
# 6185/6185 - 1s - loss: 148.5514 - decoder_loss: 49.4739 - predictor_loss: 0.1010 - val_loss: 184.3980 - val_decoder_loss: 61.4342 - val_predictor_loss: 0.1970
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 147.8242 - decoder_loss: 49.2492 - predictor_loss: 0.0984 - val_loss: 184.9338 - val_decoder_loss: 61.5723 - val_predictor_loss: 0.1901
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 146.8094 - decoder_loss: 48.8982 - predictor_loss: 0.1012 - val_loss: 185.0549 - val_decoder_loss: 61.4930 - val_predictor_loss: 0.1914
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 145.9734 - decoder_loss: 48.6169 - predictor_loss: 0.0971 - val_loss: 185.8762 - val_decoder_loss: 61.8902 - val_predictor_loss: 0.1877
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 144.6219 - decoder_loss: 48.1697 - predictor_loss: 0.0964 - val_loss: 186.2716 - val_decoder_loss: 62.2003 - val_predictor_loss: 0.1884
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 144.2624 - decoder_loss: 48.0636 - predictor_loss: 0.0952 - val_loss: 187.2365 - val_decoder_loss: 62.3780 - val_predictor_loss: 0.1932
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 143.2773 - decoder_loss: 47.7217 - predictor_loss: 0.0986 - val_loss: 186.0993 - val_decoder_loss: 61.8919 - val_predictor_loss: 0.1869
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 142.5920 - decoder_loss: 47.5241 - predictor_loss: 0.0948 - val_loss: 187.0786 - val_decoder_loss: 62.3586 - val_predictor_loss: 0.1915
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 141.6776 - decoder_loss: 47.1961 - predictor_loss: 0.0912 - val_loss: 186.1483 - val_decoder_loss: 62.0308 - val_predictor_loss: 0.1941
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 141.2078 - decoder_loss: 47.0225 - predictor_loss: 0.0920 - val_loss: 187.4077 - val_decoder_loss: 62.2173 - val_predictor_loss: 0.1992
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 140.1855 - decoder_loss: 46.6824 - predictor_loss: 0.0932 - val_loss: 187.6460 - val_decoder_loss: 62.4769 - val_predictor_loss: 0.1966
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 139.5865 - decoder_loss: 46.4979 - predictor_loss: 0.0895 - val_loss: 187.2968 - val_decoder_loss: 62.4621 - val_predictor_loss: 0.1878
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 138.7003 - decoder_loss: 46.2077 - predictor_loss: 0.0914 - val_loss: 187.3442 - val_decoder_loss: 62.2533 - val_predictor_loss: 0.2003
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 138.3901 - decoder_loss: 46.1024 - predictor_loss: 0.0909 - val_loss: 188.4157 - val_decoder_loss: 62.6313 - val_predictor_loss: 0.2047
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 137.7877 - decoder_loss: 45.8914 - predictor_loss: 0.0929 - val_loss: 188.9478 - val_decoder_loss: 62.9083 - val_predictor_loss: 0.1917
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 136.9471 - decoder_loss: 45.6233 - predictor_loss: 0.0897 - val_loss: 189.4881 - val_decoder_loss: 63.0836 - val_predictor_loss: 0.1945
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 136.4890 - decoder_loss: 45.4459 - predictor_loss: 0.0886 - val_loss: 189.6883 - val_decoder_loss: 63.1870 - val_predictor_loss: 0.1896
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 135.9806 - decoder_loss: 45.2876 - predictor_loss: 0.0915 - val_loss: 191.0026 - val_decoder_loss: 63.6266 - val_predictor_loss: 0.1944
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 135.5115 - decoder_loss: 45.1452 - predictor_loss: 0.0894 - val_loss: 190.8422 - val_decoder_loss: 63.6044 - val_predictor_loss: 0.1863
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 134.7638 - decoder_loss: 44.8990 - predictor_loss: 0.0870 - val_loss: 190.4433 - val_decoder_loss: 63.4066 - val_predictor_loss: 0.1871
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 134.6776 - decoder_loss: 44.8617 - predictor_loss: 0.0903 - val_loss: 191.7358 - val_decoder_loss: 63.8181 - val_predictor_loss: 0.1868
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 133.6705 - decoder_loss: 44.5370 - predictor_loss: 0.0871 - val_loss: 191.9866 - val_decoder_loss: 64.0461 - val_predictor_loss: 0.2083
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 133.6037 - decoder_loss: 44.5001 - predictor_loss: 0.0848 - val_loss: 193.0798 - val_decoder_loss: 64.2415 - val_predictor_loss: 0.1800
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 132.8379 - decoder_loss: 44.2683 - predictor_loss: 0.0875 - val_loss: 192.2658 - val_decoder_loss: 63.9553 - val_predictor_loss: 0.1825
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 132.6398 - decoder_loss: 44.1805 - predictor_loss: 0.0855 - val_loss: 192.9886 - val_decoder_loss: 64.2163 - val_predictor_loss: 0.1829
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 132.2829 - decoder_loss: 44.0605 - predictor_loss: 0.0863 - val_loss: 193.5588 - val_decoder_loss: 64.3861 - val_predictor_loss: 0.1788
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 131.7471 - decoder_loss: 43.8958 - predictor_loss: 0.0881 - val_loss: 194.2123 - val_decoder_loss: 64.6467 - val_predictor_loss: 0.1852
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 131.5116 - decoder_loss: 43.8117 - predictor_loss: 0.0885 - val_loss: 194.3054 - val_decoder_loss: 64.6565 - val_predictor_loss: 0.1827
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 131.2420 - decoder_loss: 43.7186 - predictor_loss: 0.0835 - val_loss: 194.6394 - val_decoder_loss: 64.6989 - val_predictor_loss: 0.1803
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 130.5705 - decoder_loss: 43.5032 - predictor_loss: 0.0905 - val_loss: 196.1677 - val_decoder_loss: 65.2744 - val_predictor_loss: 0.1797
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 130.3556 - decoder_loss: 43.4246 - predictor_loss: 0.0848 - val_loss: 195.9745 - val_decoder_loss: 65.3047 - val_predictor_loss: 0.1968
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 129.5941 - decoder_loss: 43.1512 - predictor_loss: 0.0847 - val_loss: 196.2347 - val_decoder_loss: 65.4865 - val_predictor_loss: 0.2008
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 129.7658 - decoder_loss: 43.2212 - predictor_loss: 0.0853 - val_loss: 196.7147 - val_decoder_loss: 65.5057 - val_predictor_loss: 0.1873
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 129.0491 - decoder_loss: 42.9870 - predictor_loss: 0.0854 - val_loss: 198.3534 - val_decoder_loss: 65.9940 - val_predictor_loss: 0.1923
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 128.9647 - decoder_loss: 42.9477 - predictor_loss: 0.0932 - val_loss: 198.1201 - val_decoder_loss: 65.9800 - val_predictor_loss: 0.1933
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 128.7669 - decoder_loss: 42.8756 - predictor_loss: 0.0827 - val_loss: 199.2471 - val_decoder_loss: 66.3975 - val_predictor_loss: 0.2058
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 128.3288 - decoder_loss: 42.7365 - predictor_loss: 0.0840 - val_loss: 199.7073 - val_decoder_loss: 66.3588 - val_predictor_loss: 0.1863
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 128.0591 - decoder_loss: 42.6605 - predictor_loss: 0.0856 - val_loss: 199.7815 - val_decoder_loss: 66.5928 - val_predictor_loss: 0.1929
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 127.7967 - decoder_loss: 42.5743 - predictor_loss: 0.0837 - val_loss: 200.3327 - val_decoder_loss: 66.7198 - val_predictor_loss: 0.2098
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 127.5586 - decoder_loss: 42.5021 - predictor_loss: 0.0848 - val_loss: 200.2062 - val_decoder_loss: 66.5415 - val_predictor_loss: 0.2220
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 127.5026 - decoder_loss: 42.4683 - predictor_loss: 0.0875 - val_loss: 200.8269 - val_decoder_loss: 66.9618 - val_predictor_loss: 0.1851
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 126.9265 - decoder_loss: 42.2644 - predictor_loss: 0.0820 - val_loss: 202.0374 - val_decoder_loss: 67.1600 - val_predictor_loss: 0.1987
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 126.5182 - decoder_loss: 42.1540 - predictor_loss: 0.0843 - val_loss: 202.7407 - val_decoder_loss: 67.6198 - val_predictor_loss: 0.1861
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 126.3254 - decoder_loss: 42.0844 - predictor_loss: 0.0839 - val_loss: 202.4411 - val_decoder_loss: 67.5531 - val_predictor_loss: 0.1958
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 126.0464 - decoder_loss: 41.9726 - predictor_loss: 0.0831 - val_loss: 202.9308 - val_decoder_loss: 67.5536 - val_predictor_loss: 0.1983
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 125.9011 - decoder_loss: 41.9374 - predictor_loss: 0.0835 - val_loss: 203.7641 - val_decoder_loss: 67.8857 - val_predictor_loss: 0.1945
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 125.6793 - decoder_loss: 41.8596 - predictor_loss: 0.0836 - val_loss: 203.0204 - val_decoder_loss: 67.4959 - val_predictor_loss: 0.1929
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 125.1374 - decoder_loss: 41.6808 - predictor_loss: 0.0886 - val_loss: 204.4984 - val_decoder_loss: 68.1372 - val_predictor_loss: 0.1995
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 125.1507 - decoder_loss: 41.6835 - predictor_loss: 0.0889 - val_loss: 204.8753 - val_decoder_loss: 68.1276 - val_predictor_loss: 0.1926
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 124.7502 - decoder_loss: 41.5606 - predictor_loss: 0.0841 - val_loss: 205.2296 - val_decoder_loss: 68.3533 - val_predictor_loss: 0.1821
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 124.6756 - decoder_loss: 41.5241 - predictor_loss: 0.0860 - val_loss: 205.1459 - val_decoder_loss: 68.2309 - val_predictor_loss: 0.1969
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 124.5659 - decoder_loss: 41.5031 - predictor_loss: 0.0826 - val_loss: 205.4705 - val_decoder_loss: 68.2995 - val_predictor_loss: 0.1953
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 124.3458 - decoder_loss: 41.4387 - predictor_loss: 0.0828 - val_loss: 206.5642 - val_decoder_loss: 68.7053 - val_predictor_loss: 0.2082
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.8501 - decoder_loss: 41.2499 - predictor_loss: 0.0857 - val_loss: 207.5971 - val_decoder_loss: 69.2107 - val_predictor_loss: 0.1900
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.9807 - decoder_loss: 41.2976 - predictor_loss: 0.0839 - val_loss: 207.4214 - val_decoder_loss: 69.0072 - val_predictor_loss: 0.1955
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.6264 - decoder_loss: 41.1916 - predictor_loss: 0.0832 - val_loss: 207.5184 - val_decoder_loss: 69.1120 - val_predictor_loss: 0.2017
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.6166 - decoder_loss: 41.1654 - predictor_loss: 0.0815 - val_loss: 207.9218 - val_decoder_loss: 69.1194 - val_predictor_loss: 0.1965
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.0665 - decoder_loss: 40.9969 - predictor_loss: 0.0843 - val_loss: 209.0740 - val_decoder_loss: 69.5864 - val_predictor_loss: 0.1982
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.0663 - decoder_loss: 40.9983 - predictor_loss: 0.0851 - val_loss: 207.7656 - val_decoder_loss: 69.1836 - val_predictor_loss: 0.2024
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 123.1235 - decoder_loss: 41.0069 - predictor_loss: 0.0844 - val_loss: 210.0814 - val_decoder_loss: 69.9016 - val_predictor_loss: 0.2196
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 122.7739 - decoder_loss: 40.8988 - predictor_loss: 0.0832 - val_loss: 209.0400 - val_decoder_loss: 69.5597 - val_predictor_loss: 0.1969
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 122.9683 - decoder_loss: 40.9740 - predictor_loss: 0.0827 - val_loss: 209.9270 - val_decoder_loss: 69.9247 - val_predictor_loss: 0.1945
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 122.4027 - decoder_loss: 40.7924 - predictor_loss: 0.0858 - val_loss: 210.6575 - val_decoder_loss: 70.3687 - val_predictor_loss: 0.2105
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 122.4170 - decoder_loss: 40.7693 - predictor_loss: 0.0804 - val_loss: 211.3332 - val_decoder_loss: 70.4170 - val_predictor_loss: 0.2037
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 122.0497 - decoder_loss: 40.6681 - predictor_loss: 0.0844 - val_loss: 211.7216 - val_decoder_loss: 70.3366 - val_predictor_loss: 0.1920
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 121.9802 - decoder_loss: 40.6335 - predictor_loss: 0.0804 - val_loss: 212.1857 - val_decoder_loss: 70.8096 - val_predictor_loss: 0.1914
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 121.8071 - decoder_loss: 40.5703 - predictor_loss: 0.0844 - val_loss: 213.7450 - val_decoder_loss: 71.1091 - val_predictor_loss: 0.1921
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 121.5393 - decoder_loss: 40.4817 - predictor_loss: 0.0805 - val_loss: 214.3208 - val_decoder_loss: 71.3168 - val_predictor_loss: 0.1921
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 121.4617 - decoder_loss: 40.4618 - predictor_loss: 0.0838 - val_loss: 214.2582 - val_decoder_loss: 71.4039 - val_predictor_loss: 0.2077
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 184.39804
# 6185/6185 - 1s - loss: 121.1954 - decoder_loss: 40.3773 - predictor_loss: 0.0852 - val_loss: 214.0180 - val_decoder_loss: 71.2989 - val_predictor_loss: 0.2055

# %%
# print(type(history))
# print(type(history.history))
print(history.history.keys())
# Out:
# dict_keys(['loss', 'decoder_loss', 'predictor_loss', 'val_loss', 'val_decoder_loss', 'val_predictor_loss'])

# %%
# summarize history for loss
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,7))
fig.suptitle('Various Losses')


ax1.plot(history.history['loss'])
ax1.plot( history.history['val_loss'])
ax1.set_title('Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(['train', 'Validation'], loc='lower left')


ax2.plot(history.history['decoder_loss'])
ax2.plot(history.history['val_decoder_loss'])
ax2.set_title('Decoder Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Decoder Loss')
ax2.legend(['train', 'Validation'], loc='lower left')

ax3.plot(history.history['predictor_loss']) 
ax3.plot(history.history['val_predictor_loss'])
ax3.set_title('Predictor Loss')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('Predictor Loss')
ax3.legend(['train', 'Validation'], loc='lower left')

# %% [markdown]
# # **Latent Space Visualization**

# %% [markdown]
# ### **Each Component of latent space**

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 30)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %% [markdown]
# ## **Latent Space Values of SAS Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='/drive/My Drive/ZINC/Models/OnlyQED/Diagram/'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "VAESMILES_SASLatent_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# encoded, decoded and predicted data on test dataset

encoded_xtest=encoder.predict(X_test)
# predicted_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print("Encoded data shape",encoded_xtest.shape)
# print("Predicted Property Data Shape",predicted_xtest.shape)
print("Reconstructed Test data Shape", decoded_xtest.shape)

# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)
print("Original Test Data Dimension",orig_test.shape)
print("Reconstructed Test Data Dimension", reconst_test.shape)
# Out:
# Encoded data shape (1547, 50)
# Reconstructed Test data Shape (1547, 2013)
# Original Test Data Dimension (1547, 61, 33)
# Reconstructed Test Data Dimension (1547, 61, 33)

# %% [markdown]
# ### **Reconstruction Original test data set**

# %%
# Going back from vectorized form back to a readable string on original test data
IPythonConsole.ipython_useSVG=True 
mols_orig_test= []
smi_orig_test=[]
syntax_val={0:[], 1:[]}

for id in range(len(X_test)):
  smi="".join([int_to_char[idx] for idx in np.argmax(orig_test[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_orig_test.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_orig_test.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid SMiles" ,sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)
      # print(mol)
    except:
      print('Mol {} {}'.format(id+1, mol)) 


smi_orig_test_valid=[]
mols_orig_test_valid=[]
for item in syntax_val[1]:
  smi_orig_test_valid.append(smi_orig_test[item])
  mols_orig_test_valid.append(mols_orig_test[item])
# smi_orig_test_valid


print(len(mols_orig_test_valid), "Original Valid Test Samples")
# Draw.MolsToGridImage(mols_orig_test_valid, molsPerRow=4,subImgSize=(200,200))



### **Reconstruction on reconstructed test data**

from rdkit import RDLogger  
# Going back from vectorized form back to a readable string on original test data
#Reconstruction
syntax_val={0:[], 1:[]}
mols_reconst_test= []
smi_reconst_test=[]

RDLogger.DisableLog('rdApp.*')  

for id in range(len(X_test)):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_test[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_reconst_test.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_test.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Reconstructed Smile", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol, kekulize=False)
    except:
      # print('Mol {} {}'.format(id+1, mol)) 
      continue


smi_reconst_test_valid=[]
mols_reconst_test_valid=[]
smi_orig_test_valid=[]
mols_orig_test_valid=[]

print(len(syntax_val[1]), "Reconstructed Valid Test Samples")
for item in syntax_val[1]:
  smi_reconst_test_valid.append(smi_reconst_test[item])
  smi_orig_test_valid.append(smi_orig_test[item])

  mols_reconst_test_valid.append(mols_reconst_test[item])
  mols_orig_test_valid.append(mols_orig_test[item])
  print("Molecule", item, "Original Valid", smi_orig_test[item] )
  print("Molecule", item, "Reconstructed Valid", smi_reconst_test[item])

Draw.MolsToGridImage(mols_reconst_test_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# 1547 Original Valid Test Samples
# 5 Reconstructed Valid Test Samples
# Molecule 19 Original Valid O=C(CCn1cnc2ccsc2c1=O)N1CCN(c2cccc[nH+]2)CC1
# Molecule 19 Reconstructed Valid O=C(CCc1cccccc1c2c(=O)C1CC(Cc2ccc(n2))c2)CCC1
# Molecule 267 Original Valid COC(=O)[C@@H]1CCN(C(=O)[C@H]2CCSC2)C1
# Molecule 267 Reconstructed Valid COC(=O)[C@@H](CCCNC(=O)[C@H]1CSCC1)C
# Molecule 777 Original Valid CC(=O)Nc1ccc(OCC(=O)N2CCN(C(=O)C3CC3)CC2)cc1
# Molecule 777 Reconstructed Valid CC(=O)Nc1ccc(OCC(=O)NCCCCNC(=O)NCC(C)CCC)cc1F
# Molecule 849 Original Valid O=[N+]([O-])c1ccccc1Cc1ccccc1
# Molecule 849 Reconstructed Valid O=[N+]([O-])c1ccccc1Cc1ccccc1
# Molecule 1385 Original Valid Nc1nnc(NC(=O)C2CCOCC2)s1
# Molecule 1385 Reconstructed Valid Cc1ccc(NC(=O)CSCCCCC)nc1

# %% [markdown]
# ## **Reconstruction on Training data**

# %%
# encoded, decoded and predicted data on Training dataset

encoded_xtrain=encoder.predict(X_train)
# predicted_xtest=predictor.predict(encoded_xtrain)
decoded_xtrain=decoder.predict(encoded_xtrain)
# print(encoded_xtrain.shape)
# print(predicted_xtrain.shape)
# print(decoded_xtrain.shape)

# Reshaping the original and reconstructed train data
orig_train=X_train.reshape(len(X_train), mol_size_x, mol_size_y)
reconst_train = decoded_xtrain.reshape(len(X_train), mol_size_x,mol_size_y)
# print(orig_train.shape)
# print(reconst_train.shape)
# Going back from vectorized form back to a readable string on original training data

syntax_val={0:[], 1:[]}

smi_orig_train=[]
mols_orig_train= []

for id in range(len(X_train)):
  smi="".join([int_to_char[idx] for idx in np.argmax(orig_train[id,:,:], axis=1)])
  smi = re.sub('!|E',"", smi)
  smi_orig_train.append(smi)

  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_orig_train.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(mol), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)
    except:
      print('Mol {} {}'.format(id+1, mol)) 

smi_orig_train_valid=[]
mols_orig_train_valid=[]

for item in syntax_val[1]:
  smi_orig_train_valid.append(smi_orig_train[item].rstrip('\n'))
  mols_orig_train_valid.append(mols_orig_train[item])


print(len(mols_orig_train_valid), "Original Valid Training Samples")
# Draw.MolsToGridImage(mols_orig_train_valid, molsPerRow=4,subImgSize=(200,200))

# Going back from vectorized form back to a readable string on Reconstructed training data
#Reconstruction

syntax_val={0:[], 1:[]}

smi_reconst_train=[]
mols_reconst_train= []

for id in range(len(X_train)):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_train[id,:,:], axis=1)])
  # print(len(mol))
  smi = re.sub('!|E',"", smi)
  smi_reconst_train.append(smi)
  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_train.append(mol)
  if mol is None:
    syntax_val[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol, kekulize=True)      
    except:
      # print('Mol {} {}'.format(id+1, mol)) 
      continue

smi_reconst_train_valid=[]
mols_reconst_train_valid=[]
smi_orig_train_valid=[]
mols_orig_train_valid=[]

print(len(syntax_val[1]), "Reconstructed Valid Training Samples")
for item in syntax_val[1]:
  smi_reconst_train_valid.append(smi_reconst_train[item].rstrip('\n'))
  smi_orig_train_valid.append(smi_orig_train[item].rstrip('\n'))

  mols_reconst_train_valid.append(mols_reconst_train[item])
  mols_orig_train_valid.append(mols_orig_train[item])

  print("Molecule", item,"Original Valid", smi_orig_train[item])
  print("Molecule" , item, "Reconstructed valid", smi_reconst_train[item])


Draw.MolsToGridImage(mols_reconst_train_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# 6185 Original Valid Training Samples
# 328 Reconstructed Valid Training Samples
# Molecule 71 Original Valid COCC[C@H](C)C(=O)N[C@@H](C)COC
# Molecule 71 Reconstructed valid COCC[C@H](C)C(=O)N[C@@H](C)CO
# Molecule 102 Original Valid CCOC(=O)[C@H]1C=C(C#N)O[C@@H](c2ccc(C)cc2)C1
# Molecule 102 Reconstructed valid CCOC(=O)[C@H]1CCC(C#N)O[C@@H](c2ccc(C)cc2)C1
# Molecule 121 Original Valid COc1ccc(C(=O)/C=C(\C)Nc2ccc(F)cc2F)cc1
# Molecule 121 Reconstructed valid COc1ccc(C(=O)/C=C(\C)Nc2ccc(F)cc2F)cc1
# Molecule 131 Original Valid CC[C@@H](CC(=O)NC1(C(=O)OC)CCSCC1)c1ccccc1
# Molecule 131 Reconstructed valid CC[C@@H](CC(=O)Nc1OC(=O)NCCCCSCC1)c1ccccc1
# Molecule 160 Original Valid COc1ccc(NC(=O)N2CCN(C(=O)Cc3csc4ccccc34)CC2)cc1OC
# Molecule 160 Reconstructed valid COc1ccc(NC(=O)N2CCC(C(=O)Cc3csc4ccccc34)cC2)cc1O
# Molecule 169 Original Valid CCOC(=O)c1sc(/C=C/c2nc3c(s2)CCC3)nc1C
# Molecule 169 Reconstructed valid CCOC(=O)c1sc(/C=C/c2cc3c(c2)CCn3)nc1
# Molecule 175 Original Valid Cc1cc(NC(=O)CSc2nnc3c4ccccc4n(C)c3n2)ccc1Br
# Molecule 175 Reconstructed valid Cc1cc(NC(=O)CSc2ncc3c4ccccc4n(C)c3n2)ccc1Br
# Molecule 190 Original Valid O=C1O[C@H](C(=O)Nc2ccnc3ccnn23)Cc2ccccc21
# Molecule 190 Reconstructed valid O=C1C[C@H](C(=O)Nc2cccc3ccnn23)Cc2ccccc21
# Molecule 198 Original Valid CCC(CC)[S@](=O)CCC(=O)[O-]
# Molecule 198 Reconstructed valid CCC(CC)[NH](=O)CNC(=O)[C-]
# Molecule 224 Original Valid Cc1cc(Br)ccc1CNC(=O)C1CC=CC1
# Molecule 224 Reconstructed valid Cc1cc(Br)ccc1NCC(=O)C1CC=CC1
# Molecule 231 Original Valid COC[C@H]1CCC[NH+](Cc2cc(C)n(Cc3ccco3)c2C)C1
# Molecule 231 Reconstructed valid COC[C@H]1CCC[NH+](Cc2cc(C)C(Cc3ccco3)c2C)C1C
# Molecule 262 Original Valid CC(C)c1nsc(NC[C@H](C2CC2)[NH+](C)C)n1
# Molecule 262 Reconstructed valid CC(C)c1nsc1(C[C@H](COCC1)[NH+](C)C)C1
# Molecule 290 Original Valid CN(C(=O)c1ccc(Cl)cc1O)C1CCC(=O)CC1
# Molecule 290 Reconstructed valid CN(C(=O)c1ccc(Cl)cc1C)C1CNC(=O)CC1
# Molecule 293 Original Valid Cc1cc(N)nc(SCC(=O)NC[C@@H](c2ccccc2)C(C)C)n1
# Molecule 293 Reconstructed valid Cc1cc(C)nc(SCC(=O)CC[C@@H](c2ccccc2)C(C)C)n1
# Molecule 317 Original Valid Fc1ccc(F)c(C[NH+]2CCC(n3cc(-c4cccnc4)nn3)CC2)c1F
# Molecule 317 Reconstructed valid Fc1ccc(F)c(C[NH+]2CCC(n3cc(-c4ccccc4)nn3)CC2)c1F
# Molecule 322 Original Valid COc1cc(OC)cc([C@@H](N[C@@H](C)c2ccc(F)cn2)c2[nH+]ccn2C)c1
# Molecule 322 Reconstructed valid COc1cc(OC)cc([C@@H](N[C@@H](C)c2ccc(F)cn2)c2[nH+]ccn2C)c1
# Molecule 332 Original Valid Cc1nccn1CC(=O)N1CCCC[C@@H]1CCNC(=O)c1ccccc1
# Molecule 332 Reconstructed valid Cc1ncOc1CC(=O)NN1CCC[C@@H]1CCNC(=O)c1ccccc1
# Molecule 337 Original Valid Cc1ccc(NC(=O)CSc2nnc([C@@H]3CCCN3C(=O)c3cccc(C)c3)n2C)cc1
# Molecule 337 Reconstructed valid Cc1ccc(NC(=O)CSc2nnc([C@@H]3CCCN3C(=O)c3cccc(C)c3)n2C)cc1
# Molecule 404 Original Valid Cc1ccc(C)c(NC(=S)NCCc2cccs2)c1
# Molecule 404 Reconstructed valid Cc1ccc(C)c(NC(=O)CCCc2cccs2)c1
# Molecule 405 Original Valid CNc1ncc(F)c(-c2cccc(Cl)c2)n1
# Molecule 405 Reconstructed valid CNc1ncc(F)c(-c2cccc(Cl)c2)c1
# Molecule 449 Original Valid COc1ccc(OC)c(NC(=O)c2ccc3c(c2)C(=O)N(c2cc(C)on2)C3=O)c1
# Molecule 449 Reconstructed valid COc1ccc(OC)c(NC(=O)c2ccc3c(c2)C(=O)N(c2cc(C)on2)C3=O)c1
# Molecule 452 Original Valid COC(=O)c1ccc(NC(=O)c2c(C)sc3ncnc(N4CCC[C@H](C)C4)c23)cc1
# Molecule 452 Reconstructed valid COC(=O)c1ccc(NC(=O)c2c(C)sc3ncnc(N4CCC[C@H](C)C4)c23)cc1
# Molecule 475 Original Valid COCCNC(=O)[C@H]1CCCN1S(=O)(=O)c1ccc(Br)cc1
# Molecule 475 Reconstructed valid CNCCNC(=O)[C@H]1CCCN1S(=O)(=O)c1ccc(Br)cc1
# Molecule 532 Original Valid Cc1cccc([S@@](=O)Cc2ccc(N)c(F)c2)c1
# Molecule 532 Reconstructed valid Cc1cccc([S@@](=O)Cc2ccc(N)c(F)c2)c1
# Molecule 539 Original Valid CC(C)C[C@](C)(O)CNC(=O)CC[C@H](C)O
# Molecule 539 Reconstructed valid CC(C)C[C@](C)(O)CNC(=O)CC[C@H](C)
# Molecule 552 Original Valid CCN(CC(C)(C)O)C(=O)COCc1ccccc1Cl
# Molecule 552 Reconstructed valid CCC(CC(C)(O)N)C(=O)NOCc1ccccc1Cl
# Molecule 563 Original Valid COC[C@H](NC(=O)c1cc(-c2ccccc2)c(C)[nH]c1=O)C(N)=O
# Molecule 563 Reconstructed valid COC[C@H](CC(=O)c1cc(-c2ccccc2)c(C)[nH]c1=O)C(N)=O
# Molecule 608 Original Valid CCc1nn(C)cc1CNC(=O)NCC(C)(C)Cc1ccccc1
# Molecule 608 Reconstructed valid CCc1nn(C)cc1CNC(=O)NCC(C)(C)Cc1ccccc1
# Molecule 624 Original Valid C[NH+]1CCC(NC(=O)c2ncoc2-c2ccccc2)CC1
# Molecule 624 Reconstructed valid C[NH+]1CCC(NC(=O)c2ncoc2-c2ccccc2)nC1
# Molecule 667 Original Valid CN(C)c1cccc(C(=O)OCC(=O)C(C)(C)C)c1
# Molecule 667 Reconstructed valid CC(C)c1cccc(C(=O)OCC(=O)C(C)(C)C)c1
# Molecule 675 Original Valid COc1ccc([C@@H](CNC(=O)c2ccc([N+](=O)[O-])o2)[NH+](C)C)cc1
# Molecule 675 Reconstructed valid COc1ccc([C@@H](CNC(=O)c2ccc([N+](=O)[O-])o2)[NH+](C)C)cc1
# Molecule 689 Original Valid C=CCN(CC=C)C(=O)C1CCN(C(=O)C(C)(C)C)CC1
# Molecule 689 Reconstructed valid C=CCN(CN=C)C(=O)C1CCN(C(=O)C(C)(C)C)CC1
# Molecule 710 Original Valid COc1ccc(-n2ccc(CNC(=O)c3cc(Cl)ccc3[N+](=O)[O-])n2)cc1
# Molecule 710 Reconstructed valid COc1ccc(-n2ccc(CNC(=O)c3cc(Cl)ccc3[N+](=O)[O-])n2)cc1
# Molecule 724 Original Valid COc1ccc(-c2nnc(SCC(=O)c3ccc(Br)cc3)o2)cc1OC
# Molecule 724 Reconstructed valid COc1ccc(-c2nnc(SCC(=O)c3ccc(Br)cc3)o2)cc1
# Molecule 740 Original Valid C[C@H](CC#N)Sc1ccccc1NC(=O)c1ccc(Cl)nc1Cl
# Molecule 740 Reconstructed valid C[C@H](CC#N)Sc1ccccc1NC(=O)c1ccc(Cl)nc1Cl
# Molecule 744 Original Valid COc1ccc(C)cc1NC(=O)[C@H]1CCCN1c1cc(C)ccc1[N+](=O)[O-]
# Molecule 744 Reconstructed valid COc1ccc(C)cc1NC(=O)[C@H](CCCN)c1cc(C)ccc1[N+](=O)[O-]
# Molecule 804 Original Valid Cc1ccc2nc(NC(=O)c3ccc(OCc4nc(-c5ccco5)cs4)cc3)sc2c1
# Molecule 804 Reconstructed valid Cc1ccc2nc(NC(=O)c3ccc(OCc4cc(-c5ccco5)cs4)cc3)sc2c1
# Molecule 831 Original Valid Cc1nc(Br)ccc1NC(=O)NCc1cnn(C)c1
# Molecule 831 Reconstructed valid Cc1cc(Br)ccc1NC(=O)NCc1ccC(C)c1
# Molecule 920 Original Valid C[C@H]([NH3+])[C@@H](CC(=O)[O-])c1ccccc1
# Molecule 920 Reconstructed valid C[C@H]([NH3+])[C@@H](CC(=O)[C-])c1ccccc1
# Molecule 940 Original Valid CC(C)CN(C(=O)NCc1ccc(C(F)(F)F)cc1)C1CC1
# Molecule 940 Reconstructed valid CN(C)ON(C(=O)NCc1ccc(C(F)(F)F)cc1)C1CC1
# Molecule 956 Original Valid CC(C)(C)c1nc(CC[NH2+]C2CCN(Cc3cccnc3)CC2)cs1
# Molecule 956 Reconstructed valid CC(C)(C)c1nc(CC[NH2+]C2CCN(Cc3cccnc3)CC2)cs1
# Molecule 983 Original Valid Cc1ccc(Cl)cc1N1CCN(C(=O)[C@@H]2CCC[NH2+]2)CC1
# Molecule 983 Reconstructed valid Cc1ccc(Cl)cc1NCCCN(C(=O)[C@@H](CCC[NH2+]2)C2)
# Molecule 1030 Original Valid C[C@H](OC(=O)[C@@H]1CCC[C@@H](C)C1)[C@@H]1CCCO1
# Molecule 1030 Reconstructed valid C[C@@](OC(=O)[C@@+](CCC[C@@H](C)CO)[C@@H]1)CCO1
# Molecule 1033 Original Valid [NH3+][C@@H](CSc1ccccc1F)[C@@H]1CCc2cccnc21
# Molecule 1033 Reconstructed valid [NH3+][C@@H](CSc1ccccc1F)[C@@H]1CCcccccccn1
# Molecule 1060 Original Valid Cc1ccc(F)c(Br)n1
# Molecule 1060 Reconstructed valid Cc1ccc(F)c(Br)n1
# Molecule 1081 Original Valid N#Cc1cccc(NS(=O)(=O)c2ccccc2F)c1
# Molecule 1081 Reconstructed valid N#Cc1cccc(NS(=O)(=O)c2ccccc2F)c1
# Molecule 1103 Original Valid C[C@H](Nc1cc(F)cc(F)c1)c1cc(F)ccc1O
# Molecule 1103 Reconstructed valid C[C@H](Cc1cc(F)cc(F)c1)c1cc(F)cnc1F
# Molecule 1129 Original Valid CN(C)/C=C/C(=O)Oc1ccc(Cl)cc1
# Molecule 1129 Reconstructed valid CN(C)/C=C/C(=O)Nc1ccc(Cl)cc1
# Molecule 1132 Original Valid Cc1ccc2nc(NC(=O)c3ccc(N4CCCC4)c([N+](=O)[O-])c3)sc2c1
# Molecule 1132 Reconstructed valid Cc1ccc2nc(NC(=O)c3ccc(N4CCCC4)c([N+](=O)[O-])c3)sc2c1
# Molecule 1140 Original Valid C[C@H](C#N)Sc1nc(-c2ccccc2)cs1
# Molecule 1140 Reconstructed valid C[C@H](C#N)Sc1nc(-c2ccccc2)cs1
# Molecule 1163 Original Valid COc1cccc(C[NH+]2CCC[C@H](C(=O)c3ccc(SC)cc3)C2)c1OC
# Molecule 1163 Reconstructed valid COc1cccc(C[NH+]2CCC[C@H](C(=O)c3ccc(SC)cc3)C2)c1OC
# Molecule 1209 Original Valid C[C@H]1CN(C(=O)[C@@H]2CCS(=O)(=O)C2)C[C@H](C)O1
# Molecule 1209 Reconstructed valid C[C@H]1CN(C(=O)[C@@H]2CCS(=O)(=O)C2)C[C@H](C)1
# Molecule 1215 Original Valid Cc1ccc([C@@H]2CSCCN2C(=O)N[C@@H]2[C@@H]3CCO[C@@H]3C2(C)C)o1
# Molecule 1215 Reconstructed valid Cc1ccc([C@@H]2CSCCN2C(=O)N[C@@H]2[C@@H]3CCO[C@@H]3C2(C)C)o1
# Molecule 1245 Original Valid CCC[C@@H](CC(=O)OC)NC(=O)[C@@H]1OCC[C@H]1C
# Molecule 1245 Reconstructed valid CCC[C@@H](CC(=O)NC)NC(=O)[C@@H]1CCC[C@H]1C
# Molecule 1252 Original Valid Cc1cnc2nc(Cc3ccsc3)[nH]c2c1
# Molecule 1252 Reconstructed valid Cc1cnc2nc(Cc3ccsc3)[nH]c1c2
# Molecule 1260 Original Valid C[C@@H](NCc1nnc(-c2ccccc2)s1)c1ccc(-c2ccccc2)o1
# Molecule 1260 Reconstructed valid C[C@@H](NCc1nnc(-c2ccccc2)s1)c1cnc(-c2ccccc2)o1
# Molecule 1264 Original Valid CS(=O)(=O)N1CCCN(S(=O)(=O)c2ccc(F)c(F)c2)CC1
# Molecule 1264 Reconstructed valid CS(=O)(=O)N1CCCN(S(=O)(=O)c2ccc(F)c(F)c2)CC1
# Molecule 1295 Original Valid CC[C@H](CC(=O)N1CCOC[C@H]1C(N)=O)c1ccccc1
# Molecule 1295 Reconstructed valid CC[C@H](CC(=O)N1CCOC[C@H]1C(N)=O)c1ccccc1
# Molecule 1309 Original Valid Cc1cc2cc(CNC(=O)[C@H]3CCC(=O)N(CCCN4CCCC4=O)C3)ccc2[nH]1
# Molecule 1309 Reconstructed valid Cc1cc2cc(CNC(=O)[C@H]3CCC(=O)N(CCCN4CCCC4=O)C3)ccc2[nH]1
# Molecule 1324 Original Valid COc1cccc2cc([C@@H](C)NC(=O)N3CCC(CC[NH+](C)C)CC3)oc12
# Molecule 1324 Reconstructed valid COc1cccc2cc([C@@H](C)NC(CO)NNCCC(CC[NH+](C)C)CCC)oc12
# Molecule 1355 Original Valid Cc1cccnc1C[C@@H](Cl)c1ccoc1
# Molecule 1355 Reconstructed valid Cc1ccccc1C[C@@H](Cl)c1ccoc1
# Molecule 1359 Original Valid CCOC(=O)c1cccc(NC[C@H](O)c2ccc(Cl)cc2)n1
# Molecule 1359 Reconstructed valid CCOC(=O)c1ccnc(CS[C@H](O)c2ccc(Cl)cc2)n1
# Molecule 1363 Original Valid CC[C@H](S[C@H](C)c1cccs1)C(N)=O
# Molecule 1363 Reconstructed valid CC[C@H](S[C@H](C)c1cccs1)C(N)=O
# Molecule 1377 Original Valid Cc1sc(NC(=O)Cc2ccc(F)cc2)nc1-c1ccc(F)cc1
# Molecule 1377 Reconstructed valid Cc1sc(NC(=O)Cc2ccc(F)cc2)nc1-c1ccc(F)nc1
# Molecule 1396 Original Valid CN1CCC[NH+](Cc2cc(Cl)ccc2N)CC1
# Molecule 1396 Reconstructed valid CN1CCC[NH+](Cc2cc(Cl)ccc2N)CC1
# Molecule 1428 Original Valid Cc1nnc(Cc2ccc(NC(=O)c3ccc(N4CCOCC4)cc3)cc2)o1
# Molecule 1428 Reconstructed valid Cc1nnc(Cc2ccc(NC(=O)c3ccc(N4COOCC4)cc3)cc2)o1
# Molecule 1430 Original Valid CCC[C@@H](NC(=O)C1C[C@@H](C)O[C@H](C)C1)C(=O)OC
# Molecule 1430 Reconstructed valid CCC[C@@H](NC(=O)C1C[C@@H](C)O[C@H](C)C1)C(=O)OC
# Molecule 1442 Original Valid CCn1cc([C@H]2OCC[C@H]2C[NH2+]Cc2ccc(C)s2)cn1
# Molecule 1442 Reconstructed valid CCn1cc([C@H]2OCC[C@H]2C[NH2+]Cc2ccc(C)s2)cn1
# Molecule 1443 Original Valid CC[C@H]1CCCCN(C)C1=O
# Molecule 1443 Reconstructed valid CC[C@H]1CCCCN(C)C1=C
# Molecule 1473 Original Valid C[C@H]1CCC[NH+](CC(=O)Nc2cccc(NC(=O)c3ccccc3)c2)C1
# Molecule 1473 Reconstructed valid C[C@H]1CCC[NH+](CC(=O)Nc2cccc(CC(=O)c3ccccc3)c2)n1
# Molecule 1487 Original Valid CCn1cnnc1SCC(=O)c1ccc(OC)cc1OC
# Molecule 1487 Reconstructed valid CCn1cnnc1CCC(=O)c1ccc(CC)cc1OC
# Molecule 1490 Original Valid CN(Cc1ccc(OC(F)(F)F)cc1)C(=O)c1csc(-c2cccs2)n1
# Molecule 1490 Reconstructed valid CN(Cc1ccc(OC(F)(F)F)cc1)C(=O)c1csc(-c2cccs2)n1
# Molecule 1495 Original Valid O=C(c1cc2cccc(Cl)c2o1)N1CCC([C@@H](O)c2ccccc2)CC1
# Molecule 1495 Reconstructed valid O=C(c1cc2cccc(Cl)c2o1)N1CCC([C@@H](O)c2ccccc2)CC1
# Molecule 1520 Original Valid CC[C@@H](C)NC(=O)c1ccnc(OC(C)(C)C)c1
# Molecule 1520 Reconstructed valid CC[C@@H](C)NC(=O)c1cccc(OC(O)(C)C)c1
# Molecule 1577 Original Valid COc1ncc(C(=O)Nc2nc3cc(Cl)c(C)cc3s2)cn1
# Molecule 1577 Reconstructed valid COc1ncc(C(=O)Nc2nc3cc(Cl)c(C)cc3s2)cc1
# Molecule 1603 Original Valid Cc1cccc(CCC(=O)OCc2nnc(-c3ccccc3Cl)o2)c1
# Molecule 1603 Reconstructed valid Cc1cccc(CCC(=O)NCc2nnc(-c3ccccc3Cl)o2)c1
# Molecule 1656 Original Valid CCOc1cccc([C@H](C)NC(=O)C(=O)Nc2ccc(Cl)c([N+](=O)[O-])c2)c1
# Molecule 1656 Reconstructed valid CCOc1cccc([C@H](C)NC(=O)C(=O)Nc2ccc(Cl)c([N+](=O)[O-])c2)c1
# Molecule 1667 Original Valid CCCC(=O)Nc1cccc(CNC(=O)N2CCSCC2)c1
# Molecule 1667 Reconstructed valid CCCC(=O)Nc1cccc(CNC(=O)N2CCSCC2)c1
# Molecule 1686 Original Valid Clc1cccc(-c2ccc(C[NH2+]Cc3ccc4c(c3)OCO4)o2)c1
# Molecule 1686 Reconstructed valid COc1cccc(-c2ccc(C[NH2+]Cc3ccc4c(c3)OCC4)o2)c1
# Molecule 1703 Original Valid C#CCN(CC(=O)[O-])C(=O)N(C)[C@H](C)c1cccs1
# Molecule 1703 Reconstructed valid C#CCN(CC(=O)[O-])C(=O)N(C)[C@H](C)c1cccs1
# Molecule 1731 Original Valid CCc1ccc([C@H](CO)NC(=O)[C@H]2C[C@@H]2c2ccc(F)cc2)cc1
# Molecule 1731 Reconstructed valid COc1ccc([C@H](CO)NC(=O)[C@H]2C[C@@H]2c2ccc(F)cc2)cc1
# Molecule 1740 Original Valid Cc1cccc(/C=C(/F)C(=O)[O-])c1C
# Molecule 1740 Reconstructed valid Cc1cccc(/C=C(/C)C(=O)[O-])c1C
# Molecule 1750 Original Valid COc1ccc(NC(=O)C(=O)N[C@@H]2C[C@H]2C2CCCCC2)cc1OC
# Molecule 1750 Reconstructed valid COc1ccc(NC(=O)C(=O)N[C@@H]2C[C@H]2C2CCCCC2)cc1O
# Molecule 1768 Original Valid CNS(=O)(=O)c1cccc([C@@H](C)NC(=O)C23CC4CC(CC(C4)C2)C3)c1
# Molecule 1768 Reconstructed valid CNS(=O)(=O)c1cccc([C@@H](C)NC(=O)C23CC4CC(CC(C4)c2)C3)c1
# Molecule 1804 Original Valid O=C(CSc1cccc(C(F)(F)F)c1)N1CCN(S(=O)(=O)c2cccs2)CC1
# Molecule 1804 Reconstructed valid O=C(CSc1cccc(C(F)(F)F)c1)N1CCN(S(=O)(=O)c2cccs2)Cc1
# Molecule 1809 Original Valid N#CCc1ccc(NC(=O)CNC(=O)c2ccc(Oc3ccccc3)cc2)cc1
# Molecule 1809 Reconstructed valid N#CCc1ccc(NC(=O)CNC(=O)c2ccc(C3cccccc3)cc2)cc1
# Molecule 1844 Original Valid Cc1cccc(F)c1[C@H](N)C(F)(F)F
# Molecule 1844 Reconstructed valid Cc1cccc(F)c1[C@H](C)C(F)(F)F
# Molecule 1861 Original Valid COc1ccc(OCC(=O)N2CC(OCc3ccc(Cl)cc3)C2)cc1
# Molecule 1861 Reconstructed valid COc1ccc(ONC(=O)N2CC(OCc3ccc(Cl)cc3)C2)cc1
# Molecule 1906 Original Valid C[NH2+]C[C@H](C)[C@H](C)n1cccn1
# Molecule 1906 Reconstructed valid C[NH2+]C[C@H](C)[C@H](C)c1ccccc1
# Molecule 1934 Original Valid Cc1nnc(S[C@H](C)C(=O)N2CCOCC2)n1C
# Molecule 1934 Reconstructed valid Cc1nnc(S[C@H](C)C(=O)N2CCOCC2)n1C
# Molecule 1938 Original Valid COc1ccc(NC(=O)NCC(=O)[O-])cc1Cl
# Molecule 1938 Reconstructed valid COc1ccc(NC(=O)CNC(=O)[C-])cc1Cl
# Molecule 1944 Original Valid O=C(Cc1csc(-c2ccoc2)n1)N[C@H](c1ccccc1)C1CCC1
# Molecule 1944 Reconstructed valid O=C(Cc1csc(-c2ccoc2)n1)N[C@H](c1ccccc1)C1CCC1
# Molecule 2003 Original Valid Cc1ccc2nc(COc3cccc(C(=O)N(C)[C@@H]4CCS(=O)(=O)C4)c3)cn2c1
# Molecule 2003 Reconstructed valid Cc1ccc2nc(COc3cccc(C(=O)N(C)[C@@H]4CCS(=O)(=O)C4)c3)cn2c1
# Molecule 2020 Original Valid CC[C@H](c1nc(CC(C)C)no1)N1Cc2ccccc2C1=O
# Molecule 2020 Reconstructed valid CC[C@H](c1nc(CC(O)C)no1)n1Cc2ccccc2C1=O
# Molecule 2114 Original Valid C[C@H](NC(=O)CSC[C@H](C)CO)c1ccc(F)cc1
# Molecule 2114 Reconstructed valid C[C@H](NC(=O)CCC[C@H](C)CO)c1ccc(F)cc1
# Molecule 2145 Original Valid CCC[C@H](C#N)[C@@H](O)c1ccc(C(F)(F)F)cc1
# Molecule 2145 Reconstructed valid CCC[C@H](C#N)[C@@H](O)c1ccc(C(F)(F)F)cc1
# Molecule 2162 Original Valid CCC(CC)[C@@H](O)[C@H]1CCc2ccccc2C1
# Molecule 2162 Reconstructed valid CCC(CC)[C@@H](O)[C@H]1CCc2ccccc21
# Molecule 2182 Original Valid Nc1nc(-c2cccc(F)c2)c(Br)s1
# Molecule 2182 Reconstructed valid Cc1nc(-c2cccc(F)c2)c(Br)s1
# Molecule 2245 Original Valid Cc1ccc(O)c(NS(=O)(=O)c2cc(F)c(F)c(F)c2)c1
# Molecule 2245 Reconstructed valid Cc1ccc(C)c(NS(=O)(=O)c2cc(F)c(F)c(F)c2)c1
# Molecule 2246 Original Valid CCOC(=O)C1=C(C)NC(=O)N[C@H]1c1cc(OC)ccc1O
# Molecule 2246 Reconstructed valid CCOC(=O)C1NC(C)NC(=O)N[C@H]1c1cc(OC)ccc1O
# Molecule 2260 Original Valid Cc1ccc(S(=O)(=O)Nc2ccc(C(=O)N3[C@@H](C)CCC[C@@H]3C)cc2)cc1
# Molecule 2260 Reconstructed valid Cc1ccc(S(=O)(=O)Nc2ccc(C(=O)N3[C@@H](CCCNC[C@@H]3))cc2)cc1
# Molecule 2267 Original Valid COC(=O)c1ccc(C(=O)Nc2ccc(F)c([N+](=O)[O-])c2)cc1
# Molecule 2267 Reconstructed valid COC(=O)c1ccc(C(=O)Nc2ccc(F)c([N+](=O)[O-])c2)cc1
# Molecule 2275 Original Valid CCOc1cc(C[NH+]2CCC[C@H](C(=O)N(CC)CC)C2)ccc1O
# Molecule 2275 Reconstructed valid CCOc1cc(C[NH+]2CCC[C@H](C(=O)N(CC)CC)C2)ccc1O
# Molecule 2278 Original Valid COc1ccc(-n2nnnc2S[C@@H](C)C(=O)c2cc(C)c(C)cc2C)cc1
# Molecule 2278 Reconstructed valid COc1ccc(-n2nnnc2S[C@@H](C)C(=O)c2cc(C)c(C)cc2C)cc1
# Molecule 2285 Original Valid O=C(Nc1ccc(-c2cscn2)cc1)[C@H]1CCCN(C(=O)C2=CCCCC2)C1
# Molecule 2285 Reconstructed valid O=C(Nc1ccc(-c2cscn2)cc1)[C@H]1CCCN(C(=C)C2)CCCCC2CC1
# Molecule 2306 Original Valid C[C@H]1CCCCN1S(=O)(=O)c1cccc(C(=O)N(C)c2ccc(F)cc2)c1
# Molecule 2306 Reconstructed valid C[C@H]1CCCCC1S(=O)(=O)c1cccc(C(=O)N(C)c2ccc(F)cc2)c1
# Molecule 2326 Original Valid CCO[C@H](C)C(=O)OCC(=O)NC(C)C
# Molecule 2326 Reconstructed valid CCO[C@H](CNC(=O)NCCCCC)NC(C)C
# Molecule 2346 Original Valid Cc1nn(Cc2ccccc2Cl)c(C)c1C(=O)N[C@H]1CCCCNC1=O
# Molecule 2346 Reconstructed valid Cc1nc(Cc2ccccc2Cl)c(C)N1C(=O)C[C@H]1CCCCNC1=O
# Molecule 2405 Original Valid COc1ccc(N2C[C@H](C(=O)N[C@@H](C)C(=O)NC3CCCC3)CC2=O)cc1
# Molecule 2405 Reconstructed valid COc1ccc(N2C[C@H](C(=O)N[C@@H](C)C(=O)NC3CCCC3)CC2=O)cc1
# Molecule 2407 Original Valid Cc1ccsc1CNC(=O)CCCC[NH3+]
# Molecule 2407 Reconstructed valid Cc1ccsc1CNC(=O)CCCC[NH3+]
# Molecule 2417 Original Valid CNC(=O)c1cccc(NC(=O)COc2ccc(C(C)(C)C)cc2)c1
# Molecule 2417 Reconstructed valid CNC(=O)c1cccc(NC(=O)COc2ccc(C(C)(C)C)cc2)c1
# Molecule 2425 Original Valid CCc1nc(COC(=O)c2cc(-c3ccc(Br)cc3)n[nH]2)cs1
# Molecule 2425 Reconstructed valid COc1nc(COC(=O)c2cc(-c3ccc(Br)cc3)n[nH]2)cs1
# Molecule 2438 Original Valid COc1cccc(CN(C)C(=O)C(=O)Nc2cccc3cccnc23)c1
# Molecule 2438 Reconstructed valid COc1cccc(CN(C)C(=O)C(=O)Nc2cccc3ccccc23)c1
# Molecule 2447 Original Valid Cn1cc(Br)cc1C(=O)Nc1cc(Cl)c(Cl)cn1
# Molecule 2447 Reconstructed valid CC1cc(Br)cc1C(=O)Nc1cc(Cl)c(Cl)cc1
# Molecule 2477 Original Valid Cc1cc(=O)oc(C)c1C(=O)O[C@H](C)C(=O)c1ccc(NS(C)(=O)=O)cc1
# Molecule 2477 Reconstructed valid Cc1cc(=O)oc(C)c1C(=O)O[C@H](C)C(=O)c1ccc(NS(C)(=C)=O)cc1
# Molecule 2481 Original Valid O=C(NCc1cc2ccccc2o1)Nc1cccnc1
# Molecule 2481 Reconstructed valid O=C(NCc1cc2ccccc2o1)Nc1ccccc1
# Molecule 2486 Original Valid COc1ccc(/C=N/N2CCN(Cc3ccccc3)CC2)cc1
# Molecule 2486 Reconstructed valid COc1ccc(/C=N/N2CCC(Cc3ccccc3)CC2)cc1
# Molecule 2513 Original Valid CCc1nn(C)cc1NC(=O)C(=O)N[C@H](C)C(=O)NCc1ccccc1
# Molecule 2513 Reconstructed valid CCc1nn(C)cc1NC(=O)C(=O)N[C@H](C)C(=O)NCc1ccccc1
# Molecule 2575 Original Valid Cn1cnc(C[NH2+]Cc2ccc(C(C)(C)C)cc2)n1
# Molecule 2575 Reconstructed valid Cn1ccc(C[NH2+]Cc2ccc(C(C)(C)C)cc2)n1
# Molecule 2578 Original Valid Cc1cnc(-c2cccc(NC(=O)C(=O)N[C@@H]3CCN(c4ccccc4)C3)c2)o1
# Molecule 2578 Reconstructed valid Cc1ccc(-c2cccc(NC(=O)C(=O)N[C@@H]3CC(Nc4ccccc4)C3)c2)o1
# Molecule 2628 Original Valid O=C(COc1ccccc1Cl)N/N=C1\C(=O)Nc2ccccc21
# Molecule 2628 Reconstructed valid O=C(CNc1ccccc1Cl)N/N=C1\C(=O)Nc2ccccc21
# Molecule 2642 Original Valid COC[C@@H](C)NC(=O)N[C@@H](C(N)=O)c1ccccc1
# Molecule 2642 Reconstructed valid CCC[C@@H](C)NC(=O)N[C@@H](C(N)=O)c1ccccc1
# Molecule 2685 Original Valid COC(=O)[C@H](Cl)c1ccc(Cl)c(F)c1
# Molecule 2685 Reconstructed valid COC(=O)[C@H](Cl)c1ccc(Cl)c(F)c1
# Molecule 2711 Original Valid C[C@@H]1C[C@]2(C[NH+]=C(N)N2c2ccc(Cl)cc2)CS1
# Molecule 2711 Reconstructed valid C[C@@H]1C[C@]2(C[NH+]=C(C)N2c2ccc(Cl)cc2)CS1
# Molecule 2723 Original Valid CC(=O)c1ccc(NC(=O)C[C@@H]2C(=O)Nc3nc(-c4ccc(C)cc4)nn32)cc1
# Molecule 2723 Reconstructed valid CC(=O)c1ccc(NC(=O)C[C@@H]2C(=O)Nc3cc(-c4ccc(C)cc4)nn32)cc1
# Molecule 2728 Original Valid CCOC(=O)c1ccc(CNC(=O)NCC2(C)CCCC2)o1
# Molecule 2728 Reconstructed valid CCOC(=O)c1ccc(CNC(=O)C(C)(C)CCCCC)o1
# Molecule 2734 Original Valid C=CCC[C@@H](C)[NH+](C)CCc1nccs1
# Molecule 2734 Reconstructed valid C=CCC[C@@H](C)[NH+](C)CCc1nccs1
# Molecule 2746 Original Valid C[NH+](C)CCS[C@@H]1C[C@H](C(C)(C)C)CC[C@@H]1C#N
# Molecule 2746 Reconstructed valid C[NH+](C)CCS[C@@H]1C[C@H](C(C)(C)C)CC[C@@H]1C#N
# Molecule 2782 Original Valid COc1cc(C)c2[nH]ccc2n1
# Molecule 2782 Reconstructed valid COc1cc(C)c2[nH]ccc2n1
# Molecule 2788 Original Valid O=C(c1ccccc1SC[C@H]1CCCO1)N1CCN([C@@H]2CCS(=O)(=O)C2)CC1
# Molecule 2788 Reconstructed valid O=C(c1ccccc1SC[C@H]1CNCO1)N1CCN([C@@H]2CCS(=O)(=O)C2)CC1
# Molecule 2813 Original Valid CCC[C@@H](COC)Nc1ccc(C#N)c(N)c1
# Molecule 2813 Reconstructed valid CCC[C@@H](C(N))c1ccc(C#N)c(C)c1
# Molecule 2814 Original Valid CC(=O)NCCNC(=O)CSC1CCCC1
# Molecule 2814 Reconstructed valid CC(=O)CCCNC(=O)CSC1CCCC1
# Molecule 2817 Original Valid COc1cc(Br)c(C[NH2+]C[C@H](C)O)cc1OC
# Molecule 2817 Reconstructed valid COc1cc(Br)c(C[NH2+]C[C@H](C)O)cc1O
# Molecule 2818 Original Valid C[C@H](CNC(=O)c1cccc(C(F)(F)F)c1F)c1ccncc1
# Molecule 2818 Reconstructed valid C[C@H](CNC(=O)c1cccc(S(F)(F)F)c1F)c1ccncc1
# Molecule 2894 Original Valid O=C([C@H]1CCOC1)N(CC(F)(F)F)c1ccccc1
# Molecule 2894 Reconstructed valid O=C([C@H]1CCCC1)N(CC(F)(F)F)c1ccccc1
# Molecule 2943 Original Valid CN(C[C@H](O)c1c(F)cccc1F)c1ccccc1
# Molecule 2943 Reconstructed valid CN(C[C@H](O)c1c(F)cccc1F)c1ccccc1
# Molecule 2962 Original Valid CC(C)n1cnnc1[C@H]1CCC[NH+](CC2CCC2)C1
# Molecule 2962 Reconstructed valid CN(C)C1cncc1[C@H]1CCC[NH+](CCCCCC)CC1
# Molecule 2986 Original Valid CC[C@@H](C)C(=O)Nc1cccc(CNC(=O)C[NH+]2CCCCCC2)c1
# Molecule 2986 Reconstructed valid CC[C@@H](C)C(=O)Nc1cccc(CNC(=O)C[NH+]2CCCCCC2)c1
# Molecule 3004 Original Valid CCOc1ncccc1C(=O)Nc1ccc(C(=O)NC)cc1
# Molecule 3004 Reconstructed valid CCOc1ncccc1C(=O)Nc1ccc(C(=O)NC)cc1
# Molecule 3022 Original Valid CC(C)(C)[NH2+]Cc1cccc(Oc2ncccn2)c1
# Molecule 3022 Reconstructed valid CC(C)(CC[NH2+])c1cccc(Oc2ccccn2)cS1
# Molecule 3046 Original Valid COc1ccc(NC(=O)N[C@@H](C)c2ccc(C)o2)cn1
# Molecule 3046 Reconstructed valid COc1ccc(NC(=O)N[C@@H](C)c2ccc(C)o2)cc1
# Molecule 3049 Original Valid C[C@H](Oc1ccccc1N)C(=O)c1ccc(Cl)cc1
# Molecule 3049 Reconstructed valid C[C@H](Cc1ccccc1N)C(=O)c1ccc(Cl)cc1
# Molecule 3053 Original Valid CCNC(=O)c1cccc(NC(=O)C[NH+](C)CC)c1
# Molecule 3053 Reconstructed valid CCNC(=O)c1cccc(NC(=O)C[NH+](O)CC)c1
# Molecule 3070 Original Valid N#CCOc1cccc(CC(=O)N2CCO[C@@H](c3nccs3)C2)c1
# Molecule 3070 Reconstructed valid N#CCOc1cccc(CC(=O)N2CCC[C@@H](c3cccs3)C2)c1
# Molecule 3079 Original Valid CCn1cnnc1CNC(=O)/C=C/c1ccc(C(C)(C)C)cc1
# Molecule 3079 Reconstructed valid CCn1ccnc1CNC(=O)/C=C/c1ccc(C(C)(C)C)cc1
# Molecule 3087 Original Valid CN(Cc1ccc(Cl)nc1)C(=O)Nc1cccc2ccccc12
# Molecule 3087 Reconstructed valid CN(Cc1ccc(Cl)cc1)C(=O)Nc1cccc2ccccc12
# Molecule 3092 Original Valid COC[C@@H](C)NC(=O)Cc1ccc(F)cc1F
# Molecule 3092 Reconstructed valid COC[C@@H](C)NC(=O)Cc1ccc(F)cc1F
# Molecule 3112 Original Valid O=C(NCCc1nccn1Cc1ccccc1)N[C@@H]1CCC[C@H]1CO
# Molecule 3112 Reconstructed valid O=C(NCCc1cccn1Cc1ccccc1)N[C@@H]1CCC[C@H]1C
# Molecule 3147 Original Valid CCc1ccc(CN(C)C(=O)c2cc3ccccc3[nH]2)cc1
# Molecule 3147 Reconstructed valid CCc1ccc(CN(C)C(=O)c2cc3ccccc3[nH]2)cc1
# Molecule 3163 Original Valid COc1ccccc1N1C[C@@H](C(=O)N[C@H](c2ccccc2)c2ccccn2)CC1=O
# Molecule 3163 Reconstructed valid COc1ccccc1N1C[C@@H](C(=O)N[C@H](c2ccccc2)c2ccccn2)CC1=O
# Molecule 3167 Original Valid Cc1cnc(S(=O)(=O)CCc2scnc2C)nc1
# Molecule 3167 Reconstructed valid Cc1cnc(S(=O)(=O)CCc2scnc2C)nc1
# Molecule 3182 Original Valid Cc1cccc(CN(C)c2ccc(Cl)c(CCl)n2)n1
# Molecule 3182 Reconstructed valid Cc1cccc(CN(C)c2ccc(Cl)c(CCl)n2)n1
# Molecule 3185 Original Valid O=C(NC(=S)NCc1ccco1)C1CC1
# Molecule 3185 Reconstructed valid O=C(NC(CS)1Ccccccc1)c1CC1
# Molecule 3195 Original Valid Cn1ncnc1CNC(=O)N1CCC[C@@H]1c1ccc2c(c1)OCO2
# Molecule 3195 Reconstructed valid Cn1ncnc1CNC(=O)N1CCC[C@@H]1c1ccc2c(C1)nCO2
# Molecule 3204 Original Valid C=CCNC(=O)NNC(=O)Cc1ccc(Cl)cc1
# Molecule 3204 Reconstructed valid C=CCNC(=O)NNC(=O)C1cccc(Cl)cc1
# Molecule 3211 Original Valid Cc1cccc(C(=O)N2CCC(Oc3cccnc3)CC2)c1
# Molecule 3211 Reconstructed valid Cc1cccc(C(=O)N2CCC(-c3cccnc3)CC2)c1
# Molecule 3218 Original Valid C[C@H]1CN(c2cc3c(cc2Br)C(=O)C(=O)N3)C[C@H](C)S1
# Molecule 3218 Reconstructed valid C[C@H]1CN(c2cc3c(nc2Br)C(=O)C(=O)N3)C[C@H](C)S1
# Molecule 3231 Original Valid CCOc1ccc(-c2nc3ncccn3c2NCc2ccc(Cl)cc2)cc1OC
# Molecule 3231 Reconstructed valid CCOc1ccc(-c2nc3c-c2c3c2CCccccc(Cl)cc2)cc1OC
# Molecule 3240 Original Valid CC[C@H](C)NC(=O)C(=O)Nc1c(C(N)=O)oc2ccccc12
# Molecule 3240 Reconstructed valid CC[C@H](C)NC(=O)C(=O)Nc1c(C(N)=O)oc2ccccc12
# Molecule 3266 Original Valid CC(C)C[NH+](C)CCC(=O)[O-]
# Molecule 3266 Reconstructed valid CC(C)C[NH+](C)NCC(=O)[N-]
# Molecule 3284 Original Valid O=C(N[C@H]1CCCc2ccc(F)cc21)c1ccc(Cl)nc1Cl
# Molecule 3284 Reconstructed valid O=C(N[C@H]1CCCc2ccc(F)cc21)c1ccc(Cl)nc1Cl
# Molecule 3328 Original Valid CN(C(=O)c1sccc1N)C1CCC(C)(C)CC1
# Molecule 3328 Reconstructed valid CN(C(=O)c1sccc1N)C1CCC(C)(C)CC1
# Molecule 3336 Original Valid N#CCOc1ccccc1N1CCCCC1=O
# Molecule 3336 Reconstructed valid C#CCOc1ccccc1N1CCCCC1=O
# Molecule 3375 Original Valid CC[NH2+][C@@H]1CCCC[C@H]1SC[C@@H](C)CO
# Molecule 3375 Reconstructed valid CC[NH2+][C@@H]1CCCC[C@H]1CC[C@@H](C)CO
# Molecule 3380 Original Valid CCCNC(=O)NC(C)(C)c1ncc(C)s1
# Molecule 3380 Reconstructed valid CCNNC(=O)NC(C)(N)c1ncc(C)s1
# Molecule 3443 Original Valid CC1(C)CN(c2nc(C(F)F)nc3ccccc23)CC[S@@]1=O
# Molecule 3443 Reconstructed valid CC1(C)CC(c(nc2C(F)F)nc3ccccc23)CC[S@@]1=O
# Molecule 3453 Original Valid Cc1nc([N+](=O)[O-])cn1CCC(=O)O[C@H](C)c1ccc(Cl)s1
# Molecule 3453 Reconstructed valid Cc1cc([N+](=O)[O-])cn1CCC(=O)O[C@H](O)c1ccc(Cl)s1
# Molecule 3477 Original Valid C[NH2+]Cc1cccc(-c2nccs2)c1
# Molecule 3477 Reconstructed valid C[NH2+]Cc1cccc(-c2nccs2)c1
# Molecule 3506 Original Valid CC[C@@H](O)[C@@]1(C[NH3+])CCC[C@H](C)C1
# Molecule 3506 Reconstructed valid CC[C@@H](O)[C@@]1(C[NH3+])CCC[C@H](C)C1C
# Molecule 3510 Original Valid COc1ccc(-c2cc3c(N4CCC[C@@H](C(=O)[O-])C4)nccn3n2)cc1OC
# Molecule 3510 Reconstructed valid COc1ccc(-c2cc3c(N4CCC[C@@H](C(=O)[C-])C4)nccn3n2)cc1OC
# Molecule 3518 Original Valid O=S1(=O)CCc2[nH]c3cc(F)c(F)c(F)c3c2C1
# Molecule 3518 Reconstructed valid O=S1(=O)CCc2[nH]c3cc(F)c(F)c(F)c3c2C1
# Molecule 3520 Original Valid CCc1onc(C)c1NC(=O)c1cc2cccc(F)c2o1
# Molecule 3520 Reconstructed valid CCc1onc(C)c1NC(=O)c1cc2cccc(F)c2o1
# Molecule 3558 Original Valid COC(=O)[C@@H](C)CNC(=O)Nc1ccc(C)cc1C
# Molecule 3558 Reconstructed valid COC(=O)[C@@H](C)CNC(=O)Nc1ccc(C)cc1C
# Molecule 3571 Original Valid C[C@H]([NH2+][C@H](C)C(=O)Nc1cc(F)ccc1F)c1ccc2c(c1)OCCO2
# Molecule 3571 Reconstructed valid C[C@H]([CH2+][C@H](C)C(=O)Nc1cc(F)ccc1F)c1ccc2c(c1)OCCO2
# Molecule 3588 Original Valid C[NH2+]C1CCN(C(=O)C2(C)CCCC2)CC1
# Molecule 3588 Reconstructed valid C[CH2+]C1CCN(C(=O)C(CC)CCCCC)CC1
# Molecule 3641 Original Valid CCOC(=O)Nc1ccc(NC(=O)Nc2cc(C)on2)cc1
# Molecule 3641 Reconstructed valid CCOC(=O)Nc1ccc(NC(=O)Nc2cc(C)on2)cc1
# Molecule 3678 Original Valid C[C@H](CC(=O)Nc1c(F)cccc1Br)c1ccccc1
# Molecule 3678 Reconstructed valid C[C@H](CC(=O)Nc1c(F)cccc1Br)c1ccccc1
# Molecule 3712 Original Valid Cc1c(F)cccc1NC(=O)[C@@H](C)Cc1ccccc1
# Molecule 3712 Reconstructed valid Cc1c(F)cccc1NC(=O)[C@@H](C)Cc1ccccc1
# Molecule 3773 Original Valid COc1ccc2[nH]cc(CCNC(=S)Nc3ccccc3C)c2c1
# Molecule 3773 Reconstructed valid CCc1ccc2[nH]cc(CCNC(=S)Nc3ccccc3C)c2c1
# Molecule 3777 Original Valid CCc1ccc(NC(=O)[C@H](C)OC(=O)c2cnc(C)cn2)cc1
# Molecule 3777 Reconstructed valid CCc1ncc(NC(=O)[C@H](C)CC(=O)c2cnc(C)cn2)cc1
# Molecule 3781 Original Valid Cc1noc(C[NH+]2CC[C@@H](OCCCc3ccccc3)C2)n1
# Molecule 3781 Reconstructed valid Cc1noc(C[NH+]2CC[C@@H](OCCCc3ccccc3)C2)c1
# Molecule 3788 Original Valid CC1(C)CCC[C@@H]1NC(=O)COCC(=O)[O-]
# Molecule 3788 Reconstructed valid CC1(C)CCC[C@@H]1NC(=O)COCC(=O)[O-]
# Molecule 3799 Original Valid CCCN1CCO[C@@H](C(=O)c2cc(C)ccc2F)C1
# Molecule 3799 Reconstructed valid CCCN1CCO[C@@H](C(=O)c2cc(C)ccc2F)C1
# Molecule 3807 Original Valid C[C@@H]1CC(=O)c2cc(C(=O)Nc3ccccc3Cl)c(=O)[nH]c2C1
# Molecule 3807 Reconstructed valid C[C@@H]1OC(=O)c2cc(C(=O)Nc3ccccc3Cl)c(=O)[nH]c2C1
# Molecule 3811 Original Valid O=C(CCOc1ccccc1)N1CCC(c2ccc(F)cc2)CC1
# Molecule 3811 Reconstructed valid O=C(CCOc1ccccc1)N1CCC(c2ccc(F)cc2)CC1
# Molecule 3832 Original Valid CC(C)CCNC(=O)CN1C(=O)c2ccccc2C1=O
# Molecule 3832 Reconstructed valid CN(C)CCNC(=O)CN1C(=O)c2ccccc2C1
# Molecule 3837 Original Valid O=C(N=C1NCCCCCN1)c1ccc(Br)cc1
# Molecule 3837 Reconstructed valid O=C(NCC1NCCCCCC1)c1ccc(Br)cc1
# Molecule 3845 Original Valid Cc1ccc(C)c(N2CCN(C[C@H](O)c3ccc(Cl)cc3)CC2)c1
# Molecule 3845 Reconstructed valid Cc1ccc(C)c(N2CCN(C[C@H](O)c3ccc(Cl)cc3)CC2)c1
# Molecule 3875 Original Valid CCNC(=O)NC[C@H]1CCCC[NH+]1Cc1ccccc1
# Molecule 3875 Reconstructed valid CCOC(=O)NC[C@H]1CCCC[NH+]1Cc1ccccc1
# Molecule 3877 Original Valid CC[NH+](CC)[C@H](C)CNC(=O)Nc1ccc2c(c1)NC(=O)[C@H](C)O2
# Molecule 3877 Reconstructed valid CC[NH+](CC)[C@H](C)CNC(=O)Nc1ccc2c(c1)NC(=O)[C@H](C)O2
# Molecule 3927 Original Valid Fc1ccc(C[NH+](C[C@H]2CCCO2)[C@@H]2CCSC2)cc1F
# Molecule 3927 Reconstructed valid Fc1ccc(C[NH+](C[C@H]2CCCC2)[C@@H]2CCSC2)cc1F
# Molecule 3938 Original Valid COc1ccc(OCCOc2cccc(Br)c2)cc1
# Molecule 3938 Reconstructed valid COc1ccc(OCCOc2cccc(Br)c2)cc1
# Molecule 3940 Original Valid COc1cc(C[NH+]2CCC[C@]3(CCC(=O)N(C4CC4)C3)C2)cc(OC)c1
# Molecule 3940 Reconstructed valid COc1cc(C[NH+]2CCC[C@]3(COC(=C)N(C4CC4)c3)C2)cc(OO)c1
# Molecule 3952 Original Valid C[C@H](Sc1ccc(N)cc1Cl)C(=O)NC1CC1
# Molecule 3952 Reconstructed valid C[C@H](Cc1ccc(C)cc1C1)C(=O)NC1CCC
# Molecule 3970 Original Valid COCCNC(=O)[C@@H](C)CS(=O)(=O)c1ccc(Br)cc1
# Molecule 3970 Reconstructed valid COCCNC(=O)[C@@H](C)CS(=O)(=O)c1ccc(Br)cc1
# Molecule 3971 Original Valid CCOC(=O)/C([O-])=N/c1nnc([C@@H]2CC(=O)N(c3ccccc3CC)C2)s1
# Molecule 3971 Reconstructed valid CCOC(=O)/C([O-])=N/c1cnc([C@@H]2CC(=O)N(c3ccccc3CC)C2)s1
# Molecule 3973 Original Valid O=C(c1csc(-c2ccccc2Cl)n1)N1CCOC[C@@H]1CCO
# Molecule 3973 Reconstructed valid O=C(c1csc(-c2ccccc2Cl)n1)N1CCOO[C@@H]1C
# Molecule 3986 Original Valid CN(C)C(=O)C[C@H](C[NH3+])N1CCC(C[NH+](C)C)CC1
# Molecule 3986 Reconstructed valid CN(C)C(=O)C[C@H](C[NH3+])N1CCC(C[NH+](C)C)C1
# Molecule 3997 Original Valid CC[C@@H](CO)NC(=O)N[C@@H](C)c1ccccc1Br
# Molecule 3997 Reconstructed valid CC[C@@H](CN)NC(=O)C[C@@H](C)c1ccccc1Br
# Molecule 4006 Original Valid Cc1ccccc1OCCCNC(=O)c1cc(F)ccc1F
# Molecule 4006 Reconstructed valid Cc1ccccc1NCCNNC(=O)c1cc(F)ccc1
# Molecule 4013 Original Valid C=CCCCOc1ccc(C(=O)[O-])cc1[N+](=O)[O-]
# Molecule 4013 Reconstructed valid C=C(C)Oc1ccc(C(=O)[O-])cc1[N+](=O)[O-]
# Molecule 4023 Original Valid CC1(C)CSC[C@H](Nc2cc(Cl)ccc2-n2cccn2)C1
# Molecule 4023 Reconstructed valid CC1(C)CCC[C@H](Nc2cc(Cl)ccc2-n2cccn2)C1
# Molecule 4036 Original Valid Cc1ccc(NC(=O)N2CCCN(C(=O)C(C)(C)C)CC2)cc1C
# Molecule 4036 Reconstructed valid Cc1ccc(NC(=O)N2CCCN(C(=O)C(C)(C)C)CC2)cc1C
# Molecule 4040 Original Valid C[C@@H](Sc1nnnn1-c1cccc(Cl)c1)C(=O)Nc1ccc(Br)cc1
# Molecule 4040 Reconstructed valid C[C@@H](Sc1nnnn1-c1cccc(Cl)c1)C(=O)Nc1ccc(Br)cc1
# Molecule 4055 Original Valid COC(=O)[C@@H]1NS(=O)(=O)c2ccsc2C1=O
# Molecule 4055 Reconstructed valid COC(=O)[C@@H]1NS(=O)(=O)c2ccsc2C1=O
# Molecule 4079 Original Valid CC(C)NC(=O)c1ccc2c(c1)NC(=O)CS2
# Molecule 4079 Reconstructed valid CC(CCNC(=O)c1cccNc(c1)NC(=O)CSC)
# Molecule 4087 Original Valid COc1ccc(CNC(=O)[C@@H](C)OC(=O)c2ccc(C)cc2)cc1
# Molecule 4087 Reconstructed valid COc1ccc(CNC(=O)[C@@H](C)CC(=O)c2ccc(C)cc2)cc1
# Molecule 4090 Original Valid CC(C)[C@H](CO)NS(=O)(=O)c1ccsc1C(=O)[O-]
# Molecule 4090 Reconstructed valid CC(C)[C@H](CC)NS(=O)(=O)c1ccsc1C(=O)[O-]
# Molecule 4104 Original Valid O=C(NC[C@H]1CCCO1)N1CC[C@H](Oc2ccc(C(F)(F)F)cn2)C1
# Molecule 4104 Reconstructed valid O=C(NC[C@H]1CCCC1)NCCO[C@H](Cc2ccc(C(F)(F)F)cn2)C
# Molecule 4105 Original Valid O=C(NCc1ccc(Cl)c(Cl)c1)c1ccncc1
# Molecule 4105 Reconstructed valid O=C(NCc1ccc(Cl)c(Cl)c1)c1ccncc1
# Molecule 4183 Original Valid C[NH+](C)CCOc1ccc(CNC(=O)[C@@H]2COc3ccc(F)cc3C2)cc1
# Molecule 4183 Reconstructed valid C[NH+](C)CCOc1ccc(CNC(=O)[C@@H]2Ccc3ccc(F)cc3c2)cc1
# Molecule 4195 Original Valid CC(=O)Nc1cccc(NC(=O)C(=O)NCC[NH+]2CCCC[C@@H]2C)c1C
# Molecule 4195 Reconstructed valid CC(=O)Nc1cccc(NC(=O)C(=O)N2C[CH+]2CC)C[C@@H](C)c1
# Molecule 4209 Original Valid N#Cc1ccc(NC[C@H](O)COc2ccc(I)cc2)nc1
# Molecule 4209 Reconstructed valid N#Cc1ccc(OC[C@H](C)NCc2ccc(I)cc2)nc1
# Molecule 4214 Original Valid COc1ccccc1CC(=O)N1C[C@H]2CC[C@@H]1CN(S(C)(=O)=O)C2
# Molecule 4214 Reconstructed valid COc1ccccc1CC(=O)N1C[C@H]2CC[C@@H]1CN(S(C)(=C)=O)C2
# Molecule 4268 Original Valid CC(C)CCNC(=O)[C@H]1CSCN1C(=O)Cc1cccc(F)c1F
# Molecule 4268 Reconstructed valid CC(C)CCNC(=O)[C@H]1CSCN1C(=O)Nc1cccc(F)c1F
# Molecule 4295 Original Valid Oc1ccc(C[NH2+]C[C@H]2CCCC[C@H]2CCl)cc1
# Molecule 4295 Reconstructed valid Cc1ccc(C[NH2+]C[C@H]2CCOC[C@H]2CCl)cc1
# Molecule 4328 Original Valid CCc1nn(C)c(OC)c1CNC(=O)c1cnc(N)c(Cl)c1
# Molecule 4328 Reconstructed valid CCc1nn(C)c(OC)c1CNC(=O)c1cnc(C)c(Cl)c1
# Molecule 4336 Original Valid O=C(NCCC1=CCCCC1)c1ccccc1O
# Molecule 4336 Reconstructed valid O=C(NCCC1CCCCC=1)c1ccccc1C
# Molecule 4353 Original Valid Cc1[nH]c2ccccc2c1SCCNC(=O)Cc1ccc(F)cc1
# Molecule 4353 Reconstructed valid Cc1[nH]c2ccccc2c1SCCNC(=O)Cc1ccc(F)cc1
# Molecule 4357 Original Valid CC(C)CCC(=O)N1C[C@H](C)O[C@@H](C)C1
# Molecule 4357 Reconstructed valid CC(C)CNC(=O)NOC[C@H]1CCO[C@@H](C)C1
# Molecule 4369 Original Valid CC(C)Oc1nc(NCc2ccccn2)ccc1N
# Molecule 4369 Reconstructed valid CC(C)Oc1cc(NCc2ccccn2)ccc1N
# Molecule 4384 Original Valid CC(C)[NH+]1CCN(Cc2ccncc2)C[C@@H]1CCO
# Molecule 4384 Reconstructed valid FC(C)[NH+]1CcN(Cc2ccccc2)C[C@@H]1CC
# Molecule 4385 Original Valid O=C(N[C@@H]1CCC[C@H](C(F)(F)F)C1)C1(c2ccccc2)CC1
# Molecule 4385 Reconstructed valid O=C(N[C@@H]1CCC[C@H](C(F)(F)F)c1)C1(c2ccccc2)CC1
# Molecule 4403 Original Valid CCC1=C(C(=O)OC)[C@H](c2cccc(Br)c2)NC(=S)N1
# Molecule 4403 Reconstructed valid CCC1CC(C(=O)OC)[C@@](c2cccc(Br)c2)NC(=S)N1
# Molecule 4435 Original Valid O=C(/C=C/c1cccs1)c1ccc(NC(=O)c2ccco2)cc1
# Molecule 4435 Reconstructed valid O=C(/C=C/c1cccs1)c1ccc(NC(=O)c2ccco2)cc1
# Molecule 4476 Original Valid Cc1ccc(C)c(OCCSC[C@H](O)CO)c1
# Molecule 4476 Reconstructed valid Cc1ccc(C)c(CCCSC[C@H](O)CO)c1
# Molecule 4477 Original Valid O=C1NCCS[C@@H]1Cc1ccccc1
# Molecule 4477 Reconstructed valid O=C1NCCC[C@@H]1Cc2ccccc2
# Molecule 4525 Original Valid CCc1nn(C)cc1CNC(=O)c1cc(C)nc2ccc(OC)cc12
# Molecule 4525 Reconstructed valid CCc1nn(C)cc1CNC(=O)c1cc(C)nc2ccc(O2)cc1
# Molecule 4576 Original Valid Cc1nc(C[NH+]2CCC[C@@H]2CN2CCOCC2)cs1
# Molecule 4576 Reconstructed valid Cc1cc(C[NH+]2CCC[C@@H]CCNCCCOCc2)ns1
# Molecule 4579 Original Valid Cc1ccc(CC(=O)NCc2ccccn2)cc1C
# Molecule 4579 Reconstructed valid Cc1ccc(CC(=O)NCc2ccccn2)cc1
# Molecule 4604 Original Valid N#Cc1cccc(CNC(=O)c2csc(C#CCN)c2)c1
# Molecule 4604 Reconstructed valid N#Cc1cncc(CNC(=O)c2csc(C#CCC)c2)c1
# Molecule 4613 Original Valid CCOc1cc(C)ccc1NC(=O)c1cccnc1
# Molecule 4613 Reconstructed valid CCOc1cc(C)ccc1NC(=O)c1cccnc1
# Molecule 4646 Original Valid CCCOc1ccc(NC(=O)CNC(=O)c2ccoc2)cc1Cl
# Molecule 4646 Reconstructed valid C=CCc1ccc(NC(=O)NNC(=O)c2ccoc2)cc1Cl
# Molecule 4657 Original Valid CC(C)[C@@H]1C(=O)O[C@H](c2ccccc2)N1C(=O)c1ccccc1
# Molecule 4657 Reconstructed valid CC(C)[C@@H]1C(=O)N[C@H](c2ccccc2)N1C(=O)c1ccccc1
# Molecule 4665 Original Valid CCc1nn(C)cc1NC(=O)c1cccnc1Br
# Molecule 4665 Reconstructed valid CCc1nn(C)cc1NC(=O)c1ccccc1Br
# Molecule 4684 Original Valid O=C(Nc1ccc(F)c(F)c1F)c1ccccc1F
# Molecule 4684 Reconstructed valid O=C(Nc1ccc(F)c(F)c1F)c1ccccc1F
# Molecule 4731 Original Valid CC(C)COc1ccc(C(C)(C)C(=O)NCC#N)cc1
# Molecule 4731 Reconstructed valid CC(C)COc1ccc(CNCN(C)C(=O)NCC#N)cc1
# Molecule 4746 Original Valid CCCc1cc(NC(=O)C(=O)N[C@H]2CCCC[C@H]2SCC)n(C)n1
# Molecule 4746 Reconstructed valid CCCc1cc(NC(=O)C(=O)N[C@H]2CCCC[C@H]2SCC)n(C)c1
# Molecule 4776 Original Valid O=C(c1cc(=O)c2ccccc2o1)N(C[C@@H]1CCCO1)C[C@H]1CCCO1
# Molecule 4776 Reconstructed valid O=C(c1cc(=O)c2ccccc2o1)N(C[C@@H]1CCCC1)C[C@H]1CCCO1
# Molecule 4783 Original Valid CC(=O)c1cccc(NC(=S)Nc2ccc(C)cc2)c1
# Molecule 4783 Reconstructed valid CC(=O)c1cccc(NC(=O)Nc2ccc(C)cc2)c1
# Molecule 4788 Original Valid O=C(N[C@H]1C=C[C@@H](C(=O)[O-])C1)c1ccc(Br)cc1
# Molecule 4788 Reconstructed valid O=C(N[C@H]1CCC[C@@H](C(=O)[O-])O1)c1ccc(Br)cc1
# Molecule 4796 Original Valid Cc1cc(=O)n2c(n1)SC[C@@H]2CC(=O)NC1CCCC1
# Molecule 4796 Reconstructed valid Cc1nc(=O)n2c(n1)SC[C@@H]2CC(=O)NC1CCCC1
# Molecule 4822 Original Valid O=C(C[NH+](Cc1ccc(O)cc1O)C[C@@H]1CCCO1)N1CCCC1
# Molecule 4822 Reconstructed valid O=C(C[NH+](Cc1ccc(O)cc1O)C[C@@H]1CCCO1)C1CCCC1
# Molecule 4846 Original Valid CC[C@@H](C)N1C(=O)C=CC1=O
# Molecule 4846 Reconstructed valid CC[C@@H](O)N1C(=O)N=CC1=O
# Molecule 4871 Original Valid O=[S@](c1cnc2ccccc2n1)[C@@H]1CCC[NH2+]C1
# Molecule 4871 Reconstructed valid O=[S@](c1ccc2ccccc2n1)[C@@H]1CCC[NH2+]C1
# Molecule 4877 Original Valid COc1ccccc1-n1nnnc1S[C@@H](C)C(=O)Nc1cccc(Cl)c1C
# Molecule 4877 Reconstructed valid COc1ccccc1-n1nncc1C[C@@H](C)C(=O)Nc1cccc(Cl)c1C
# Molecule 4892 Original Valid Cc1cnc(C(C)(C)NC(=O)c2csc(-c3ccoc3)n2)s1
# Molecule 4892 Reconstructed valid Cc1cnc(C)Cc(C)NC(=O)c2ccc(-c3ccoc3)C2Cs1
# Molecule 4904 Original Valid Cc1cc(S(=O)(=O)N2CCC[C@H](C#N)C2)sc1Br
# Molecule 4904 Reconstructed valid Cc1cc(S(=O)(=O)N2CCC[C@H](C#N)C2)sc1Br
# Molecule 4941 Original Valid N#C[C@H]1COCCN1CC(=O)Nc1ccc(F)c(F)c1
# Molecule 4941 Reconstructed valid N#C[C@H](CCCCNC)C(=O)Nc1ccc(F)c(F)c1
# Molecule 4942 Original Valid C[C@@H](CNCc1ccc(Cl)nc1)[NH+](C)Cc1ccccc1
# Molecule 4942 Reconstructed valid C[C@@H](CNCc1ccc(Cl)nc1)[NH+](C)Cc1ccccc1
# Molecule 4975 Original Valid Cc1nnc(NC(=O)Cc2ccc(-n3cccn3)cc2)s1
# Molecule 4975 Reconstructed valid Cc1nnc(NC(=O)Nc2cnc(-n3cccc3)cc2)o1
# Molecule 4977 Original Valid CC(C)CNC(=O)NNC(=O)c1cc(F)ccc1Br
# Molecule 4977 Reconstructed valid CC(C)CNC(=O)NNC(=O)c1cc(F)ccc1Br
# Molecule 4978 Original Valid CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(CSc3ccccc3)cc2C)cc1
# Molecule 4978 Reconstructed valid CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(CSc3ccccc3)cc2C)cc1
# Molecule 5016 Original Valid CC(C)c1nc(N(C)C[C@@H]2CC[NH+](C)C2)sc1C(=O)[O-]
# Molecule 5016 Reconstructed valid CC(C)c1nc(N(C)N[C@@H]2CC[NH+](C)C2)sc1C(=O)[O-]
# Molecule 5040 Original Valid CCOC(=O)[C@@H](C)c1ccc(OC)c(OC)c1
# Molecule 5040 Reconstructed valid CCOC(=O)[C@@H](C)c1ccc(CN)c(OC)c1
# Molecule 5056 Original Valid COCC[C@@H](C)C(=O)N(C)Cc1ccccc1N1CCCC1
# Molecule 5056 Reconstructed valid CCCC[C@@H](C)C(=O)N(C)Cc1ccccc1C1CCCC1
# Molecule 5065 Original Valid O=C(c1cccnc1)N1CCN(C(=O)c2ccccc2N2CCOCC2)CC1
# Molecule 5065 Reconstructed valid O=C(c1cccnc1)N1CCN(C(=O)c2ccccc2C2CCOCC2)CC1
# Molecule 5072 Original Valid CC(C)C[C@@H](C)CC(=O)NC1CC(C)C1
# Molecule 5072 Reconstructed valid CC(C)C[C@@H](C)CC(=O)NC1CC(C)C1
# Molecule 5096 Original Valid CC[C@@H](CNC(=O)NC1CCCC1)c1ccccc1
# Molecule 5096 Reconstructed valid CC[C@@H](CNC(=O)NC1=CCC1)c1ccccc1
# Molecule 5103 Original Valid O=C(Nc1ccc([N+](=O)[O-])cc1)Nc1cn[nH]c1
# Molecule 5103 Reconstructed valid O=C(Nc1ccc([N+](=O)[O-])cc1)Nc1cn[CH]c1
# Molecule 5118 Original Valid O=C(COc1ccc(-c2ccccc2)cc1Br)NC[C@@H]1CCCO1
# Molecule 5118 Reconstructed valid O=C(COc1ccc(-c2ccccc2)nc1Br)CC[C@@H]1CCCC1
# Molecule 5177 Original Valid Cc1ccc([C@@H](O)[C@@H]2CSCCS2)cc1
# Molecule 5177 Reconstructed valid Cc1ccc([C@@H](N)[C@@H]2CCCCS2)cc1
# Molecule 5238 Original Valid N#Cc1ccc(OC(=O)C[C@@H]2C=CCC2)cc1
# Molecule 5238 Reconstructed valid N#Cc1ccc(NC(=O)N[C@@H]2C=CCC2)cc1
# Molecule 5240 Original Valid Cc1ccc(C(=O)Nc2nc(S(C)(=O)=O)oc2-c2ccccc2)cc1
# Molecule 5240 Reconstructed valid Cc1ccc(C(=O)Nc2nc(S(C)(=O)=O)oc2-c2ccccc2)cc1
# Molecule 5245 Original Valid COc1cccc(C[C@@H]2C[C@@H](C)CC[C@H]2O)n1
# Molecule 5245 Reconstructed valid COc1cccc(C[C@@H]2C[C@@H](C)CC[C@H]2C)c1
# Molecule 5251 Original Valid Cc1noc(C)c1S(=O)(=O)N1CCC(C(=O)NNC(=O)c2ccc(Cl)cc2)CC1
# Molecule 5251 Reconstructed valid Cc1noc(C)c1S(=O)(=O)N1CCC(C(=O)NNC(=O)c2ccc(Cl)cc2)CC1
# Molecule 5254 Original Valid C[C@@H](SCC(=O)N1CCc2cc(S(N)(=O)=O)ccc21)c1c(F)cccc1F
# Molecule 5254 Reconstructed valid C[C@@H](NCC(=O)N1CCc2cc(S(N)(=O)=O)ccc21)c1c(F)cccc1F
# Molecule 5269 Original Valid CCNC(=O)CN(CC)C(=O)N[C@@H](C)c1ccc(-n2ccnc2)cc1
# Molecule 5269 Reconstructed valid CCNC(=O)CC(CC)C(=O)N[C@@H](C)c1ccc(-n2cccc2)cc1
# Molecule 5274 Original Valid O=[N+]([O-])c1ccc(N[C@@H]2CC[NH+](C[C@H]3CC=CCC3)C2)nc1
# Molecule 5274 Reconstructed valid O=[N+]([O-])c1ccc(N[C@@H]2CC[NH+](C[C@H]3CC=CCc3)C2)nc1
# Molecule 5276 Original Valid Cc1noc2nc(C3CCN(C(=O)COC[C@H]4CCCO4)CC3)cc(C(F)(F)F)c12
# Molecule 5276 Reconstructed valid Cc1coc2nc(C3CCN(C(=C)COC[C@H]4CCCO4)CC3)cc(C(F)(F)F)c12
# Molecule 5298 Original Valid COc1ccc(F)c(N[C@H](C)C[NH3+])c1
# Molecule 5298 Reconstructed valid COc1ccc(F)c(C[C@H](C)C[NH3+])c1
# Molecule 5300 Original Valid COc1cccc(C(=O)N2CCC(C(=O)c3ccc(C)cc3)CC2)c1F
# Molecule 5300 Reconstructed valid COc1cccc(C(=O)N2CCC(C(=O)c3ccc(C)cc3)nn2)c1F
# Molecule 5314 Original Valid O[C@H]1CCCC[C@@H]1Cc1ccccn1
# Molecule 5314 Reconstructed valid O[C@H]1CCCC[C@@H]1Cc1ccccc1
# Molecule 5353 Original Valid CCc1ccc(-c2cncc(N)n2)cc1
# Molecule 5353 Reconstructed valid COc1ccc(-c2cnnc(N)n2)cc1
# Molecule 5367 Original Valid CC(C)OCc1cccc(NC(=O)C(=O)N2C[C@H]3CCCC[C@@H]3C2)c1
# Molecule 5367 Reconstructed valid CC(C)NNc1cccc(NC(=O)C(=O)N2C[C@+]3CCCC[C@@H]3C2)c1
# Molecule 5377 Original Valid C[C@@H](O)c1ccccc1NC(=O)[C@@H]1CC[NH2+][C@@H]1C
# Molecule 5377 Reconstructed valid C[C@@H](O)c1ccccc1NC(=O)[C@@H]1CC[NH2+][C@@H]1C
# Molecule 5396 Original Valid CCOc1ccc(O)c(C[NH+](C)[C@@H](C)Cc2cccs2)c1
# Molecule 5396 Reconstructed valid CCOc1ccc(O)c(C[NH+](C)[C@@H](C)Cc2cccs2)c1
# Molecule 5397 Original Valid Cc1ccc(OCC(=O)Nc2ccc(-n3ccnc3C)nc2)cc1
# Molecule 5397 Reconstructed valid Cc1ccc(OCC(=O)Nc2ccc(-n3cccc3C)cc2)cc1
# Molecule 5414 Original Valid CC(=O)N1CC[C@@H]([NH2+]CCO)C1
# Molecule 5414 Reconstructed valid CC(=O)N1CC[C@@H]([NH2+]CCO)C1
# Molecule 5417 Original Valid COC(=O)CCNC(=O)C(=O)Nc1ccc(Cl)cc1C(F)(F)F
# Molecule 5417 Reconstructed valid COC(=O)CCNC(=O)C(=O)Nc1ccc(Cl)cc1C(F)(F)F
# Molecule 5434 Original Valid CCOc1ccccc1[C@@H]([NH3+])[C@H]1CSCCS1
# Molecule 5434 Reconstructed valid CCOc1ccccc1[C@@H]([NH3+])[C@H]1CSCCS1
# Molecule 5439 Original Valid COc1cc(F)cc(CNC(=O)C(=O)Nc2cccc3cccnc23)c1
# Molecule 5439 Reconstructed valid COc1cc(F)cc(CNC(=O)C(=O)Nc2ccccc3ccnc23)c1
# Molecule 5459 Original Valid CCC[NH+]1CCC(CNC(=O)N[C@@H](C)c2ccc(-n3cccn3)cc2)CC1
# Molecule 5459 Reconstructed valid CCC[CH+]1CCC(CNC(=O)N[C@@H](C)c2ccc(-n3cccn3)cc2)CC1
# Molecule 5501 Original Valid COc1ccc(CNC(=O)[C@H](C)Sc2cccc(C)c2)cc1OC
# Molecule 5501 Reconstructed valid COc1ccc(CNC(=O)[C@H](C)Sc2cccc(C)c2)cc1C
# Molecule 5533 Original Valid O=C(CSc1nc2ccccc2s1)Nc1nc2ccccc2s1
# Molecule 5533 Reconstructed valid O=C(CSc1nc2ccccc2s1)Nc1cc2ccccc2s1
# Molecule 5564 Original Valid COc1cccc(-c2cc(C(=O)Nc3ccc(-c4c[nH+]c5n4CCC5)cc3)[nH]n2)c1
# Molecule 5564 Reconstructed valid COc1cccc(-c2cc(C(=O)Nc3ccc(-c4c[nH+]c5n4CCC5)cc3)[nH]n2)c1
# Molecule 5575 Original Valid Cc1cc(NC(=O)C(=O)NCc2ccc(F)cc2)no1
# Molecule 5575 Reconstructed valid Cc1cc(NC(=O)C(=O)NCc2ccc(F)cc2)no1
# Molecule 5593 Original Valid NC(=O)[C@@H]1CCN(C(=O)CCc2cccc(Br)c2)C1
# Molecule 5593 Reconstructed valid NC(=O)[C@@H]1CCC(C(=O)CCc2cccc(Br)c2)C1
# Molecule 5596 Original Valid Cc1cc(C[C@H](C)NC(=O)N[C@@H]2CC[C@H]([NH+](C)C)C2)n[nH]1
# Molecule 5596 Reconstructed valid Cc1cc(C[C@H](C)NC(=O)N[C@@H]2CC[C@H]([NH+](C)C)C2)n[nH]1
# Molecule 5614 Original Valid Cc1nc2cc(F)ccc2cc1C(=O)N1CCN(S(=O)(=O)N2CC[NH+](C)CC2)CC1
# Molecule 5614 Reconstructed valid Cc1nc2cc(F)ccc2cc1C(=O)N1CCN(S(=O)(=O)N2CC[NH+](C)CC2)CC1
# Molecule 5625 Original Valid CC(=O)C1=C(C)C(C(=O)CSc2nc3ccccc3o2)=N[C@H]1C
# Molecule 5625 Reconstructed valid CC(=O)C1CC(CCC(CC=O)CSc2nc3ccccc3o2)=N[C@H]1
# Molecule 5629 Original Valid Cc1ccc(OCCNC(=O)CNC(=O)c2ccc(C)cc2)cc1
# Molecule 5629 Reconstructed valid Cc1ccc(OCCNC(=O)CNC(=O)c2ccc(C)cn2)cc1
# Molecule 5642 Original Valid CC[C@H]1CCCC[C@H]1[NH2+]Cc1ccc([N+](=O)[O-])cc1
# Molecule 5642 Reconstructed valid CC[C@H]1CCCC[C@H]1[NH2+]Cc1ccc([N+](=O)[O-])cc1
# Molecule 5650 Original Valid NC(=O)c1ccc(C(=O)Oc2cc(F)cc(Br)c2)cn1
# Molecule 5650 Reconstructed valid NC(=O)c1ccc(C(=O)Oc2cc(F)cc(Br)c2)cc1
# Molecule 5668 Original Valid NC(=O)C1CC[NH+](Cc2ccc(Cl)s2)CC1
# Molecule 5668 Reconstructed valid NC(=O)C1CC[NH+](Cc2ccc(Cl)s2)Cc1
# Molecule 5692 Original Valid CC[S@@](=O)[C@@H]1CCC[C@H](NC(=O)N2CCSCC2)C1
# Molecule 5692 Reconstructed valid CC[S@@](=O)[C@@H]1CCC[C@H](NC(=O)NCCCSCC)CC1
# Molecule 5707 Original Valid CNC(=O)CC1CCN(C(=O)N[C@@H](c2ccccn2)C(C)C)CC1
# Molecule 5707 Reconstructed valid CNC(=O)CC1CCN(C(=O)N[C@@H](c2ccccc2)C(C)C)CC1
# Molecule 5736 Original Valid O=C(CN1CCO[C@@H](c2cccc(F)c2)C1)N1CCCCCCC1
# Molecule 5736 Reconstructed valid C=C(CCNCCC[C@@H](c2cccc(F)c2)c1)N(CCCC)CC1
# Molecule 5738 Original Valid C[C@@H](C[NH2+]Cc1cn(C)nc1C(C)(C)C)Sc1ccccc1
# Molecule 5738 Reconstructed valid C[C@@H](C[NH2+]Cc1nn(C)nc1C(C)(C)C)Sc1ccccc1
# Molecule 5749 Original Valid CCCCN1C(=O)S[C@H](Nc2cccc(C(F)(F)F)c2)C1=O
# Molecule 5749 Reconstructed valid CCCCN1C(=O)S[C@H](Nc2cccc(C(F)(F)F)c2)C1=O
# Molecule 5769 Original Valid CCNC(=O)[C@H](C)Sc1cccc(N)c1
# Molecule 5769 Reconstructed valid CCNC(=O)[C@H](C)Sc1cccc(N)c1
# Molecule 5783 Original Valid NC(=O)N1CCC[C@H]1C(=O)N[C@@H]1CCCN(c2ccccc2Cl)C1
# Molecule 5783 Reconstructed valid NC(=O)N1CCC[C@H]1C(=O)N[C@@H]1CCCN(c2ccccc2Cl)C1
# Molecule 5786 Original Valid Cc1cc(C)n(C[C@@H](C)CNC(=O)C[C@@H]2CCS(=O)(=O)C2)n1
# Molecule 5786 Reconstructed valid Cc1cc(C)n(C[C@@H](C)CCC(=O)C[C@@H]2CCS(=O)(=O)O2)n1
# Molecule 5791 Original Valid CC(C)C(=O)N(c1ccc(Br)cc1)[C@H]1C=CS(=O)(=O)C1
# Molecule 5791 Reconstructed valid CC(C)C(=O)N(c1ccc(Br)cc1)[C@H]1C=CS(=O)(=O)C1
# Molecule 5819 Original Valid COc1ncccc1C(=O)NCc1ccccc1C[NH+]1CCCC[C@@H]1C
# Molecule 5819 Reconstructed valid COc1ccccc1C(=O)NCc1ccccc1C[NH+]1CCCC[C@@H]1CO
# Molecule 5830 Original Valid O=c1[nH]c(Cc2ccc([N+](=O)[O-])cc2)nc2scc(-c3ccccc3)c12
# Molecule 5830 Reconstructed valid O=C1[nH]c(Cccccc([N+](=O)[O-])cc2)nccscc(-c3ccccc3)c12
# Molecule 5860 Original Valid CC(C)(C)c1ncc(C(=O)Nc2cccc(C(=O)N3CCCCC3)c2)cn1
# Molecule 5860 Reconstructed valid CC(C)(C)c1ncc(C(=O)Nc2cccc(C(=O)N3CCCCC3)c2)cc1
# Molecule 5865 Original Valid CC(C)[NH+](C)CCOCC[NH3+]
# Molecule 5865 Reconstructed valid CC(C)[CH+](C)CCCCC[NH3+]
# Molecule 5884 Original Valid C=CCn1c([C@H](C)NC(=O)COC)nc2ccccc21
# Molecule 5884 Reconstructed valid CCCCn1c([C@H](C)NC(=O)CCC)nc2ccccc21
# Molecule 5893 Original Valid CCOC(=O)[C@H]1C(=O)C=C(c2ccc(C)cc2)C[C@H]1c1cccc(F)c1
# Molecule 5893 Reconstructed valid CCOC(=O)[C@H]1C(=N)C=C(c2ccc(C)cc2)C[C@H]1c1cccc(F)c1
# Molecule 5898 Original Valid COc1c(C)cc(C[NH2+]Cc2n[nH]c(-c3ccco3)n2)cc1C
# Molecule 5898 Reconstructed valid COc1c(C)cc(C[NH2+]Cc2n[nH]c(-c3ccco3)n2)cc1C
# Molecule 5937 Original Valid CC1=C(C)C[C@@H](C(=O)[O-])[C@@H](C(=O)NCCN2CCOCC2)C1
# Molecule 5937 Reconstructed valid Cc1cn(C)C[C@@H](C(=O)[C-])[C@@H](C(=O)NCCN2CCOCC2)C1
# Molecule 5957 Original Valid CCn1nnnc1COc1ccc(C(=O)Nc2c(C)nsc2C)cc1
# Molecule 5957 Reconstructed valid CCn1nnnc1COc1ccc(C(=O)Nc2c(C)nsc2C)cc1
# Molecule 5988 Original Valid O=C(C1CCCC1)N1CCCCCC1
# Molecule 5988 Reconstructed valid O=C(CCCCCCO)N1CCCCCC1
# Molecule 5998 Original Valid CC(C)(C)c1nc(CN2CCN(C(=O)[C@@H]3C[C@H]4CC[C@@H]3C4)CC2)no1
# Molecule 5998 Reconstructed valid CC(C)(C)c1nc(CN2CCN(C(=O)[C@@H]3C[C@H]4CC[C@@H]3C4)CC2)no1
# Molecule 6001 Original Valid C[NH2+]CC(=O)N1CCC[C@@H](c2cccc(C)n2)C1
# Molecule 6001 Reconstructed valid C[NH2+]NC(=O)N1CCC[C@@H](c2cccc(C)n2)C1
# Molecule 6010 Original Valid CC(C)n1ncnc1C[C@@H](O)c1ccc(Cl)cn1
# Molecule 6010 Reconstructed valid CC(C)n1ncnc1C[C@@H](O)c1ccc(Cl)cn1
# Molecule 6014 Original Valid C[NH+](CC1CC([O-])C1)[C@@H]1CCOC2(CCCCC2)C1
# Molecule 6014 Reconstructed valid C[NH+](CCCCC([O-])CC)[C@@H]1CCOC2(CNCCC2)C1
# Molecule 6015 Original Valid Cc1nn(CC(=O)[O-])c(C)c1S(=O)(=O)N1CCC(C)(C)C1
# Molecule 6015 Reconstructed valid Cc1=C(CC(=O)[O-])c(C)c1S(=O)(=O)N1CCC(C)(C)C1
# Molecule 6017 Original Valid COc1ccc(C(=O)CCC(=O)N2C[C@@H](C)OC[C@@H]2C)cc1F
# Molecule 6017 Reconstructed valid COc1ccc(C(=O)NCC(=O)N2C[C@@H](C)CC[C@@H]2C)cc1F
# Molecule 6054 Original Valid O=C(NC[C@@H]1CC[NH+](Cc2cccc(O)c2)C1)c1cc2ccccc2[nH]1
# Molecule 6054 Reconstructed valid O=C(NC[C@@H]1CC[NH+](Cc2cccc(O)c2)C1)c1cc2ccccc2[nH]1
# Molecule 6067 Original Valid Cc1nnc(Nc2ccccc2)o1
# Molecule 6067 Reconstructed valid Cc1nnc(Nc2ccccc2)o1
# Molecule 6078 Original Valid CN(C)C(=O)Nc1cccc(C(=O)N[C@H](CC(F)(F)F)c2ccc(F)cc2)c1
# Molecule 6078 Reconstructed valid CN(C)C(=O)Nc1cccc(C(=O)N[C@H](CC(F)(F)F)c2ccc(F)cc2)c1
# Molecule 6089 Original Valid CC(C)C[NH+]1CCN(C(=O)N[C@H](C)c2cccc(-n3cccn3)c2)CC1
# Molecule 6089 Reconstructed valid CC(C)C[CH+]1CCN(C(=O)N[C@H](C)c2cccc(-n3cccn3)c2)cC1
# Molecule 6097 Original Valid CC(=O)Nc1cccc(F)c1
# Molecule 6097 Reconstructed valid CC(=O)Nc1cccc(F)c1
# Molecule 6118 Original Valid CN(C)C(=O)CNC(=O)Nc1ccc(F)cc1Cl
# Molecule 6118 Reconstructed valid CN(C)C(=O)CNC(=O)Cc1ccc(F)cc1Cl
# Molecule 6126 Original Valid Cc1n[nH]c(C)c1CCC(=O)NCC[NH+]1CCC[C@@H](C)C1
# Molecule 6126 Reconstructed valid Cc1n[nH]c(C)c1CCC(=O)NCC[NH+]1CCC[C@@H](C)C1
# Molecule 6139 Original Valid C[C@H](Cc1ccc([N+](=O)[O-])cc1)C(=O)[O-]
# Molecule 6139 Reconstructed valid C[C@H](Cc1ccc([N+](=O)[O-])cc1)C(=O)[O-]
# /usr/local/lib/python3.7/site-packages/rdkit/Chem/Draw/IPythonConsole.py:192: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   % (maxMols))

# %%
print("Validity Percentage of Training Reconstructed Molecules", (len(mols_reconst_train_valid)/len(mols_reconst_train))*100, "%")
print("Validity Percentage of Testing Reconstructed Molecules", (len(mols_reconst_test_valid)/len(mols_reconst_test))*100,"%")
# Out:
# Validity Percentage of Training Reconstructed Molecules 5.303152789005659 %
# Validity Percentage of Testing Reconstructed Molecules 0.3232062055591467 %

# %% [markdown]
# # **Generating New Valid Molecules from Normal Distribution**

# %%
syntax_val_new={0:[], 1:[]}


smi_reconst_new=[]
smi_reconst_new_valid=[]

mols_reconst_new= []
mols_reconst_new_valid=[]

n_mol=10000

latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))

#Passing it to Decoder
reconst_sample = decoder.predict(latent_samples)
reconst_smi=reconst_sample.reshape(n_mol, mol_size_x, mol_size_y) 

for id, latent_mol in enumerate(reconst_smi):
  smi="".join([int_to_char[idx] for idx in np.argmax(reconst_smi[id,:,:], axis=1)])
  smi = re.sub('!|E',"", smi)
  smi_reconst_new.append(smi)

  mol = Chem.MolFromSmiles(smi, sanitize=True)
  mols_reconst_new.append(mol)
  if mol is None:
    syntax_val_new[0].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t invalid SMILES", sep=' ')
    # print(mol, end ='\n', sep= ' ')
    continue
  else:
    syntax_val_new[1].append(id)
    # print('Mol', id+1, "\t length =",len(smi), "\t",  smi, "\t Valid New Smiles", sep=' ', end ='\n', flush = True)
    try:
      Chem.SanitizeMol(mol)      
    except:
      print('Mol {} {}'.format(id+1, mol)) 

i=1
for item in syntax_val_new[1]:
  smi_reconst_new_valid.append(smi_reconst_new[item].rstrip('\n'))
  mols_reconst_new_valid.append(mols_reconst_new[item])
  print("New valid Molecule", i, smi_reconst_new[item], "Index=", item)
  i=i+1

print(len(mols_reconst_new_valid), "New Valid Molecules")
Draw.MolsToGridImage(mols_reconst_new_valid, molsPerRow=4,subImgSize=(200,200))
# Out:
# New valid Molecule 1 COc1ccccCNC(=O)CnCCnnncccc1 Index= 9055
# 1 New Valid Molecules

# %% [markdown]
# # **Property Acceptance of Newly Generated Valid Molecules**

# %%
# Calculating mean and standard deviation of all property values on test data

SAS_mean_test= np.mean(y_test_property, axis=0)
SAS_std_test = np.std(y_test_property, axis=0)
print("Mean of SAS Property Value", SAS_mean_test)
print("Standard Deviation of SAS Property Value", SAS_std_test)

# Predicting Properties of New Valid Molecules

if len(syntax_val_new[1])!=0:
  predicted_prop_samples=predictor.predict(latent_samples[syntax_val_new[1]])
  for ((id,item), val_mol_id) in zip(enumerate(predicted_prop_samples), syntax_val_new[1]):
    # print(id)
    e=predicted_prop_samples[id][0]<(SAS_mean_test+SAS_std_test)
    f=predicted_prop_samples[id][0]>=(SAS_mean_test-SAS_std_test)
    print("Predicted Properties of molecule ", val_mol_id,predicted_prop_samples[id][0])
    if (e & f):
      print("Mol having index {}, Property Validated".format(val_mol_id))    
    else:    
      print("Mol having index {}, Property Invalidated".format(val_mol_id))
else:
  print("No Valid Molecule Generated")
# Out:
# Mean of SAS Property Value [3.03445567]
# Standard Deviation of SAS Property Value [0.83916364]
# Predicted Properties of molecule  9055 8.336451
# Mol having index 9055, Property Invalidated

# %%
# print(syntax_val_new[1])
# print(predicted_prop_samples.shape)
# print(predicted_prop_samples)
# print(type(predicted_prop_samples))
