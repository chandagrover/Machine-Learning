# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SMILEVAEMultipleProperty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# !pip install tensorflow==1.12
# !pip install keras==2.2.4
# !pip install h5py
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.12 (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.1.2, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2, 2.4.0rc3)
# ERROR: No matching distribution found for tensorflow==1.12
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.7/site-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.19.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.5.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (5.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.14.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py->keras==2.2.4) (1.5.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/site-packages (from h5py) (1.19.4)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py) (1.5.2)

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-11-25 10:49:23--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2020-11-25 10:49:23--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - ca-certificates==2020.1.1=0
#     - certifi==2020.4.5.1=py37_0
#     - cffi==1.14.0=py37he30daa8_1
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.1=py37h7b6447c_0
#     - conda==4.8.3=py37_0
#     - cryptography==2.9.2=py37h1ba5d50_0
#     - idna==2.9=py_1
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.3=he6710b0_1
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1g=h7b6447c_0
#     - pip==20.0.2=py37_3
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.20=py_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.7=hcff3b4d_5
#     - readline==8.0=h7b6447c_0
#     - requests==2.23.0=py37_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==46.4.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h62c20be_1
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.46.0=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.11.8-py37h8~ --> pkgs/main::certifi-2020.4.5.1-py37_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.8.3-py37_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m32.193s
# user	0m33.425s
# sys	0m6.344s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.11.8-ha878542_0
#   certifi              pkgs/main::certifi-2020.4.5.1-py37_0 --> conda-forge::certifi-2020.11.8-py37h89c1867_0
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.9.2-py37h89c1867_0
#   openssl              pkgs/main::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1h-h516909a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# real	0m12.738s
# user	0m11.456s
# sys	0m1.188s

# %%
# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re

# FOR VAE Architecture 
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model
from keras.losses import mse, binary_crossentropy
import keras
from keras import layers
import tensorflow as tf
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import rdkit
print("RDKit: %s"%rdkit.__version__)
print("Keras: %s"%keras.__version__)
# Out:
# RDKit: 2020.09.1
# Keras: 2.2.4

# %% [markdown]
# # **Data Fetching**

# %%
WEIGHTS_FOLDER = 'sample_data/weights/'
smifile = "sample_data/SMILEWithProp.csv"
data = pd.read_csv(smifile, delimiter = ",", header='infer')
NUM_SMILES = len(data)
data.head()
# Out:
#                                               smiles  ...       SAS
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  ...  2.084095
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print(smiles_train.shape)
print(smiles_test.shape)
print(NUM_SMILES)
# Out:
# (1207, 4)
# (302, 4)
# 1509

# %%
logP_train = smiles_train['logP']
logP_test = smiles_test['logP']

qed_train=smiles_train['qed']
qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([logP_train, qed_train, SAS_train])
test= np.array([logP_test, qed_test, SAS_test])
y_train_property=train.transpose()
y_test_property=test.transpose()

# %%
#Labels for the Smiles String. We will deal with three properties values.
print(type(y_train_property))
print(type(y_test_property))
print(y_train_property.shape)
print(y_test_property.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1207, 3)
# (302, 3)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(len(charset), embed)
# print(embed)
# Out:
# 40 108

# %%
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
# Out:
# (1207, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=281
print(smiles_train['smiles'][idx])
from rdkit.Chem.Draw import IPythonConsole
m = Chem.MolFromSmiles(smiles_train['smiles'][idx])
m
# Out:
# Cc1ccc(NC(=S)NC(C)C)cc1C

# %%
# Going back from vectorized form back to a readable string
strr="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
line = re.sub('[!E]', '', strr)
print(len(line))
print(line)
m = Chem.MolFromSmiles(line)
m
# Out:
# 25
# Cc1ccc(NC(=S)NC(C)C)cc1C

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print(orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# 4320

# %% [markdown]
# # **VAE with Predictor**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=20 # Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(3, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# ### **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input

  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  vae_output = vae_decoder(vae_encoder_output)

  # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE with Predictor')

  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()

# %% [markdown]
# ### **VAE Loss Function**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
    
  vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  return vae_loss_val

# %% [markdown]
# **Plotting all models**

# %%
# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='smilesvae_predictor.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False


# Plot the Encoder Model
plot_model(encoder, to_file='only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

#Plot the Predictor Model
plot_model(predictor, to_file='only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# plot_model(vae_model, to_file='smilesvae_model.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False

# %% [markdown]
# **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "sample_data/train_ckpt/cp.ckpt"
new_check_path='VAE_Predictor{epoch:02d}.h5'            #'VAE_Predictor{epoch:02d}.h5'
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=new_check_path, verbose=1, save_weights_only=False, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(new_check_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **Training or Loading the VAE-Predictor Model**

# %%
pre_trained=True
epochs=500
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[1.0, 20.0]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )   
      vae_predictor.save(new_check_path)
    else:
      vae_predictor.load_weights(new_check_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback]) 
      vae_predictor.save(new_check_path)
# Out:
# Train on 1207 samples, validate on 302 samples
# Epoch 1/500
#  - 3s - loss: 29.2140 - decoder_loss: 29.0335 - predictor_loss: 0.0090 - val_loss: 32.8512 - val_decoder_loss: 32.6600 - val_predictor_loss: 0.0096
#
# Epoch 00001: val_loss did not improve from 31.89801
# Epoch 2/500
#  - 3s - loss: 29.3347 - decoder_loss: 29.1476 - predictor_loss: 0.0094 - val_loss: 32.3409 - val_decoder_loss: 32.1228 - val_predictor_loss: 0.0109
#
# Epoch 00002: val_loss did not improve from 31.89801
# Epoch 3/500
#  - 3s - loss: 28.7861 - decoder_loss: 28.6120 - predictor_loss: 0.0087 - val_loss: 32.7488 - val_decoder_loss: 32.5374 - val_predictor_loss: 0.0106
#
# Epoch 00003: val_loss did not improve from 31.89801
# Epoch 4/500
#  - 3s - loss: 28.9669 - decoder_loss: 28.7659 - predictor_loss: 0.0100 - val_loss: 32.9330 - val_decoder_loss: 32.7171 - val_predictor_loss: 0.0108
#
# Epoch 00004: val_loss did not improve from 31.89801
# Epoch 5/500
#  - 3s - loss: 29.1364 - decoder_loss: 28.9271 - predictor_loss: 0.0105 - val_loss: 32.7805 - val_decoder_loss: 32.5754 - val_predictor_loss: 0.0103
#
# Epoch 00005: val_loss did not improve from 31.89801
# Epoch 6/500
#  - 3s - loss: 29.2958 - decoder_loss: 29.0971 - predictor_loss: 0.0099 - val_loss: 32.3407 - val_decoder_loss: 32.0592 - val_predictor_loss: 0.0141
#
# Epoch 00006: val_loss did not improve from 31.89801
# Epoch 7/500
#  - 3s - loss: 29.3188 - decoder_loss: 29.1270 - predictor_loss: 0.0096 - val_loss: 32.9171 - val_decoder_loss: 32.6698 - val_predictor_loss: 0.0124
#
# Epoch 00007: val_loss did not improve from 31.89801
# Epoch 8/500
#  - 3s - loss: 29.1006 - decoder_loss: 28.8785 - predictor_loss: 0.0111 - val_loss: 33.3180 - val_decoder_loss: 33.0350 - val_predictor_loss: 0.0141
#
# Epoch 00008: val_loss did not improve from 31.89801
# Epoch 9/500
#  - 3s - loss: 29.2702 - decoder_loss: 29.0748 - predictor_loss: 0.0098 - val_loss: 32.2570 - val_decoder_loss: 32.0470 - val_predictor_loss: 0.0105
#
# Epoch 00009: val_loss did not improve from 31.89801
# Epoch 10/500
#  - 3s - loss: 29.3069 - decoder_loss: 29.1134 - predictor_loss: 0.0097 - val_loss: 33.1768 - val_decoder_loss: 32.9446 - val_predictor_loss: 0.0116
#
# Epoch 00010: val_loss did not improve from 31.89801
# Epoch 11/500
#  - 3s - loss: 29.0927 - decoder_loss: 28.9062 - predictor_loss: 0.0093 - val_loss: 32.3897 - val_decoder_loss: 32.1559 - val_predictor_loss: 0.0117
#
# Epoch 00011: val_loss did not improve from 31.89801
# Epoch 12/500
#  - 3s - loss: 28.9907 - decoder_loss: 28.8046 - predictor_loss: 0.0093 - val_loss: 32.5866 - val_decoder_loss: 32.3786 - val_predictor_loss: 0.0104
#
# Epoch 00012: val_loss did not improve from 31.89801
# Epoch 13/500
#  - 3s - loss: 29.3048 - decoder_loss: 29.1036 - predictor_loss: 0.0101 - val_loss: 32.7129 - val_decoder_loss: 32.4963 - val_predictor_loss: 0.0108
#
# Epoch 00013: val_loss did not improve from 31.89801
# Epoch 14/500
#  - 3s - loss: 29.1125 - decoder_loss: 28.9112 - predictor_loss: 0.0101 - val_loss: 32.5147 - val_decoder_loss: 32.2924 - val_predictor_loss: 0.0111
#
# Epoch 00014: val_loss did not improve from 31.89801
# Epoch 15/500
#  - 3s - loss: 29.2858 - decoder_loss: 29.0983 - predictor_loss: 0.0094 - val_loss: 32.7312 - val_decoder_loss: 32.4941 - val_predictor_loss: 0.0119
#
# Epoch 00015: val_loss did not improve from 31.89801
# Epoch 16/500
#  - 3s - loss: 29.3509 - decoder_loss: 29.1329 - predictor_loss: 0.0109 - val_loss: 32.7797 - val_decoder_loss: 32.5441 - val_predictor_loss: 0.0118
#
# Epoch 00016: val_loss did not improve from 31.89801
# Epoch 17/500
#  - 3s - loss: 28.9399 - decoder_loss: 28.7289 - predictor_loss: 0.0105 - val_loss: 32.9223 - val_decoder_loss: 32.5573 - val_predictor_loss: 0.0183
#
# Epoch 00017: val_loss did not improve from 31.89801
# Epoch 18/500
#  - 3s - loss: 29.0770 - decoder_loss: 28.8730 - predictor_loss: 0.0102 - val_loss: 32.4393 - val_decoder_loss: 32.1682 - val_predictor_loss: 0.0136
#
# Epoch 00018: val_loss did not improve from 31.89801
# Epoch 19/500
#  - 3s - loss: 28.9783 - decoder_loss: 28.7868 - predictor_loss: 0.0096 - val_loss: 32.5457 - val_decoder_loss: 32.3041 - val_predictor_loss: 0.0121
#
# Epoch 00019: val_loss did not improve from 31.89801
# Epoch 20/500
#  - 3s - loss: 28.7944 - decoder_loss: 28.5856 - predictor_loss: 0.0104 - val_loss: 32.7398 - val_decoder_loss: 32.4974 - val_predictor_loss: 0.0121
#
# Epoch 00020: val_loss did not improve from 31.89801
# Epoch 21/500
#  - 3s - loss: 29.1749 - decoder_loss: 28.9730 - predictor_loss: 0.0101 - val_loss: 33.0292 - val_decoder_loss: 32.8118 - val_predictor_loss: 0.0109
#
# Epoch 00021: val_loss did not improve from 31.89801
# Epoch 22/500
#  - 3s - loss: 29.1489 - decoder_loss: 28.9600 - predictor_loss: 0.0094 - val_loss: 32.8201 - val_decoder_loss: 32.6032 - val_predictor_loss: 0.0108
#
# Epoch 00022: val_loss did not improve from 31.89801
# Epoch 23/500
#  - 3s - loss: 29.1386 - decoder_loss: 28.9507 - predictor_loss: 0.0094 - val_loss: 32.3349 - val_decoder_loss: 32.0764 - val_predictor_loss: 0.0129
#
# Epoch 00023: val_loss did not improve from 31.89801
# Epoch 24/500
#  - 3s - loss: 29.2018 - decoder_loss: 29.0096 - predictor_loss: 0.0096 - val_loss: 32.8503 - val_decoder_loss: 32.6455 - val_predictor_loss: 0.0102
#
# Epoch 00024: val_loss did not improve from 31.89801
# Epoch 25/500
#  - 3s - loss: 29.1927 - decoder_loss: 29.0111 - predictor_loss: 0.0091 - val_loss: 32.9626 - val_decoder_loss: 32.7634 - val_predictor_loss: 0.0100
#
# Epoch 00025: val_loss did not improve from 31.89801
# Epoch 26/500
#  - 3s - loss: 28.8722 - decoder_loss: 28.6902 - predictor_loss: 0.0091 - val_loss: 33.3019 - val_decoder_loss: 33.0895 - val_predictor_loss: 0.0106
#
# Epoch 00026: val_loss did not improve from 31.89801
# Epoch 27/500
#  - 3s - loss: 28.9984 - decoder_loss: 28.8041 - predictor_loss: 0.0097 - val_loss: 32.5533 - val_decoder_loss: 32.3571 - val_predictor_loss: 0.0098
#
# Epoch 00027: val_loss did not improve from 31.89801
# Epoch 28/500
#  - 3s - loss: 29.2094 - decoder_loss: 29.0147 - predictor_loss: 0.0097 - val_loss: 32.4993 - val_decoder_loss: 32.2445 - val_predictor_loss: 0.0127
#
# Epoch 00028: val_loss did not improve from 31.89801
# Epoch 29/500
#  - 3s - loss: 28.8716 - decoder_loss: 28.6651 - predictor_loss: 0.0103 - val_loss: 33.2864 - val_decoder_loss: 33.0548 - val_predictor_loss: 0.0116
#
# Epoch 00029: val_loss did not improve from 31.89801
# Epoch 30/500
#  - 3s - loss: 29.3201 - decoder_loss: 29.1188 - predictor_loss: 0.0101 - val_loss: 33.2628 - val_decoder_loss: 32.8724 - val_predictor_loss: 0.0195
#
# Epoch 00030: val_loss did not improve from 31.89801
# Epoch 31/500
#  - 3s - loss: 29.2778 - decoder_loss: 29.0477 - predictor_loss: 0.0115 - val_loss: 32.7191 - val_decoder_loss: 32.4374 - val_predictor_loss: 0.0141
#
# Epoch 00031: val_loss did not improve from 31.89801
# Epoch 32/500
#  - 3s - loss: 29.0472 - decoder_loss: 28.8203 - predictor_loss: 0.0113 - val_loss: 32.5881 - val_decoder_loss: 32.3538 - val_predictor_loss: 0.0117
#
# Epoch 00032: val_loss did not improve from 31.89801
# Epoch 33/500
#  - 3s - loss: 29.0769 - decoder_loss: 28.8789 - predictor_loss: 0.0099 - val_loss: 32.3633 - val_decoder_loss: 32.1475 - val_predictor_loss: 0.0108
#
# Epoch 00033: val_loss did not improve from 31.89801
# Epoch 34/500
#  - 3s - loss: 28.7874 - decoder_loss: 28.5957 - predictor_loss: 0.0096 - val_loss: 32.7685 - val_decoder_loss: 32.5409 - val_predictor_loss: 0.0114
#
# Epoch 00034: val_loss did not improve from 31.89801
# Epoch 35/500
#  - 3s - loss: 29.0351 - decoder_loss: 28.8558 - predictor_loss: 0.0090 - val_loss: 32.6327 - val_decoder_loss: 32.4358 - val_predictor_loss: 0.0098
#
# Epoch 00035: val_loss did not improve from 31.89801
# Epoch 36/500
#  - 3s - loss: 29.1208 - decoder_loss: 28.9361 - predictor_loss: 0.0092 - val_loss: 32.9165 - val_decoder_loss: 32.7178 - val_predictor_loss: 0.0099
#
# Epoch 00036: val_loss did not improve from 31.89801
# Epoch 37/500
#  - 3s - loss: 29.0732 - decoder_loss: 28.8685 - predictor_loss: 0.0102 - val_loss: 33.0591 - val_decoder_loss: 32.8331 - val_predictor_loss: 0.0113
#
# Epoch 00037: val_loss did not improve from 31.89801
# Epoch 38/500
#  - 3s - loss: 29.1247 - decoder_loss: 28.9310 - predictor_loss: 0.0097 - val_loss: 32.8985 - val_decoder_loss: 32.6450 - val_predictor_loss: 0.0127
#
# Epoch 00038: val_loss did not improve from 31.89801
# Epoch 39/500
#  - 3s - loss: 29.2934 - decoder_loss: 29.0828 - predictor_loss: 0.0105 - val_loss: 32.3630 - val_decoder_loss: 32.1267 - val_predictor_loss: 0.0118
#
# Epoch 00039: val_loss did not improve from 31.89801
# Epoch 40/500
#  - 3s - loss: 29.2409 - decoder_loss: 29.0457 - predictor_loss: 0.0098 - val_loss: 32.9975 - val_decoder_loss: 32.7487 - val_predictor_loss: 0.0124
#
# Epoch 00040: val_loss did not improve from 31.89801
# Epoch 41/500
#  - 3s - loss: 29.1379 - decoder_loss: 28.9128 - predictor_loss: 0.0113 - val_loss: 32.6933 - val_decoder_loss: 32.4325 - val_predictor_loss: 0.0130
#
# Epoch 00041: val_loss did not improve from 31.89801
# Epoch 42/500
#  - 3s - loss: 29.0066 - decoder_loss: 28.8114 - predictor_loss: 0.0098 - val_loss: 32.9817 - val_decoder_loss: 32.7774 - val_predictor_loss: 0.0102
#
# Epoch 00042: val_loss did not improve from 31.89801
# Epoch 43/500
#  - 3s - loss: 29.0347 - decoder_loss: 28.8640 - predictor_loss: 0.0085 - val_loss: 32.4960 - val_decoder_loss: 32.3043 - val_predictor_loss: 0.0096
#
# Epoch 00043: val_loss did not improve from 31.89801
# Epoch 44/500
#  - 3s - loss: 29.2055 - decoder_loss: 29.0355 - predictor_loss: 0.0085 - val_loss: 32.6439 - val_decoder_loss: 32.4479 - val_predictor_loss: 0.0098
#
# Epoch 00044: val_loss did not improve from 31.89801
# Epoch 45/500
#  - 3s - loss: 28.8027 - decoder_loss: 28.6175 - predictor_loss: 0.0093 - val_loss: 32.5491 - val_decoder_loss: 32.3478 - val_predictor_loss: 0.0101
#
# Epoch 00045: val_loss did not improve from 31.89801
# Epoch 46/500
#  - 3s - loss: 29.1656 - decoder_loss: 28.9922 - predictor_loss: 0.0087 - val_loss: 33.0710 - val_decoder_loss: 32.8442 - val_predictor_loss: 0.0113
#
# Epoch 00046: val_loss did not improve from 31.89801
# Epoch 47/500
#  - 3s - loss: 29.3248 - decoder_loss: 29.1289 - predictor_loss: 0.0098 - val_loss: 32.4356 - val_decoder_loss: 32.1897 - val_predictor_loss: 0.0123
#
# Epoch 00047: val_loss did not improve from 31.89801
# Epoch 48/500
#  - 3s - loss: 29.2940 - decoder_loss: 29.1008 - predictor_loss: 0.0097 - val_loss: 32.7808 - val_decoder_loss: 32.5492 - val_predictor_loss: 0.0116
#
# Epoch 00048: val_loss did not improve from 31.89801
# Epoch 49/500
#  - 3s - loss: 28.8697 - decoder_loss: 28.6863 - predictor_loss: 0.0092 - val_loss: 32.8032 - val_decoder_loss: 32.5755 - val_predictor_loss: 0.0114
#
# Epoch 00049: val_loss did not improve from 31.89801
# Epoch 50/500
#  - 3s - loss: 28.8822 - decoder_loss: 28.6914 - predictor_loss: 0.0095 - val_loss: 32.2901 - val_decoder_loss: 32.0618 - val_predictor_loss: 0.0114
#
# Epoch 00050: val_loss did not improve from 31.89801
# Epoch 51/500
#  - 3s - loss: 28.9732 - decoder_loss: 28.7776 - predictor_loss: 0.0098 - val_loss: 32.7182 - val_decoder_loss: 32.5252 - val_predictor_loss: 0.0097
#
# Epoch 00051: val_loss did not improve from 31.89801
# Epoch 52/500
#  - 3s - loss: 29.0994 - decoder_loss: 28.9069 - predictor_loss: 0.0096 - val_loss: 32.9000 - val_decoder_loss: 32.6711 - val_predictor_loss: 0.0114
#
# Epoch 00052: val_loss did not improve from 31.89801
# Epoch 53/500
#  - 3s - loss: 28.9622 - decoder_loss: 28.7743 - predictor_loss: 0.0094 - val_loss: 33.1102 - val_decoder_loss: 32.8739 - val_predictor_loss: 0.0118
#
# Epoch 00053: val_loss did not improve from 31.89801
# Epoch 54/500
#  - 3s - loss: 29.2304 - decoder_loss: 29.0300 - predictor_loss: 0.0100 - val_loss: 32.9930 - val_decoder_loss: 32.7514 - val_predictor_loss: 0.0121
#
# Epoch 00054: val_loss did not improve from 31.89801
# Epoch 55/500
#  - 3s - loss: 29.3038 - decoder_loss: 29.0975 - predictor_loss: 0.0103 - val_loss: 32.2291 - val_decoder_loss: 32.0031 - val_predictor_loss: 0.0113
#
# Epoch 00055: val_loss did not improve from 31.89801
# Epoch 56/500
#  - 3s - loss: 29.2396 - decoder_loss: 29.0420 - predictor_loss: 0.0099 - val_loss: 32.4258 - val_decoder_loss: 32.2198 - val_predictor_loss: 0.0103
#
# Epoch 00056: val_loss did not improve from 31.89801
# Epoch 57/500
#  - 3s - loss: 29.0243 - decoder_loss: 28.8264 - predictor_loss: 0.0099 - val_loss: 32.4045 - val_decoder_loss: 32.1979 - val_predictor_loss: 0.0103
#
# Epoch 00057: val_loss did not improve from 31.89801
# Epoch 58/500
#  - 3s - loss: 29.0256 - decoder_loss: 28.8140 - predictor_loss: 0.0106 - val_loss: 32.4501 - val_decoder_loss: 32.2433 - val_predictor_loss: 0.0103
#
# Epoch 00058: val_loss did not improve from 31.89801
# Epoch 59/500
#  - 3s - loss: 29.3565 - decoder_loss: 29.1345 - predictor_loss: 0.0111 - val_loss: 32.6937 - val_decoder_loss: 32.3676 - val_predictor_loss: 0.0163
#
# Epoch 00059: val_loss did not improve from 31.89801
# Epoch 60/500
#  - 3s - loss: 29.2174 - decoder_loss: 28.9876 - predictor_loss: 0.0115 - val_loss: 32.4907 - val_decoder_loss: 32.2510 - val_predictor_loss: 0.0120
#
# Epoch 00060: val_loss did not improve from 31.89801
# Epoch 61/500
#  - 3s - loss: 29.1593 - decoder_loss: 28.9387 - predictor_loss: 0.0110 - val_loss: 32.6605 - val_decoder_loss: 32.4463 - val_predictor_loss: 0.0107
#
# Epoch 00061: val_loss did not improve from 31.89801
# Epoch 62/500
#  - 3s - loss: 28.9969 - decoder_loss: 28.7991 - predictor_loss: 0.0099 - val_loss: 32.5162 - val_decoder_loss: 32.3071 - val_predictor_loss: 0.0105
#
# Epoch 00062: val_loss did not improve from 31.89801
# Epoch 63/500
#  - 3s - loss: 29.1885 - decoder_loss: 28.9901 - predictor_loss: 0.0099 - val_loss: 32.6023 - val_decoder_loss: 32.3054 - val_predictor_loss: 0.0148
#
# Epoch 00063: val_loss did not improve from 31.89801
# Epoch 64/500
#  - 3s - loss: 29.0539 - decoder_loss: 28.8519 - predictor_loss: 0.0101 - val_loss: 33.2303 - val_decoder_loss: 32.9863 - val_predictor_loss: 0.0122
#
# Epoch 00064: val_loss did not improve from 31.89801
# Epoch 65/500
#  - 3s - loss: 28.8009 - decoder_loss: 28.5990 - predictor_loss: 0.0101 - val_loss: 33.0574 - val_decoder_loss: 32.8410 - val_predictor_loss: 0.0108
#
# Epoch 00065: val_loss did not improve from 31.89801
# Epoch 66/500
#  - 3s - loss: 28.9330 - decoder_loss: 28.7481 - predictor_loss: 0.0092 - val_loss: 32.4564 - val_decoder_loss: 32.2080 - val_predictor_loss: 0.0124
#
# Epoch 00066: val_loss did not improve from 31.89801
# Epoch 67/500
#  - 3s - loss: 28.9519 - decoder_loss: 28.7540 - predictor_loss: 0.0099 - val_loss: 33.2858 - val_decoder_loss: 33.0492 - val_predictor_loss: 0.0118
#
# Epoch 00067: val_loss did not improve from 31.89801
# Epoch 68/500
#  - 3s - loss: 29.3167 - decoder_loss: 29.1098 - predictor_loss: 0.0103 - val_loss: 32.0463 - val_decoder_loss: 31.8277 - val_predictor_loss: 0.0109
#
# Epoch 00068: val_loss did not improve from 31.89801
# Epoch 69/500
#  - 3s - loss: 29.1653 - decoder_loss: 28.9638 - predictor_loss: 0.0101 - val_loss: 32.4960 - val_decoder_loss: 32.2779 - val_predictor_loss: 0.0109
#
# Epoch 00069: val_loss did not improve from 31.89801
# Epoch 70/500
#  - 3s - loss: 29.1309 - decoder_loss: 28.9298 - predictor_loss: 0.0101 - val_loss: 33.0196 - val_decoder_loss: 32.7981 - val_predictor_loss: 0.0111
#
# Epoch 00070: val_loss did not improve from 31.89801
# Epoch 71/500
#  - 3s - loss: 28.9247 - decoder_loss: 28.7200 - predictor_loss: 0.0102 - val_loss: 33.0384 - val_decoder_loss: 32.8341 - val_predictor_loss: 0.0102
#
# Epoch 00071: val_loss did not improve from 31.89801
# Epoch 72/500
#  - 3s - loss: 29.2545 - decoder_loss: 29.0376 - predictor_loss: 0.0108 - val_loss: 32.8263 - val_decoder_loss: 32.6180 - val_predictor_loss: 0.0104
#
# Epoch 00072: val_loss did not improve from 31.89801
# Epoch 73/500
#  - 3s - loss: 29.2889 - decoder_loss: 29.0951 - predictor_loss: 0.0097 - val_loss: 32.8207 - val_decoder_loss: 32.5935 - val_predictor_loss: 0.0114
#
# Epoch 00073: val_loss did not improve from 31.89801
# Epoch 74/500
#  - 3s - loss: 29.0989 - decoder_loss: 28.9042 - predictor_loss: 0.0097 - val_loss: 32.6354 - val_decoder_loss: 32.4273 - val_predictor_loss: 0.0104
#
# Epoch 00074: val_loss did not improve from 31.89801
# Epoch 75/500
#  - 3s - loss: 28.9101 - decoder_loss: 28.7305 - predictor_loss: 0.0090 - val_loss: 32.6279 - val_decoder_loss: 32.4287 - val_predictor_loss: 0.0100
#
# Epoch 00075: val_loss did not improve from 31.89801
# Epoch 76/500
#  - 3s - loss: 29.0271 - decoder_loss: 28.8235 - predictor_loss: 0.0102 - val_loss: 33.1412 - val_decoder_loss: 32.9093 - val_predictor_loss: 0.0116
#
# Epoch 00076: val_loss did not improve from 31.89801
# Epoch 77/500
#  - 3s - loss: 29.0604 - decoder_loss: 28.8799 - predictor_loss: 0.0090 - val_loss: 32.3750 - val_decoder_loss: 32.1789 - val_predictor_loss: 0.0098
#
# Epoch 00077: val_loss did not improve from 31.89801
# Epoch 78/500
#  - 3s - loss: 29.1242 - decoder_loss: 28.9387 - predictor_loss: 0.0093 - val_loss: 33.0044 - val_decoder_loss: 32.7256 - val_predictor_loss: 0.0139
#
# Epoch 00078: val_loss did not improve from 31.89801
# Epoch 79/500
#  - 3s - loss: 29.0499 - decoder_loss: 28.8534 - predictor_loss: 0.0098 - val_loss: 32.4479 - val_decoder_loss: 32.2293 - val_predictor_loss: 0.0109
#
# Epoch 00079: val_loss did not improve from 31.89801
# Epoch 80/500
#  - 3s - loss: 28.7070 - decoder_loss: 28.5318 - predictor_loss: 0.0088 - val_loss: 32.3743 - val_decoder_loss: 32.1672 - val_predictor_loss: 0.0104
#
# Epoch 00080: val_loss did not improve from 31.89801
# Epoch 81/500
#  - 3s - loss: 29.0855 - decoder_loss: 28.9052 - predictor_loss: 0.0090 - val_loss: 33.2899 - val_decoder_loss: 33.0273 - val_predictor_loss: 0.0131
#
# Epoch 00081: val_loss did not improve from 31.89801
# Epoch 82/500
#  - 3s - loss: 29.1791 - decoder_loss: 28.9849 - predictor_loss: 0.0097 - val_loss: 33.4887 - val_decoder_loss: 33.2155 - val_predictor_loss: 0.0137
#
# Epoch 00082: val_loss did not improve from 31.89801
# Epoch 83/500
#  - 3s - loss: 29.0351 - decoder_loss: 28.8224 - predictor_loss: 0.0106 - val_loss: 32.9200 - val_decoder_loss: 32.7055 - val_predictor_loss: 0.0107
#
# Epoch 00083: val_loss did not improve from 31.89801
# Epoch 84/500
#  - 3s - loss: 28.9778 - decoder_loss: 28.7879 - predictor_loss: 0.0095 - val_loss: 33.1955 - val_decoder_loss: 32.9986 - val_predictor_loss: 0.0098
#
# Epoch 00084: val_loss did not improve from 31.89801
# Epoch 85/500
#  - 3s - loss: 28.8670 - decoder_loss: 28.6798 - predictor_loss: 0.0094 - val_loss: 32.4325 - val_decoder_loss: 32.2224 - val_predictor_loss: 0.0105
#
# Epoch 00085: val_loss did not improve from 31.89801
# Epoch 86/500
#  - 3s - loss: 28.8521 - decoder_loss: 28.6748 - predictor_loss: 0.0089 - val_loss: 32.1592 - val_decoder_loss: 31.9553 - val_predictor_loss: 0.0102
#
# Epoch 00086: val_loss did not improve from 31.89801
# Epoch 87/500
#  - 3s - loss: 28.9039 - decoder_loss: 28.7095 - predictor_loss: 0.0097 - val_loss: 32.4953 - val_decoder_loss: 32.2705 - val_predictor_loss: 0.0112
#
# Epoch 00087: val_loss did not improve from 31.89801
# Epoch 88/500
#  - 3s - loss: 28.9890 - decoder_loss: 28.7950 - predictor_loss: 0.0097 - val_loss: 32.4734 - val_decoder_loss: 32.2271 - val_predictor_loss: 0.0123
#
# Epoch 00088: val_loss did not improve from 31.89801
# Epoch 89/500
#  - 3s - loss: 29.0021 - decoder_loss: 28.7914 - predictor_loss: 0.0105 - val_loss: 32.2718 - val_decoder_loss: 32.0268 - val_predictor_loss: 0.0123
#
# Epoch 00089: val_loss did not improve from 31.89801
# Epoch 90/500
#  - 3s - loss: 28.8321 - decoder_loss: 28.6471 - predictor_loss: 0.0092 - val_loss: 32.5063 - val_decoder_loss: 32.3209 - val_predictor_loss: 0.0093
#
# Epoch 00090: val_loss did not improve from 31.89801
# Epoch 91/500
#  - 3s - loss: 28.9641 - decoder_loss: 28.7823 - predictor_loss: 0.0091 - val_loss: 32.4767 - val_decoder_loss: 32.2746 - val_predictor_loss: 0.0101
#
# Epoch 00091: val_loss did not improve from 31.89801
# Epoch 92/500
#  - 3s - loss: 28.8997 - decoder_loss: 28.7130 - predictor_loss: 0.0093 - val_loss: 32.5040 - val_decoder_loss: 32.2694 - val_predictor_loss: 0.0117
#
# Epoch 00092: val_loss did not improve from 31.89801
# Epoch 93/500
#  - 3s - loss: 29.0597 - decoder_loss: 28.8602 - predictor_loss: 0.0100 - val_loss: 32.7877 - val_decoder_loss: 32.5571 - val_predictor_loss: 0.0115
#
# Epoch 00093: val_loss did not improve from 31.89801
# Epoch 94/500
#  - 3s - loss: 28.8497 - decoder_loss: 28.6566 - predictor_loss: 0.0097 - val_loss: 32.6874 - val_decoder_loss: 32.4829 - val_predictor_loss: 0.0102
#
# Epoch 00094: val_loss did not improve from 31.89801
# Epoch 95/500
#  - 3s - loss: 28.9686 - decoder_loss: 28.7909 - predictor_loss: 0.0089 - val_loss: 32.9171 - val_decoder_loss: 32.6991 - val_predictor_loss: 0.0109
#
# Epoch 00095: val_loss did not improve from 31.89801
# Epoch 96/500
#  - 3s - loss: 29.3088 - decoder_loss: 29.1063 - predictor_loss: 0.0101 - val_loss: 32.3621 - val_decoder_loss: 32.1153 - val_predictor_loss: 0.0123
#
# Epoch 00096: val_loss did not improve from 31.89801
# Epoch 97/500
#  - 3s - loss: 28.9345 - decoder_loss: 28.7357 - predictor_loss: 0.0099 - val_loss: 32.2219 - val_decoder_loss: 32.0174 - val_predictor_loss: 0.0102
#
# Epoch 00097: val_loss did not improve from 31.89801
# Epoch 98/500
#  - 3s - loss: 28.9592 - decoder_loss: 28.7805 - predictor_loss: 0.0089 - val_loss: 32.2954 - val_decoder_loss: 32.0846 - val_predictor_loss: 0.0105
#
# Epoch 00098: val_loss did not improve from 31.89801
# Epoch 99/500
#  - 3s - loss: 28.9478 - decoder_loss: 28.7623 - predictor_loss: 0.0093 - val_loss: 32.1408 - val_decoder_loss: 31.9335 - val_predictor_loss: 0.0104
#
# Epoch 00099: val_loss did not improve from 31.89801
# Epoch 100/500
#  - 3s - loss: 28.7645 - decoder_loss: 28.5565 - predictor_loss: 0.0104 - val_loss: 31.9743 - val_decoder_loss: 31.7694 - val_predictor_loss: 0.0102
#
# Epoch 00100: val_loss did not improve from 31.89801
# Epoch 101/500
#  - 3s - loss: 29.1786 - decoder_loss: 28.9899 - predictor_loss: 0.0094 - val_loss: 32.9933 - val_decoder_loss: 32.7705 - val_predictor_loss: 0.0111
#
# Epoch 00101: val_loss did not improve from 31.89801
# Epoch 102/500
#  - 3s - loss: 28.8246 - decoder_loss: 28.6350 - predictor_loss: 0.0095 - val_loss: 32.4615 - val_decoder_loss: 32.2397 - val_predictor_loss: 0.0111
#
# Epoch 00102: val_loss did not improve from 31.89801
# Epoch 103/500
#  - 3s - loss: 29.1121 - decoder_loss: 28.9173 - predictor_loss: 0.0097 - val_loss: 33.2342 - val_decoder_loss: 33.0112 - val_predictor_loss: 0.0111
#
# Epoch 00103: val_loss did not improve from 31.89801
# Epoch 104/500
#  - 3s - loss: 29.3229 - decoder_loss: 29.1140 - predictor_loss: 0.0104 - val_loss: 32.6579 - val_decoder_loss: 32.4511 - val_predictor_loss: 0.0103
#
# Epoch 00104: val_loss did not improve from 31.89801
# Epoch 105/500
#  - 3s - loss: 29.3325 - decoder_loss: 29.1289 - predictor_loss: 0.0102 - val_loss: 32.6815 - val_decoder_loss: 32.4257 - val_predictor_loss: 0.0128
#
# Epoch 00105: val_loss did not improve from 31.89801
# Epoch 106/500
#  - 3s - loss: 29.1569 - decoder_loss: 28.9621 - predictor_loss: 0.0097 - val_loss: 32.1227 - val_decoder_loss: 31.8916 - val_predictor_loss: 0.0116
#
# Epoch 00106: val_loss did not improve from 31.89801
# Epoch 107/500
#  - 3s - loss: 29.4606 - decoder_loss: 29.2617 - predictor_loss: 0.0099 - val_loss: 32.3680 - val_decoder_loss: 32.1764 - val_predictor_loss: 0.0096
#
# Epoch 00107: val_loss did not improve from 31.89801
# Epoch 108/500
#  - 3s - loss: 29.0596 - decoder_loss: 28.8505 - predictor_loss: 0.0105 - val_loss: 32.3367 - val_decoder_loss: 32.1384 - val_predictor_loss: 0.0099
#
# Epoch 00108: val_loss did not improve from 31.89801
# Epoch 109/500
#  - 3s - loss: 29.0518 - decoder_loss: 28.8476 - predictor_loss: 0.0102 - val_loss: 32.2305 - val_decoder_loss: 32.0266 - val_predictor_loss: 0.0102
#
# Epoch 00109: val_loss did not improve from 31.89801
# Epoch 110/500
#  - 3s - loss: 29.0239 - decoder_loss: 28.8290 - predictor_loss: 0.0097 - val_loss: 32.0977 - val_decoder_loss: 31.9013 - val_predictor_loss: 0.0098
#
# Epoch 00110: val_loss did not improve from 31.89801
# Epoch 111/500
#  - 3s - loss: 28.9153 - decoder_loss: 28.7285 - predictor_loss: 0.0093 - val_loss: 32.7258 - val_decoder_loss: 32.4954 - val_predictor_loss: 0.0115
#
# Epoch 00111: val_loss did not improve from 31.89801
# Epoch 112/500
#  - 3s - loss: 29.1424 - decoder_loss: 28.9459 - predictor_loss: 0.0098 - val_loss: 32.4885 - val_decoder_loss: 32.2498 - val_predictor_loss: 0.0119
#
# Epoch 00112: val_loss did not improve from 31.89801
# Epoch 113/500
#  - 3s - loss: 28.9853 - decoder_loss: 28.7613 - predictor_loss: 0.0112 - val_loss: 32.9407 - val_decoder_loss: 32.6279 - val_predictor_loss: 0.0156
#
# Epoch 00113: val_loss did not improve from 31.89801
# Epoch 114/500
#  - 3s - loss: 29.0299 - decoder_loss: 28.8200 - predictor_loss: 0.0105 - val_loss: 32.4155 - val_decoder_loss: 32.1950 - val_predictor_loss: 0.0110
#
# Epoch 00114: val_loss did not improve from 31.89801
# Epoch 115/500
#  - 3s - loss: 29.0947 - decoder_loss: 28.9029 - predictor_loss: 0.0096 - val_loss: 32.7748 - val_decoder_loss: 32.5178 - val_predictor_loss: 0.0129
#
# Epoch 00115: val_loss did not improve from 31.89801
# Epoch 116/500
#  - 3s - loss: 29.2129 - decoder_loss: 28.9994 - predictor_loss: 0.0107 - val_loss: 32.8391 - val_decoder_loss: 32.6171 - val_predictor_loss: 0.0111
#
# Epoch 00116: val_loss did not improve from 31.89801
# Epoch 117/500
#  - 3s - loss: 28.9389 - decoder_loss: 28.7418 - predictor_loss: 0.0099 - val_loss: 32.2058 - val_decoder_loss: 31.9554 - val_predictor_loss: 0.0125
#
# Epoch 00117: val_loss did not improve from 31.89801
# Epoch 118/500
#  - 3s - loss: 29.3989 - decoder_loss: 29.1860 - predictor_loss: 0.0106 - val_loss: 32.3890 - val_decoder_loss: 32.1728 - val_predictor_loss: 0.0108
#
# Epoch 00118: val_loss did not improve from 31.89801
# Epoch 119/500
#  - 3s - loss: 29.0590 - decoder_loss: 28.8693 - predictor_loss: 0.0095 - val_loss: 32.6981 - val_decoder_loss: 32.4515 - val_predictor_loss: 0.0123
#
# Epoch 00119: val_loss did not improve from 31.89801
# Epoch 120/500
#  - 3s - loss: 28.9453 - decoder_loss: 28.7599 - predictor_loss: 0.0093 - val_loss: 33.0212 - val_decoder_loss: 32.8154 - val_predictor_loss: 0.0103
#
# Epoch 00120: val_loss did not improve from 31.89801
# Epoch 121/500
#  - 3s - loss: 29.2250 - decoder_loss: 29.0410 - predictor_loss: 0.0092 - val_loss: 32.5563 - val_decoder_loss: 32.3580 - val_predictor_loss: 0.0099
#
# Epoch 00121: val_loss did not improve from 31.89801
# Epoch 122/500
#  - 3s - loss: 29.1463 - decoder_loss: 28.9541 - predictor_loss: 0.0096 - val_loss: 33.0387 - val_decoder_loss: 32.7889 - val_predictor_loss: 0.0125
#
# Epoch 00122: val_loss did not improve from 31.89801
# Epoch 123/500
#  - 3s - loss: 28.9087 - decoder_loss: 28.7109 - predictor_loss: 0.0099 - val_loss: 32.6215 - val_decoder_loss: 32.4019 - val_predictor_loss: 0.0110
#
# Epoch 00123: val_loss did not improve from 31.89801
# Epoch 124/500
#  - 3s - loss: 28.8932 - decoder_loss: 28.7050 - predictor_loss: 0.0094 - val_loss: 32.4203 - val_decoder_loss: 32.2110 - val_predictor_loss: 0.0105
#
# Epoch 00124: val_loss did not improve from 31.89801
# Epoch 125/500
#  - 3s - loss: 29.0295 - decoder_loss: 28.8422 - predictor_loss: 0.0094 - val_loss: 32.7484 - val_decoder_loss: 32.5553 - val_predictor_loss: 0.0097
#
# Epoch 00125: val_loss did not improve from 31.89801
# Epoch 126/500
#  - 3s - loss: 29.0915 - decoder_loss: 28.8971 - predictor_loss: 0.0097 - val_loss: 31.9560 - val_decoder_loss: 31.6887 - val_predictor_loss: 0.0134
#
# Epoch 00126: val_loss did not improve from 31.89801
# Epoch 127/500
#  - 3s - loss: 29.0039 - decoder_loss: 28.7992 - predictor_loss: 0.0102 - val_loss: 32.3566 - val_decoder_loss: 32.1397 - val_predictor_loss: 0.0108
#
# Epoch 00127: val_loss did not improve from 31.89801
# Epoch 128/500
#  - 3s - loss: 29.0268 - decoder_loss: 28.8427 - predictor_loss: 0.0092 - val_loss: 31.8906 - val_decoder_loss: 31.6979 - val_predictor_loss: 0.0096
#
# Epoch 00128: val_loss improved from 31.89801 to 31.89063, saving model to VAE_Predictor128.h5
# Epoch 129/500
#  - 3s - loss: 28.9206 - decoder_loss: 28.7391 - predictor_loss: 0.0091 - val_loss: 32.0901 - val_decoder_loss: 31.8469 - val_predictor_loss: 0.0122
#
# Epoch 00129: val_loss did not improve from 31.89063
# Epoch 130/500
#  - 3s - loss: 29.0524 - decoder_loss: 28.8480 - predictor_loss: 0.0102 - val_loss: 32.8352 - val_decoder_loss: 32.6307 - val_predictor_loss: 0.0102
#
# Epoch 00130: val_loss did not improve from 31.89063
# Epoch 131/500
#  - 3s - loss: 29.4085 - decoder_loss: 29.2052 - predictor_loss: 0.0102 - val_loss: 33.3377 - val_decoder_loss: 33.0584 - val_predictor_loss: 0.0140
#
# Epoch 00131: val_loss did not improve from 31.89063
# Epoch 132/500
#  - 3s - loss: 28.9922 - decoder_loss: 28.7853 - predictor_loss: 0.0103 - val_loss: 32.8388 - val_decoder_loss: 32.5243 - val_predictor_loss: 0.0157
#
# Epoch 00132: val_loss did not improve from 31.89063
# Epoch 133/500
#  - 3s - loss: 29.1552 - decoder_loss: 28.9301 - predictor_loss: 0.0113 - val_loss: 33.1146 - val_decoder_loss: 32.8996 - val_predictor_loss: 0.0107
#
# Epoch 00133: val_loss did not improve from 31.89063
# Epoch 134/500
#  - 3s - loss: 29.0244 - decoder_loss: 28.8051 - predictor_loss: 0.0110 - val_loss: 32.1619 - val_decoder_loss: 31.9376 - val_predictor_loss: 0.0112
#
# Epoch 00134: val_loss did not improve from 31.89063
# Epoch 135/500
#  - 3s - loss: 29.1612 - decoder_loss: 28.9495 - predictor_loss: 0.0106 - val_loss: 32.6015 - val_decoder_loss: 32.4064 - val_predictor_loss: 0.0098
#
# Epoch 00135: val_loss did not improve from 31.89063
# Epoch 136/500
#  - 3s - loss: 29.2368 - decoder_loss: 29.0154 - predictor_loss: 0.0111 - val_loss: 32.9412 - val_decoder_loss: 32.7060 - val_predictor_loss: 0.0118
#
# Epoch 00136: val_loss did not improve from 31.89063
# Epoch 137/500
#  - 3s - loss: 29.2505 - decoder_loss: 29.0437 - predictor_loss: 0.0103 - val_loss: 32.2809 - val_decoder_loss: 32.0449 - val_predictor_loss: 0.0118
#
# Epoch 00137: val_loss did not improve from 31.89063
# Epoch 138/500
#  - 3s - loss: 28.8787 - decoder_loss: 28.6886 - predictor_loss: 0.0095 - val_loss: 32.4830 - val_decoder_loss: 32.2519 - val_predictor_loss: 0.0116
#
# Epoch 00138: val_loss did not improve from 31.89063
# Epoch 139/500
#  - 3s - loss: 29.1657 - decoder_loss: 28.9560 - predictor_loss: 0.0105 - val_loss: 32.6811 - val_decoder_loss: 32.4735 - val_predictor_loss: 0.0104
#
# Epoch 00139: val_loss did not improve from 31.89063
# Epoch 140/500
#  - 3s - loss: 28.9620 - decoder_loss: 28.7733 - predictor_loss: 0.0094 - val_loss: 32.5295 - val_decoder_loss: 32.2181 - val_predictor_loss: 0.0156
#
# Epoch 00140: val_loss did not improve from 31.89063
# Epoch 141/500
#  - 3s - loss: 29.0610 - decoder_loss: 28.8569 - predictor_loss: 0.0102 - val_loss: 32.3261 - val_decoder_loss: 32.0643 - val_predictor_loss: 0.0131
#
# Epoch 00141: val_loss did not improve from 31.89063
# Epoch 142/500
#  - 3s - loss: 28.9799 - decoder_loss: 28.7917 - predictor_loss: 0.0094 - val_loss: 32.2039 - val_decoder_loss: 31.9338 - val_predictor_loss: 0.0135
#
# Epoch 00142: val_loss did not improve from 31.89063
# Epoch 143/500
#  - 3s - loss: 28.9981 - decoder_loss: 28.8133 - predictor_loss: 0.0092 - val_loss: 32.2636 - val_decoder_loss: 32.0665 - val_predictor_loss: 0.0099
#
# Epoch 00143: val_loss did not improve from 31.89063
# Epoch 144/500
#  - 3s - loss: 28.9768 - decoder_loss: 28.7779 - predictor_loss: 0.0099 - val_loss: 32.3009 - val_decoder_loss: 32.0752 - val_predictor_loss: 0.0113
#
# Epoch 00144: val_loss did not improve from 31.89063
# Epoch 145/500
#  - 3s - loss: 29.1501 - decoder_loss: 28.9503 - predictor_loss: 0.0100 - val_loss: 32.6317 - val_decoder_loss: 32.4274 - val_predictor_loss: 0.0102
#
# Epoch 00145: val_loss did not improve from 31.89063
# Epoch 146/500
#  - 3s - loss: 28.8185 - decoder_loss: 28.6345 - predictor_loss: 0.0092 - val_loss: 32.6941 - val_decoder_loss: 32.4784 - val_predictor_loss: 0.0108
#
# Epoch 00146: val_loss did not improve from 31.89063
# Epoch 147/500
#  - 3s - loss: 29.3138 - decoder_loss: 29.1094 - predictor_loss: 0.0102 - val_loss: 32.6921 - val_decoder_loss: 32.4805 - val_predictor_loss: 0.0106
#
# Epoch 00147: val_loss did not improve from 31.89063
# Epoch 148/500
#  - 3s - loss: 28.9356 - decoder_loss: 28.7385 - predictor_loss: 0.0099 - val_loss: 33.2144 - val_decoder_loss: 32.9997 - val_predictor_loss: 0.0107
#
# Epoch 00148: val_loss did not improve from 31.89063
# Epoch 149/500
#  - 3s - loss: 28.9326 - decoder_loss: 28.7487 - predictor_loss: 0.0092 - val_loss: 32.9346 - val_decoder_loss: 32.7352 - val_predictor_loss: 0.0100
#
# Epoch 00149: val_loss did not improve from 31.89063
# Epoch 150/500
#  - 3s - loss: 28.8643 - decoder_loss: 28.6837 - predictor_loss: 0.0090 - val_loss: 33.5414 - val_decoder_loss: 33.2889 - val_predictor_loss: 0.0126
#
# Epoch 00150: val_loss did not improve from 31.89063
# Epoch 151/500
#  - 3s - loss: 29.0234 - decoder_loss: 28.8287 - predictor_loss: 0.0097 - val_loss: 32.3805 - val_decoder_loss: 32.1601 - val_predictor_loss: 0.0110
#
# Epoch 00151: val_loss did not improve from 31.89063
# Epoch 152/500
#  - 3s - loss: 29.0134 - decoder_loss: 28.8156 - predictor_loss: 0.0099 - val_loss: 32.4382 - val_decoder_loss: 32.2048 - val_predictor_loss: 0.0117
#
# Epoch 00152: val_loss did not improve from 31.89063
# Epoch 153/500
#  - 3s - loss: 29.0811 - decoder_loss: 28.8943 - predictor_loss: 0.0093 - val_loss: 32.7777 - val_decoder_loss: 32.5726 - val_predictor_loss: 0.0103
#
# Epoch 00153: val_loss did not improve from 31.89063
# Epoch 154/500
#  - 3s - loss: 29.1739 - decoder_loss: 28.9785 - predictor_loss: 0.0098 - val_loss: 32.7207 - val_decoder_loss: 32.5052 - val_predictor_loss: 0.0108
#
# Epoch 00154: val_loss did not improve from 31.89063
# Epoch 155/500
#  - 3s - loss: 28.9703 - decoder_loss: 28.7703 - predictor_loss: 0.0100 - val_loss: 32.0751 - val_decoder_loss: 31.8483 - val_predictor_loss: 0.0113
#
# Epoch 00155: val_loss did not improve from 31.89063
# Epoch 156/500
#  - 3s - loss: 28.9886 - decoder_loss: 28.7779 - predictor_loss: 0.0105 - val_loss: 32.5107 - val_decoder_loss: 32.2914 - val_predictor_loss: 0.0110
#
# Epoch 00156: val_loss did not improve from 31.89063
# Epoch 157/500
#  - 3s - loss: 29.1727 - decoder_loss: 28.9734 - predictor_loss: 0.0100 - val_loss: 32.5615 - val_decoder_loss: 32.3624 - val_predictor_loss: 0.0100
#
# Epoch 00157: val_loss did not improve from 31.89063
# Epoch 158/500
#  - 3s - loss: 28.8216 - decoder_loss: 28.6384 - predictor_loss: 0.0092 - val_loss: 32.2538 - val_decoder_loss: 32.0612 - val_predictor_loss: 0.0096
#
# Epoch 00158: val_loss did not improve from 31.89063
# Epoch 159/500
#  - 3s - loss: 28.6406 - decoder_loss: 28.4656 - predictor_loss: 0.0087 - val_loss: 32.6376 - val_decoder_loss: 32.4466 - val_predictor_loss: 0.0096
#
# Epoch 00159: val_loss did not improve from 31.89063
# Epoch 160/500
#  - 3s - loss: 28.9787 - decoder_loss: 28.7846 - predictor_loss: 0.0097 - val_loss: 32.3485 - val_decoder_loss: 32.0393 - val_predictor_loss: 0.0155
#
# Epoch 00160: val_loss did not improve from 31.89063
# Epoch 161/500
#  - 3s - loss: 28.8779 - decoder_loss: 28.6788 - predictor_loss: 0.0100 - val_loss: 32.4439 - val_decoder_loss: 32.2513 - val_predictor_loss: 0.0096
#
# Epoch 00161: val_loss did not improve from 31.89063
# Epoch 162/500
#  - 3s - loss: 29.1964 - decoder_loss: 29.0110 - predictor_loss: 0.0093 - val_loss: 31.9695 - val_decoder_loss: 31.7459 - val_predictor_loss: 0.0112
#
# Epoch 00162: val_loss did not improve from 31.89063
# Epoch 163/500
#  - 3s - loss: 29.1115 - decoder_loss: 28.9133 - predictor_loss: 0.0099 - val_loss: 32.1426 - val_decoder_loss: 31.9199 - val_predictor_loss: 0.0111
#
# Epoch 00163: val_loss did not improve from 31.89063
# Epoch 164/500
#  - 3s - loss: 28.9938 - decoder_loss: 28.7987 - predictor_loss: 0.0098 - val_loss: 33.1953 - val_decoder_loss: 32.8806 - val_predictor_loss: 0.0157
#
# Epoch 00164: val_loss did not improve from 31.89063
# Epoch 165/500
#  - 3s - loss: 29.0752 - decoder_loss: 28.8588 - predictor_loss: 0.0108 - val_loss: 32.1801 - val_decoder_loss: 31.9448 - val_predictor_loss: 0.0118
#
# Epoch 00165: val_loss did not improve from 31.89063
# Epoch 166/500
#  - 3s - loss: 28.9439 - decoder_loss: 28.7488 - predictor_loss: 0.0098 - val_loss: 33.0212 - val_decoder_loss: 32.7721 - val_predictor_loss: 0.0125
#
# Epoch 00166: val_loss did not improve from 31.89063
# Epoch 167/500
#  - 3s - loss: 28.7566 - decoder_loss: 28.5702 - predictor_loss: 0.0093 - val_loss: 32.6545 - val_decoder_loss: 32.4097 - val_predictor_loss: 0.0122
#
# Epoch 00167: val_loss did not improve from 31.89063
# Epoch 168/500
#  - 3s - loss: 28.9681 - decoder_loss: 28.7642 - predictor_loss: 0.0102 - val_loss: 32.3237 - val_decoder_loss: 32.1197 - val_predictor_loss: 0.0102
#
# Epoch 00168: val_loss did not improve from 31.89063
# Epoch 169/500
#  - 3s - loss: 29.2587 - decoder_loss: 29.0484 - predictor_loss: 0.0105 - val_loss: 33.0390 - val_decoder_loss: 32.7565 - val_predictor_loss: 0.0141
#
# Epoch 00169: val_loss did not improve from 31.89063
# Epoch 170/500
#  - 3s - loss: 29.2182 - decoder_loss: 29.0076 - predictor_loss: 0.0105 - val_loss: 32.4530 - val_decoder_loss: 32.2265 - val_predictor_loss: 0.0113
#
# Epoch 00170: val_loss did not improve from 31.89063
# Epoch 171/500
#  - 3s - loss: 29.0417 - decoder_loss: 28.8425 - predictor_loss: 0.0100 - val_loss: 32.5825 - val_decoder_loss: 32.3130 - val_predictor_loss: 0.0135
#
# Epoch 00171: val_loss did not improve from 31.89063
# Epoch 172/500
#  - 3s - loss: 28.9724 - decoder_loss: 28.7795 - predictor_loss: 0.0096 - val_loss: 32.2588 - val_decoder_loss: 32.0398 - val_predictor_loss: 0.0109
#
# Epoch 00172: val_loss did not improve from 31.89063
# Epoch 173/500
#  - 3s - loss: 28.8589 - decoder_loss: 28.6686 - predictor_loss: 0.0095 - val_loss: 32.0496 - val_decoder_loss: 31.8516 - val_predictor_loss: 0.0099
#
# Epoch 00173: val_loss did not improve from 31.89063
# Epoch 174/500
#  - 3s - loss: 29.3194 - decoder_loss: 29.1386 - predictor_loss: 0.0090 - val_loss: 32.2608 - val_decoder_loss: 32.0281 - val_predictor_loss: 0.0116
#
# Epoch 00174: val_loss did not improve from 31.89063
# Epoch 175/500
#  - 3s - loss: 28.9557 - decoder_loss: 28.7725 - predictor_loss: 0.0092 - val_loss: 32.2732 - val_decoder_loss: 32.0777 - val_predictor_loss: 0.0098
#
# Epoch 00175: val_loss did not improve from 31.89063
# Epoch 176/500
#  - 3s - loss: 29.1592 - decoder_loss: 28.9810 - predictor_loss: 0.0089 - val_loss: 33.0356 - val_decoder_loss: 32.8323 - val_predictor_loss: 0.0102
#
# Epoch 00176: val_loss did not improve from 31.89063
# Epoch 177/500
#  - 3s - loss: 28.9137 - decoder_loss: 28.7392 - predictor_loss: 0.0087 - val_loss: 32.2969 - val_decoder_loss: 32.0842 - val_predictor_loss: 0.0106
#
# Epoch 00177: val_loss did not improve from 31.89063
# Epoch 178/500
#  - 3s - loss: 28.9279 - decoder_loss: 28.7290 - predictor_loss: 0.0099 - val_loss: 32.8127 - val_decoder_loss: 32.5927 - val_predictor_loss: 0.0110
#
# Epoch 00178: val_loss did not improve from 31.89063
# Epoch 179/500
#  - 3s - loss: 29.0232 - decoder_loss: 28.8224 - predictor_loss: 0.0100 - val_loss: 32.1626 - val_decoder_loss: 31.9634 - val_predictor_loss: 0.0100
#
# Epoch 00179: val_loss did not improve from 31.89063
# Epoch 180/500
#  - 3s - loss: 28.8408 - decoder_loss: 28.6659 - predictor_loss: 0.0087 - val_loss: 32.3370 - val_decoder_loss: 32.1085 - val_predictor_loss: 0.0114
#
# Epoch 00180: val_loss did not improve from 31.89063
# Epoch 181/500
#  - 3s - loss: 28.8858 - decoder_loss: 28.6995 - predictor_loss: 0.0093 - val_loss: 32.5276 - val_decoder_loss: 32.3199 - val_predictor_loss: 0.0104
#
# Epoch 00181: val_loss did not improve from 31.89063
# Epoch 182/500
#  - 3s - loss: 29.0610 - decoder_loss: 28.8882 - predictor_loss: 0.0086 - val_loss: 32.5246 - val_decoder_loss: 32.3174 - val_predictor_loss: 0.0104
#
# Epoch 00182: val_loss did not improve from 31.89063
# Epoch 183/500
#  - 3s - loss: 29.1261 - decoder_loss: 28.9104 - predictor_loss: 0.0108 - val_loss: 32.8125 - val_decoder_loss: 32.5801 - val_predictor_loss: 0.0116
#
# Epoch 00183: val_loss did not improve from 31.89063
# Epoch 184/500
#  - 3s - loss: 28.8603 - decoder_loss: 28.6682 - predictor_loss: 0.0096 - val_loss: 32.2533 - val_decoder_loss: 32.0478 - val_predictor_loss: 0.0103
#
# Epoch 00184: val_loss did not improve from 31.89063
# Epoch 185/500
#  - 3s - loss: 29.2826 - decoder_loss: 29.0714 - predictor_loss: 0.0106 - val_loss: 32.5887 - val_decoder_loss: 32.3659 - val_predictor_loss: 0.0111
#
# Epoch 00185: val_loss did not improve from 31.89063
# Epoch 186/500
#  - 3s - loss: 28.9270 - decoder_loss: 28.7438 - predictor_loss: 0.0092 - val_loss: 32.5163 - val_decoder_loss: 32.2852 - val_predictor_loss: 0.0116
#
# Epoch 00186: val_loss did not improve from 31.89063
# Epoch 187/500
#  - 3s - loss: 29.1568 - decoder_loss: 28.9681 - predictor_loss: 0.0094 - val_loss: 32.8041 - val_decoder_loss: 32.6052 - val_predictor_loss: 0.0099
#
# Epoch 00187: val_loss did not improve from 31.89063
# Epoch 188/500
#  - 3s - loss: 29.0500 - decoder_loss: 28.8555 - predictor_loss: 0.0097 - val_loss: 32.5471 - val_decoder_loss: 32.3491 - val_predictor_loss: 0.0099
#
# Epoch 00188: val_loss did not improve from 31.89063
# Epoch 189/500
#  - 3s - loss: 29.0053 - decoder_loss: 28.8096 - predictor_loss: 0.0098 - val_loss: 32.4947 - val_decoder_loss: 32.2892 - val_predictor_loss: 0.0103
#
# Epoch 00189: val_loss did not improve from 31.89063
# Epoch 190/500
#  - 3s - loss: 28.9687 - decoder_loss: 28.7831 - predictor_loss: 0.0093 - val_loss: 32.1461 - val_decoder_loss: 31.9336 - val_predictor_loss: 0.0106
#
# Epoch 00190: val_loss did not improve from 31.89063
# Epoch 191/500
#  - 3s - loss: 29.0332 - decoder_loss: 28.8512 - predictor_loss: 0.0091 - val_loss: 32.8972 - val_decoder_loss: 32.6929 - val_predictor_loss: 0.0102
#
# Epoch 00191: val_loss did not improve from 31.89063
# Epoch 192/500
#  - 3s - loss: 29.0888 - decoder_loss: 28.9079 - predictor_loss: 0.0090 - val_loss: 32.3620 - val_decoder_loss: 32.1668 - val_predictor_loss: 0.0098
#
# Epoch 00192: val_loss did not improve from 31.89063
# Epoch 193/500
#  - 3s - loss: 28.8182 - decoder_loss: 28.6294 - predictor_loss: 0.0094 - val_loss: 32.8910 - val_decoder_loss: 32.6694 - val_predictor_loss: 0.0111
#
# Epoch 00193: val_loss did not improve from 31.89063
# Epoch 194/500
#  - 3s - loss: 28.9961 - decoder_loss: 28.8025 - predictor_loss: 0.0097 - val_loss: 32.7937 - val_decoder_loss: 32.5148 - val_predictor_loss: 0.0139
#
# Epoch 00194: val_loss did not improve from 31.89063
# Epoch 195/500
#  - 3s - loss: 29.0489 - decoder_loss: 28.8390 - predictor_loss: 0.0105 - val_loss: 32.5292 - val_decoder_loss: 32.3033 - val_predictor_loss: 0.0113
#
# Epoch 00195: val_loss did not improve from 31.89063
# Epoch 196/500
#  - 3s - loss: 28.8747 - decoder_loss: 28.7004 - predictor_loss: 0.0087 - val_loss: 32.7184 - val_decoder_loss: 32.5294 - val_predictor_loss: 0.0095
#
# Epoch 00196: val_loss did not improve from 31.89063
# Epoch 197/500
#  - 3s - loss: 28.8747 - decoder_loss: 28.6919 - predictor_loss: 0.0091 - val_loss: 32.8727 - val_decoder_loss: 32.6266 - val_predictor_loss: 0.0123
#
# Epoch 00197: val_loss did not improve from 31.89063
# Epoch 198/500
#  - 3s - loss: 29.0102 - decoder_loss: 28.7972 - predictor_loss: 0.0107 - val_loss: 32.0860 - val_decoder_loss: 31.8322 - val_predictor_loss: 0.0127
#
# Epoch 00198: val_loss did not improve from 31.89063
# Epoch 199/500
#  - 3s - loss: 29.0172 - decoder_loss: 28.8188 - predictor_loss: 0.0099 - val_loss: 32.7012 - val_decoder_loss: 32.4821 - val_predictor_loss: 0.0110
#
# Epoch 00199: val_loss did not improve from 31.89063
# Epoch 200/500
#  - 3s - loss: 28.6584 - decoder_loss: 28.4771 - predictor_loss: 0.0091 - val_loss: 32.7666 - val_decoder_loss: 32.5666 - val_predictor_loss: 0.0100
#
# Epoch 00200: val_loss did not improve from 31.89063
# Epoch 201/500
#  - 3s - loss: 29.0521 - decoder_loss: 28.8639 - predictor_loss: 0.0094 - val_loss: 32.4273 - val_decoder_loss: 32.2157 - val_predictor_loss: 0.0106
#
# Epoch 00201: val_loss did not improve from 31.89063
# Epoch 202/500
#  - 3s - loss: 29.0162 - decoder_loss: 28.8222 - predictor_loss: 0.0097 - val_loss: 32.6100 - val_decoder_loss: 32.3163 - val_predictor_loss: 0.0147
#
# Epoch 00202: val_loss did not improve from 31.89063
# Epoch 203/500
#  - 3s - loss: 28.7954 - decoder_loss: 28.6056 - predictor_loss: 0.0095 - val_loss: 32.6910 - val_decoder_loss: 32.4540 - val_predictor_loss: 0.0118
#
# Epoch 00203: val_loss did not improve from 31.89063
# Epoch 204/500
#  - 3s - loss: 28.7520 - decoder_loss: 28.5652 - predictor_loss: 0.0093 - val_loss: 33.1719 - val_decoder_loss: 32.9532 - val_predictor_loss: 0.0109
#
# Epoch 00204: val_loss did not improve from 31.89063
# Epoch 205/500
#  - 3s - loss: 28.8599 - decoder_loss: 28.6720 - predictor_loss: 0.0094 - val_loss: 32.3815 - val_decoder_loss: 32.1531 - val_predictor_loss: 0.0114
#
# Epoch 00205: val_loss did not improve from 31.89063
# Epoch 206/500
#  - 3s - loss: 29.0910 - decoder_loss: 28.9128 - predictor_loss: 0.0089 - val_loss: 32.7985 - val_decoder_loss: 32.6073 - val_predictor_loss: 0.0096
#
# Epoch 00206: val_loss did not improve from 31.89063
# Epoch 207/500
#  - 3s - loss: 29.1041 - decoder_loss: 28.9174 - predictor_loss: 0.0093 - val_loss: 32.3399 - val_decoder_loss: 32.1314 - val_predictor_loss: 0.0104
#
# Epoch 00207: val_loss did not improve from 31.89063
# Epoch 208/500
#  - 3s - loss: 29.0622 - decoder_loss: 28.8632 - predictor_loss: 0.0100 - val_loss: 32.3281 - val_decoder_loss: 32.0270 - val_predictor_loss: 0.0151
#
# Epoch 00208: val_loss did not improve from 31.89063
# Epoch 209/500
#  - 3s - loss: 29.0629 - decoder_loss: 28.8460 - predictor_loss: 0.0108 - val_loss: 32.5220 - val_decoder_loss: 32.2399 - val_predictor_loss: 0.0141
#
# Epoch 00209: val_loss did not improve from 31.89063
# Epoch 210/500
#  - 3s - loss: 28.9918 - decoder_loss: 28.7934 - predictor_loss: 0.0099 - val_loss: 32.9250 - val_decoder_loss: 32.7302 - val_predictor_loss: 0.0097
#
# Epoch 00210: val_loss did not improve from 31.89063
# Epoch 211/500
#  - 3s - loss: 29.2458 - decoder_loss: 29.0308 - predictor_loss: 0.0108 - val_loss: 32.3666 - val_decoder_loss: 32.1225 - val_predictor_loss: 0.0122
#
# Epoch 00211: val_loss did not improve from 31.89063
# Epoch 212/500
#  - 3s - loss: 28.8896 - decoder_loss: 28.6584 - predictor_loss: 0.0116 - val_loss: 31.9122 - val_decoder_loss: 31.6829 - val_predictor_loss: 0.0115
#
# Epoch 00212: val_loss did not improve from 31.89063
# Epoch 213/500
#  - 3s - loss: 29.1737 - decoder_loss: 28.9628 - predictor_loss: 0.0105 - val_loss: 32.7632 - val_decoder_loss: 32.5520 - val_predictor_loss: 0.0106
#
# Epoch 00213: val_loss did not improve from 31.89063
# Epoch 214/500
#  - 3s - loss: 28.8690 - decoder_loss: 28.6788 - predictor_loss: 0.0095 - val_loss: 32.1890 - val_decoder_loss: 31.9966 - val_predictor_loss: 0.0096
#
# Epoch 00214: val_loss did not improve from 31.89063
# Epoch 215/500
#  - 3s - loss: 28.8056 - decoder_loss: 28.6252 - predictor_loss: 0.0090 - val_loss: 32.2249 - val_decoder_loss: 32.0380 - val_predictor_loss: 0.0093
#
# Epoch 00215: val_loss did not improve from 31.89063
# Epoch 216/500
#  - 3s - loss: 28.8768 - decoder_loss: 28.7025 - predictor_loss: 0.0087 - val_loss: 32.3307 - val_decoder_loss: 32.1085 - val_predictor_loss: 0.0111
#
# Epoch 00216: val_loss did not improve from 31.89063
# Epoch 217/500
#  - 3s - loss: 28.9039 - decoder_loss: 28.7022 - predictor_loss: 0.0101 - val_loss: 31.9501 - val_decoder_loss: 31.6990 - val_predictor_loss: 0.0126
#
# Epoch 00217: val_loss did not improve from 31.89063
# Epoch 218/500
#  - 3s - loss: 28.7511 - decoder_loss: 28.5459 - predictor_loss: 0.0103 - val_loss: 32.6031 - val_decoder_loss: 32.3315 - val_predictor_loss: 0.0136
#
# Epoch 00218: val_loss did not improve from 31.89063
# Epoch 219/500
#  - 3s - loss: 29.1508 - decoder_loss: 28.9482 - predictor_loss: 0.0101 - val_loss: 32.3012 - val_decoder_loss: 32.0235 - val_predictor_loss: 0.0139
#
# Epoch 00219: val_loss did not improve from 31.89063
# Epoch 220/500
#  - 3s - loss: 29.1894 - decoder_loss: 28.9821 - predictor_loss: 0.0104 - val_loss: 32.2779 - val_decoder_loss: 32.0544 - val_predictor_loss: 0.0112
#
# Epoch 00220: val_loss did not improve from 31.89063
# Epoch 221/500
#  - 3s - loss: 29.0390 - decoder_loss: 28.8525 - predictor_loss: 0.0093 - val_loss: 33.1262 - val_decoder_loss: 32.9091 - val_predictor_loss: 0.0109
#
# Epoch 00221: val_loss did not improve from 31.89063
# Epoch 222/500
#  - 3s - loss: 29.1560 - decoder_loss: 28.9536 - predictor_loss: 0.0101 - val_loss: 32.8407 - val_decoder_loss: 32.5783 - val_predictor_loss: 0.0131
#
# Epoch 00222: val_loss did not improve from 31.89063
# Epoch 223/500
#  - 3s - loss: 28.8996 - decoder_loss: 28.6843 - predictor_loss: 0.0108 - val_loss: 33.4943 - val_decoder_loss: 33.2130 - val_predictor_loss: 0.0141
#
# Epoch 00223: val_loss did not improve from 31.89063
# Epoch 224/500
# ...
# Epoch 427/500
#  - 3s - loss: 28.8802 - decoder_loss: 28.6979 - predictor_loss: 0.0091 - val_loss: 32.0939 - val_decoder_loss: 31.8887 - val_predictor_loss: 0.0103
#
# Epoch 00427: val_loss did not improve from 31.73305
# Epoch 428/500
#  - 3s - loss: 29.1588 - decoder_loss: 28.9752 - predictor_loss: 0.0092 - val_loss: 32.5608 - val_decoder_loss: 32.3439 - val_predictor_loss: 0.0108
#
# Epoch 00428: val_loss did not improve from 31.73305
# Epoch 429/500
#  - 3s - loss: 29.0478 - decoder_loss: 28.8574 - predictor_loss: 0.0095 - val_loss: 32.1848 - val_decoder_loss: 31.9786 - val_predictor_loss: 0.0103
#
# Epoch 00429: val_loss did not improve from 31.73305
# Epoch 430/500
#  - 3s - loss: 28.9560 - decoder_loss: 28.7428 - predictor_loss: 0.0107 - val_loss: 32.3621 - val_decoder_loss: 32.1367 - val_predictor_loss: 0.0113
#
# Epoch 00430: val_loss did not improve from 31.73305
# Epoch 431/500
#  - 3s - loss: 29.1026 - decoder_loss: 28.9126 - predictor_loss: 0.0095 - val_loss: 32.8353 - val_decoder_loss: 32.6199 - val_predictor_loss: 0.0108
#
# Epoch 00431: val_loss did not improve from 31.73305
# Epoch 432/500
#  - 3s - loss: 29.0357 - decoder_loss: 28.8160 - predictor_loss: 0.0110 - val_loss: 32.7918 - val_decoder_loss: 32.5888 - val_predictor_loss: 0.0101
#
# Epoch 00432: val_loss did not improve from 31.73305
# Epoch 433/500
#  - 3s - loss: 28.6783 - decoder_loss: 28.5008 - predictor_loss: 0.0089 - val_loss: 32.4052 - val_decoder_loss: 32.2021 - val_predictor_loss: 0.0102
#
# Epoch 00433: val_loss did not improve from 31.73305
# Epoch 434/500
#  - 3s - loss: 28.7230 - decoder_loss: 28.5363 - predictor_loss: 0.0093 - val_loss: 32.1992 - val_decoder_loss: 31.9622 - val_predictor_loss: 0.0119
#
# Epoch 00434: val_loss did not improve from 31.73305
# Epoch 435/500
#  - 3s - loss: 28.7811 - decoder_loss: 28.5892 - predictor_loss: 0.0096 - val_loss: 32.7742 - val_decoder_loss: 32.4873 - val_predictor_loss: 0.0143
#
# Epoch 00435: val_loss did not improve from 31.73305
# Epoch 436/500
#  - 3s - loss: 28.9461 - decoder_loss: 28.7063 - predictor_loss: 0.0120 - val_loss: 32.6928 - val_decoder_loss: 32.4470 - val_predictor_loss: 0.0123
#
# Epoch 00436: val_loss did not improve from 31.73305
# Epoch 437/500
#  - 3s - loss: 28.6660 - decoder_loss: 28.4490 - predictor_loss: 0.0109 - val_loss: 32.2599 - val_decoder_loss: 32.0218 - val_predictor_loss: 0.0119
#
# Epoch 00437: val_loss did not improve from 31.73305
# Epoch 438/500
#  - 3s - loss: 28.8386 - decoder_loss: 28.6391 - predictor_loss: 0.0100 - val_loss: 31.9914 - val_decoder_loss: 31.7399 - val_predictor_loss: 0.0126
#
# Epoch 00438: val_loss did not improve from 31.73305
# Epoch 439/500
#  - 3s - loss: 28.6284 - decoder_loss: 28.4472 - predictor_loss: 0.0091 - val_loss: 32.3380 - val_decoder_loss: 32.1473 - val_predictor_loss: 0.0095
#
# Epoch 00439: val_loss did not improve from 31.73305
# Epoch 440/500
#  - 3s - loss: 28.6737 - decoder_loss: 28.5028 - predictor_loss: 0.0085 - val_loss: 32.7300 - val_decoder_loss: 32.5302 - val_predictor_loss: 0.0100
#
# Epoch 00440: val_loss did not improve from 31.73305
# Epoch 441/500
#  - 3s - loss: 28.9585 - decoder_loss: 28.7824 - predictor_loss: 0.0088 - val_loss: 32.6197 - val_decoder_loss: 32.4017 - val_predictor_loss: 0.0109
#
# Epoch 00441: val_loss did not improve from 31.73305
# Epoch 442/500
#  - 3s - loss: 28.7522 - decoder_loss: 28.5693 - predictor_loss: 0.0091 - val_loss: 32.1958 - val_decoder_loss: 31.9789 - val_predictor_loss: 0.0108
#
# Epoch 00442: val_loss did not improve from 31.73305
# Epoch 443/500
#  - 3s - loss: 29.0921 - decoder_loss: 28.9084 - predictor_loss: 0.0092 - val_loss: 32.7709 - val_decoder_loss: 32.5365 - val_predictor_loss: 0.0117
#
# Epoch 00443: val_loss did not improve from 31.73305
# Epoch 444/500
#  - 3s - loss: 28.9156 - decoder_loss: 28.7088 - predictor_loss: 0.0103 - val_loss: 32.8176 - val_decoder_loss: 32.5145 - val_predictor_loss: 0.0152
#
# Epoch 00444: val_loss did not improve from 31.73305
# Epoch 445/500
#  - 3s - loss: 28.5033 - decoder_loss: 28.3058 - predictor_loss: 0.0099 - val_loss: 32.0174 - val_decoder_loss: 31.8167 - val_predictor_loss: 0.0100
#
# Epoch 00445: val_loss did not improve from 31.73305
# Epoch 446/500
#  - 3s - loss: 28.3639 - decoder_loss: 28.1835 - predictor_loss: 0.0090 - val_loss: 32.7057 - val_decoder_loss: 32.4911 - val_predictor_loss: 0.0107
#
# Epoch 00446: val_loss did not improve from 31.73305
# Epoch 447/500
#  - 3s - loss: 28.5597 - decoder_loss: 28.3658 - predictor_loss: 0.0097 - val_loss: 32.1556 - val_decoder_loss: 31.9413 - val_predictor_loss: 0.0107
#
# Epoch 00447: val_loss did not improve from 31.73305
# Epoch 448/500
#  - 3s - loss: 28.7880 - decoder_loss: 28.6118 - predictor_loss: 0.0088 - val_loss: 32.2462 - val_decoder_loss: 32.0343 - val_predictor_loss: 0.0106
#
# Epoch 00448: val_loss did not improve from 31.73305
# Epoch 449/500
#  - 3s - loss: 28.7598 - decoder_loss: 28.5428 - predictor_loss: 0.0108 - val_loss: 32.2326 - val_decoder_loss: 31.9958 - val_predictor_loss: 0.0118
#
# Epoch 00449: val_loss did not improve from 31.73305
# Epoch 450/500
#  - 3s - loss: 29.1423 - decoder_loss: 28.9322 - predictor_loss: 0.0105 - val_loss: 32.1775 - val_decoder_loss: 31.8391 - val_predictor_loss: 0.0169
#
# Epoch 00450: val_loss did not improve from 31.73305
# Epoch 451/500
#  - 3s - loss: 28.7571 - decoder_loss: 28.5107 - predictor_loss: 0.0123 - val_loss: 32.2669 - val_decoder_loss: 32.0335 - val_predictor_loss: 0.0117
#
# Epoch 00451: val_loss did not improve from 31.73305
# Epoch 452/500
#  - 3s - loss: 28.8726 - decoder_loss: 28.6804 - predictor_loss: 0.0096 - val_loss: 32.1848 - val_decoder_loss: 31.9970 - val_predictor_loss: 0.0094
#
# Epoch 00452: val_loss did not improve from 31.73305
# Epoch 453/500
#  - 3s - loss: 28.9271 - decoder_loss: 28.7392 - predictor_loss: 0.0094 - val_loss: 32.8305 - val_decoder_loss: 32.6010 - val_predictor_loss: 0.0115
#
# Epoch 00453: val_loss did not improve from 31.73305
# Epoch 454/500
#  - 3s - loss: 28.8762 - decoder_loss: 28.6700 - predictor_loss: 0.0103 - val_loss: 32.0422 - val_decoder_loss: 31.8251 - val_predictor_loss: 0.0109
#
# Epoch 00454: val_loss did not improve from 31.73305
# Epoch 455/500
#  - 3s - loss: 28.8569 - decoder_loss: 28.6705 - predictor_loss: 0.0093 - val_loss: 32.8073 - val_decoder_loss: 32.5745 - val_predictor_loss: 0.0116
#
# Epoch 00455: val_loss did not improve from 31.73305
# Epoch 456/500
#  - 3s - loss: 29.0377 - decoder_loss: 28.8376 - predictor_loss: 0.0100 - val_loss: 31.9238 - val_decoder_loss: 31.7412 - val_predictor_loss: 0.0091
#
# Epoch 00456: val_loss did not improve from 31.73305
# Epoch 457/500
#  - 3s - loss: 29.0192 - decoder_loss: 28.8249 - predictor_loss: 0.0097 - val_loss: 32.0627 - val_decoder_loss: 31.8721 - val_predictor_loss: 0.0095
#
# Epoch 00457: val_loss did not improve from 31.73305
# Epoch 458/500
#  - 3s - loss: 28.9333 - decoder_loss: 28.7582 - predictor_loss: 0.0088 - val_loss: 32.2589 - val_decoder_loss: 32.0683 - val_predictor_loss: 0.0095
#
# Epoch 00458: val_loss did not improve from 31.73305
# Epoch 459/500
#  - 3s - loss: 28.8573 - decoder_loss: 28.6829 - predictor_loss: 0.0087 - val_loss: 32.0284 - val_decoder_loss: 31.8004 - val_predictor_loss: 0.0114
#
# Epoch 00459: val_loss did not improve from 31.73305
# Epoch 460/500
#  - 3s - loss: 28.9747 - decoder_loss: 28.7838 - predictor_loss: 0.0095 - val_loss: 31.6385 - val_decoder_loss: 31.4105 - val_predictor_loss: 0.0114
#
# Epoch 00460: val_loss improved from 31.73305 to 31.63848, saving model to VAE_Predictor460.h5
# Epoch 461/500
#  - 3s - loss: 29.0532 - decoder_loss: 28.8547 - predictor_loss: 0.0099 - val_loss: 32.1142 - val_decoder_loss: 31.9164 - val_predictor_loss: 0.0099
#
# Epoch 00461: val_loss did not improve from 31.63848
# Epoch 462/500
#  - 3s - loss: 28.8173 - decoder_loss: 28.6300 - predictor_loss: 0.0094 - val_loss: 31.8542 - val_decoder_loss: 31.6534 - val_predictor_loss: 0.0100
#
# Epoch 00462: val_loss did not improve from 31.63848
# Epoch 463/500
#  - 3s - loss: 28.8864 - decoder_loss: 28.6930 - predictor_loss: 0.0097 - val_loss: 32.8274 - val_decoder_loss: 32.6290 - val_predictor_loss: 0.0099
#
# Epoch 00463: val_loss did not improve from 31.63848
# Epoch 464/500
#  - 3s - loss: 28.7345 - decoder_loss: 28.5563 - predictor_loss: 0.0089 - val_loss: 32.5938 - val_decoder_loss: 32.3779 - val_predictor_loss: 0.0108
#
# Epoch 00464: val_loss did not improve from 31.63848
# Epoch 465/500
#  - 3s - loss: 29.2672 - decoder_loss: 29.0760 - predictor_loss: 0.0096 - val_loss: 32.7895 - val_decoder_loss: 32.5789 - val_predictor_loss: 0.0105
#
# Epoch 00465: val_loss did not improve from 31.63848
# Epoch 466/500
#  - 3s - loss: 28.9104 - decoder_loss: 28.7103 - predictor_loss: 0.0100 - val_loss: 32.2456 - val_decoder_loss: 32.0557 - val_predictor_loss: 0.0095
#
# Epoch 00466: val_loss did not improve from 31.63848
# Epoch 467/500
#  - 3s - loss: 28.7594 - decoder_loss: 28.5424 - predictor_loss: 0.0108 - val_loss: 32.8228 - val_decoder_loss: 32.6088 - val_predictor_loss: 0.0107
#
# Epoch 00467: val_loss did not improve from 31.63848
# Epoch 468/500
#  - 3s - loss: 28.4169 - decoder_loss: 28.2413 - predictor_loss: 0.0088 - val_loss: 31.4852 - val_decoder_loss: 31.2716 - val_predictor_loss: 0.0107
#
# Epoch 00468: val_loss improved from 31.63848 to 31.48520, saving model to VAE_Predictor468.h5
# Epoch 469/500
#  - 3s - loss: 28.8105 - decoder_loss: 28.6246 - predictor_loss: 0.0093 - val_loss: 32.4136 - val_decoder_loss: 32.1543 - val_predictor_loss: 0.0130
#
# Epoch 00469: val_loss did not improve from 31.48520
# Epoch 470/500
#  - 3s - loss: 28.8809 - decoder_loss: 28.6971 - predictor_loss: 0.0092 - val_loss: 32.1659 - val_decoder_loss: 31.9371 - val_predictor_loss: 0.0114
#
# Epoch 00470: val_loss did not improve from 31.48520
# Epoch 471/500
#  - 3s - loss: 28.8878 - decoder_loss: 28.6883 - predictor_loss: 0.0100 - val_loss: 32.0049 - val_decoder_loss: 31.7995 - val_predictor_loss: 0.0103
#
# Epoch 00471: val_loss did not improve from 31.48520
# Epoch 472/500
#  - 3s - loss: 28.5807 - decoder_loss: 28.3986 - predictor_loss: 0.0091 - val_loss: 31.9962 - val_decoder_loss: 31.7980 - val_predictor_loss: 0.0099
#
# Epoch 00472: val_loss did not improve from 31.48520
# Epoch 473/500
#  - 3s - loss: 28.8513 - decoder_loss: 28.6799 - predictor_loss: 0.0086 - val_loss: 31.7924 - val_decoder_loss: 31.5853 - val_predictor_loss: 0.0104
#
# Epoch 00473: val_loss did not improve from 31.48520
# Epoch 474/500
#  - 3s - loss: 28.8486 - decoder_loss: 28.6622 - predictor_loss: 0.0093 - val_loss: 32.3483 - val_decoder_loss: 32.1452 - val_predictor_loss: 0.0102
#
# Epoch 00474: val_loss did not improve from 31.48520
# Epoch 475/500
#  - 3s - loss: 28.8973 - decoder_loss: 28.6823 - predictor_loss: 0.0107 - val_loss: 32.3937 - val_decoder_loss: 32.1264 - val_predictor_loss: 0.0134
#
# Epoch 00475: val_loss did not improve from 31.48520
# Epoch 476/500
#  - 3s - loss: 28.8351 - decoder_loss: 28.6440 - predictor_loss: 0.0096 - val_loss: 32.2178 - val_decoder_loss: 31.9807 - val_predictor_loss: 0.0119
#
# Epoch 00476: val_loss did not improve from 31.48520
# Epoch 477/500
#  - 3s - loss: 28.7370 - decoder_loss: 28.5267 - predictor_loss: 0.0105 - val_loss: 31.9253 - val_decoder_loss: 31.7161 - val_predictor_loss: 0.0105
#
# Epoch 00477: val_loss did not improve from 31.48520
# Epoch 478/500
#  - 3s - loss: 28.5430 - decoder_loss: 28.3552 - predictor_loss: 0.0094 - val_loss: 32.2372 - val_decoder_loss: 32.0055 - val_predictor_loss: 0.0116
#
# Epoch 00478: val_loss did not improve from 31.48520
# Epoch 479/500
#  - 3s - loss: 28.8761 - decoder_loss: 28.6953 - predictor_loss: 0.0090 - val_loss: 32.7052 - val_decoder_loss: 32.5055 - val_predictor_loss: 0.0100
#
# Epoch 00479: val_loss did not improve from 31.48520
# Epoch 480/500
#  - 3s - loss: 28.6908 - decoder_loss: 28.4899 - predictor_loss: 0.0100 - val_loss: 31.8515 - val_decoder_loss: 31.6366 - val_predictor_loss: 0.0107
#
# Epoch 00480: val_loss did not improve from 31.48520
# Epoch 481/500
#  - 3s - loss: 28.4542 - decoder_loss: 28.2596 - predictor_loss: 0.0097 - val_loss: 32.4657 - val_decoder_loss: 32.2332 - val_predictor_loss: 0.0116
#
# Epoch 00481: val_loss did not improve from 31.48520
# Epoch 482/500
#  - 3s - loss: 29.0359 - decoder_loss: 28.8509 - predictor_loss: 0.0093 - val_loss: 32.0608 - val_decoder_loss: 31.8414 - val_predictor_loss: 0.0110
#
# Epoch 00482: val_loss did not improve from 31.48520
# Epoch 483/500
#  - 3s - loss: 28.8210 - decoder_loss: 28.6309 - predictor_loss: 0.0095 - val_loss: 32.3287 - val_decoder_loss: 32.0437 - val_predictor_loss: 0.0142
#
# Epoch 00483: val_loss did not improve from 31.48520
# Epoch 484/500
#  - 3s - loss: 28.8394 - decoder_loss: 28.6518 - predictor_loss: 0.0094 - val_loss: 32.7839 - val_decoder_loss: 32.5641 - val_predictor_loss: 0.0110
#
# Epoch 00484: val_loss did not improve from 31.48520
# Epoch 485/500
#  - 3s - loss: 28.8825 - decoder_loss: 28.7008 - predictor_loss: 0.0091 - val_loss: 31.8373 - val_decoder_loss: 31.6315 - val_predictor_loss: 0.0103
#
# Epoch 00485: val_loss did not improve from 31.48520
# Epoch 486/500
#  - 3s - loss: 28.9405 - decoder_loss: 28.7533 - predictor_loss: 0.0094 - val_loss: 32.9734 - val_decoder_loss: 32.7547 - val_predictor_loss: 0.0109
#
# Epoch 00486: val_loss did not improve from 31.48520
# Epoch 487/500
#  - 3s - loss: 28.8751 - decoder_loss: 28.6669 - predictor_loss: 0.0104 - val_loss: 32.4897 - val_decoder_loss: 32.2030 - val_predictor_loss: 0.0143
#
# Epoch 00487: val_loss did not improve from 31.48520
# Epoch 488/500
#  - 3s - loss: 28.9399 - decoder_loss: 28.7301 - predictor_loss: 0.0105 - val_loss: 31.8708 - val_decoder_loss: 31.6598 - val_predictor_loss: 0.0106
#
# Epoch 00488: val_loss did not improve from 31.48520
# Epoch 489/500
#  - 3s - loss: 28.8283 - decoder_loss: 28.6382 - predictor_loss: 0.0095 - val_loss: 31.9256 - val_decoder_loss: 31.6952 - val_predictor_loss: 0.0115
#
# Epoch 00489: val_loss did not improve from 31.48520
# Epoch 490/500
#  - 3s - loss: 28.8088 - decoder_loss: 28.6009 - predictor_loss: 0.0104 - val_loss: 32.6089 - val_decoder_loss: 32.3489 - val_predictor_loss: 0.0130
#
# Epoch 00490: val_loss did not improve from 31.48520
# Epoch 491/500
#  - 3s - loss: 28.9665 - decoder_loss: 28.7380 - predictor_loss: 0.0114 - val_loss: 32.6402 - val_decoder_loss: 32.4325 - val_predictor_loss: 0.0104
#
# Epoch 00491: val_loss did not improve from 31.48520
# Epoch 492/500
#  - 3s - loss: 28.7006 - decoder_loss: 28.5081 - predictor_loss: 0.0096 - val_loss: 32.5269 - val_decoder_loss: 32.3032 - val_predictor_loss: 0.0112
#
# Epoch 00492: val_loss did not improve from 31.48520
# Epoch 493/500
#  - 3s - loss: 28.6662 - decoder_loss: 28.4829 - predictor_loss: 0.0092 - val_loss: 32.8410 - val_decoder_loss: 32.6266 - val_predictor_loss: 0.0107
#
# Epoch 00493: val_loss did not improve from 31.48520
# Epoch 494/500
#  - 3s - loss: 28.5214 - decoder_loss: 28.3505 - predictor_loss: 0.0085 - val_loss: 32.1604 - val_decoder_loss: 31.9625 - val_predictor_loss: 0.0099
#
# Epoch 00494: val_loss did not improve from 31.48520
# Epoch 495/500
#  - 3s - loss: 28.7718 - decoder_loss: 28.5740 - predictor_loss: 0.0099 - val_loss: 32.5433 - val_decoder_loss: 32.3456 - val_predictor_loss: 0.0099
#
# Epoch 00495: val_loss did not improve from 31.48520
# Epoch 496/500
#  - 3s - loss: 28.7990 - decoder_loss: 28.5923 - predictor_loss: 0.0103 - val_loss: 31.6587 - val_decoder_loss: 31.4280 - val_predictor_loss: 0.0115
#
# Epoch 00496: val_loss did not improve from 31.48520
# Epoch 497/500
#  - 3s - loss: 28.9085 - decoder_loss: 28.7236 - predictor_loss: 0.0092 - val_loss: 32.0151 - val_decoder_loss: 31.8084 - val_predictor_loss: 0.0103
#
# Epoch 00497: val_loss did not improve from 31.48520
# Epoch 498/500
#  - 3s - loss: 28.7257 - decoder_loss: 28.5315 - predictor_loss: 0.0097 - val_loss: 32.1242 - val_decoder_loss: 31.9176 - val_predictor_loss: 0.0103
#
# Epoch 00498: val_loss did not improve from 31.48520
# Epoch 499/500
#  - 3s - loss: 28.5626 - decoder_loss: 28.3927 - predictor_loss: 0.0085 - val_loss: 32.7135 - val_decoder_loss: 32.5195 - val_predictor_loss: 0.0097
#
# Epoch 00499: val_loss did not improve from 31.48520
# Epoch 500/500
#  - 3s - loss: 29.0439 - decoder_loss: 28.8398 - predictor_loss: 0.0102 - val_loss: 32.7703 - val_decoder_loss: 32.4842 - val_predictor_loss: 0.0143
#
# Epoch 00500: val_loss did not improve from 31.48520

# %%
vae_predictor.save('my_model.h5')
# vae_predictor.save(checkpoint_path)

# %%
# new_model = tf.keras.models.load_model('my_model.h5')
# history = new_model.fit(x_train[:2000], y_train[:2000],
#               batch_size=BATCH_SIZE,
#               epochs=6,
#               validation_data=(x_val[:100], y_val[:100]),
#               shuffle=True)

# %% [markdown]
# # **Latent Space Visualization**

# %% [markdown]
# ### **Each Component of latent space**

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 20)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %% [markdown]
# ### **logP Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=logP_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('logP on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# ### **qed Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=qed_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('qed on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# ### **SAS Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# Calculating mean and standard deviation of all property values on test data

logp_mean_test, qed_mean_test,SAS_mean_test= np.mean(y_test_property, axis=0)
logp_std_test, qed_std_test,SAS_std_test = np.std(y_test_property, axis=0)

# %%
# encoded, decoded and predicted data on test dataset

encoded_xtest=encoder.predict(X_test)
predicted_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print(encoded_xtest.shape)
print(predicted_xtest.shape)
print(decoded_xtest.shape)
# Out:
# (302, 20)
# (302, 3)
# (302, 4320)

# %%
# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)
print(orig_test.shape)
print(reconst_test.shape)
# Out:
# (302, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Reconstruction and Prediction on Original test data set**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
idx=157
print(predicted_xtest[idx])

#Reconstruction

mol="".join([int_to_char[idx] for idx in np.argmax(orig_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [2.2281196 0.8984758 5.594723 ]
# !C1=C[C@H]2C[C@@H]1C[C@H]2CN1CC[NH+](C2CCCCCC2)CC1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# C1=C[C@H]2C[C@@H]1C[C@H]2CN1CC[NH+](C2CCCCCC2)CC1
#
# 50

# %% [markdown]
# ### **Reconstruction and Prediction of property on reconstructed test data**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
print(predicted_xtest[idx])

#Reconstruction
mol="".join([int_to_char[idx] for idx in np.argmax(reconst_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [2.2281196 0.8984758 5.594723 ]
# !C1=C[C@H]2C[C@@H]1C[C@H]2CN1CC[NH+](C2CCCCCC2)CC1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# C1=C[C@H]2C[C@@H]1C[C@H]2CN1CC[NH+](C2CCCCCC2)CC1
#
# 50

# %% [markdown]
# # **Generating New Samples from Normal Distribution with Specific Property**

# %%
prop_val={}
m=None
n_mol=10
i=0
latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))
# print(latent_samples.shape)
predicted_prop_samples=predictor.predict(latent_samples)
# print(predicted_prop_samples.shape)
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)

#Checking the property of molecule
for id, latent_mol in enumerate(latent_samples):
  a=predicted_prop_samples[id][0]<(logp_mean_test+logp_std_test)
  b=predicted_prop_samples[id][0]>=(logp_mean_test-logp_std_test)
  c=predicted_prop_samples[id][1]<(qed_mean_test+qed_std_test)
  d=predicted_prop_samples[id][1]>=(qed_mean_test-qed_std_test)
  e=predicted_prop_samples[id][2]<(SAS_mean_test+SAS_std_test)
  f=predicted_prop_samples[id][2]>=(SAS_mean_test-SAS_std_test)
  if ((a & b) & (c & d) & (e & f)):  #Checking if all of the property values matches
    prop_val[i]=1
    print("Mol {}, Property Validated".format(id+1))
    print("Predicted Properties=")
    print(predicted_prop_samples[id][0], predicted_prop_samples[id][1], predicted_prop_samples[id][2])

    #Passing it to Decoder Now
    reconst_sample = decoder.predict(latent_samples[id:id+1])
    new_mol=reconst_sample.reshape(mol_size_x, mol_size_y) 
    mol="".join([int_to_char[idx] for idx in np.argmax(new_mol[:,:], axis=1)])
    mol = re.sub('!|E',"", mol)
    m = Chem.MolFromSmiles(mol, sanitize=False)
    if m is None:
      print('Mol {} {}, invalid SMILES'.format(id+1,m))
      continue                   
    else:
      try:
        m = Chem.SanitizeMol(m)
        print(m)
      except:
        print('Mol {}, invalid chemistry'.format(id+1)) 
    m
  else:    #No decoding happens here
    prop_val[i]=0
    print("Mol {}, Property Invalidated".format(id+1))
# Out:
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# Mol 1, Property Invalidated
# Mol 2, Property Invalidated
# Mol 3, Property Invalidated
# Mol 4, Property Invalidated
# Mol 5, Property Invalidated
# Mol 6, Property Invalidated
# Mol 7, Property Invalidated
# Mol 8, Property Validated
# Predicted Properties=
# 3.932834 0.76988006 3.3039303
# Mol 8 None, invalid SMILES
# Mol 9, Property Invalidated
# Mol 10, Property Invalidated
# RDKit ERROR: [13:27:41] SMILES Parse Error: syntax error while parsing: Cc1cc(c(C)c1CC(=O)CC@Cc(C)CC(nC)1)CC1
# RDKit ERROR:
# RDKit ERROR:
# RDKit ERROR: [13:27:41] SMILES Parse Error: Failed parsing SMILES 'Cc1cc(c(C)c1CC(=O)CC@Cc(C)CC(nC)1)CC1
# RDKit ERROR:
# RDKit ERROR: ' for input: 'Cc1cc(c(C)c1CC(=O)CC@Cc(C)CC(nC)1)CC1
# RDKit ERROR:
# RDKit ERROR: '
