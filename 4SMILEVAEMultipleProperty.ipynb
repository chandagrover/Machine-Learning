# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SMILEVAEMultipleProperty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# !pip install tensorflow==1.12
# !pip install keras==2.2.4
# !pip install h5py
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.12 (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.1.2, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2)
# ERROR: No matching distribution found for tensorflow==1.12
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.7/site-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.19.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (5.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (3.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.5.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py->keras==2.2.4) (1.5.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/site-packages (from h5py) (1.19.4)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py) (1.5.2)

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-11-23 11:32:15--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2020-11-23 11:32:15--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - ca-certificates==2020.1.1=0
#     - certifi==2020.4.5.1=py37_0
#     - cffi==1.14.0=py37he30daa8_1
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.1=py37h7b6447c_0
#     - conda==4.8.3=py37_0
#     - cryptography==2.9.2=py37h1ba5d50_0
#     - idna==2.9=py_1
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.3=he6710b0_1
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1g=h7b6447c_0
#     - pip==20.0.2=py37_3
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.20=py_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.7=hcff3b4d_5
#     - readline==8.0=h7b6447c_0
#     - requests==2.23.0=py37_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==46.4.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h62c20be_1
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.46.0=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.11.8-py37h8~ --> pkgs/main::certifi-2020.4.5.1-py37_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.8.3-py37_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m26.799s
# user	0m31.692s
# sys	0m5.854s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.11.8-ha878542_0
#   certifi              pkgs/main::certifi-2020.4.5.1-py37_0 --> conda-forge::certifi-2020.11.8-py37h89c1867_0
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.9.2-py37h89c1867_0
#   openssl              pkgs/main::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1h-h516909a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# real	0m12.405s
# user	0m11.214s
# sys	0m1.114s

# %%
# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re

# FOR VAE Architecture 
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model
from keras.losses import mse, binary_crossentropy
import keras
from keras import layers
import tensorflow as tf
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import rdkit
print("RDKit: %s"%rdkit.__version__)
print("Keras: %s"%keras.__version__)
# Out:
# RDKit: 2020.09.1
# Keras: 2.2.4

# %% [markdown]
# # **Data Fetching**

# %%
WEIGHTS_FOLDER = 'sample_data/weights/'
smifile = "sample_data/SMILEWithProp.csv"
data = pd.read_csv(smifile, delimiter = ",", header='infer')
NUM_SMILES = len(data)
data.head()
# Out:
#                                               smiles  ...       SAS
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  ...  2.084095
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print(smiles_train.shape)
print(smiles_test.shape)
print(NUM_SMILES)
# Out:
# (1207, 4)
# (302, 4)
# 1509

# %%
logP_train = smiles_train['logP']
logP_test = smiles_test['logP']

qed_train=smiles_train['qed']
qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([logP_train, qed_train, SAS_train])
test= np.array([logP_test, qed_test, SAS_test])
y_train_property=train.transpose()
y_test_property=test.transpose()

# %%
#Labels for the Smiles String. We will deal with three properties values.
print(type(y_train_property))
print(type(y_test_property))
print(y_train_property.shape)
print(y_test_property.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1207, 3)
# (302, 3)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(len(charset), embed)
# print(embed)
# Out:
# 40 108

# %%
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
# Out:
# (1207, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=584
print(smiles_train['smiles'][idx])
from rdkit.Chem.Draw import IPythonConsole
m = Chem.MolFromSmiles(smiles_train['smiles'][idx])
m
# Out:
# O=C(N[C@@H]1CCO[C@@H]1c1ccc(Cl)c(F)c1)[C@H]1Cc2ccccc2O1

# %%
# Going back from vectorized form back to a readable string
strr="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
line = re.sub('[!E]', '', strr)
print(len(line))
print(line)
m = Chem.MolFromSmiles(line)
m
# Out:
# 56
# O=C(N[C@@H]1CCO[C@@H]1c1ccc(Cl)c(F)c1)[C@H]1Cc2ccccc2O1

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print(orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# 4320

# %% [markdown]
# # **VAE with Predictor**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=20 # Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer 
  # in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(3, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# ### **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input
  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  # combines the model by passing the encoder output to the input of the decoder.
  vae_output = vae_decoder(vae_encoder_output)

  # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE with Predictor')
  # vae_model = Model(vae_input, vae_output, name='Only VAE')
  # VAE Model
  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()

# %% [markdown]
# ### **Plotting all models**

# %%
# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='smilesvae_predictor.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False


# Plot the Encoder Model
plot_model(encoder, to_file='only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

#Plot the Predictor Model
plot_model(predictor, to_file='only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# plot_model(vae_model, to_file='smilesvae_model.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False

# %% [markdown]
# ### **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "sample_data/train_ckpt/cp.ckpt"
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_weights_only=True, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(checkpoint_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **VAE with Predictor**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
    
  vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  return vae_loss_val

# %% [markdown]
# ### **Training or Loading the Model**

# %%
pre_trained=True
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[1.0, 20.0]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )   
    else:
      # vae_predictor.compile(optimizer='adam', 
      #                  loss=[vae_loss, 'mean_squared_error'], 
      #                  loss_weights=[1.0, 20.0]     
      #                  ) 
      vae_predictor.load_weights(checkpoint_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback])
# Out:
# Train on 1207 samples, validate on 302 samples
# Epoch 1/50
#  - 3s - loss: 76.8847 - decoder_loss: 75.9234 - predictor_loss: 0.0481 - val_loss: 109.9462 - val_decoder_loss: 108.6939 - val_predictor_loss: 0.0626
#
# Epoch 00001: val_loss improved from 111.97534 to 109.94625, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 2/50
#  - 3s - loss: 75.7814 - decoder_loss: 74.8293 - predictor_loss: 0.0476 - val_loss: 108.7926 - val_decoder_loss: 107.5274 - val_predictor_loss: 0.0633
#
# Epoch 00002: val_loss improved from 109.94625 to 108.79265, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 3/50
#  - 3s - loss: 74.3604 - decoder_loss: 73.4281 - predictor_loss: 0.0466 - val_loss: 106.9406 - val_decoder_loss: 105.7932 - val_predictor_loss: 0.0574
#
# Epoch 00003: val_loss improved from 108.79265 to 106.94060, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 4/50
#  - 3s - loss: 73.2290 - decoder_loss: 72.3016 - predictor_loss: 0.0464 - val_loss: 103.7751 - val_decoder_loss: 102.5418 - val_predictor_loss: 0.0617
#
# Epoch 00004: val_loss improved from 106.94060 to 103.77507, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 5/50
#  - 3s - loss: 71.9589 - decoder_loss: 71.0796 - predictor_loss: 0.0440 - val_loss: 103.2150 - val_decoder_loss: 102.0560 - val_predictor_loss: 0.0579
#
# Epoch 00005: val_loss improved from 103.77507 to 103.21500, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 6/50
#  - 3s - loss: 71.0876 - decoder_loss: 70.2210 - predictor_loss: 0.0433 - val_loss: 101.6553 - val_decoder_loss: 100.4861 - val_predictor_loss: 0.0585
#
# Epoch 00006: val_loss improved from 103.21500 to 101.65533, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 7/50
#  - 3s - loss: 70.4434 - decoder_loss: 69.5296 - predictor_loss: 0.0457 - val_loss: 99.8278 - val_decoder_loss: 98.5818 - val_predictor_loss: 0.0623
#
# Epoch 00007: val_loss improved from 101.65533 to 99.82781, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 8/50
#  - 3s - loss: 69.2338 - decoder_loss: 68.2936 - predictor_loss: 0.0470 - val_loss: 97.5889 - val_decoder_loss: 96.3488 - val_predictor_loss: 0.0620
#
# Epoch 00008: val_loss improved from 99.82781 to 97.58886, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 9/50
#  - 3s - loss: 68.1294 - decoder_loss: 67.2828 - predictor_loss: 0.0423 - val_loss: 97.1905 - val_decoder_loss: 96.0653 - val_predictor_loss: 0.0563
#
# Epoch 00009: val_loss improved from 97.58886 to 97.19047, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 10/50
#  - 3s - loss: 67.4314 - decoder_loss: 66.5692 - predictor_loss: 0.0431 - val_loss: 95.4358 - val_decoder_loss: 94.2335 - val_predictor_loss: 0.0601
#
# Epoch 00010: val_loss improved from 97.19047 to 95.43581, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 11/50
#  - 3s - loss: 66.6961 - decoder_loss: 65.8622 - predictor_loss: 0.0417 - val_loss: 93.2609 - val_decoder_loss: 92.1109 - val_predictor_loss: 0.0575
#
# Epoch 00011: val_loss improved from 95.43581 to 93.26088, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 12/50
#  - 3s - loss: 65.8914 - decoder_loss: 65.0562 - predictor_loss: 0.0418 - val_loss: 92.5873 - val_decoder_loss: 91.4260 - val_predictor_loss: 0.0581
#
# Epoch 00012: val_loss improved from 93.26088 to 92.58728, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 13/50
#  - 3s - loss: 64.7906 - decoder_loss: 63.9591 - predictor_loss: 0.0416 - val_loss: 91.5239 - val_decoder_loss: 90.2844 - val_predictor_loss: 0.0620
#
# Epoch 00013: val_loss improved from 92.58728 to 91.52394, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 14/50
#  - 3s - loss: 64.2467 - decoder_loss: 63.3810 - predictor_loss: 0.0433 - val_loss: 90.0079 - val_decoder_loss: 88.8440 - val_predictor_loss: 0.0582
#
# Epoch 00014: val_loss improved from 91.52394 to 90.00787, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 15/50
#  - 3s - loss: 63.5931 - decoder_loss: 62.7898 - predictor_loss: 0.0402 - val_loss: 88.9506 - val_decoder_loss: 87.8562 - val_predictor_loss: 0.0547
#
# Epoch 00015: val_loss improved from 90.00787 to 88.95056, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 16/50
#  - 3s - loss: 63.0260 - decoder_loss: 62.2412 - predictor_loss: 0.0392 - val_loss: 88.4401 - val_decoder_loss: 87.3473 - val_predictor_loss: 0.0546
#
# Epoch 00016: val_loss improved from 88.95056 to 88.44010, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 17/50
#  - 3s - loss: 62.1909 - decoder_loss: 61.4291 - predictor_loss: 0.0381 - val_loss: 86.7422 - val_decoder_loss: 85.6712 - val_predictor_loss: 0.0536
#
# Epoch 00017: val_loss improved from 88.44010 to 86.74225, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 18/50
#  - 3s - loss: 61.9926 - decoder_loss: 61.2472 - predictor_loss: 0.0373 - val_loss: 85.3987 - val_decoder_loss: 84.3632 - val_predictor_loss: 0.0518
#
# Epoch 00018: val_loss improved from 86.74225 to 85.39873, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 19/50
#  - 3s - loss: 61.2834 - decoder_loss: 60.5141 - predictor_loss: 0.0385 - val_loss: 83.6217 - val_decoder_loss: 82.5653 - val_predictor_loss: 0.0528
#
# Epoch 00019: val_loss improved from 85.39873 to 83.62167, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 20/50
#  - 3s - loss: 60.6282 - decoder_loss: 59.8639 - predictor_loss: 0.0382 - val_loss: 83.4013 - val_decoder_loss: 82.3826 - val_predictor_loss: 0.0509
#
# Epoch 00020: val_loss improved from 83.62167 to 83.40130, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 21/50
#  - 3s - loss: 60.5311 - decoder_loss: 59.7904 - predictor_loss: 0.0370 - val_loss: 82.7894 - val_decoder_loss: 81.7281 - val_predictor_loss: 0.0531
#
# Epoch 00021: val_loss improved from 83.40130 to 82.78943, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 22/50
#  - 3s - loss: 59.8840 - decoder_loss: 59.0986 - predictor_loss: 0.0393 - val_loss: 81.4747 - val_decoder_loss: 80.4060 - val_predictor_loss: 0.0534
#
# Epoch 00022: val_loss improved from 82.78943 to 81.47471, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 23/50
#  - 3s - loss: 58.9928 - decoder_loss: 58.2486 - predictor_loss: 0.0372 - val_loss: 80.9953 - val_decoder_loss: 79.9355 - val_predictor_loss: 0.0530
#
# Epoch 00023: val_loss improved from 81.47471 to 80.99533, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 24/50
#  - 3s - loss: 58.9533 - decoder_loss: 58.2199 - predictor_loss: 0.0367 - val_loss: 78.6789 - val_decoder_loss: 77.6554 - val_predictor_loss: 0.0512
#
# Epoch 00024: val_loss improved from 80.99533 to 78.67888, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 25/50
#  - 3s - loss: 58.1622 - decoder_loss: 57.4371 - predictor_loss: 0.0363 - val_loss: 78.5039 - val_decoder_loss: 77.4792 - val_predictor_loss: 0.0512
#
# Epoch 00025: val_loss improved from 78.67888 to 78.50394, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 26/50
#  - 3s - loss: 57.9490 - decoder_loss: 57.2239 - predictor_loss: 0.0363 - val_loss: 77.7431 - val_decoder_loss: 76.7221 - val_predictor_loss: 0.0511
#
# Epoch 00026: val_loss improved from 78.50394 to 77.74309, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 27/50
#  - 3s - loss: 57.5592 - decoder_loss: 56.8354 - predictor_loss: 0.0362 - val_loss: 77.3540 - val_decoder_loss: 76.2857 - val_predictor_loss: 0.0534
#
# Epoch 00027: val_loss improved from 77.74309 to 77.35399, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 28/50
#  - 3s - loss: 56.8328 - decoder_loss: 56.1135 - predictor_loss: 0.0360 - val_loss: 76.0901 - val_decoder_loss: 75.0545 - val_predictor_loss: 0.0518
#
# Epoch 00028: val_loss improved from 77.35399 to 76.09013, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 29/50
#  - 3s - loss: 56.3775 - decoder_loss: 55.6710 - predictor_loss: 0.0353 - val_loss: 76.0792 - val_decoder_loss: 75.1272 - val_predictor_loss: 0.0476
#
# Epoch 00029: val_loss improved from 76.09013 to 76.07922, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 30/50
#  - 3s - loss: 55.9915 - decoder_loss: 55.3172 - predictor_loss: 0.0337 - val_loss: 74.7400 - val_decoder_loss: 73.7343 - val_predictor_loss: 0.0503
#
# Epoch 00030: val_loss improved from 76.07922 to 74.74001, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 31/50
#  - 3s - loss: 55.7064 - decoder_loss: 54.9846 - predictor_loss: 0.0361 - val_loss: 74.4018 - val_decoder_loss: 73.3315 - val_predictor_loss: 0.0535
#
# Epoch 00031: val_loss improved from 74.74001 to 74.40182, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 32/50
#  - 3s - loss: 55.4805 - decoder_loss: 54.7913 - predictor_loss: 0.0345 - val_loss: 73.5907 - val_decoder_loss: 72.6239 - val_predictor_loss: 0.0483
#
# Epoch 00032: val_loss improved from 74.40182 to 73.59069, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 33/50
#  - 3s - loss: 54.9951 - decoder_loss: 54.2914 - predictor_loss: 0.0352 - val_loss: 73.0888 - val_decoder_loss: 72.0211 - val_predictor_loss: 0.0534
#
# Epoch 00033: val_loss improved from 73.59069 to 73.08883, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 34/50
#  - 3s - loss: 54.7943 - decoder_loss: 54.0802 - predictor_loss: 0.0357 - val_loss: 71.7718 - val_decoder_loss: 70.7035 - val_predictor_loss: 0.0534
#
# Epoch 00034: val_loss improved from 73.08883 to 71.77179, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 35/50
#  - 3s - loss: 54.3773 - decoder_loss: 53.6681 - predictor_loss: 0.0355 - val_loss: 71.4291 - val_decoder_loss: 70.5041 - val_predictor_loss: 0.0462
#
# Epoch 00035: val_loss improved from 71.77179 to 71.42907, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 36/50
#  - 3s - loss: 54.0016 - decoder_loss: 53.3326 - predictor_loss: 0.0334 - val_loss: 70.6535 - val_decoder_loss: 69.7013 - val_predictor_loss: 0.0476
#
# Epoch 00036: val_loss improved from 71.42907 to 70.65352, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 37/50
#  - 3s - loss: 53.7201 - decoder_loss: 53.0491 - predictor_loss: 0.0336 - val_loss: 69.9660 - val_decoder_loss: 69.0150 - val_predictor_loss: 0.0476
#
# Epoch 00037: val_loss improved from 70.65352 to 69.96604, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 38/50
#  - 3s - loss: 53.6796 - decoder_loss: 52.9967 - predictor_loss: 0.0341 - val_loss: 70.8554 - val_decoder_loss: 69.8319 - val_predictor_loss: 0.0512
#
# Epoch 00038: val_loss did not improve from 69.96604
# Epoch 39/50
#  - 3s - loss: 53.3457 - decoder_loss: 52.6681 - predictor_loss: 0.0339 - val_loss: 70.5060 - val_decoder_loss: 69.5396 - val_predictor_loss: 0.0483
#
# Epoch 00039: val_loss did not improve from 69.96604
# Epoch 40/50
#  - 3s - loss: 52.9898 - decoder_loss: 52.3458 - predictor_loss: 0.0322 - val_loss: 68.5586 - val_decoder_loss: 67.6448 - val_predictor_loss: 0.0457
#
# Epoch 00040: val_loss improved from 69.96604 to 68.55861, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 41/50
#  - 3s - loss: 52.9495 - decoder_loss: 52.3312 - predictor_loss: 0.0309 - val_loss: 69.3105 - val_decoder_loss: 68.3063 - val_predictor_loss: 0.0502
#
# Epoch 00041: val_loss did not improve from 68.55861
# Epoch 42/50
#  - 3s - loss: 53.0248 - decoder_loss: 52.3508 - predictor_loss: 0.0337 - val_loss: 67.9844 - val_decoder_loss: 67.0184 - val_predictor_loss: 0.0483
#
# Epoch 00042: val_loss improved from 68.55861 to 67.98438, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 43/50
#  - 3s - loss: 52.2434 - decoder_loss: 51.5985 - predictor_loss: 0.0322 - val_loss: 66.5440 - val_decoder_loss: 65.6425 - val_predictor_loss: 0.0451
#
# Epoch 00043: val_loss improved from 67.98438 to 66.54398, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 44/50
#  - 3s - loss: 52.1672 - decoder_loss: 51.5346 - predictor_loss: 0.0316 - val_loss: 66.9693 - val_decoder_loss: 65.8887 - val_predictor_loss: 0.0540
#
# Epoch 00044: val_loss did not improve from 66.54398
# Epoch 45/50
#  - 3s - loss: 51.6432 - decoder_loss: 50.9653 - predictor_loss: 0.0339 - val_loss: 65.7587 - val_decoder_loss: 64.7910 - val_predictor_loss: 0.0484
#
# Epoch 00045: val_loss improved from 66.54398 to 65.75870, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 46/50
#  - 3s - loss: 51.3005 - decoder_loss: 50.6782 - predictor_loss: 0.0311 - val_loss: 64.6051 - val_decoder_loss: 63.7622 - val_predictor_loss: 0.0421
#
# Epoch 00046: val_loss improved from 65.75870 to 64.60514, saving model to sample_data/train_ckpt/cp.ckpt
# Epoch 47/50
#  - 3s - loss: 51.2087 - decoder_loss: 50.5736 - predictor_loss: 0.0318 - val_loss: 65.4731 - val_decoder_loss: 64.5469 - val_predictor_loss: 0.0463
#
# Epoch 00047: val_loss did not improve from 64.60514
# Epoch 48/50
#  - 3s - loss: 51.1175 - decoder_loss: 50.4548 - predictor_loss: 0.0331 - val_loss: 65.1823 - val_decoder_loss: 64.2460 - val_predictor_loss: 0.0468
#
# Epoch 00048: val_loss did not improve from 64.60514
# Epoch 49/50
#  - 3s - loss: 50.9218 - decoder_loss: 50.2298 - predictor_loss: 0.0346 - val_loss: 65.2793 - val_decoder_loss: 64.2874 - val_predictor_loss: 0.0496
#
# Epoch 00049: val_loss did not improve from 64.60514
# Epoch 50/50
#  - 3s - loss: 50.8034 - decoder_loss: 50.1157 - predictor_loss: 0.0344 - val_loss: 64.8543 - val_decoder_loss: 63.8537 - val_predictor_loss: 0.0500
#
# Epoch 00050: val_loss did not improve from 64.60514

# %%
# # Loading the pre-trained weights
# # Create a basic model instance
# epochs=100
# encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor_ckpt2 = create_model()
# vae_predictor_ckpt2.load_weights(checkpoint_path)
# vae_predictor_ckpt2.compile(optimizer='adam', 
#                       loss=[vae_loss, 'mean_squared_error'], 
#                       loss_weights=[1.0, 20.0]     
#                       ) 
# vae_predictor_ckpt2.fit(x=X_train,
#                             y=[X_train,y_train_property], 
#                             epochs=epochs,
#                             validation_data=(X_test, [X_test, y_test_property]),
#                             verbose=2,
#                             callbacks=[cp_callback] )

# %%
# #get the latest checkpoint file
# checkpoint_dir = os.path.dirname(checkpoint_path)
# latest = tf.train.latest_checkpoint(checkpoint_dir)
# #Create a new model instance
# encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor_latest_checkpoint = create_model()
# # Load the previously saved weights
# vae_predictor_latest_checkpoint.load_weights(latest)
# # Include the epoch in the file name (uses `str.format`)
# checkpoint_path = "traiinig2/cp-{epoch:04d}.ckpt"

# %% [markdown]
# # **Latent Space Visualization**

# %%
# graph = tf.get_default_graph()

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 20)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=logP_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('logP on test data')
plt.savefig(filename)
plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=qed_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('qed on test data')
plt.savefig(filename)
plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# Calculating mean and standard deviation of all property values on test data

logp_mean_test, qed_mean_test,SAS_mean_test= np.mean(y_test_property, axis=0)
logp_std_test, qed_std_test,SAS_std_test = np.std(y_test_property, axis=0)

# %%
# encoded, decoded and predicted data on test dataset

encoded_xtest=encoder.predict(X_test)
predicted_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print(encoded_xtest.shape)
print(predicted_xtest.shape)
print(decoded_xtest.shape)
# Out:
# (302, 20)
# (302, 3)
# (302, 4320)

# %%
# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)
print(orig_test.shape)
print(reconst_test.shape)
# Out:
# (302, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Reconstruction and Prediction on Original test data set**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
idx=147
print(predicted_xtest[idx])
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)


#Reconstruction

mol="".join([int_to_char[idx] for idx in np.argmax(orig_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [0.49185953 0.66299134 4.474377  ]
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# !CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
#
# 67

# %% [markdown]
# ### **Reconstruction and Prediction of property on reconstructed test data**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
print(predicted_xtest[idx])
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)

#Reconstruction
mol="".join([int_to_char[idx] for idx in np.argmax(reconst_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [0.49185953 0.66299134 4.474377  ]
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# !CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
#
# 67

# %% [markdown]
# # **Generating New Samples from Normal Distribution**

# %%
prop_val={}
m=None
n_mol=10
i=0
latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))
# print(latent_samples.shape)
predicted_prop_samples=predictor.predict(latent_samples)
# print(predicted_prop_samples.shape)

#Checking the property of molecule
for id, latent_mol in enumerate(latent_samples):
  a=predicted_prop_samples[id][0]<(logp_mean_test+logp_std_test)
  b=predicted_prop_samples[id][0]>=(logp_mean_test-logp_std_test)
  c=predicted_prop_samples[id][1]<(qed_mean_test+qed_std_test)
  d=predicted_prop_samples[id][1]>=(qed_mean_test-qed_std_test)
  e=predicted_prop_samples[id][2]<(SAS_mean_test+SAS_std_test)
  f=predicted_prop_samples[id][2]>=(SAS_mean_test-SAS_std_test)
  if ((a & b) & (c & d) & (e & f)):  #Checking if all of the property values matches
    prop_val[i]=1
    print("Mol {}, Property Validated".format(id+1))

    #Passing it to Decoder Now
    reconst_sample = decoder.predict(latent_samples[id:id+1])
    new_mol=reconst_sample.reshape(mol_size_x, mol_size_y) 
    mol="".join([int_to_char[idx] for idx in np.argmax(new_mol[:,:], axis=1)])
    mol = re.sub('!|E',"", mol)
    m = Chem.MolFromSmiles(mol, sanitize=False)
    print(m)
    if m is None:
      print('Mol {}, invalid SMILES'.format(id+1))
      continue                   
    else:
      try:
        m = Chem.SanitizeMol(m)
      except:
        print('Mol {}, invalid chemistry'.format(id+1)) 
    m
  else:    #No decoding happens here
    prop_val[i]=0
    print("Mol {}, Property Invalidated".format(id+1))
# Out:
# Mol 1, Property Validated
# None
# Mol 1, invalid SMILES
# Mol 2, Property Invalidated
# Mol 3, Property Invalidated
# Mol 4, Property Validated
# None
# Mol 4, invalid SMILES
# Mol 5, Property Validated
# None
# Mol 5, invalid SMILES
# Mol 6, Property Validated
# None
# Mol 6, invalid SMILES
# Mol 7, Property Validated
# None
# Mol 7, invalid SMILES
# Mol 8, Property Validated
# None
# Mol 8, invalid SMILES
# Mol 9, Property Invalidated
# Mol 10, Property Invalidated
# RDKit ERROR: [12:01:09] SMILES Parse Error: extra close parentheses while parsing: CCC1Cc1C(C(=O)Ncccccc(N2C=C)cCNC)N1CCC)Ncc
# RDKit ERROR:
# RDKit ERROR:
# RDKit ERROR: [12:01:09] SMILES Parse Error: Failed parsing SMILES 'CCC1Cc1C(C(=O)Ncccccc(N2C=C)cCNC)N1CCC)Ncc
# RDKit ERROR:
# RDKit ERROR: ' for input: 'CCC1Cc1C(C(=O)Ncccccc(N2C=C)cCNC)N1CCC)Ncc
# RDKit ERROR:
# RDKit ERROR: '
# RDKit ERROR: [12:01:09] SMILES Parse Error: syntax error while parsing: Cc11ccccccc1N3CCnC((cCcc3ccl)c1C)CC1@=CO1N2
# RDKit ERROR: 1
# RDKit ERROR: [12:01:09] SMILES Parse Error: Failed parsing SMILES 'Cc11ccccccc1N3CCnC((cCcc3ccl)c1C)CC1@=CO1N2
# RDKit ERROR: 1' for input: 'Cc11ccccccc1N3CCnC((cCcc3ccl)c1C)CC1@=CO1N2
# RDKit ERROR: 1'
# RDKit ERROR: [12:01:09] SMILES Parse Error: syntax error while parsing: O=CC(c1cn(1cCc11nC(3C)ccC@C))3cccCClC@11BBBBBBBBBBBBBBBBBBBBBBBBBBBB
# RDKit ERROR: [12:01:09] SMILES Parse Error: Failed parsing SMILES 'O=CC(c1cn(1cCc11nC(3C)ccC@C))3cccCClC@11BBBBBBBBBBBBBBBBBBBBBBBBBBBB' for input: 'O=CC(c1cn(1cCc11nC(3C)ccC@C))3cccCClC@11BBBBBBBBBBBBBBBBBBBBBBBBBBBB'
# RDKit ERROR: [12:01:09] SMILES Parse Error: syntax error while parsing: CCC(NHCC(@)(c1))C(1cCccc@cccccccc11cBBBBBBBBBBBBBBB
# RDKit ERROR: [12:01:09] SMILES Parse Error: Failed parsing SMILES 'CCC(NHCC(@)(c1))C(1cCccc@cccccccc11cBBBBBBBBBBBBBBB' for input: 'CCC(NHCC(@)(c1))C(1cCccc@cccccccc11cBBBBBBBBBBBBBBB'
# RDKit ERROR: [12:01:09] SMILES Parse Error: syntax error while parsing: O=C(NC1CcN(C@=@)(=@cCn11N)1@@cCC()cccc21
# RDKit ERROR: [12:01:09] SMILES Parse Error: Failed parsing SMILES 'O=C(NC1CcN(C@=@)(=@cCn11N)1@@cCC()cccc21' for input: 'O=C(NC1CcN(C@=@)(=@cCn11N)1@@cCC()cccc21'
# RDKit ERROR: [12:01:09] SMILES Parse Error: extra open parentheses for input: 'CCC(cCcC(CN-Nc1cc(c(ccc)c2cCCCC1
# RDKit ERROR: 1'

# %%
# reconst_samples = decoder.predict(latent_samples)
# new_mols=reconst_samples.reshape(n_mol, mol_size_x, mol_size_y)
# print(new_mols.shape)
# Out:
# (10, 108, 40)

# %%
# # Generating new Smile Strings sampled from a standard normal distribution
# m=None
# n_mol=10
# reconst_strings = decoder.predict(np.random.normal(0,1,size=(n_mol,Z_DIM)))
# new_mols=reconst_strings.reshape(n_mol, mol_size_x, mol_size_y)

# # Going back from vectorized form back to a readable string
# for id, molecule in enumerate(new_mols):

#   mol="".join([int_to_char[idx] for idx in np.argmax(new_mols[id,:,:], axis=1)])
#   mol = re.sub('!|E',"", mol)
#   print(mol)
#   m = Chem.MolFromSmiles(mol, sanitize=False)
#   # print(m)
#   m
#   if m is None:
#     print('invalid SMILES')
#     continue                   
#   else:
#     try:
#       m = Chem.SanitizeMol(m)
#     except:
#       print('invalid chemistry') 
#   m

# %%
# # Generating new Smile Strings sampled from a standard normal distribution
# m=None
# n_mol=5

# reconst_strings = decoder.predict(np.random.normal(0,1,size=(n_mol,Z_DIM)))
# new_mols=reconst_strings.reshape(n_mol, mol_size_x, mol_size_y)

# # Going back from vectorized form back to a readable string
# for id, molecule in enumerate(new_mols):
#   mol="".join([int_to_char[idx] for idx in np.argmax(new_mols[id,:,:], axis=1)])
#   mol = re.sub('!|E',"", mol)
#   m = Chem.MolFromSmiles(mol, sanitize=False)
#   print(m)
#   m
#   if m is None:
#     print('invalid SMILES')
#     continue                   
#   else:
#     try:
#       m = Chem.SanitizeMol(m)
#     except:
#       print('invalid chemistry') 
#   m
