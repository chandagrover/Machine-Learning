# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SMILEVAEMultipleProperty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# !pip install tensorflow==1.12
# !pip install keras==2.2.4
# !pip install h5py
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.12 (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.1.2, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2, 2.4.0rc3)
# ERROR: No matching distribution found for tensorflow==1.12
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.7/site-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.19.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.5.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (5.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.14.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py->keras==2.2.4) (1.5.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/site-packages (from h5py) (1.19.4)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py) (1.5.2)

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-11-25 10:49:23--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2020-11-25 10:49:23--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - ca-certificates==2020.1.1=0
#     - certifi==2020.4.5.1=py37_0
#     - cffi==1.14.0=py37he30daa8_1
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.1=py37h7b6447c_0
#     - conda==4.8.3=py37_0
#     - cryptography==2.9.2=py37h1ba5d50_0
#     - idna==2.9=py_1
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.3=he6710b0_1
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1g=h7b6447c_0
#     - pip==20.0.2=py37_3
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.20=py_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.7=hcff3b4d_5
#     - readline==8.0=h7b6447c_0
#     - requests==2.23.0=py37_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==46.4.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h62c20be_1
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.46.0=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.11.8-py37h8~ --> pkgs/main::certifi-2020.4.5.1-py37_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.8.3-py37_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m32.193s
# user	0m33.425s
# sys	0m6.344s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.11.8-ha878542_0
#   certifi              pkgs/main::certifi-2020.4.5.1-py37_0 --> conda-forge::certifi-2020.11.8-py37h89c1867_0
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.9.2-py37h89c1867_0
#   openssl              pkgs/main::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1h-h516909a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# real	0m12.738s
# user	0m11.456s
# sys	0m1.188s

# %%
# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re

# FOR VAE Architecture 
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model
from keras.losses import mse, binary_crossentropy
import keras
from keras import layers
import tensorflow as tf
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import rdkit
print("RDKit: %s"%rdkit.__version__)
print("Keras: %s"%keras.__version__)
# Out:
# RDKit: 2020.09.1
# Keras: 2.2.4

# %% [markdown]
# # **Data Fetching**

# %%
WEIGHTS_FOLDER = 'sample_data/weights/'
smifile = "sample_data/SMILEWithProp.csv"
data = pd.read_csv(smifile, delimiter = ",", header='infer')
NUM_SMILES = len(data)
data.head()
# Out:
#                                               smiles  ...       SAS
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  ...  2.084095
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print(smiles_train.shape)
print(smiles_test.shape)
print(NUM_SMILES)
# Out:
# (1207, 4)
# (302, 4)
# 1509

# %%
logP_train = smiles_train['logP']
logP_test = smiles_test['logP']

qed_train=smiles_train['qed']
qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([logP_train, qed_train, SAS_train])
test= np.array([logP_test, qed_test, SAS_test])
y_train_property=train.transpose()
y_test_property=test.transpose()

# %%
#Labels for the Smiles String. We will deal with three properties values.
print(type(y_train_property))
print(type(y_test_property))
print(y_train_property.shape)
print(y_test_property.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1207, 3)
# (302, 3)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(len(charset), embed)
# print(embed)
# Out:
# 40 108

# %%
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
# Out:
# (1207, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=281
print(smiles_train['smiles'][idx])
from rdkit.Chem.Draw import IPythonConsole
m = Chem.MolFromSmiles(smiles_train['smiles'][idx])
m
# Out:
# Cc1ccc(NC(=S)NC(C)C)cc1C

# %%
# Going back from vectorized form back to a readable string
strr="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
line = re.sub('[!E]', '', strr)
print(len(line))
print(line)
m = Chem.MolFromSmiles(line)
m
# Out:
# 25
# Cc1ccc(NC(=S)NC(C)C)cc1C

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print(orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# 4320

# %% [markdown]
# # **VAE with Predictor**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=20 # Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(3, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# ### **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input

  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  vae_output = vae_decoder(vae_encoder_output)

  # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE with Predictor')

  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()

# %% [markdown]
# ### **VAE Loss Function**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
    
  vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  return vae_loss_val

# %% [markdown]
# **Plotting all models**

# %%
# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='smilesvae_predictor.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False


# Plot the Encoder Model
plot_model(encoder, to_file='only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

#Plot the Predictor Model
plot_model(predictor, to_file='only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# plot_model(vae_model, to_file='smilesvae_model.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False

# %% [markdown]
# **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "sample_data/train_ckpt/cp.ckpt"
new_check_path='VAE_Predictor{epoch:02d}.h5'            #'VAE_Predictor{epoch:02d}.h5'
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=new_check_path, verbose=1, save_weights_only=False, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(new_check_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **Training or Loading the VAE-Predictor Model**

# %%
pre_trained=True
epochs=1500
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[1.0, 20.0]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )   
      vae_predictor.save(new_check_path)
    else:
      vae_predictor.load_weights(new_check_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback]) 
      vae_predictor.save(new_check_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 251/1500
#  - 3s - loss: 36.0756 - decoder_loss: 35.8148 - predictor_loss: 0.0130 - val_loss: 41.0939 - val_decoder_loss: 40.8114 - val_predictor_loss: 0.0141
#
# Epoch 00251: val_loss did not improve from 40.87731
# Epoch 252/1500
#  - 3s - loss: 36.0058 - decoder_loss: 35.7271 - predictor_loss: 0.0139 - val_loss: 40.9531 - val_decoder_loss: 40.5753 - val_predictor_loss: 0.0189
#
# Epoch 00252: val_loss did not improve from 40.87731
# Epoch 253/1500
#  - 3s - loss: 35.9846 - decoder_loss: 35.7158 - predictor_loss: 0.0134 - val_loss: 41.8456 - val_decoder_loss: 41.5189 - val_predictor_loss: 0.0163
#
# Epoch 00253: val_loss did not improve from 40.87731
# Epoch 254/1500
#  - 3s - loss: 36.0647 - decoder_loss: 35.7958 - predictor_loss: 0.0134 - val_loss: 41.6727 - val_decoder_loss: 41.3194 - val_predictor_loss: 0.0177
#
# Epoch 00254: val_loss did not improve from 40.87731
# Epoch 255/1500
#  - 3s - loss: 35.7187 - decoder_loss: 35.4469 - predictor_loss: 0.0136 - val_loss: 41.0361 - val_decoder_loss: 40.7178 - val_predictor_loss: 0.0159
#
# Epoch 00255: val_loss did not improve from 40.87731
# Epoch 256/1500
#  - 3s - loss: 35.4503 - decoder_loss: 35.1920 - predictor_loss: 0.0129 - val_loss: 41.6038 - val_decoder_loss: 41.2412 - val_predictor_loss: 0.0181
#
# Epoch 00256: val_loss did not improve from 40.87731
# Epoch 257/1500
#  - 3s - loss: 36.2142 - decoder_loss: 35.9076 - predictor_loss: 0.0153 - val_loss: 40.8204 - val_decoder_loss: 40.4271 - val_predictor_loss: 0.0197
#
# Epoch 00257: val_loss improved from 40.87731 to 40.82044, saving model to VAE_Predictor257.h5
# Epoch 258/1500
#  - 3s - loss: 35.7905 - decoder_loss: 35.4923 - predictor_loss: 0.0149 - val_loss: 41.0717 - val_decoder_loss: 40.7811 - val_predictor_loss: 0.0145
#
# Epoch 00258: val_loss did not improve from 40.82044
# Epoch 259/1500
#  - 3s - loss: 35.7255 - decoder_loss: 35.4457 - predictor_loss: 0.0140 - val_loss: 41.3559 - val_decoder_loss: 41.0069 - val_predictor_loss: 0.0175
#
# Epoch 00259: val_loss did not improve from 40.82044
# Epoch 260/1500
#  - 3s - loss: 35.9332 - decoder_loss: 35.6609 - predictor_loss: 0.0136 - val_loss: 41.2089 - val_decoder_loss: 40.9105 - val_predictor_loss: 0.0149
#
# Epoch 00260: val_loss did not improve from 40.82044
# Epoch 261/1500
#  - 3s - loss: 35.9150 - decoder_loss: 35.6577 - predictor_loss: 0.0129 - val_loss: 41.3856 - val_decoder_loss: 41.0700 - val_predictor_loss: 0.0158
#
# Epoch 00261: val_loss did not improve from 40.82044
# Epoch 262/1500
#  - 3s - loss: 35.8687 - decoder_loss: 35.5889 - predictor_loss: 0.0140 - val_loss: 40.7286 - val_decoder_loss: 40.4325 - val_predictor_loss: 0.0148
#
# Epoch 00262: val_loss improved from 40.82044 to 40.72861, saving model to VAE_Predictor262.h5
# Epoch 263/1500
#  - 3s - loss: 35.7147 - decoder_loss: 35.4634 - predictor_loss: 0.0126 - val_loss: 41.2371 - val_decoder_loss: 40.9524 - val_predictor_loss: 0.0142
#
# Epoch 00263: val_loss did not improve from 40.72861
# Epoch 264/1500
#  - 3s - loss: 35.6979 - decoder_loss: 35.4509 - predictor_loss: 0.0124 - val_loss: 41.5244 - val_decoder_loss: 41.2049 - val_predictor_loss: 0.0160
#
# Epoch 00264: val_loss did not improve from 40.72861
# Epoch 265/1500
#  - 3s - loss: 35.5991 - decoder_loss: 35.3127 - predictor_loss: 0.0143 - val_loss: 41.3725 - val_decoder_loss: 41.0671 - val_predictor_loss: 0.0153
#
# Epoch 00265: val_loss did not improve from 40.72861
# Epoch 266/1500
#  - 3s - loss: 35.6352 - decoder_loss: 35.3789 - predictor_loss: 0.0128 - val_loss: 40.2001 - val_decoder_loss: 39.9166 - val_predictor_loss: 0.0142
#
# Epoch 00266: val_loss improved from 40.72861 to 40.20008, saving model to VAE_Predictor266.h5
# Epoch 267/1500
#  - 3s - loss: 35.5145 - decoder_loss: 35.2538 - predictor_loss: 0.0130 - val_loss: 40.4643 - val_decoder_loss: 40.1187 - val_predictor_loss: 0.0173
#
# Epoch 00267: val_loss did not improve from 40.20008
# Epoch 268/1500
#  - 3s - loss: 35.7577 - decoder_loss: 35.4942 - predictor_loss: 0.0132 - val_loss: 41.0771 - val_decoder_loss: 40.7247 - val_predictor_loss: 0.0176
#
# Epoch 00268: val_loss did not improve from 40.20008
# Epoch 269/1500
#  - 3s - loss: 35.8393 - decoder_loss: 35.5620 - predictor_loss: 0.0139 - val_loss: 41.1450 - val_decoder_loss: 40.8449 - val_predictor_loss: 0.0150
#
# Epoch 00269: val_loss did not improve from 40.20008
# Epoch 270/1500
#  - 3s - loss: 35.5756 - decoder_loss: 35.3024 - predictor_loss: 0.0137 - val_loss: 40.7849 - val_decoder_loss: 40.4892 - val_predictor_loss: 0.0148
#
# Epoch 00270: val_loss did not improve from 40.20008
# Epoch 271/1500
#  - 3s - loss: 35.6885 - decoder_loss: 35.4129 - predictor_loss: 0.0138 - val_loss: 40.9713 - val_decoder_loss: 40.6092 - val_predictor_loss: 0.0181
#
# Epoch 00271: val_loss did not improve from 40.20008
# Epoch 272/1500
#  - 3s - loss: 35.5925 - decoder_loss: 35.3171 - predictor_loss: 0.0138 - val_loss: 40.5049 - val_decoder_loss: 40.2198 - val_predictor_loss: 0.0143
#
# Epoch 00272: val_loss did not improve from 40.20008
# Epoch 273/1500
#  - 3s - loss: 35.7671 - decoder_loss: 35.4887 - predictor_loss: 0.0139 - val_loss: 40.5624 - val_decoder_loss: 40.2258 - val_predictor_loss: 0.0168
#
# Epoch 00273: val_loss did not improve from 40.20008
# Epoch 274/1500
#  - 3s - loss: 35.6849 - decoder_loss: 35.4157 - predictor_loss: 0.0135 - val_loss: 40.8495 - val_decoder_loss: 40.5360 - val_predictor_loss: 0.0157
#
# Epoch 00274: val_loss did not improve from 40.20008
# Epoch 275/1500
#  - 3s - loss: 35.4748 - decoder_loss: 35.1984 - predictor_loss: 0.0138 - val_loss: 40.7637 - val_decoder_loss: 40.4240 - val_predictor_loss: 0.0170
#
# Epoch 00275: val_loss did not improve from 40.20008
# Epoch 276/1500
#  - 3s - loss: 35.4886 - decoder_loss: 35.2157 - predictor_loss: 0.0136 - val_loss: 40.5859 - val_decoder_loss: 40.2834 - val_predictor_loss: 0.0151
#
# Epoch 00276: val_loss did not improve from 40.20008
# Epoch 277/1500
#  - 3s - loss: 35.4918 - decoder_loss: 35.2435 - predictor_loss: 0.0124 - val_loss: 40.9599 - val_decoder_loss: 40.6583 - val_predictor_loss: 0.0151
#
# Epoch 00277: val_loss did not improve from 40.20008
# Epoch 278/1500
#  - 3s - loss: 35.3803 - decoder_loss: 35.1031 - predictor_loss: 0.0139 - val_loss: 40.6102 - val_decoder_loss: 40.2912 - val_predictor_loss: 0.0160
#
# Epoch 00278: val_loss did not improve from 40.20008
# Epoch 279/1500
#  - 3s - loss: 35.5320 - decoder_loss: 35.2060 - predictor_loss: 0.0163 - val_loss: 40.3401 - val_decoder_loss: 39.9762 - val_predictor_loss: 0.0182
#
# Epoch 00279: val_loss did not improve from 40.20008
# Epoch 280/1500
#  - 3s - loss: 35.4910 - decoder_loss: 35.1616 - predictor_loss: 0.0165 - val_loss: 40.1277 - val_decoder_loss: 39.7536 - val_predictor_loss: 0.0187
#
# Epoch 00280: val_loss improved from 40.20008 to 40.12771, saving model to VAE_Predictor280.h5
# Epoch 281/1500
#  - 3s - loss: 35.4067 - decoder_loss: 35.1217 - predictor_loss: 0.0143 - val_loss: 40.6406 - val_decoder_loss: 40.2838 - val_predictor_loss: 0.0178
#
# Epoch 00281: val_loss did not improve from 40.12771
# Epoch 282/1500
#  - 3s - loss: 35.4328 - decoder_loss: 35.1115 - predictor_loss: 0.0161 - val_loss: 40.4241 - val_decoder_loss: 40.0796 - val_predictor_loss: 0.0172
#
# Epoch 00282: val_loss did not improve from 40.12771
# Epoch 283/1500
#  - 3s - loss: 35.5130 - decoder_loss: 35.2311 - predictor_loss: 0.0141 - val_loss: 40.3314 - val_decoder_loss: 39.9781 - val_predictor_loss: 0.0177
#
# Epoch 00283: val_loss did not improve from 40.12771
# Epoch 284/1500
#  - 3s - loss: 35.6444 - decoder_loss: 35.3298 - predictor_loss: 0.0157 - val_loss: 41.4098 - val_decoder_loss: 41.0940 - val_predictor_loss: 0.0158
#
# Epoch 00284: val_loss did not improve from 40.12771
# Epoch 285/1500
#  - 3s - loss: 35.4345 - decoder_loss: 35.1560 - predictor_loss: 0.0139 - val_loss: 40.6541 - val_decoder_loss: 40.3419 - val_predictor_loss: 0.0156
#
# Epoch 00285: val_loss did not improve from 40.12771
# Epoch 286/1500
#  - 3s - loss: 35.3474 - decoder_loss: 35.0581 - predictor_loss: 0.0145 - val_loss: 41.0732 - val_decoder_loss: 40.7441 - val_predictor_loss: 0.0165
#
# Epoch 00286: val_loss did not improve from 40.12771
# Epoch 287/1500
#  - 3s - loss: 35.5305 - decoder_loss: 35.2506 - predictor_loss: 0.0140 - val_loss: 40.7992 - val_decoder_loss: 40.4347 - val_predictor_loss: 0.0182
#
# Epoch 00287: val_loss did not improve from 40.12771
# Epoch 288/1500
#  - 3s - loss: 35.5047 - decoder_loss: 35.2287 - predictor_loss: 0.0138 - val_loss: 40.6717 - val_decoder_loss: 40.3552 - val_predictor_loss: 0.0158
#
# Epoch 00288: val_loss did not improve from 40.12771
# Epoch 289/1500
#  - 3s - loss: 35.6539 - decoder_loss: 35.3586 - predictor_loss: 0.0148 - val_loss: 40.9563 - val_decoder_loss: 40.5259 - val_predictor_loss: 0.0215
#
# Epoch 00289: val_loss did not improve from 40.12771
# Epoch 290/1500
#  - 3s - loss: 35.5460 - decoder_loss: 35.2566 - predictor_loss: 0.0145 - val_loss: 40.1675 - val_decoder_loss: 39.8597 - val_predictor_loss: 0.0154
#
# Epoch 00290: val_loss did not improve from 40.12771
# Epoch 291/1500
#  - 3s - loss: 35.4675 - decoder_loss: 35.1978 - predictor_loss: 0.0135 - val_loss: 40.6115 - val_decoder_loss: 40.3282 - val_predictor_loss: 0.0142
#
# Epoch 00291: val_loss did not improve from 40.12771
# Epoch 292/1500
#  - 3s - loss: 35.0261 - decoder_loss: 34.7671 - predictor_loss: 0.0130 - val_loss: 40.3664 - val_decoder_loss: 40.0053 - val_predictor_loss: 0.0181
#
# Epoch 00292: val_loss did not improve from 40.12771
# Epoch 293/1500
#  - 3s - loss: 35.0958 - decoder_loss: 34.8296 - predictor_loss: 0.0133 - val_loss: 40.1880 - val_decoder_loss: 39.8571 - val_predictor_loss: 0.0165
#
# Epoch 00293: val_loss did not improve from 40.12771
# Epoch 294/1500
#  - 3s - loss: 35.0260 - decoder_loss: 34.7628 - predictor_loss: 0.0132 - val_loss: 40.0357 - val_decoder_loss: 39.7373 - val_predictor_loss: 0.0149
#
# Epoch 00294: val_loss improved from 40.12771 to 40.03568, saving model to VAE_Predictor294.h5
# Epoch 295/1500
#  - 3s - loss: 35.3599 - decoder_loss: 35.0958 - predictor_loss: 0.0132 - val_loss: 39.7355 - val_decoder_loss: 39.4354 - val_predictor_loss: 0.0150
#
# Epoch 00295: val_loss improved from 40.03568 to 39.73551, saving model to VAE_Predictor295.h5
# Epoch 296/1500
#  - 3s - loss: 35.1691 - decoder_loss: 34.9093 - predictor_loss: 0.0130 - val_loss: 39.5234 - val_decoder_loss: 39.1776 - val_predictor_loss: 0.0173
#
# Epoch 00296: val_loss improved from 39.73551 to 39.52341, saving model to VAE_Predictor296.h5
# Epoch 297/1500
#  - 3s - loss: 35.3458 - decoder_loss: 35.0748 - predictor_loss: 0.0135 - val_loss: 40.0646 - val_decoder_loss: 39.7436 - val_predictor_loss: 0.0161
#
# Epoch 00297: val_loss did not improve from 39.52341
# Epoch 298/1500
#  - 3s - loss: 34.9601 - decoder_loss: 34.6941 - predictor_loss: 0.0133 - val_loss: 40.5986 - val_decoder_loss: 40.1895 - val_predictor_loss: 0.0205
#
# Epoch 00298: val_loss did not improve from 39.52341
# Epoch 299/1500
#  - 3s - loss: 35.4187 - decoder_loss: 35.1315 - predictor_loss: 0.0144 - val_loss: 39.8639 - val_decoder_loss: 39.5358 - val_predictor_loss: 0.0164
#
# Epoch 00299: val_loss did not improve from 39.52341
# Epoch 300/1500
#  - 3s - loss: 34.9068 - decoder_loss: 34.6496 - predictor_loss: 0.0129 - val_loss: 40.0005 - val_decoder_loss: 39.6761 - val_predictor_loss: 0.0162
#
# Epoch 00300: val_loss did not improve from 39.52341
# Epoch 301/1500
#  - 3s - loss: 34.8766 - decoder_loss: 34.6295 - predictor_loss: 0.0124 - val_loss: 39.9130 - val_decoder_loss: 39.5932 - val_predictor_loss: 0.0160
#
# Epoch 00301: val_loss did not improve from 39.52341
# Epoch 302/1500
#  - 3s - loss: 35.0704 - decoder_loss: 34.8172 - predictor_loss: 0.0127 - val_loss: 40.3627 - val_decoder_loss: 40.0526 - val_predictor_loss: 0.0155
#
# Epoch 00302: val_loss did not improve from 39.52341
# Epoch 303/1500
#  - 3s - loss: 35.2152 - decoder_loss: 34.9492 - predictor_loss: 0.0133 - val_loss: 40.5807 - val_decoder_loss: 40.2841 - val_predictor_loss: 0.0148
#
# Epoch 00303: val_loss did not improve from 39.52341
# Epoch 304/1500
#  - 3s - loss: 35.3019 - decoder_loss: 35.0281 - predictor_loss: 0.0137 - val_loss: 39.9152 - val_decoder_loss: 39.5297 - val_predictor_loss: 0.0193
#
# Epoch 00304: val_loss did not improve from 39.52341
# Epoch 305/1500
#  - 3s - loss: 35.2095 - decoder_loss: 34.9396 - predictor_loss: 0.0135 - val_loss: 39.9825 - val_decoder_loss: 39.6818 - val_predictor_loss: 0.0150
#
# Epoch 00305: val_loss did not improve from 39.52341
# Epoch 306/1500
#  - 3s - loss: 34.8662 - decoder_loss: 34.6115 - predictor_loss: 0.0127 - val_loss: 40.1458 - val_decoder_loss: 39.8255 - val_predictor_loss: 0.0160
#
# Epoch 00306: val_loss did not improve from 39.52341
# Epoch 307/1500
#  - 3s - loss: 34.9829 - decoder_loss: 34.7063 - predictor_loss: 0.0138 - val_loss: 40.2733 - val_decoder_loss: 39.8929 - val_predictor_loss: 0.0190
#
# Epoch 00307: val_loss did not improve from 39.52341
# Epoch 308/1500
#  - 3s - loss: 34.8038 - decoder_loss: 34.5521 - predictor_loss: 0.0126 - val_loss: 39.4007 - val_decoder_loss: 39.1192 - val_predictor_loss: 0.0141
#
# Epoch 00308: val_loss improved from 39.52341 to 39.40071, saving model to VAE_Predictor308.h5
# Epoch 309/1500
#  - 3s - loss: 34.9212 - decoder_loss: 34.6645 - predictor_loss: 0.0128 - val_loss: 39.9125 - val_decoder_loss: 39.5287 - val_predictor_loss: 0.0192
#
# Epoch 00309: val_loss did not improve from 39.40071
# Epoch 310/1500
#  - 3s - loss: 35.1581 - decoder_loss: 34.8780 - predictor_loss: 0.0140 - val_loss: 40.4582 - val_decoder_loss: 40.1299 - val_predictor_loss: 0.0164
#
# Epoch 00310: val_loss did not improve from 39.40071
# Epoch 311/1500
#  - 3s - loss: 34.9133 - decoder_loss: 34.6450 - predictor_loss: 0.0134 - val_loss: 39.9317 - val_decoder_loss: 39.6096 - val_predictor_loss: 0.0161
#
# Epoch 00311: val_loss did not improve from 39.40071
# Epoch 312/1500
#  - 3s - loss: 35.0131 - decoder_loss: 34.7577 - predictor_loss: 0.0128 - val_loss: 39.7111 - val_decoder_loss: 39.4311 - val_predictor_loss: 0.0140
#
# Epoch 00312: val_loss did not improve from 39.40071
# Epoch 313/1500
#  - 3s - loss: 34.8900 - decoder_loss: 34.6482 - predictor_loss: 0.0121 - val_loss: 39.7608 - val_decoder_loss: 39.4560 - val_predictor_loss: 0.0152
#
# Epoch 00313: val_loss did not improve from 39.40071
# Epoch 314/1500
#  - 3s - loss: 34.9508 - decoder_loss: 34.7008 - predictor_loss: 0.0125 - val_loss: 39.8400 - val_decoder_loss: 39.5311 - val_predictor_loss: 0.0154
#
# Epoch 00314: val_loss did not improve from 39.40071
# Epoch 315/1500
#  - 3s - loss: 34.9720 - decoder_loss: 34.7159 - predictor_loss: 0.0128 - val_loss: 39.9957 - val_decoder_loss: 39.6930 - val_predictor_loss: 0.0151
#
# Epoch 00315: val_loss did not improve from 39.40071
# Epoch 316/1500
#  - 3s - loss: 35.0669 - decoder_loss: 34.7870 - predictor_loss: 0.0140 - val_loss: 39.6178 - val_decoder_loss: 39.3031 - val_predictor_loss: 0.0157
#
# Epoch 00316: val_loss did not improve from 39.40071
# Epoch 317/1500
#  - 3s - loss: 34.6806 - decoder_loss: 34.4000 - predictor_loss: 0.0140 - val_loss: 39.8814 - val_decoder_loss: 39.5750 - val_predictor_loss: 0.0153
#
# Epoch 00317: val_loss did not improve from 39.40071
# Epoch 318/1500
#  - 3s - loss: 34.8076 - decoder_loss: 34.5143 - predictor_loss: 0.0147 - val_loss: 39.5464 - val_decoder_loss: 39.2521 - val_predictor_loss: 0.0147
#
# Epoch 00318: val_loss did not improve from 39.40071
# Epoch 319/1500
#  - 3s - loss: 34.9293 - decoder_loss: 34.6637 - predictor_loss: 0.0133 - val_loss: 39.7024 - val_decoder_loss: 39.3357 - val_predictor_loss: 0.0183
#
# Epoch 00319: val_loss did not improve from 39.40071
# Epoch 320/1500
#  - 3s - loss: 34.8173 - decoder_loss: 34.5207 - predictor_loss: 0.0148 - val_loss: 39.6182 - val_decoder_loss: 39.3282 - val_predictor_loss: 0.0145
#
# Epoch 00320: val_loss did not improve from 39.40071
# Epoch 321/1500
#  - 3s - loss: 35.0964 - decoder_loss: 34.8110 - predictor_loss: 0.0143 - val_loss: 40.0266 - val_decoder_loss: 39.6858 - val_predictor_loss: 0.0170
#
# Epoch 00321: val_loss did not improve from 39.40071
# Epoch 322/1500
#  - 3s - loss: 34.7888 - decoder_loss: 34.5384 - predictor_loss: 0.0125 - val_loss: 39.2919 - val_decoder_loss: 38.9759 - val_predictor_loss: 0.0158
#
# Epoch 00322: val_loss improved from 39.40071 to 39.29194, saving model to VAE_Predictor322.h5
# Epoch 323/1500
#  - 3s - loss: 34.6742 - decoder_loss: 34.4273 - predictor_loss: 0.0123 - val_loss: 39.8701 - val_decoder_loss: 39.5824 - val_predictor_loss: 0.0144
#
# Epoch 00323: val_loss did not improve from 39.29194
# Epoch 324/1500
#  - 3s - loss: 34.5782 - decoder_loss: 34.3169 - predictor_loss: 0.0131 - val_loss: 39.1352 - val_decoder_loss: 38.8425 - val_predictor_loss: 0.0146
#
# Epoch 00324: val_loss improved from 39.29194 to 39.13516, saving model to VAE_Predictor324.h5
# Epoch 325/1500
#  - 3s - loss: 34.6527 - decoder_loss: 34.4120 - predictor_loss: 0.0120 - val_loss: 39.5440 - val_decoder_loss: 39.2302 - val_predictor_loss: 0.0157
#
# Epoch 00325: val_loss did not improve from 39.13516
# Epoch 326/1500
#  - 3s - loss: 34.6907 - decoder_loss: 34.4261 - predictor_loss: 0.0132 - val_loss: 40.1046 - val_decoder_loss: 39.8073 - val_predictor_loss: 0.0149
#
# Epoch 00326: val_loss did not improve from 39.13516
# Epoch 327/1500
#  - 3s - loss: 34.6987 - decoder_loss: 34.4333 - predictor_loss: 0.0133 - val_loss: 39.3116 - val_decoder_loss: 38.9954 - val_predictor_loss: 0.0158
#
# Epoch 00327: val_loss did not improve from 39.13516
# Epoch 328/1500
#  - 3s - loss: 34.6708 - decoder_loss: 34.4017 - predictor_loss: 0.0135 - val_loss: 40.0746 - val_decoder_loss: 39.7073 - val_predictor_loss: 0.0184
#
# Epoch 00328: val_loss did not improve from 39.13516
# Epoch 329/1500
#  - 3s - loss: 34.6750 - decoder_loss: 34.3843 - predictor_loss: 0.0145 - val_loss: 40.3437 - val_decoder_loss: 39.9633 - val_predictor_loss: 0.0190
#
# Epoch 00329: val_loss did not improve from 39.13516
# Epoch 330/1500
#  - 3s - loss: 34.5737 - decoder_loss: 34.2817 - predictor_loss: 0.0146 - val_loss: 39.5887 - val_decoder_loss: 39.1239 - val_predictor_loss: 0.0232
#
# Epoch 00330: val_loss did not improve from 39.13516
# Epoch 331/1500
#  - 3s - loss: 34.5927 - decoder_loss: 34.2774 - predictor_loss: 0.0158 - val_loss: 39.3113 - val_decoder_loss: 38.8998 - val_predictor_loss: 0.0206
#
# Epoch 00331: val_loss did not improve from 39.13516
# Epoch 332/1500
#  - 3s - loss: 34.7752 - decoder_loss: 34.5136 - predictor_loss: 0.0131 - val_loss: 39.4141 - val_decoder_loss: 39.1263 - val_predictor_loss: 0.0144
#
# Epoch 00332: val_loss did not improve from 39.13516
# Epoch 333/1500
#  - 3s - loss: 34.5646 - decoder_loss: 34.3027 - predictor_loss: 0.0131 - val_loss: 39.2065 - val_decoder_loss: 38.8589 - val_predictor_loss: 0.0174
#
# Epoch 00333: val_loss did not improve from 39.13516
# Epoch 334/1500
#  - 3s - loss: 34.6465 - decoder_loss: 34.3822 - predictor_loss: 0.0132 - val_loss: 39.3576 - val_decoder_loss: 39.0250 - val_predictor_loss: 0.0166
#
# Epoch 00334: val_loss did not improve from 39.13516
# Epoch 335/1500
#  - 3s - loss: 34.5759 - decoder_loss: 34.3015 - predictor_loss: 0.0137 - val_loss: 39.5371 - val_decoder_loss: 39.2403 - val_predictor_loss: 0.0148
#
# Epoch 00335: val_loss did not improve from 39.13516
# Epoch 336/1500
#  - 3s - loss: 34.4334 - decoder_loss: 34.1767 - predictor_loss: 0.0128 - val_loss: 40.3135 - val_decoder_loss: 40.0196 - val_predictor_loss: 0.0147
#
# Epoch 00336: val_loss did not improve from 39.13516
# Epoch 337/1500
#  - 3s - loss: 34.6898 - decoder_loss: 34.4461 - predictor_loss: 0.0122 - val_loss: 39.9344 - val_decoder_loss: 39.6059 - val_predictor_loss: 0.0164
#
# Epoch 00337: val_loss did not improve from 39.13516
# Epoch 338/1500
#  - 3s - loss: 34.9662 - decoder_loss: 34.6917 - predictor_loss: 0.0137 - val_loss: 40.2142 - val_decoder_loss: 39.9146 - val_predictor_loss: 0.0150
#
# Epoch 00338: val_loss did not improve from 39.13516
# Epoch 339/1500
#  - 3s - loss: 34.4635 - decoder_loss: 34.1861 - predictor_loss: 0.0139 - val_loss: 38.8968 - val_decoder_loss: 38.5858 - val_predictor_loss: 0.0155
#
# Epoch 00339: val_loss improved from 39.13516 to 38.89675, saving model to VAE_Predictor339.h5
# Epoch 340/1500
#  - 3s - loss: 34.4954 - decoder_loss: 34.2420 - predictor_loss: 0.0127 - val_loss: 39.2379 - val_decoder_loss: 38.9522 - val_predictor_loss: 0.0143
#
# Epoch 00340: val_loss did not improve from 38.89675
# Epoch 341/1500
#  - 3s - loss: 34.2159 - decoder_loss: 33.9444 - predictor_loss: 0.0136 - val_loss: 39.3077 - val_decoder_loss: 38.9787 - val_predictor_loss: 0.0164
#
# Epoch 00341: val_loss did not improve from 38.89675
# Epoch 342/1500
#  - 3s - loss: 34.2810 - decoder_loss: 34.0147 - predictor_loss: 0.0133 - val_loss: 38.9949 - val_decoder_loss: 38.6843 - val_predictor_loss: 0.0155
#
# Epoch 00342: val_loss did not improve from 38.89675
# Epoch 343/1500
#  - 3s - loss: 34.2933 - decoder_loss: 34.0307 - predictor_loss: 0.0131 - val_loss: 39.2291 - val_decoder_loss: 38.9182 - val_predictor_loss: 0.0155
#
# Epoch 00343: val_loss did not improve from 38.89675
# Epoch 344/1500
#  - 3s - loss: 34.3402 - decoder_loss: 34.0618 - predictor_loss: 0.0139 - val_loss: 38.9636 - val_decoder_loss: 38.6207 - val_predictor_loss: 0.0171
#
# Epoch 00344: val_loss did not improve from 38.89675
# Epoch 345/1500
#  - 3s - loss: 34.4245 - decoder_loss: 34.1629 - predictor_loss: 0.0131 - val_loss: 39.0521 - val_decoder_loss: 38.7713 - val_predictor_loss: 0.0140
#
# Epoch 00345: val_loss did not improve from 38.89675
# Epoch 346/1500
#  - 3s - loss: 34.7420 - decoder_loss: 34.4879 - predictor_loss: 0.0127 - val_loss: 39.3993 - val_decoder_loss: 39.0801 - val_predictor_loss: 0.0160
#
# Epoch 00346: val_loss did not improve from 38.89675
# Epoch 347/1500
#  - 3s - loss: 34.3843 - decoder_loss: 34.1357 - predictor_loss: 0.0124 - val_loss: 39.2844 - val_decoder_loss: 38.9609 - val_predictor_loss: 0.0162
#
# Epoch 00347: val_loss did not improve from 38.89675
# Epoch 348/1500
#  - 3s - loss: 34.3736 - decoder_loss: 34.1175 - predictor_loss: 0.0128 - val_loss: 39.1740 - val_decoder_loss: 38.8662 - val_predictor_loss: 0.0154
#
# Epoch 00348: val_loss did not improve from 38.89675
# Epoch 349/1500
#  - 3s - loss: 34.5629 - decoder_loss: 34.3122 - predictor_loss: 0.0125 - val_loss: 39.1035 - val_decoder_loss: 38.7825 - val_predictor_loss: 0.0160
#
# Epoch 00349: val_loss did not improve from 38.89675
# Epoch 350/1500
#  - 3s - loss: 34.6289 - decoder_loss: 34.3803 - predictor_loss: 0.0124 - val_loss: 39.9520 - val_decoder_loss: 39.6320 - val_predictor_loss: 0.0160
#
# Epoch 00350: val_loss did not improve from 38.89675
# Epoch 351/1500
#  - 3s - loss: 34.5452 - decoder_loss: 34.2748 - predictor_loss: 0.0135 - val_loss: 38.5396 - val_decoder_loss: 38.2349 - val_predictor_loss: 0.0152
#
# Epoch 00351: val_loss improved from 38.89675 to 38.53957, saving model to VAE_Predictor351.h5
# Epoch 352/1500
#  - 3s - loss: 34.4991 - decoder_loss: 34.2210 - predictor_loss: 0.0139 - val_loss: 38.9495 - val_decoder_loss: 38.6805 - val_predictor_loss: 0.0135
#
# Epoch 00352: val_loss did not improve from 38.53957
# Epoch 353/1500
#  - 3s - loss: 34.4397 - decoder_loss: 34.1944 - predictor_loss: 0.0123 - val_loss: 38.9708 - val_decoder_loss: 38.5880 - val_predictor_loss: 0.0191
#
# Epoch 00353: val_loss did not improve from 38.53957
# Epoch 354/1500
#  - 3s - loss: 34.3234 - decoder_loss: 34.0518 - predictor_loss: 0.0136 - val_loss: 39.0376 - val_decoder_loss: 38.6997 - val_predictor_loss: 0.0169
#
# Epoch 00354: val_loss did not improve from 38.53957
# Epoch 355/1500
#  - 3s - loss: 34.3274 - decoder_loss: 34.0633 - predictor_loss: 0.0132 - val_loss: 39.1882 - val_decoder_loss: 38.9079 - val_predictor_loss: 0.0140
#
# Epoch 00355: val_loss did not improve from 38.53957
# Epoch 356/1500
#  - 3s - loss: 34.4265 - decoder_loss: 34.1646 - predictor_loss: 0.0131 - val_loss: 39.5072 - val_decoder_loss: 39.1186 - val_predictor_loss: 0.0194
#
# Epoch 00356: val_loss did not improve from 38.53957
# Epoch 357/1500
#  - 3s - loss: 34.2085 - decoder_loss: 33.9337 - predictor_loss: 0.0137 - val_loss: 38.8405 - val_decoder_loss: 38.5211 - val_predictor_loss: 0.0160
#
# Epoch 00357: val_loss did not improve from 38.53957
# Epoch 358/1500
#  - 3s - loss: 34.3043 - decoder_loss: 34.0487 - predictor_loss: 0.0128 - val_loss: 38.6271 - val_decoder_loss: 38.3241 - val_predictor_loss: 0.0152
#
# Epoch 00358: val_loss did not improve from 38.53957
# Epoch 359/1500
#  - 3s - loss: 34.0872 - decoder_loss: 33.8278 - predictor_loss: 0.0130 - val_loss: 39.2708 - val_decoder_loss: 38.9315 - val_predictor_loss: 0.0170
#
# Epoch 00359: val_loss did not improve from 38.53957
# Epoch 360/1500
#  - 3s - loss: 34.2164 - decoder_loss: 33.9442 - predictor_loss: 0.0136 - val_loss: 38.9925 - val_decoder_loss: 38.6419 - val_predictor_loss: 0.0175
#
# Epoch 00360: val_loss did not improve from 38.53957
# Epoch 361/1500
#  - 3s - loss: 34.4712 - decoder_loss: 34.2185 - predictor_loss: 0.0126 - val_loss: 39.3890 - val_decoder_loss: 39.0906 - val_predictor_loss: 0.0149
#
# Epoch 00361: val_loss did not improve from 38.53957
# Epoch 362/1500
#  - 3s - loss: 34.2258 - decoder_loss: 33.9862 - predictor_loss: 0.0120 - val_loss: 38.9173 - val_decoder_loss: 38.6254 - val_predictor_loss: 0.0146
#
# Epoch 00362: val_loss did not improve from 38.53957
# Epoch 363/1500
#  - 3s - loss: 33.8217 - decoder_loss: 33.5741 - predictor_loss: 0.0124 - val_loss: 38.8592 - val_decoder_loss: 38.5915 - val_predictor_loss: 0.0134
#
# Epoch 00363: val_loss did not improve from 38.53957
# Epoch 364/1500
#  - 3s - loss: 34.3533 - decoder_loss: 34.1153 - predictor_loss: 0.0119 - val_loss: 38.8984 - val_decoder_loss: 38.6245 - val_predictor_loss: 0.0137
#
# Epoch 00364: val_loss did not improve from 38.53957
# Epoch 365/1500
#  - 3s - loss: 34.3897 - decoder_loss: 34.1389 - predictor_loss: 0.0125 - val_loss: 38.9874 - val_decoder_loss: 38.6961 - val_predictor_loss: 0.0146
#
# Epoch 00365: val_loss did not improve from 38.53957
# Epoch 366/1500
#  - 3s - loss: 34.3997 - decoder_loss: 34.1492 - predictor_loss: 0.0125 - val_loss: 39.2625 - val_decoder_loss: 38.9526 - val_predictor_loss: 0.0155
#
# Epoch 00366: val_loss did not improve from 38.53957
# Epoch 367/1500
#  - 3s - loss: 34.1091 - decoder_loss: 33.8409 - predictor_loss: 0.0134 - val_loss: 38.7013 - val_decoder_loss: 38.3885 - val_predictor_loss: 0.0156
#
# Epoch 00367: val_loss did not improve from 38.53957
# Epoch 368/1500
#  - 3s - loss: 34.1693 - decoder_loss: 33.9163 - predictor_loss: 0.0127 - val_loss: 39.2751 - val_decoder_loss: 38.9694 - val_predictor_loss: 0.0153
#
# Epoch 00368: val_loss did not improve from 38.53957
# Epoch 369/1500
#  - 3s - loss: 34.2854 - decoder_loss: 34.0432 - predictor_loss: 0.0121 - val_loss: 39.1137 - val_decoder_loss: 38.8249 - val_predictor_loss: 0.0144
#
# Epoch 00369: val_loss did not improve from 38.53957
# Epoch 370/1500
#  - 3s - loss: 34.5493 - decoder_loss: 34.3098 - predictor_loss: 0.0120 - val_loss: 38.6234 - val_decoder_loss: 38.3273 - val_predictor_loss: 0.0148
#
# Epoch 00370: val_loss did not improve from 38.53957
# Epoch 371/1500
#  - 3s - loss: 34.1310 - decoder_loss: 33.8858 - predictor_loss: 0.0123 - val_loss: 38.6204 - val_decoder_loss: 38.2700 - val_predictor_loss: 0.0175
#
# Epoch 00371: val_loss did not improve from 38.53957
# Epoch 372/1500
#  - 3s - loss: 33.9137 - decoder_loss: 33.6706 - predictor_loss: 0.0122 - val_loss: 38.6975 - val_decoder_loss: 38.4032 - val_predictor_loss: 0.0147
#
# Epoch 00372: val_loss did not improve from 38.53957
# Epoch 373/1500
#  - 3s - loss: 34.1557 - decoder_loss: 33.9176 - predictor_loss: 0.0119 - val_loss: 39.4016 - val_decoder_loss: 39.1215 - val_predictor_loss: 0.0140
#
# Epoch 00373: val_loss did not improve from 38.53957
# Epoch 374/1500
#  - 3s - loss: 34.2002 - decoder_loss: 33.9545 - predictor_loss: 0.0123 - val_loss: 38.0397 - val_decoder_loss: 37.7478 - val_predictor_loss: 0.0146
#
# Epoch 00374: val_loss improved from 38.53957 to 38.03974, saving model to VAE_Predictor374.h5
# Epoch 375/1500
#  - 3s - loss: 33.8750 - decoder_loss: 33.6059 - predictor_loss: 0.0135 - val_loss: 39.2797 - val_decoder_loss: 38.9682 - val_predictor_loss: 0.0156
#
# Epoch 00375: val_loss did not improve from 38.03974
# Epoch 376/1500
#  - 3s - loss: 34.4340 - decoder_loss: 34.1608 - predictor_loss: 0.0137 - val_loss: 39.1043 - val_decoder_loss: 38.7603 - val_predictor_loss: 0.0172
#
# Epoch 00376: val_loss did not improve from 38.03974
# Epoch 377/1500
#  - 3s - loss: 34.1753 - decoder_loss: 33.9222 - predictor_loss: 0.0127 - val_loss: 38.5944 - val_decoder_loss: 38.3006 - val_predictor_loss: 0.0147
#
# Epoch 00377: val_loss did not improve from 38.03974
# Epoch 378/1500
#  - 3s - loss: 33.9825 - decoder_loss: 33.7404 - predictor_loss: 0.0121 - val_loss: 38.6736 - val_decoder_loss: 38.4032 - val_predictor_loss: 0.0135
#
# Epoch 00378: val_loss did not improve from 38.03974
# Epoch 379/1500
#  - 3s - loss: 33.9873 - decoder_loss: 33.7430 - predictor_loss: 0.0122 - val_loss: 39.0046 - val_decoder_loss: 38.6847 - val_predictor_loss: 0.0160
#
# Epoch 00379: val_loss did not improve from 38.03974
# Epoch 380/1500
#  - 3s - loss: 33.9287 - decoder_loss: 33.6661 - predictor_loss: 0.0131 - val_loss: 39.0089 - val_decoder_loss: 38.6536 - val_predictor_loss: 0.0178
#
# Epoch 00380: val_loss did not improve from 38.03974
# Epoch 381/1500
#  - 3s - loss: 34.3224 - decoder_loss: 34.0304 - predictor_loss: 0.0146 - val_loss: 38.5344 - val_decoder_loss: 38.2123 - val_predictor_loss: 0.0161
#
# Epoch 00381: val_loss did not improve from 38.03974
# Epoch 382/1500
#  - 3s - loss: 33.9788 - decoder_loss: 33.7229 - predictor_loss: 0.0128 - val_loss: 38.3295 - val_decoder_loss: 38.0298 - val_predictor_loss: 0.0150
#
# Epoch 00382: val_loss did not improve from 38.03974
# Epoch 383/1500
#  - 3s - loss: 33.7981 - decoder_loss: 33.5516 - predictor_loss: 0.0123 - val_loss: 38.8335 - val_decoder_loss: 38.4755 - val_predictor_loss: 0.0179
#
# Epoch 00383: val_loss did not improve from 38.03974
# Epoch 384/1500
#  - 3s - loss: 33.7508 - decoder_loss: 33.5085 - predictor_loss: 0.0121 - val_loss: 38.9764 - val_decoder_loss: 38.7114 - val_predictor_loss: 0.0133
#
# Epoch 00384: val_loss did not improve from 38.03974
# Epoch 385/1500
#  - 3s - loss: 33.8813 - decoder_loss: 33.6546 - predictor_loss: 0.0113 - val_loss: 37.8786 - val_decoder_loss: 37.5895 - val_predictor_loss: 0.0145
#
# Epoch 00385: val_loss improved from 38.03974 to 37.87857, saving model to VAE_Predictor385.h5
# Epoch 386/1500
#  - 3s - loss: 34.0174 - decoder_loss: 33.7740 - predictor_loss: 0.0122 - val_loss: 38.3477 - val_decoder_loss: 38.0629 - val_predictor_loss: 0.0142
#
# Epoch 00386: val_loss did not improve from 37.87857
# Epoch 387/1500
#  - 3s - loss: 33.7375 - decoder_loss: 33.4722 - predictor_loss: 0.0133 - val_loss: 38.9340 - val_decoder_loss: 38.5598 - val_predictor_loss: 0.0187
#
# Epoch 00387: val_loss did not improve from 37.87857
# Epoch 388/1500
#  - 3s - loss: 34.2236 - decoder_loss: 33.9228 - predictor_loss: 0.0150 - val_loss: 38.8712 - val_decoder_loss: 38.5167 - val_predictor_loss: 0.0177
#
# Epoch 00388: val_loss did not improve from 37.87857
# Epoch 389/1500
#  - 3s - loss: 33.7673 - decoder_loss: 33.5247 - predictor_loss: 0.0121 - val_loss: 37.9678 - val_decoder_loss: 37.6491 - val_predictor_loss: 0.0159
#
# Epoch 00389: val_loss did not improve from 37.87857
# Epoch 390/1500
#  - 3s - loss: 34.0836 - decoder_loss: 33.8373 - predictor_loss: 0.0123 - val_loss: 39.0821 - val_decoder_loss: 38.7172 - val_predictor_loss: 0.0182
#
# Epoch 00390: val_loss did not improve from 37.87857
# Epoch 391/1500
#  - 3s - loss: 33.6858 - decoder_loss: 33.4289 - predictor_loss: 0.0128 - val_loss: 38.4720 - val_decoder_loss: 38.1960 - val_predictor_loss: 0.0138
#
# Epoch 00391: val_loss did not improve from 37.87857
# Epoch 392/1500
#  - 3s - loss: 34.1040 - decoder_loss: 33.8595 - predictor_loss: 0.0122 - val_loss: 38.7377 - val_decoder_loss: 38.4717 - val_predictor_loss: 0.0133
#
# Epoch 00392: val_loss did not improve from 37.87857
# Epoch 393/1500
#  - 3s - loss: 33.5083 - decoder_loss: 33.2711 - predictor_loss: 0.0119 - val_loss: 38.5358 - val_decoder_loss: 38.2559 - val_predictor_loss: 0.0140
#
# Epoch 00393: val_loss did not improve from 37.87857
# Epoch 394/1500
#  - 3s - loss: 33.7863 - decoder_loss: 33.5526 - predictor_loss: 0.0117 - val_loss: 38.5167 - val_decoder_loss: 38.2436 - val_predictor_loss: 0.0137
#
# Epoch 00394: val_loss did not improve from 37.87857
# Epoch 395/1500
#  - 3s - loss: 33.9018 - decoder_loss: 33.6668 - predictor_loss: 0.0117 - val_loss: 38.3764 - val_decoder_loss: 38.0324 - val_predictor_loss: 0.0172
#
# Epoch 00395: val_loss did not improve from 37.87857
# Epoch 396/1500
#  - 3s - loss: 33.7718 - decoder_loss: 33.5213 - predictor_loss: 0.0125 - val_loss: 38.5603 - val_decoder_loss: 38.2806 - val_predictor_loss: 0.0140
#
# Epoch 00396: val_loss did not improve from 37.87857
# Epoch 397/1500
#  - 3s - loss: 33.7809 - decoder_loss: 33.5205 - predictor_loss: 0.0130 - val_loss: 38.2049 - val_decoder_loss: 37.9246 - val_predictor_loss: 0.0140
#
# Epoch 00397: val_loss did not improve from 37.87857
# Epoch 398/1500
#  - 3s - loss: 33.7883 - decoder_loss: 33.5329 - predictor_loss: 0.0128 - val_loss: 38.2981 - val_decoder_loss: 38.0183 - val_predictor_loss: 0.0140
#
# Epoch 00398: val_loss did not improve from 37.87857
# Epoch 399/1500
#  - 3s - loss: 33.8708 - decoder_loss: 33.6270 - predictor_loss: 0.0122 - val_loss: 38.3324 - val_decoder_loss: 38.0687 - val_predictor_loss: 0.0132
#
# Epoch 00399: val_loss did not improve from 37.87857
# Epoch 400/1500
#  - 3s - loss: 34.0063 - decoder_loss: 33.7523 - predictor_loss: 0.0127 - val_loss: 38.4047 - val_decoder_loss: 38.0933 - val_predictor_loss: 0.0156
#
# Epoch 00400: val_loss did not improve from 37.87857
# Epoch 401/1500
#  - 3s - loss: 33.6550 - decoder_loss: 33.3874 - predictor_loss: 0.0134 - val_loss: 38.3316 - val_decoder_loss: 38.0087 - val_predictor_loss: 0.0161
#
# Epoch 00401: val_loss did not improve from 37.87857
# Epoch 402/1500
#  - 3s - loss: 33.9044 - decoder_loss: 33.6521 - predictor_loss: 0.0126 - val_loss: 38.8497 - val_decoder_loss: 38.5305 - val_predictor_loss: 0.0160
#
# Epoch 00402: val_loss did not improve from 37.87857
# Epoch 403/1500
#  - 3s - loss: 33.9557 - decoder_loss: 33.7031 - predictor_loss: 0.0126 - val_loss: 38.4739 - val_decoder_loss: 38.1724 - val_predictor_loss: 0.0151
#
# Epoch 00403: val_loss did not improve from 37.87857
# Epoch 404/1500
#  - 3s - loss: 33.6178 - decoder_loss: 33.3654 - predictor_loss: 0.0126 - val_loss: 38.3003 - val_decoder_loss: 38.0286 - val_predictor_loss: 0.0136
#
# Epoch 00404: val_loss did not improve from 37.87857
# Epoch 405/1500
#  - 3s - loss: 33.9266 - decoder_loss: 33.6773 - predictor_loss: 0.0125 - val_loss: 39.1945 - val_decoder_loss: 38.8877 - val_predictor_loss: 0.0153
#
# Epoch 00405: val_loss did not improve from 37.87857
# Epoch 406/1500
#  - 3s - loss: 34.1450 - decoder_loss: 33.8865 - predictor_loss: 0.0129 - val_loss: 38.3315 - val_decoder_loss: 38.0096 - val_predictor_loss: 0.0161
#
# Epoch 00406: val_loss did not improve from 37.87857
# Epoch 407/1500
#  - 3s - loss: 33.7541 - decoder_loss: 33.4949 - predictor_loss: 0.0130 - val_loss: 38.4979 - val_decoder_loss: 38.1806 - val_predictor_loss: 0.0159
#
# Epoch 00407: val_loss did not improve from 37.87857
# Epoch 408/1500
#  - 3s - loss: 33.5324 - decoder_loss: 33.2696 - predictor_loss: 0.0131 - val_loss: 38.6064 - val_decoder_loss: 38.2812 - val_predictor_loss: 0.0163
#
# Epoch 00408: val_loss did not improve from 37.87857
# Epoch 409/1500
#  - 3s - loss: 33.5061 - decoder_loss: 33.2617 - predictor_loss: 0.0122 - val_loss: 38.2685 - val_decoder_loss: 37.9272 - val_predictor_loss: 0.0171
#
# Epoch 00409: val_loss did not improve from 37.87857
# Epoch 410/1500
#  - 3s - loss: 33.8470 - decoder_loss: 33.5773 - predictor_loss: 0.0135 - val_loss: 38.1527 - val_decoder_loss: 37.8303 - val_predictor_loss: 0.0161
#
# Epoch 00410: val_loss did not improve from 37.87857
# Epoch 411/1500
#  - 3s - loss: 33.6031 - decoder_loss: 33.3513 - predictor_loss: 0.0126 - val_loss: 37.7335 - val_decoder_loss: 37.4278 - val_predictor_loss: 0.0153
#
# Epoch 00411: val_loss improved from 37.87857 to 37.73353, saving model to VAE_Predictor411.h5
# Epoch 412/1500
#  - 3s - loss: 33.7168 - decoder_loss: 33.4301 - predictor_loss: 0.0143 - val_loss: 38.4391 - val_decoder_loss: 38.1331 - val_predictor_loss: 0.0153
#
# Epoch 00412: val_loss did not improve from 37.73353
# Epoch 413/1500
#  - 3s - loss: 33.8847 - decoder_loss: 33.6173 - predictor_loss: 0.0134 - val_loss: 38.2843 - val_decoder_loss: 37.9864 - val_predictor_loss: 0.0149
#
# Epoch 00413: val_loss did not improve from 37.73353
# Epoch 414/1500
#  - 3s - loss: 33.8098 - decoder_loss: 33.5653 - predictor_loss: 0.0122 - val_loss: 38.1692 - val_decoder_loss: 37.8933 - val_predictor_loss: 0.0138
#
# Epoch 00414: val_loss did not improve from 37.73353
# Epoch 415/1500
#  - 3s - loss: 33.4807 - decoder_loss: 33.2307 - predictor_loss: 0.0125 - val_loss: 38.5082 - val_decoder_loss: 38.2264 - val_predictor_loss: 0.0141
#
# Epoch 00415: val_loss did not improve from 37.73353
# Epoch 416/1500
#  - 3s - loss: 33.6829 - decoder_loss: 33.4236 - predictor_loss: 0.0130 - val_loss: 38.1705 - val_decoder_loss: 37.8831 - val_predictor_loss: 0.0144
#
# Epoch 00416: val_loss did not improve from 37.73353
# Epoch 417/1500
#  - 3s - loss: 33.6104 - decoder_loss: 33.3428 - predictor_loss: 0.0134 - val_loss: 38.7884 - val_decoder_loss: 38.4603 - val_predictor_loss: 0.0164
#
# Epoch 00417: val_loss did not improve from 37.73353
# Epoch 418/1500
#  - 3s - loss: 33.7251 - decoder_loss: 33.4591 - predictor_loss: 0.0133 - val_loss: 37.9360 - val_decoder_loss: 37.6435 - val_predictor_loss: 0.0146
#
# Epoch 00418: val_loss did not improve from 37.73353
# Epoch 419/1500
#  - 3s - loss: 33.5453 - decoder_loss: 33.3056 - predictor_loss: 0.0120 - val_loss: 38.4354 - val_decoder_loss: 38.1315 - val_predictor_loss: 0.0152
#
# Epoch 00419: val_loss did not improve from 37.73353
# Epoch 420/1500
#  - 3s - loss: 33.6538 - decoder_loss: 33.4078 - predictor_loss: 0.0123 - val_loss: 37.7100 - val_decoder_loss: 37.4137 - val_predictor_loss: 0.0148
#
# Epoch 00420: val_loss improved from 37.73353 to 37.70997, saving model to VAE_Predictor420.h5
# Epoch 421/1500
#  - 3s - loss: 33.6659 - decoder_loss: 33.4115 - predictor_loss: 0.0127 - val_loss: 37.8605 - val_decoder_loss: 37.5805 - val_predictor_loss: 0.0140
#
# Epoch 00421: val_loss did not improve from 37.70997
# Epoch 422/1500
#  - 3s - loss: 33.5706 - decoder_loss: 33.3217 - predictor_loss: 0.0124 - val_loss: 38.4354 - val_decoder_loss: 38.1359 - val_predictor_loss: 0.0150
#
# Epoch 00422: val_loss did not improve from 37.70997
# Epoch 423/1500
#  - 3s - loss: 33.9887 - decoder_loss: 33.7305 - predictor_loss: 0.0129 - val_loss: 38.3989 - val_decoder_loss: 38.0387 - val_predictor_loss: 0.0180
#
# Epoch 00423: val_loss did not improve from 37.70997
# Epoch 424/1500
#  - 3s - loss: 33.7793 - decoder_loss: 33.4786 - predictor_loss: 0.0150 - val_loss: 37.4289 - val_decoder_loss: 37.0791 - val_predictor_loss: 0.0175
#
# Epoch 00424: val_loss improved from 37.70997 to 37.42886, saving model to VAE_Predictor424.h5
# Epoch 425/1500
#  - 3s - loss: 33.4483 - decoder_loss: 33.1794 - predictor_loss: 0.0134 - val_loss: 38.0286 - val_decoder_loss: 37.7431 - val_predictor_loss: 0.0143
#
# Epoch 00425: val_loss did not improve from 37.42886
# Epoch 426/1500
#  - 3s - loss: 33.4016 - decoder_loss: 33.1718 - predictor_loss: 0.0115 - val_loss: 38.4302 - val_decoder_loss: 38.1137 - val_predictor_loss: 0.0158
#
# Epoch 00426: val_loss did not improve from 37.42886
# Epoch 427/1500
#  - 3s - loss: 33.6332 - decoder_loss: 33.3708 - predictor_loss: 0.0131 - val_loss: 39.1304 - val_decoder_loss: 38.8188 - val_predictor_loss: 0.0156
#
# Epoch 00427: val_loss did not improve from 37.42886
# Epoch 428/1500
#  - 3s - loss: 33.8269 - decoder_loss: 33.5616 - predictor_loss: 0.0133 - val_loss: 38.1797 - val_decoder_loss: 37.8903 - val_predictor_loss: 0.0145
#
# Epoch 00428: val_loss did not improve from 37.42886
# Epoch 429/1500
#  - 3s - loss: 33.3405 - decoder_loss: 33.0821 - predictor_loss: 0.0129 - val_loss: 38.0527 - val_decoder_loss: 37.6965 - val_predictor_loss: 0.0178
#
# Epoch 00429: val_loss did not improve from 37.42886
# Epoch 430/1500
#  - 3s - loss: 33.4733 - decoder_loss: 33.2258 - predictor_loss: 0.0124 - val_loss: 38.1989 - val_decoder_loss: 37.9304 - val_predictor_loss: 0.0134
#
# Epoch 00430: val_loss did not improve from 37.42886
# Epoch 431/1500
#  - 3s - loss: 33.4841 - decoder_loss: 33.2197 - predictor_loss: 0.0132 - val_loss: 37.9796 - val_decoder_loss: 37.6918 - val_predictor_loss: 0.0144
#
# Epoch 00431: val_loss did not improve from 37.42886
# Epoch 432/1500
#  - 3s - loss: 33.4477 - decoder_loss: 33.1928 - predictor_loss: 0.0127 - val_loss: 37.8178 - val_decoder_loss: 37.5460 - val_predictor_loss: 0.0136
#
# Epoch 00432: val_loss did not improve from 37.42886
# Epoch 433/1500
#  - 3s - loss: 33.6745 - decoder_loss: 33.4277 - predictor_loss: 0.0123 - val_loss: 37.7925 - val_decoder_loss: 37.4871 - val_predictor_loss: 0.0153
#
# Epoch 00433: val_loss did not improve from 37.42886
# Epoch 434/1500
#  - 3s - loss: 33.3454 - decoder_loss: 33.0864 - predictor_loss: 0.0130 - val_loss: 37.8327 - val_decoder_loss: 37.5373 - val_predictor_loss: 0.0148
#
# Epoch 00434: val_loss did not improve from 37.42886
# Epoch 435/1500
#  - 3s - loss: 33.2479 - decoder_loss: 33.0201 - predictor_loss: 0.0114 - val_loss: 38.2985 - val_decoder_loss: 38.0253 - val_predictor_loss: 0.0137
#
# Epoch 00435: val_loss did not improve from 37.42886
# Epoch 436/1500
#  - 3s - loss: 33.5146 - decoder_loss: 33.2716 - predictor_loss: 0.0121 - val_loss: 37.5350 - val_decoder_loss: 37.2629 - val_predictor_loss: 0.0136
#
# Epoch 00436: val_loss did not improve from 37.42886
# Epoch 437/1500
#  - 3s - loss: 33.3190 - decoder_loss: 33.0886 - predictor_loss: 0.0115 - val_loss: 37.6865 - val_decoder_loss: 37.4305 - val_predictor_loss: 0.0128
#
# Epoch 00437: val_loss did not improve from 37.42886
# Epoch 438/1500
#  - 3s - loss: 33.3809 - decoder_loss: 33.1390 - predictor_loss: 0.0121 - val_loss: 37.7441 - val_decoder_loss: 37.4613 - val_predictor_loss: 0.0141
#
# Epoch 00438: val_loss did not improve from 37.42886
# Epoch 439/1500
#  - 3s - loss: 33.4519 - decoder_loss: 33.2106 - predictor_loss: 0.0121 - val_loss: 37.3740 - val_decoder_loss: 37.1154 - val_predictor_loss: 0.0129
#
# Epoch 00439: val_loss improved from 37.42886 to 37.37399, saving model to VAE_Predictor439.h5
# Epoch 440/1500
#  - 3s - loss: 33.3903 - decoder_loss: 33.1495 - predictor_loss: 0.0120 - val_loss: 37.8931 - val_decoder_loss: 37.6000 - val_predictor_loss: 0.0147
#
# Epoch 00440: val_loss did not improve from 37.37399
# Epoch 441/1500
#  - 3s - loss: 33.3646 - decoder_loss: 33.1202 - predictor_loss: 0.0122 - val_loss: 38.5212 - val_decoder_loss: 38.1792 - val_predictor_loss: 0.0171
#
# Epoch 00441: val_loss did not improve from 37.37399
# Epoch 442/1500
#  - 3s - loss: 33.3895 - decoder_loss: 33.1445 - predictor_loss: 0.0122 - val_loss: 38.0288 - val_decoder_loss: 37.7432 - val_predictor_loss: 0.0143
#
# Epoch 00442: val_loss did not improve from 37.37399
# Epoch 443/1500
#  - 3s - loss: 33.4584 - decoder_loss: 33.2310 - predictor_loss: 0.0114 - val_loss: 37.7170 - val_decoder_loss: 37.4571 - val_predictor_loss: 0.0130
#
# Epoch 00443: val_loss did not improve from 37.37399
# Epoch 444/1500
#  - 3s - loss: 33.1953 - decoder_loss: 32.9643 - predictor_loss: 0.0115 - val_loss: 38.2900 - val_decoder_loss: 38.0133 - val_predictor_loss: 0.0138
#
# Epoch 00444: val_loss did not improve from 37.37399
# Epoch 445/1500
#  - 3s - loss: 33.1304 - decoder_loss: 32.8761 - predictor_loss: 0.0127 - val_loss: 37.1506 - val_decoder_loss: 36.8454 - val_predictor_loss: 0.0153
#
# Epoch 00445: val_loss improved from 37.37399 to 37.15059, saving model to VAE_Predictor445.h5
# Epoch 446/1500
#  - 3s - loss: 33.2830 - decoder_loss: 33.0230 - predictor_loss: 0.0130 - val_loss: 38.5869 - val_decoder_loss: 38.2432 - val_predictor_loss: 0.0172
#
# Epoch 00446: val_loss did not improve from 37.15059
# Epoch 447/1500
#  - 3s - loss: 33.2853 - decoder_loss: 33.0477 - predictor_loss: 0.0119 - val_loss: 37.7868 - val_decoder_loss: 37.4147 - val_predictor_loss: 0.0186
#
# Epoch 00447: val_loss did not improve from 37.15059
# Epoch 448/1500
#  - 3s - loss: 33.3065 - decoder_loss: 33.0530 - predictor_loss: 0.0127 - val_loss: 37.5259 - val_decoder_loss: 37.2235 - val_predictor_loss: 0.0151
#
# Epoch 00448: val_loss did not improve from 37.15059
# Epoch 449/1500
#  - 3s - loss: 33.1256 - decoder_loss: 32.8712 - predictor_loss: 0.0127 - val_loss: 37.6089 - val_decoder_loss: 37.2984 - val_predictor_loss: 0.0155
#
# Epoch 00449: val_loss did not improve from 37.15059
# Epoch 450/1500
#  - 3s - loss: 33.3381 - decoder_loss: 33.0848 - predictor_loss: 0.0127 - val_loss: 37.5449 - val_decoder_loss: 37.2647 - val_predictor_loss: 0.0140
#
# Epoch 00450: val_loss did not improve from 37.15059
# Epoch 451/1500
#  - 3s - loss: 33.1577 - decoder_loss: 32.9093 - predictor_loss: 0.0124 - val_loss: 38.0655 - val_decoder_loss: 37.7291 - val_predictor_loss: 0.0168
#
# Epoch 00451: val_loss did not improve from 37.15059
# Epoch 452/1500
#  - 3s - loss: 33.4083 - decoder_loss: 33.1621 - predictor_loss: 0.0123 - val_loss: 37.5432 - val_decoder_loss: 37.2641 - val_predictor_loss: 0.0140
#
# Epoch 00452: val_loss did not improve from 37.15059
# Epoch 453/1500
#  - 3s - loss: 33.1772 - decoder_loss: 32.9189 - predictor_loss: 0.0129 - val_loss: 38.3047 - val_decoder_loss: 38.0333 - val_predictor_loss: 0.0136
#
# Epoch 00453: val_loss did not improve from 37.15059
# Epoch 454/1500
#  - 3s - loss: 33.1266 - decoder_loss: 32.8908 - predictor_loss: 0.0118 - val_loss: 38.1271 - val_decoder_loss: 37.8505 - val_predictor_loss: 0.0138
#
# Epoch 00454: val_loss did not improve from 37.15059
# Epoch 455/1500
#  - 3s - loss: 33.2657 - decoder_loss: 33.0120 - predictor_loss: 0.0127 - val_loss: 37.4254 - val_decoder_loss: 37.1254 - val_predictor_loss: 0.0150
#
# Epoch 00455: val_loss did not improve from 37.15059
# Epoch 456/1500
#  - 3s - loss: 33.1210 - decoder_loss: 32.8697 - predictor_loss: 0.0126 - val_loss: 37.8964 - val_decoder_loss: 37.6077 - val_predictor_loss: 0.0144
#
# Epoch 00456: val_loss did not improve from 37.15059
# Epoch 457/1500
#  - 3s - loss: 33.2370 - decoder_loss: 32.9921 - predictor_loss: 0.0122 - val_loss: 37.4005 - val_decoder_loss: 37.1409 - val_predictor_loss: 0.0130
#
# Epoch 00457: val_loss did not improve from 37.15059
# Epoch 458/1500
#  - 3s - loss: 33.0363 - decoder_loss: 32.8077 - predictor_loss: 0.0114 - val_loss: 37.6598 - val_decoder_loss: 37.3648 - val_predictor_loss: 0.0147
#
# Epoch 00458: val_loss did not improve from 37.15059
# Epoch 459/1500
#  - 3s - loss: 33.0007 - decoder_loss: 32.7624 - predictor_loss: 0.0119 - val_loss: 37.6797 - val_decoder_loss: 37.4000 - val_predictor_loss: 0.0140
#
# Epoch 00459: val_loss did not improve from 37.15059
# Epoch 460/1500
#  - 3s - loss: 32.9703 - decoder_loss: 32.7075 - predictor_loss: 0.0131 - val_loss: 37.1457 - val_decoder_loss: 36.7805 - val_predictor_loss: 0.0183
#
# Epoch 00460: val_loss improved from 37.15059 to 37.14567, saving model to VAE_Predictor460.h5
# Epoch 461/1500
#  - 3s - loss: 32.9963 - decoder_loss: 32.7503 - predictor_loss: 0.0123 - val_loss: 37.6546 - val_decoder_loss: 37.3972 - val_predictor_loss: 0.0129
#
# Epoch 00461: val_loss did not improve from 37.14567
# Epoch 462/1500
#  - 3s - loss: 33.1786 - decoder_loss: 32.9576 - predictor_loss: 0.0111 - val_loss: 38.0388 - val_decoder_loss: 37.7758 - val_predictor_loss: 0.0132
#
# Epoch 00462: val_loss did not improve from 37.14567
# Epoch 463/1500
#  - 3s - loss: 32.9450 - decoder_loss: 32.7174 - predictor_loss: 0.0114 - val_loss: 37.8522 - val_decoder_loss: 37.5621 - val_predictor_loss: 0.0145
#
# Epoch 00463: val_loss did not improve from 37.14567
# Epoch 464/1500
#  - 3s - loss: 33.0991 - decoder_loss: 32.8619 - predictor_loss: 0.0119 - val_loss: 37.2294 - val_decoder_loss: 36.9253 - val_predictor_loss: 0.0152
#
# Epoch 00464: val_loss did not improve from 37.14567
# Epoch 465/1500
#  - 3s - loss: 32.9996 - decoder_loss: 32.7689 - predictor_loss: 0.0115 - val_loss: 37.9768 - val_decoder_loss: 37.6870 - val_predictor_loss: 0.0145
#
# Epoch 00465: val_loss did not improve from 37.14567
# Epoch 466/1500
#  - 3s - loss: 33.1972 - decoder_loss: 32.9474 - predictor_loss: 0.0125 - val_loss: 38.2219 - val_decoder_loss: 37.9204 - val_predictor_loss: 0.0151
#
# Epoch 00466: val_loss did not improve from 37.14567
# Epoch 467/1500
#  - 3s - loss: 33.1885 - decoder_loss: 32.9494 - predictor_loss: 0.0120 - val_loss: 37.7414 - val_decoder_loss: 37.4640 - val_predictor_loss: 0.0139
#
# Epoch 00467: val_loss did not improve from 37.14567
# Epoch 468/1500
#  - 3s - loss: 33.0070 - decoder_loss: 32.7499 - predictor_loss: 0.0129 - val_loss: 37.5718 - val_decoder_loss: 37.2484 - val_predictor_loss: 0.0162
#
# Epoch 00468: val_loss did not improve from 37.14567
# Epoch 469/1500
# ...
#
# Epoch 01427: val_loss did not improve from 32.54448
# Epoch 1428/1500
#  - 3s - loss: 29.8073 - decoder_loss: 29.6099 - predictor_loss: 0.0099 - val_loss: 32.9528 - val_decoder_loss: 32.7432 - val_predictor_loss: 0.0105
#
# Epoch 01428: val_loss did not improve from 32.54448
# Epoch 1429/1500
#  - 3s - loss: 29.4390 - decoder_loss: 29.2301 - predictor_loss: 0.0104 - val_loss: 33.6607 - val_decoder_loss: 33.4030 - val_predictor_loss: 0.0129
#
# Epoch 01429: val_loss did not improve from 32.54448
# Epoch 1430/1500
#  - 3s - loss: 29.7712 - decoder_loss: 29.5742 - predictor_loss: 0.0099 - val_loss: 34.5717 - val_decoder_loss: 34.3209 - val_predictor_loss: 0.0125
#
# Epoch 01430: val_loss did not improve from 32.54448
# Epoch 1431/1500
#  - 3s - loss: 29.8743 - decoder_loss: 29.6779 - predictor_loss: 0.0098 - val_loss: 33.4655 - val_decoder_loss: 33.2291 - val_predictor_loss: 0.0118
#
# Epoch 01431: val_loss did not improve from 32.54448
# Epoch 1432/1500
#  - 3s - loss: 29.8778 - decoder_loss: 29.6712 - predictor_loss: 0.0103 - val_loss: 33.0884 - val_decoder_loss: 32.8429 - val_predictor_loss: 0.0123
#
# Epoch 01432: val_loss did not improve from 32.54448
# Epoch 1433/1500
#  - 3s - loss: 29.8398 - decoder_loss: 29.6091 - predictor_loss: 0.0115 - val_loss: 33.0641 - val_decoder_loss: 32.8284 - val_predictor_loss: 0.0118
#
# Epoch 01433: val_loss did not improve from 32.54448
# Epoch 1434/1500
#  - 3s - loss: 29.5520 - decoder_loss: 29.3530 - predictor_loss: 0.0100 - val_loss: 33.1979 - val_decoder_loss: 32.9074 - val_predictor_loss: 0.0145
#
# Epoch 01434: val_loss did not improve from 32.54448
# Epoch 1435/1500
#  - 3s - loss: 29.6796 - decoder_loss: 29.4782 - predictor_loss: 0.0101 - val_loss: 34.4073 - val_decoder_loss: 34.1588 - val_predictor_loss: 0.0124
#
# Epoch 01435: val_loss did not improve from 32.54448
# Epoch 1436/1500
#  - 3s - loss: 29.5316 - decoder_loss: 29.3339 - predictor_loss: 0.0099 - val_loss: 32.6778 - val_decoder_loss: 32.4456 - val_predictor_loss: 0.0116
#
# Epoch 01436: val_loss did not improve from 32.54448
# Epoch 1437/1500
#  - 3s - loss: 29.5705 - decoder_loss: 29.3593 - predictor_loss: 0.0106 - val_loss: 33.0512 - val_decoder_loss: 32.8142 - val_predictor_loss: 0.0118
#
# Epoch 01437: val_loss did not improve from 32.54448
# Epoch 1438/1500
#  - 3s - loss: 29.5306 - decoder_loss: 29.3379 - predictor_loss: 0.0096 - val_loss: 33.3478 - val_decoder_loss: 33.1081 - val_predictor_loss: 0.0120
#
# Epoch 01438: val_loss did not improve from 32.54448
# Epoch 1439/1500
#  - 3s - loss: 29.7768 - decoder_loss: 29.5487 - predictor_loss: 0.0114 - val_loss: 34.1632 - val_decoder_loss: 33.8877 - val_predictor_loss: 0.0138
#
# Epoch 01439: val_loss did not improve from 32.54448
# Epoch 1440/1500
#  - 3s - loss: 29.7696 - decoder_loss: 29.5575 - predictor_loss: 0.0106 - val_loss: 33.6965 - val_decoder_loss: 33.4514 - val_predictor_loss: 0.0123
#
# Epoch 01440: val_loss did not improve from 32.54448
# Epoch 1441/1500
#  - 3s - loss: 29.9336 - decoder_loss: 29.7157 - predictor_loss: 0.0109 - val_loss: 33.3347 - val_decoder_loss: 33.0692 - val_predictor_loss: 0.0133
#
# Epoch 01441: val_loss did not improve from 32.54448
# Epoch 1442/1500
#  - 3s - loss: 29.7731 - decoder_loss: 29.5437 - predictor_loss: 0.0115 - val_loss: 33.5961 - val_decoder_loss: 33.3726 - val_predictor_loss: 0.0112
#
# Epoch 01442: val_loss did not improve from 32.54448
# Epoch 1443/1500
#  - 3s - loss: 29.5877 - decoder_loss: 29.3543 - predictor_loss: 0.0117 - val_loss: 33.6174 - val_decoder_loss: 33.3883 - val_predictor_loss: 0.0115
#
# Epoch 01443: val_loss did not improve from 32.54448
# Epoch 1444/1500
#  - 3s - loss: 29.9143 - decoder_loss: 29.7060 - predictor_loss: 0.0104 - val_loss: 33.6072 - val_decoder_loss: 33.3855 - val_predictor_loss: 0.0111
#
# Epoch 01444: val_loss did not improve from 32.54448
# Epoch 1445/1500
#  - 3s - loss: 29.8930 - decoder_loss: 29.6923 - predictor_loss: 0.0100 - val_loss: 33.3916 - val_decoder_loss: 33.1689 - val_predictor_loss: 0.0111
#
# Epoch 01445: val_loss did not improve from 32.54448
# Epoch 1446/1500
#  - 3s - loss: 29.6883 - decoder_loss: 29.4645 - predictor_loss: 0.0112 - val_loss: 33.2635 - val_decoder_loss: 33.0504 - val_predictor_loss: 0.0107
#
# Epoch 01446: val_loss did not improve from 32.54448
# Epoch 1447/1500
#  - 3s - loss: 29.9816 - decoder_loss: 29.7634 - predictor_loss: 0.0109 - val_loss: 33.4637 - val_decoder_loss: 33.1922 - val_predictor_loss: 0.0136
#
# Epoch 01447: val_loss did not improve from 32.54448
# Epoch 1448/1500
#  - 3s - loss: 29.6549 - decoder_loss: 29.4458 - predictor_loss: 0.0105 - val_loss: 33.3305 - val_decoder_loss: 33.1135 - val_predictor_loss: 0.0108
#
# Epoch 01448: val_loss did not improve from 32.54448
# Epoch 1449/1500
#  - 3s - loss: 30.0135 - decoder_loss: 29.8207 - predictor_loss: 0.0096 - val_loss: 33.2439 - val_decoder_loss: 33.0078 - val_predictor_loss: 0.0118
#
# Epoch 01449: val_loss did not improve from 32.54448
# Epoch 1450/1500
#  - 3s - loss: 29.9629 - decoder_loss: 29.7668 - predictor_loss: 0.0098 - val_loss: 33.3940 - val_decoder_loss: 33.1657 - val_predictor_loss: 0.0114
#
# Epoch 01450: val_loss did not improve from 32.54448
# Epoch 1451/1500
#  - 3s - loss: 29.5323 - decoder_loss: 29.3302 - predictor_loss: 0.0101 - val_loss: 33.5395 - val_decoder_loss: 33.2965 - val_predictor_loss: 0.0121
#
# Epoch 01451: val_loss did not improve from 32.54448
# Epoch 1452/1500
#  - 3s - loss: 30.0933 - decoder_loss: 29.8856 - predictor_loss: 0.0104 - val_loss: 33.3093 - val_decoder_loss: 32.9974 - val_predictor_loss: 0.0156
#
# Epoch 01452: val_loss did not improve from 32.54448
# Epoch 1453/1500
#  - 3s - loss: 29.6351 - decoder_loss: 29.4306 - predictor_loss: 0.0102 - val_loss: 33.6519 - val_decoder_loss: 33.4066 - val_predictor_loss: 0.0123
#
# Epoch 01453: val_loss did not improve from 32.54448
# Epoch 1454/1500
#  - 3s - loss: 29.4932 - decoder_loss: 29.3069 - predictor_loss: 0.0093 - val_loss: 33.3319 - val_decoder_loss: 33.1152 - val_predictor_loss: 0.0108
#
# Epoch 01454: val_loss did not improve from 32.54448
# Epoch 1455/1500
#  - 3s - loss: 29.5653 - decoder_loss: 29.3556 - predictor_loss: 0.0105 - val_loss: 32.5356 - val_decoder_loss: 32.3176 - val_predictor_loss: 0.0109
#
# Epoch 01455: val_loss improved from 32.54448 to 32.53561, saving model to VAE_Predictor1455.h5
# Epoch 1456/1500
#  - 3s - loss: 29.5237 - decoder_loss: 29.3363 - predictor_loss: 0.0094 - val_loss: 33.3587 - val_decoder_loss: 33.1299 - val_predictor_loss: 0.0114
#
# Epoch 01456: val_loss did not improve from 32.53561
# Epoch 1457/1500
#  - 3s - loss: 29.6649 - decoder_loss: 29.4643 - predictor_loss: 0.0100 - val_loss: 33.2595 - val_decoder_loss: 33.0277 - val_predictor_loss: 0.0116
#
# Epoch 01457: val_loss did not improve from 32.53561
# Epoch 1458/1500
#  - 3s - loss: 29.7247 - decoder_loss: 29.5291 - predictor_loss: 0.0098 - val_loss: 33.5827 - val_decoder_loss: 33.3723 - val_predictor_loss: 0.0105
#
# Epoch 01458: val_loss did not improve from 32.53561
# Epoch 1459/1500
#  - 3s - loss: 29.9514 - decoder_loss: 29.7559 - predictor_loss: 0.0098 - val_loss: 33.5146 - val_decoder_loss: 33.2877 - val_predictor_loss: 0.0113
#
# Epoch 01459: val_loss did not improve from 32.53561
# Epoch 1460/1500
#  - 3s - loss: 29.8243 - decoder_loss: 29.6262 - predictor_loss: 0.0099 - val_loss: 33.3165 - val_decoder_loss: 33.0907 - val_predictor_loss: 0.0113
#
# Epoch 01460: val_loss did not improve from 32.53561
# Epoch 1461/1500
#  - 3s - loss: 29.7320 - decoder_loss: 29.5395 - predictor_loss: 0.0096 - val_loss: 32.8144 - val_decoder_loss: 32.5988 - val_predictor_loss: 0.0108
#
# Epoch 01461: val_loss did not improve from 32.53561
# Epoch 1462/1500
#  - 3s - loss: 29.3753 - decoder_loss: 29.1898 - predictor_loss: 0.0093 - val_loss: 33.6708 - val_decoder_loss: 33.4292 - val_predictor_loss: 0.0121
#
# Epoch 01462: val_loss did not improve from 32.53561
# Epoch 1463/1500
#  - 3s - loss: 29.7007 - decoder_loss: 29.4988 - predictor_loss: 0.0101 - val_loss: 33.2553 - val_decoder_loss: 32.9626 - val_predictor_loss: 0.0146
#
# Epoch 01463: val_loss did not improve from 32.53561
# Epoch 1464/1500
#  - 3s - loss: 29.3900 - decoder_loss: 29.1856 - predictor_loss: 0.0102 - val_loss: 33.1017 - val_decoder_loss: 32.8752 - val_predictor_loss: 0.0113
#
# Epoch 01464: val_loss did not improve from 32.53561
# Epoch 1465/1500
#  - 3s - loss: 29.5735 - decoder_loss: 29.3708 - predictor_loss: 0.0101 - val_loss: 32.9100 - val_decoder_loss: 32.6753 - val_predictor_loss: 0.0117
#
# Epoch 01465: val_loss did not improve from 32.53561
# Epoch 1466/1500
#  - 3s - loss: 29.5633 - decoder_loss: 29.3417 - predictor_loss: 0.0111 - val_loss: 33.3315 - val_decoder_loss: 33.0759 - val_predictor_loss: 0.0128
#
# Epoch 01466: val_loss did not improve from 32.53561
# Epoch 1467/1500
#  - 3s - loss: 30.0295 - decoder_loss: 29.8307 - predictor_loss: 0.0099 - val_loss: 33.0385 - val_decoder_loss: 32.7794 - val_predictor_loss: 0.0130
#
# Epoch 01467: val_loss did not improve from 32.53561
# Epoch 1468/1500
#  - 3s - loss: 29.5144 - decoder_loss: 29.2942 - predictor_loss: 0.0110 - val_loss: 33.6159 - val_decoder_loss: 33.2991 - val_predictor_loss: 0.0158
#
# Epoch 01468: val_loss did not improve from 32.53561
# Epoch 1469/1500
#  - 3s - loss: 29.5182 - decoder_loss: 29.3066 - predictor_loss: 0.0106 - val_loss: 33.6754 - val_decoder_loss: 33.4561 - val_predictor_loss: 0.0110
#
# Epoch 01469: val_loss did not improve from 32.53561
# Epoch 1470/1500
#  - 3s - loss: 29.9323 - decoder_loss: 29.7238 - predictor_loss: 0.0104 - val_loss: 33.2773 - val_decoder_loss: 33.0271 - val_predictor_loss: 0.0125
#
# Epoch 01470: val_loss did not improve from 32.53561
# Epoch 1471/1500
#  - 3s - loss: 29.9627 - decoder_loss: 29.7300 - predictor_loss: 0.0116 - val_loss: 33.2964 - val_decoder_loss: 33.0159 - val_predictor_loss: 0.0140
#
# Epoch 01471: val_loss did not improve from 32.53561
# Epoch 1472/1500
#  - 3s - loss: 29.6834 - decoder_loss: 29.4735 - predictor_loss: 0.0105 - val_loss: 33.3614 - val_decoder_loss: 33.0772 - val_predictor_loss: 0.0142
#
# Epoch 01472: val_loss did not improve from 32.53561
# Epoch 1473/1500
#  - 3s - loss: 29.6227 - decoder_loss: 29.4027 - predictor_loss: 0.0110 - val_loss: 33.2298 - val_decoder_loss: 32.8174 - val_predictor_loss: 0.0206
#
# Epoch 01473: val_loss did not improve from 32.53561
# Epoch 1474/1500
#  - 3s - loss: 29.7514 - decoder_loss: 29.5202 - predictor_loss: 0.0116 - val_loss: 33.3724 - val_decoder_loss: 33.1438 - val_predictor_loss: 0.0114
#
# Epoch 01474: val_loss did not improve from 32.53561
# Epoch 1475/1500
#  - 3s - loss: 29.3989 - decoder_loss: 29.2020 - predictor_loss: 0.0098 - val_loss: 33.2634 - val_decoder_loss: 33.0038 - val_predictor_loss: 0.0130
#
# Epoch 01475: val_loss did not improve from 32.53561
# Epoch 1476/1500
#  - 3s - loss: 29.4239 - decoder_loss: 29.2099 - predictor_loss: 0.0107 - val_loss: 33.3328 - val_decoder_loss: 33.0974 - val_predictor_loss: 0.0118
#
# Epoch 01476: val_loss did not improve from 32.53561
# Epoch 1477/1500
#  - 3s - loss: 29.7620 - decoder_loss: 29.5565 - predictor_loss: 0.0103 - val_loss: 33.5227 - val_decoder_loss: 33.2868 - val_predictor_loss: 0.0118
#
# Epoch 01477: val_loss did not improve from 32.53561
# Epoch 1478/1500
#  - 3s - loss: 29.6943 - decoder_loss: 29.4896 - predictor_loss: 0.0102 - val_loss: 33.2304 - val_decoder_loss: 33.0075 - val_predictor_loss: 0.0111
#
# Epoch 01478: val_loss did not improve from 32.53561
# Epoch 1479/1500
#  - 3s - loss: 29.7803 - decoder_loss: 29.5734 - predictor_loss: 0.0103 - val_loss: 32.9748 - val_decoder_loss: 32.6902 - val_predictor_loss: 0.0142
#
# Epoch 01479: val_loss did not improve from 32.53561
# Epoch 1480/1500
#  - 3s - loss: 29.6244 - decoder_loss: 29.4059 - predictor_loss: 0.0109 - val_loss: 33.0576 - val_decoder_loss: 32.7544 - val_predictor_loss: 0.0152
#
# Epoch 01480: val_loss did not improve from 32.53561
# Epoch 1481/1500
#  - 3s - loss: 29.7337 - decoder_loss: 29.5287 - predictor_loss: 0.0102 - val_loss: 33.5535 - val_decoder_loss: 33.3129 - val_predictor_loss: 0.0120
#
# Epoch 01481: val_loss did not improve from 32.53561
# Epoch 1482/1500
#  - 3s - loss: 29.6014 - decoder_loss: 29.4068 - predictor_loss: 0.0097 - val_loss: 33.3282 - val_decoder_loss: 33.1114 - val_predictor_loss: 0.0108
#
# Epoch 01482: val_loss did not improve from 32.53561
# Epoch 1483/1500
#  - 3s - loss: 29.6893 - decoder_loss: 29.4715 - predictor_loss: 0.0109 - val_loss: 33.1741 - val_decoder_loss: 32.9451 - val_predictor_loss: 0.0114
#
# Epoch 01483: val_loss did not improve from 32.53561
# Epoch 1484/1500
#  - 3s - loss: 29.6430 - decoder_loss: 29.4477 - predictor_loss: 0.0098 - val_loss: 33.2892 - val_decoder_loss: 33.0783 - val_predictor_loss: 0.0105
#
# Epoch 01484: val_loss did not improve from 32.53561
# Epoch 1485/1500
#  - 3s - loss: 29.7489 - decoder_loss: 29.5559 - predictor_loss: 0.0097 - val_loss: 33.5280 - val_decoder_loss: 33.3103 - val_predictor_loss: 0.0109
#
# Epoch 01485: val_loss did not improve from 32.53561
# Epoch 1486/1500
#  - 3s - loss: 29.3978 - decoder_loss: 29.2000 - predictor_loss: 0.0099 - val_loss: 33.1893 - val_decoder_loss: 32.9780 - val_predictor_loss: 0.0106
#
# Epoch 01486: val_loss did not improve from 32.53561
# Epoch 1487/1500
#  - 3s - loss: 29.3993 - decoder_loss: 29.1901 - predictor_loss: 0.0105 - val_loss: 33.0288 - val_decoder_loss: 32.8028 - val_predictor_loss: 0.0113
#
# Epoch 01487: val_loss did not improve from 32.53561
# Epoch 1488/1500
#  - 3s - loss: 29.5171 - decoder_loss: 29.3027 - predictor_loss: 0.0107 - val_loss: 33.2507 - val_decoder_loss: 33.0423 - val_predictor_loss: 0.0104
#
# Epoch 01488: val_loss did not improve from 32.53561
# Epoch 1489/1500
#  - 3s - loss: 29.8844 - decoder_loss: 29.6858 - predictor_loss: 0.0099 - val_loss: 33.0730 - val_decoder_loss: 32.8033 - val_predictor_loss: 0.0135
#
# Epoch 01489: val_loss did not improve from 32.53561
# Epoch 1490/1500
#  - 3s - loss: 29.6948 - decoder_loss: 29.4893 - predictor_loss: 0.0103 - val_loss: 33.5454 - val_decoder_loss: 33.2942 - val_predictor_loss: 0.0126
#
# Epoch 01490: val_loss did not improve from 32.53561
# Epoch 1491/1500
#  - 3s - loss: 29.9830 - decoder_loss: 29.7941 - predictor_loss: 0.0094 - val_loss: 33.8224 - val_decoder_loss: 33.5760 - val_predictor_loss: 0.0123
#
# Epoch 01491: val_loss did not improve from 32.53561
# Epoch 1492/1500
#  - 3s - loss: 29.6509 - decoder_loss: 29.4504 - predictor_loss: 0.0100 - val_loss: 33.3128 - val_decoder_loss: 33.0702 - val_predictor_loss: 0.0121
#
# Epoch 01492: val_loss did not improve from 32.53561
# Epoch 1493/1500
#  - 3s - loss: 29.2401 - decoder_loss: 29.0424 - predictor_loss: 0.0099 - val_loss: 32.8912 - val_decoder_loss: 32.6575 - val_predictor_loss: 0.0117
#
# Epoch 01493: val_loss did not improve from 32.53561
# Epoch 1494/1500
#  - 3s - loss: 29.7307 - decoder_loss: 29.4991 - predictor_loss: 0.0116 - val_loss: 33.4344 - val_decoder_loss: 33.0770 - val_predictor_loss: 0.0179
#
# Epoch 01494: val_loss did not improve from 32.53561
# Epoch 1495/1500
#  - 3s - loss: 29.3064 - decoder_loss: 29.0821 - predictor_loss: 0.0112 - val_loss: 32.5904 - val_decoder_loss: 32.3756 - val_predictor_loss: 0.0107
#
# Epoch 01495: val_loss did not improve from 32.53561
# Epoch 1496/1500
#  - 3s - loss: 29.5654 - decoder_loss: 29.3567 - predictor_loss: 0.0104 - val_loss: 33.1607 - val_decoder_loss: 32.8941 - val_predictor_loss: 0.0133
#
# Epoch 01496: val_loss did not improve from 32.53561
# Epoch 1497/1500
#  - 3s - loss: 29.7571 - decoder_loss: 29.5566 - predictor_loss: 0.0100 - val_loss: 33.2281 - val_decoder_loss: 32.9464 - val_predictor_loss: 0.0141
#
# Epoch 01497: val_loss did not improve from 32.53561
# Epoch 1498/1500
#  - 3s - loss: 29.5991 - decoder_loss: 29.3910 - predictor_loss: 0.0104 - val_loss: 33.3157 - val_decoder_loss: 33.0106 - val_predictor_loss: 0.0153
#
# Epoch 01498: val_loss did not improve from 32.53561
# Epoch 1499/1500
#  - 3s - loss: 29.7551 - decoder_loss: 29.5407 - predictor_loss: 0.0107 - val_loss: 33.4965 - val_decoder_loss: 33.2593 - val_predictor_loss: 0.0119
#
# Epoch 01499: val_loss did not improve from 32.53561
# Epoch 1500/1500
#  - 3s - loss: 29.9026 - decoder_loss: 29.6973 - predictor_loss: 0.0103 - val_loss: 33.7355 - val_decoder_loss: 33.5087 - val_predictor_loss: 0.0113
#
# Epoch 01500: val_loss did not improve from 32.53561

# %%
# vae_predictor.save('my_model.h5')
# vae_predictor.save(checkpoint_path)

# %%
# new_model = tf.keras.models.load_model('my_model.h5')
# history = new_model.fit(x_train[:2000], y_train[:2000],
#               batch_size=BATCH_SIZE,
#               epochs=6,
#               validation_data=(x_val[:100], y_val[:100]),
#               shuffle=True)

# %% [markdown]
# # **Latent Space Visualization**

# %% [markdown]
# ### **Each Component of latent space**

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 20)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %% [markdown]
# ### **logP Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=logP_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('logP on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# ### **qed Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=qed_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('qed on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# ### **SAS Properties**

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

# z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# Calculating mean and standard deviation of all property values on test data

logp_mean_test, qed_mean_test,SAS_mean_test= np.mean(y_test_property, axis=0)
logp_std_test, qed_std_test,SAS_std_test = np.std(y_test_property, axis=0)

# %%
# encoded, decoded and predicted data on test dataset

encoded_xtest=encoder.predict(X_test)
predicted_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print(encoded_xtest.shape)
print(predicted_xtest.shape)
print(decoded_xtest.shape)
# Out:
# (302, 20)
# (302, 3)
# (302, 4320)

# %%
# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)
print(orig_test.shape)
print(reconst_test.shape)
# Out:
# (302, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Reconstruction and Prediction on Original test data set**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
idx=147
print(predicted_xtest[idx])

#Reconstruction

mol="".join([int_to_char[idx] for idx in np.argmax(orig_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [-0.54766476  0.54758894  3.3742037 ]
# !CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
#
# 67

# %% [markdown]
# ### **Reconstruction and Prediction of property on reconstructed test data**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
print(predicted_xtest[idx])

#Reconstruction
mol="".join([int_to_char[idx] for idx in np.argmax(reconst_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [-0.54766476  0.54758894  3.3742037 ]
# !CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1
#
# 67

# %% [markdown]
# # **Generating New Samples from Normal Distribution**

# %%
prop_val={}
m=None
n_mol=10
i=0
latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))
# print(latent_samples.shape)
predicted_prop_samples=predictor.predict(latent_samples)
# print(predicted_prop_samples.shape)
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)

#Checking the property of molecule
for id, latent_mol in enumerate(latent_samples):
  a=predicted_prop_samples[id][0]<(logp_mean_test+logp_std_test)
  b=predicted_prop_samples[id][0]>=(logp_mean_test-logp_std_test)
  c=predicted_prop_samples[id][1]<(qed_mean_test+qed_std_test)
  d=predicted_prop_samples[id][1]>=(qed_mean_test-qed_std_test)
  e=predicted_prop_samples[id][2]<(SAS_mean_test+SAS_std_test)
  f=predicted_prop_samples[id][2]>=(SAS_mean_test-SAS_std_test)
  if ((a & b) & (c & d) & (e & f)):  #Checking if all of the property values matches
    prop_val[i]=1
    print("Mol {}, Property Validated".format(id+1))
    print("Predicted Properties=")
    print(predicted_prop_samples[id][0], predicted_prop_samples[id][1], predicted_prop_samples[id][2])

    #Passing it to Decoder Now
    reconst_sample = decoder.predict(latent_samples[id:id+1])
    new_mol=reconst_sample.reshape(mol_size_x, mol_size_y) 
    mol="".join([int_to_char[idx] for idx in np.argmax(new_mol[:,:], axis=1)])
    mol = re.sub('!|E',"", mol)
    m = Chem.MolFromSmiles(mol, sanitize=False)
    if m is None:
      print('Mol {} {}, invalid SMILES'.format(id+1,m))
      continue                   
    else:
      try:
        m = Chem.SanitizeMol(m)
        print(m)
      except:
        print('Mol {}, invalid chemistry'.format(id+1)) 
    m
  else:    #No decoding happens here
    prop_val[i]=0
    print("Mol {}, Property Invalidated".format(id+1))
# Out:
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# Mol 1, Property Validated
# Predicted Properties=
# 1.6451175 0.6780293 2.7453349
# Mol 1 None, invalid SMILES
# Mol 2, Property Validated
# Predicted Properties=
# 1.1108537 0.6490067 3.283796
# Mol 2 None, invalid SMILES
# Mol 3, Property Invalidated
# Mol 4, Property Invalidated
# Mol 5, Property Invalidated
# Mol 6, Property Invalidated
# Mol 7, Property Validated
# Predicted Properties=
# 2.9817033 0.79532284 3.4232337
# Mol 7 None, invalid SMILES
# Mol 8, Property Invalidated
# Mol 9, Property Invalidated
# Mol 10, Property Invalidated
# RDKit ERROR: [12:20:13] SMILES Parse Error: syntax error while parsing: C=((CCC(C)c1c[N(C](c1([C@C1CC1)]CC
# RDKit ERROR:
# RDKit ERROR: [12:20:13] SMILES Parse Error: Failed parsing SMILES 'C=((CCC(C)c1c[N(C](c1([C@C1CC1)]CC
# RDKit ERROR: ' for input: 'C=((CCC(C)c1c[N(C](c1([C@C1CC1)]CC
# RDKit ERROR: '
# RDKit ERROR: [12:20:13] SMILES Parse Error: syntax error while parsing: CC(1C(COC(C)c1CN[C@=N)CCCCcc[2](C)(cOccc2CC))N@[)c2]CO)Cc11
# RDKit ERROR: [12:20:13] SMILES Parse Error: Failed parsing SMILES 'CC(1C(COC(C)c1CN[C@=N)CCCCcc[2](C)(cOccc2CC))N@[)c2]CO)Cc11' for input: 'CC(1C(COC(C)c1CN[C@=N)CCCCcc[2](C)(cOccc2CC))N@[)c2]CO)Cc11'
# RDKit ERROR: [12:20:13] SMILES Parse Error: syntax error while parsing: CCCcccc(C@=O)NNCCcC][C(C2CCCCC()2C]]cO)
# RDKit ERROR: [12:20:13] SMILES Parse Error: Failed parsing SMILES 'CCCcccc(C@=O)NNCCcC][C(C2CCCCC()2C]]cO)' for input: 'CCCcccc(C@=O)NNCCcC][C(C2CCCCC()2C]]cO)'
