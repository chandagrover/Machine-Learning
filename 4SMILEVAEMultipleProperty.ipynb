# %% [markdown]
# <a href="https://colab.research.google.com/github/chandagrover/Machine-Learning/blob/master/4SMILEVAEMultipleProperty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic Installs and Imports**

# %%
# !pip install tensorflow==1.12
# !pip install keras==2.2.4
# !pip install h5py
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.12 (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.1.2, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2)
# ERROR: No matching distribution found for tensorflow==1.12
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.7/site-packages (2.2.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (5.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.14.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.19.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/site-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py->keras==2.2.4) (1.5.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/site-packages (from h5py) (1.19.4)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from h5py) (1.5.2)

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.3-Linux-x86_64.sh
# !time bash ./Miniconda3-py37_4.8.3-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-11-23 13:39:28--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh [following]
# --2020-11-23 13:39:29--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - ca-certificates==2020.1.1=0
#     - certifi==2020.4.5.1=py37_0
#     - cffi==1.14.0=py37he30daa8_1
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.1=py37h7b6447c_0
#     - conda==4.8.3=py37_0
#     - cryptography==2.9.2=py37h1ba5d50_0
#     - idna==2.9=py_1
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.3=he6710b0_1
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1g=h7b6447c_0
#     - pip==20.0.2=py37_3
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.20=py_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.7=hcff3b4d_5
#     - readline==8.0=h7b6447c_0
#     - requests==2.23.0=py37_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==46.4.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h62c20be_1
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.46.0=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.11.8-py37h8~ --> pkgs/main::certifi-2020.4.5.1-py37_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.8.3-py37_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m27.752s
# user	0m32.838s
# sys	0m6.157s
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.11.8-ha878542_0
#   certifi              pkgs/main::certifi-2020.4.5.1-py37_0 --> conda-forge::certifi-2020.11.8-py37h89c1867_0
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.9.2-py37h89c1867_0
#   openssl              pkgs/main::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1h-h516909a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# real	0m12.421s
# user	0m11.192s
# sys	0m1.171s

# %%
# General Imports
import os
import pandas as pd
import numpy as np
import sklearn
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
import re

# FOR VAE Architecture 
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model
from keras.losses import mse, binary_crossentropy
import keras
from keras import layers
import tensorflow as tf
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import rdkit
print("RDKit: %s"%rdkit.__version__)
print("Keras: %s"%keras.__version__)
# Out:
# RDKit: 2020.09.1
# Keras: 2.2.4

# %% [markdown]
# # **Data Fetching**

# %%
WEIGHTS_FOLDER = 'sample_data/weights/'
smifile = "sample_data/SMILEWithProp.csv"
data = pd.read_csv(smifile, delimiter = ",", header='infer')
NUM_SMILES = len(data)
data.head()
# Out:
#                                               smiles  ...       SAS
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  ...  2.084095
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  ...  3.432004
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  ...  2.470633
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  ...  2.822753
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  ...  4.035182
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
smiles_train, smiles_test = train_test_split(data, test_size=0.2, shuffle=False)
print(smiles_train.shape)
print(smiles_test.shape)
print(NUM_SMILES)
# Out:
# (1207, 4)
# (302, 4)
# 1509

# %%
logP_train = smiles_train['logP']
logP_test = smiles_test['logP']

qed_train=smiles_train['qed']
qed_test=smiles_test['qed']

SAS_train=smiles_train['SAS']
SAS_test=smiles_test['SAS']

train=np.array([logP_train, qed_train, SAS_train])
test= np.array([logP_test, qed_test, SAS_test])
y_train_property=train.transpose()
y_test_property=test.transpose()

# %%
#Labels for the Smiles String. We will deal with three properties values.
print(type(y_train_property))
print(type(y_test_property))
print(y_train_property.shape)
print(y_test_property.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1207, 3)
# (302, 3)

# %% [markdown]
# ### **Vector Representation of Data**

# %%
charset = set("".join(list(data.smiles))+"!E")
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
# embed = max([len(smile) for smile in data.smiles]) + 5
embed = max([len(smile) for smile in data.smiles])+2
# print(char_to_int)
print(len(charset), embed)
# print(embed)
# Out:
# 40 108

# %%
def vectorize(smiles):
        onehot_flatList=[[]]
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        print(one_hot.shape)
        for i,smile in enumerate(smiles):
            #encode the startchar
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,:,:]

X_train= vectorize(smiles_train['smiles'].values)
X_test = vectorize(smiles_test['smiles'].values)
# Out:
# (1207, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Checking if Vectorization works!!**

# %%
idx=584
print(smiles_train['smiles'][idx])
from rdkit.Chem.Draw import IPythonConsole
m = Chem.MolFromSmiles(smiles_train['smiles'][idx])
m
# Out:
# O=C(N[C@@H]1CCO[C@@H]1c1ccc(Cl)c(F)c1)[C@H]1Cc2ccccc2O1

# %%
# Going back from vectorized form back to a readable string
strr="".join([int_to_char[idx] for idx in np.argmax(X_train[idx,:,:], axis=1)])
# String After Tructation of extra symbols
line = re.sub('[!E]', '', strr)
print(len(line))
print(line)
m = Chem.MolFromSmiles(line)
m
# Out:
# 56
# O=C(N[C@@H]1CCO[C@@H]1c1ccc(Cl)c(F)c1)[C@H]1Cc2ccccc2O1

# %%
mol_size_x=X_train.shape[1]
mol_size_y=X_train.shape[2]
orig_dim = mol_size_x * mol_size_y
# print(mol_size_x)
# print(mol_size_y)
print(orig_dim)
X_train = np.reshape(X_train, [-1, orig_dim])
X_test = np.reshape(X_test, [-1, orig_dim])
# print(type(X_train))
# print(X_train.shape)
# print(X_train.shape[1])
# Out:
# 4320

# %% [markdown]
# # **VAE with Predictor**

# %%
# Network Parameters
INPUT_DIM=(orig_dim,)   # SMILES dimension
intermediate_dim=512
BATCH_SIZE=5
Z_DIM=20 # Dimension of the latent vector (z)
epochs=50
pre_trained=False

# %% [markdown]
# ### **Encoder**

# %%
# ENCODER
def build_vae_encoder(input_dim, output_dim):
  
  # Clear tensorflow session to reset layer
  global K
  K.clear_session()
  
  # Define model input
  encoder_input = Input(shape = input_dim, name = 'encoder_input')
  
  #Intermediate layer
  x = Dense(intermediate_dim,activation='relu', name='hidden')(encoder_input)
 
  #Model Output
  mean_mu = Dense(output_dim, name = 'mu')(x)
  log_var = Dense(output_dim, name = 'log_var')(x)

  # Defining a function for sampling
  def sampling(args):
    mean_mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mean_mu), mean=0., stddev=1.) 
    return mean_mu + K.exp(log_var/2)*epsilon   
  
  # Using a Keras Lambda Layer to include the sampling function as a layer 
  # in the model
  encoder_output = Lambda(sampling, output_shape=(2,), name='encoder_output')([mean_mu, log_var])

  return encoder_input, encoder_output, mean_mu, log_var, Model(encoder_input, encoder_output, name='encoder')

# %% [markdown]
# ### **Decoder**

# %%
# Decoder
def build_decoder(input_dim, output_dim):

  # Define model input
  decoder_input = Input(shape = (input_dim,) , name = 'decoder_input')
  
  #Intermediate Layer
  x = Dense(intermediate_dim, activation='relu', name='hidden')(decoder_input)

    # Define model output
  decoder_output = Dense(output_dim, activation='sigmoid', name='decoder_lastlayer')(x)


  return decoder_input, decoder_output, Model(decoder_input, decoder_output, name='decoder')

# %% [markdown]
# ### **Predictor**

# %%
def create_predictor_linear():
    '''
    Creates a regressor that estimates property values 
    from latent variables.
    '''
    predictor_input = layers.Input(shape=(Z_DIM,), name='predictor_input', dtype='float32')
    
    x = layers.Dense(10, activation='relu', name='hidden')(predictor_input)
    x = layers.Dense(3, activation='linear', name='predictor_lastlayer', dtype='float32')(x)
    return Model(predictor_input, x, name='predictor')

# %% [markdown]
# **Creating the OverAll Model**

# %%
# Model Creation 
def create_model():

  #Creating Encoder
  vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder  = build_vae_encoder(input_dim = INPUT_DIM,                                                                                         output_dim = Z_DIM)
# vae_encoder.summary()
  
  
  #Creating Decoder
  vae_decoder_input, vae_decoder_output, vae_decoder = build_decoder(input_dim = Z_DIM, output_dim=orig_dim)
# vae_decoder.summary()

  #Creating the Predictor
  predictor = create_predictor_linear()
  t_predicted = predictor(mean_mu)
  


  #Creating the VAE Model 
  vae_input = vae_encoder_input
  # Output will be the output of the decoder. The term - decoder(encoder_output) 
  # combines the model by passing the encoder output to the input of the decoder.
  vae_output = vae_decoder(vae_encoder_output)

  # VAE Model with Predictor
  vae_predictor = Model(vae_input, [vae_output,t_predicted], name='VAE with Predictor')

  return vae_encoder_input, vae_encoder_output,  mean_mu, log_var, vae_encoder, vae_decoder_input, vae_decoder_output, vae_decoder,predictor, vae_input, vae_output, vae_predictor

#Creating the overall Model
encoder_input, encoder_output,  mean_mu, log_var, encoder, decoder_input, decoder_output, decoder, predictor, vae_input, vae_output, vae_predictor = create_model()

# %% [markdown]
# **Plotting all models**

# %%
# Plot the VAE-Predictor Model
plot_model(vae_predictor, to_file='smilesvae_predictor.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False


# Plot the Encoder Model
plot_model(encoder, to_file='only_encoder.png', show_shapes=True, show_layer_names=True)  #, expand_nested=True

# Plot the Decoder Model
plot_model(decoder, to_file='only_decoder.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

#Plot the Predictor Model
plot_model(predictor, to_file='only_predictor.png', show_shapes=True, show_layer_names=True)    #, expand_nested=True

# plot_model(vae_model, to_file='smilesvae_model.png', show_shapes=True, show_layer_names=True)   #, expand_nested=False

# %% [markdown]
# ### **VAE Loss Function**

# %%
#VAE Loss Function
def vae_loss(vae_input, vae_output):
  reconstruction_loss = binary_crossentropy(vae_input, vae_output)
  reconstruction_loss = reconstruction_loss * orig_dim
    
  kl_loss = 1 + log_var - K.square(mean_mu) - K.exp(log_var)
  kl_loss = K.sum(kl_loss, axis=-1)    
  kl_loss = kl_loss * -0.5
    
  vae_loss_val = K.mean(reconstruction_loss + kl_loss)
  return vae_loss_val

# %% [markdown]
# **Checkpoint**

# %%
# Creating Model Checkpoint for training...

checkpoint_path = "sample_data/train_ckpt/cp.ckpt"
new_check_path='VAE_Predictor{epoch:02d}.h5'
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=new_check_path, verbose=1, save_weights_only=False, save_best_only=True)   #, save_freq=5

# Loading weights from the latest checkpoints
#get the latest checkpoint file
checkpoint_dir = os.path.dirname(new_check_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)

# %% [markdown]
# ### **Training or Loading the VAE-Predictor Model**

# %%
pre_trained=True
epochs=3000
if __name__ == '__main__':          
#     Train the Variational AutoEncoder
    if pre_trained==False:
      vae_predictor.compile(optimizer='adam', 
                      loss=[vae_loss, 'mean_squared_error'], 
                      loss_weights=[1.0, 20.0]     
                      ) 
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback] )   
    else:
      # vae_predictor.compile(optimizer='adam', 
      #                  loss=[vae_loss, 'mean_squared_error'], 
      #                  loss_weights=[1.0, 20.0]     
      #                  ) 
      vae_predictor.load_weights(new_check_path)
      history = vae_predictor.fit(x=X_train,
                            y=[X_train,y_train_property], 
                            epochs=epochs,
                            validation_data=(X_test, [X_test, y_test_property]),
                            verbose=2,
                            callbacks=[cp_callback])
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1751/3000
#  - 3s - loss: 29.2223 - decoder_loss: 29.0203 - predictor_loss: 0.0101 - val_loss: 33.7956 - val_decoder_loss: 33.5457 - val_predictor_loss: 0.0125
#
# Epoch 01751: val_loss did not improve from 32.65404
# Epoch 1752/3000
#  - 3s - loss: 29.1255 - decoder_loss: 28.9265 - predictor_loss: 0.0099 - val_loss: 34.1652 - val_decoder_loss: 33.9028 - val_predictor_loss: 0.0131
#
# Epoch 01752: val_loss did not improve from 32.65404
# Epoch 1753/3000
#  - 3s - loss: 29.2736 - decoder_loss: 29.0780 - predictor_loss: 0.0098 - val_loss: 33.5827 - val_decoder_loss: 33.3438 - val_predictor_loss: 0.0119
#
# Epoch 01753: val_loss did not improve from 32.65404
# Epoch 1754/3000
#  - 3s - loss: 29.4614 - decoder_loss: 29.2538 - predictor_loss: 0.0104 - val_loss: 34.0728 - val_decoder_loss: 33.8487 - val_predictor_loss: 0.0112
#
# Epoch 01754: val_loss did not improve from 32.65404
# Epoch 1755/3000
#  - 3s - loss: 29.1912 - decoder_loss: 28.9925 - predictor_loss: 0.0099 - val_loss: 33.3746 - val_decoder_loss: 33.1073 - val_predictor_loss: 0.0134
#
# Epoch 01755: val_loss did not improve from 32.65404
# Epoch 1756/3000
#  - 3s - loss: 29.3921 - decoder_loss: 29.1854 - predictor_loss: 0.0103 - val_loss: 33.7734 - val_decoder_loss: 33.5293 - val_predictor_loss: 0.0122
#
# Epoch 01756: val_loss did not improve from 32.65404
# Epoch 1757/3000
#  - 3s - loss: 29.0358 - decoder_loss: 28.8387 - predictor_loss: 0.0099 - val_loss: 32.7590 - val_decoder_loss: 32.5348 - val_predictor_loss: 0.0112
#
# Epoch 01757: val_loss did not improve from 32.65404
# Epoch 1758/3000
#  - 3s - loss: 29.1279 - decoder_loss: 28.9519 - predictor_loss: 0.0088 - val_loss: 33.7521 - val_decoder_loss: 33.5281 - val_predictor_loss: 0.0112
#
# Epoch 01758: val_loss did not improve from 32.65404
# Epoch 1759/3000
#  - 3s - loss: 29.6383 - decoder_loss: 29.4343 - predictor_loss: 0.0102 - val_loss: 33.4270 - val_decoder_loss: 33.1528 - val_predictor_loss: 0.0137
#
# Epoch 01759: val_loss did not improve from 32.65404
# Epoch 1760/3000
#  - 3s - loss: 29.2086 - decoder_loss: 29.0167 - predictor_loss: 0.0096 - val_loss: 33.5279 - val_decoder_loss: 33.2813 - val_predictor_loss: 0.0123
#
# Epoch 01760: val_loss did not improve from 32.65404
# Epoch 1761/3000
#  - 3s - loss: 29.4878 - decoder_loss: 29.3007 - predictor_loss: 0.0094 - val_loss: 32.9652 - val_decoder_loss: 32.7266 - val_predictor_loss: 0.0119
#
# Epoch 01761: val_loss did not improve from 32.65404
# Epoch 1762/3000
#  - 3s - loss: 29.4750 - decoder_loss: 29.2721 - predictor_loss: 0.0101 - val_loss: 32.7664 - val_decoder_loss: 32.4903 - val_predictor_loss: 0.0138
#
# Epoch 01762: val_loss did not improve from 32.65404
# Epoch 1763/3000
#  - 3s - loss: 29.4741 - decoder_loss: 29.2602 - predictor_loss: 0.0107 - val_loss: 33.3779 - val_decoder_loss: 33.1488 - val_predictor_loss: 0.0115
#
# Epoch 01763: val_loss did not improve from 32.65404
# Epoch 1764/3000
#  - 3s - loss: 29.3278 - decoder_loss: 29.1292 - predictor_loss: 0.0099 - val_loss: 32.9034 - val_decoder_loss: 32.6490 - val_predictor_loss: 0.0127
#
# Epoch 01764: val_loss did not improve from 32.65404
# Epoch 1765/3000
#  - 3s - loss: 29.3310 - decoder_loss: 29.1263 - predictor_loss: 0.0102 - val_loss: 33.2539 - val_decoder_loss: 33.0285 - val_predictor_loss: 0.0113
#
# Epoch 01765: val_loss did not improve from 32.65404
# Epoch 1766/3000
#  - 3s - loss: 29.2856 - decoder_loss: 29.0847 - predictor_loss: 0.0100 - val_loss: 33.4721 - val_decoder_loss: 33.2354 - val_predictor_loss: 0.0118
#
# Epoch 01766: val_loss did not improve from 32.65404
# Epoch 1767/3000
#  - 3s - loss: 29.1771 - decoder_loss: 28.9788 - predictor_loss: 0.0099 - val_loss: 33.3599 - val_decoder_loss: 33.1417 - val_predictor_loss: 0.0109
#
# Epoch 01767: val_loss did not improve from 32.65404
# Epoch 1768/3000
#  - 3s - loss: 29.3159 - decoder_loss: 29.1288 - predictor_loss: 0.0094 - val_loss: 33.1038 - val_decoder_loss: 32.8463 - val_predictor_loss: 0.0129
#
# Epoch 01768: val_loss did not improve from 32.65404
# Epoch 1769/3000
#  - 3s - loss: 29.3036 - decoder_loss: 29.1027 - predictor_loss: 0.0100 - val_loss: 33.2608 - val_decoder_loss: 32.9945 - val_predictor_loss: 0.0133
#
# Epoch 01769: val_loss did not improve from 32.65404
# Epoch 1770/3000
#  - 3s - loss: 29.4000 - decoder_loss: 29.1878 - predictor_loss: 0.0106 - val_loss: 34.0915 - val_decoder_loss: 33.8108 - val_predictor_loss: 0.0140
#
# Epoch 01770: val_loss did not improve from 32.65404
# Epoch 1771/3000
#  - 3s - loss: 29.4124 - decoder_loss: 29.2084 - predictor_loss: 0.0102 - val_loss: 33.8926 - val_decoder_loss: 33.6620 - val_predictor_loss: 0.0115
#
# Epoch 01771: val_loss did not improve from 32.65404
# Epoch 1772/3000
#  - 3s - loss: 29.4994 - decoder_loss: 29.2906 - predictor_loss: 0.0104 - val_loss: 33.2216 - val_decoder_loss: 32.9825 - val_predictor_loss: 0.0120
#
# Epoch 01772: val_loss did not improve from 32.65404
# Epoch 1773/3000
#  - 3s - loss: 29.1505 - decoder_loss: 28.9609 - predictor_loss: 0.0095 - val_loss: 32.8686 - val_decoder_loss: 32.6508 - val_predictor_loss: 0.0109
#
# Epoch 01773: val_loss did not improve from 32.65404
# Epoch 1774/3000
#  - 3s - loss: 29.4650 - decoder_loss: 29.2785 - predictor_loss: 0.0093 - val_loss: 33.6263 - val_decoder_loss: 33.3962 - val_predictor_loss: 0.0115
#
# Epoch 01774: val_loss did not improve from 32.65404
# Epoch 1775/3000
#  - 3s - loss: 29.1624 - decoder_loss: 28.9737 - predictor_loss: 0.0094 - val_loss: 33.6417 - val_decoder_loss: 33.3997 - val_predictor_loss: 0.0121
#
# Epoch 01775: val_loss did not improve from 32.65404
# Epoch 1776/3000
#  - 3s - loss: 29.0519 - decoder_loss: 28.8398 - predictor_loss: 0.0106 - val_loss: 33.4256 - val_decoder_loss: 33.1533 - val_predictor_loss: 0.0136
#
# Epoch 01776: val_loss did not improve from 32.65404
# Epoch 1777/3000
#  - 3s - loss: 28.9955 - decoder_loss: 28.7998 - predictor_loss: 0.0098 - val_loss: 32.8137 - val_decoder_loss: 32.5832 - val_predictor_loss: 0.0115
#
# Epoch 01777: val_loss did not improve from 32.65404
# Epoch 1778/3000
#  - 3s - loss: 29.0496 - decoder_loss: 28.8613 - predictor_loss: 0.0094 - val_loss: 33.5660 - val_decoder_loss: 33.3220 - val_predictor_loss: 0.0122
#
# Epoch 01778: val_loss did not improve from 32.65404
# Epoch 1779/3000
#  - 3s - loss: 29.1536 - decoder_loss: 28.9558 - predictor_loss: 0.0099 - val_loss: 33.5667 - val_decoder_loss: 33.3131 - val_predictor_loss: 0.0127
#
# Epoch 01779: val_loss did not improve from 32.65404
# Epoch 1780/3000
#  - 3s - loss: 29.3159 - decoder_loss: 29.1294 - predictor_loss: 0.0093 - val_loss: 33.4365 - val_decoder_loss: 33.2171 - val_predictor_loss: 0.0110
#
# Epoch 01780: val_loss did not improve from 32.65404
# Epoch 1781/3000
#  - 3s - loss: 29.3092 - decoder_loss: 29.1002 - predictor_loss: 0.0105 - val_loss: 33.1289 - val_decoder_loss: 32.7978 - val_predictor_loss: 0.0166
#
# Epoch 01781: val_loss did not improve from 32.65404
# Epoch 1782/3000
#  - 3s - loss: 29.2004 - decoder_loss: 28.9758 - predictor_loss: 0.0112 - val_loss: 33.5537 - val_decoder_loss: 33.3133 - val_predictor_loss: 0.0120
#
# Epoch 01782: val_loss did not improve from 32.65404
# Epoch 1783/3000
#  - 3s - loss: 29.2626 - decoder_loss: 29.0666 - predictor_loss: 0.0098 - val_loss: 33.1799 - val_decoder_loss: 32.9370 - val_predictor_loss: 0.0121
#
# Epoch 01783: val_loss did not improve from 32.65404
# Epoch 1784/3000
#  - 3s - loss: 29.3206 - decoder_loss: 29.1068 - predictor_loss: 0.0107 - val_loss: 33.2721 - val_decoder_loss: 32.9714 - val_predictor_loss: 0.0150
#
# Epoch 01784: val_loss did not improve from 32.65404
# Epoch 1785/3000
#  - 3s - loss: 29.3818 - decoder_loss: 29.1669 - predictor_loss: 0.0107 - val_loss: 33.3390 - val_decoder_loss: 33.0814 - val_predictor_loss: 0.0129
#
# Epoch 01785: val_loss did not improve from 32.65404
# Epoch 1786/3000
#  - 3s - loss: 29.3327 - decoder_loss: 29.1313 - predictor_loss: 0.0101 - val_loss: 33.1652 - val_decoder_loss: 32.9190 - val_predictor_loss: 0.0123
#
# Epoch 01786: val_loss did not improve from 32.65404
# Epoch 1787/3000
#  - 3s - loss: 29.3444 - decoder_loss: 29.1552 - predictor_loss: 0.0095 - val_loss: 34.1557 - val_decoder_loss: 33.9195 - val_predictor_loss: 0.0118
#
# Epoch 01787: val_loss did not improve from 32.65404
# Epoch 1788/3000
#  - 3s - loss: 29.5319 - decoder_loss: 29.3341 - predictor_loss: 0.0099 - val_loss: 33.5518 - val_decoder_loss: 33.3273 - val_predictor_loss: 0.0112
#
# Epoch 01788: val_loss did not improve from 32.65404
# Epoch 1789/3000
#  - 3s - loss: 29.5004 - decoder_loss: 29.2874 - predictor_loss: 0.0107 - val_loss: 33.3096 - val_decoder_loss: 33.0360 - val_predictor_loss: 0.0137
#
# Epoch 01789: val_loss did not improve from 32.65404
# Epoch 1790/3000
#  - 3s - loss: 29.3932 - decoder_loss: 29.2051 - predictor_loss: 0.0094 - val_loss: 33.4225 - val_decoder_loss: 33.1895 - val_predictor_loss: 0.0117
#
# Epoch 01790: val_loss did not improve from 32.65404
# Epoch 1791/3000
#  - 3s - loss: 29.0677 - decoder_loss: 28.8847 - predictor_loss: 0.0091 - val_loss: 33.2971 - val_decoder_loss: 33.0698 - val_predictor_loss: 0.0114
#
# Epoch 01791: val_loss did not improve from 32.65404
# Epoch 1792/3000
#  - 3s - loss: 29.1596 - decoder_loss: 28.9674 - predictor_loss: 0.0096 - val_loss: 33.1866 - val_decoder_loss: 32.9591 - val_predictor_loss: 0.0114
#
# Epoch 01792: val_loss did not improve from 32.65404
# Epoch 1793/3000
#  - 3s - loss: 29.1222 - decoder_loss: 28.9355 - predictor_loss: 0.0093 - val_loss: 33.6912 - val_decoder_loss: 33.4374 - val_predictor_loss: 0.0127
#
# Epoch 01793: val_loss did not improve from 32.65404
# Epoch 1794/3000
#  - 3s - loss: 29.6087 - decoder_loss: 29.4127 - predictor_loss: 0.0098 - val_loss: 33.7511 - val_decoder_loss: 33.4694 - val_predictor_loss: 0.0141
#
# Epoch 01794: val_loss did not improve from 32.65404
# Epoch 1795/3000
#  - 3s - loss: 29.3733 - decoder_loss: 29.1559 - predictor_loss: 0.0109 - val_loss: 33.3325 - val_decoder_loss: 33.0976 - val_predictor_loss: 0.0117
#
# Epoch 01795: val_loss did not improve from 32.65404
# Epoch 1796/3000
#  - 3s - loss: 29.0819 - decoder_loss: 28.8895 - predictor_loss: 0.0096 - val_loss: 33.6536 - val_decoder_loss: 33.4110 - val_predictor_loss: 0.0121
#
# Epoch 01796: val_loss did not improve from 32.65404
# Epoch 1797/3000
#  - 3s - loss: 29.5620 - decoder_loss: 29.3544 - predictor_loss: 0.0104 - val_loss: 33.7962 - val_decoder_loss: 33.5436 - val_predictor_loss: 0.0126
#
# Epoch 01797: val_loss did not improve from 32.65404
# Epoch 1798/3000
#  - 3s - loss: 29.3232 - decoder_loss: 29.1170 - predictor_loss: 0.0103 - val_loss: 33.6579 - val_decoder_loss: 33.3792 - val_predictor_loss: 0.0139
#
# Epoch 01798: val_loss did not improve from 32.65404
# Epoch 1799/3000
#  - 3s - loss: 29.2984 - decoder_loss: 29.1026 - predictor_loss: 0.0098 - val_loss: 32.8945 - val_decoder_loss: 32.6768 - val_predictor_loss: 0.0109
#
# Epoch 01799: val_loss did not improve from 32.65404
# Epoch 1800/3000
#  - 3s - loss: 29.3692 - decoder_loss: 29.1755 - predictor_loss: 0.0097 - val_loss: 33.3842 - val_decoder_loss: 33.1536 - val_predictor_loss: 0.0115
#
# Epoch 01800: val_loss did not improve from 32.65404
# Epoch 1801/3000
#  - 3s - loss: 29.7101 - decoder_loss: 29.5092 - predictor_loss: 0.0100 - val_loss: 33.6489 - val_decoder_loss: 33.4078 - val_predictor_loss: 0.0121
#
# Epoch 01801: val_loss did not improve from 32.65404
# Epoch 1802/3000
#  - 3s - loss: 28.8227 - decoder_loss: 28.6212 - predictor_loss: 0.0101 - val_loss: 34.1121 - val_decoder_loss: 33.8676 - val_predictor_loss: 0.0122
#
# Epoch 01802: val_loss did not improve from 32.65404
# Epoch 1803/3000
#  - 3s - loss: 29.3099 - decoder_loss: 29.1233 - predictor_loss: 0.0093 - val_loss: 33.4775 - val_decoder_loss: 33.2303 - val_predictor_loss: 0.0124
#
# Epoch 01803: val_loss did not improve from 32.65404
# Epoch 1804/3000
#  - 3s - loss: 29.3499 - decoder_loss: 29.1575 - predictor_loss: 0.0096 - val_loss: 33.0658 - val_decoder_loss: 32.8306 - val_predictor_loss: 0.0118
#
# Epoch 01804: val_loss did not improve from 32.65404
# Epoch 1805/3000
#  - 3s - loss: 29.2570 - decoder_loss: 29.0431 - predictor_loss: 0.0107 - val_loss: 33.9611 - val_decoder_loss: 33.5983 - val_predictor_loss: 0.0181
#
# Epoch 01805: val_loss did not improve from 32.65404
# Epoch 1806/3000
#  - 3s - loss: 29.1773 - decoder_loss: 28.9465 - predictor_loss: 0.0115 - val_loss: 33.2534 - val_decoder_loss: 32.9520 - val_predictor_loss: 0.0151
#
# Epoch 01806: val_loss did not improve from 32.65404
# Epoch 1807/3000
#  - 3s - loss: 29.1276 - decoder_loss: 28.9247 - predictor_loss: 0.0101 - val_loss: 32.7003 - val_decoder_loss: 32.4651 - val_predictor_loss: 0.0118
#
# Epoch 01807: val_loss did not improve from 32.65404
# Epoch 1808/3000
#  - 3s - loss: 29.3624 - decoder_loss: 29.1688 - predictor_loss: 0.0097 - val_loss: 33.3054 - val_decoder_loss: 33.0626 - val_predictor_loss: 0.0121
#
# Epoch 01808: val_loss did not improve from 32.65404
# Epoch 1809/3000
#  - 3s - loss: 29.4449 - decoder_loss: 29.2259 - predictor_loss: 0.0109 - val_loss: 33.0686 - val_decoder_loss: 32.8014 - val_predictor_loss: 0.0134
#
# Epoch 01809: val_loss did not improve from 32.65404
# Epoch 1810/3000
#  - 3s - loss: 29.5842 - decoder_loss: 29.3823 - predictor_loss: 0.0101 - val_loss: 33.3684 - val_decoder_loss: 33.1425 - val_predictor_loss: 0.0113
#
# Epoch 01810: val_loss did not improve from 32.65404
# Epoch 1811/3000
#  - 3s - loss: 29.4565 - decoder_loss: 29.2704 - predictor_loss: 0.0093 - val_loss: 33.3945 - val_decoder_loss: 33.1493 - val_predictor_loss: 0.0123
#
# Epoch 01811: val_loss did not improve from 32.65404
# Epoch 1812/3000
#  - 3s - loss: 29.2419 - decoder_loss: 29.0299 - predictor_loss: 0.0106 - val_loss: 34.3792 - val_decoder_loss: 34.1465 - val_predictor_loss: 0.0116
#
# Epoch 01812: val_loss did not improve from 32.65404
# Epoch 1813/3000
#  - 3s - loss: 29.4088 - decoder_loss: 29.1978 - predictor_loss: 0.0105 - val_loss: 33.0532 - val_decoder_loss: 32.7927 - val_predictor_loss: 0.0130
#
# Epoch 01813: val_loss did not improve from 32.65404
# Epoch 1814/3000
#  - 3s - loss: 29.3656 - decoder_loss: 29.1641 - predictor_loss: 0.0101 - val_loss: 34.4913 - val_decoder_loss: 34.1996 - val_predictor_loss: 0.0146
#
# Epoch 01814: val_loss did not improve from 32.65404
# Epoch 1815/3000
#  - 3s - loss: 29.4014 - decoder_loss: 29.1938 - predictor_loss: 0.0104 - val_loss: 32.7134 - val_decoder_loss: 32.4633 - val_predictor_loss: 0.0125
#
# Epoch 01815: val_loss did not improve from 32.65404
# Epoch 1816/3000
#  - 3s - loss: 29.4178 - decoder_loss: 29.2206 - predictor_loss: 0.0099 - val_loss: 33.3953 - val_decoder_loss: 33.1514 - val_predictor_loss: 0.0122
#
# Epoch 01816: val_loss did not improve from 32.65404
# Epoch 1817/3000
#  - 3s - loss: 29.4611 - decoder_loss: 29.2593 - predictor_loss: 0.0101 - val_loss: 33.2980 - val_decoder_loss: 33.0521 - val_predictor_loss: 0.0123
#
# Epoch 01817: val_loss did not improve from 32.65404
# Epoch 1818/3000
#  - 3s - loss: 29.2256 - decoder_loss: 29.0364 - predictor_loss: 0.0095 - val_loss: 33.2859 - val_decoder_loss: 33.0687 - val_predictor_loss: 0.0109
#
# Epoch 01818: val_loss did not improve from 32.65404
# Epoch 1819/3000
#  - 3s - loss: 29.4296 - decoder_loss: 29.2485 - predictor_loss: 0.0091 - val_loss: 33.7220 - val_decoder_loss: 33.4890 - val_predictor_loss: 0.0117
#
# Epoch 01819: val_loss did not improve from 32.65404
# Epoch 1820/3000
#  - 3s - loss: 29.4122 - decoder_loss: 29.2153 - predictor_loss: 0.0098 - val_loss: 33.1575 - val_decoder_loss: 32.9221 - val_predictor_loss: 0.0118
#
# Epoch 01820: val_loss did not improve from 32.65404
# Epoch 1821/3000
#  - 3s - loss: 29.1502 - decoder_loss: 28.9477 - predictor_loss: 0.0101 - val_loss: 33.5701 - val_decoder_loss: 33.3160 - val_predictor_loss: 0.0127
#
# Epoch 01821: val_loss did not improve from 32.65404
# Epoch 1822/3000
#  - 3s - loss: 29.2138 - decoder_loss: 29.0199 - predictor_loss: 0.0097 - val_loss: 33.9448 - val_decoder_loss: 33.7103 - val_predictor_loss: 0.0117
#
# Epoch 01822: val_loss did not improve from 32.65404
# Epoch 1823/3000
#  - 3s - loss: 29.3129 - decoder_loss: 29.1132 - predictor_loss: 0.0100 - val_loss: 32.7757 - val_decoder_loss: 32.5425 - val_predictor_loss: 0.0117
#
# Epoch 01823: val_loss did not improve from 32.65404
# Epoch 1824/3000
#  - 3s - loss: 29.0127 - decoder_loss: 28.8194 - predictor_loss: 0.0097 - val_loss: 33.4554 - val_decoder_loss: 33.2095 - val_predictor_loss: 0.0123
#
# Epoch 01824: val_loss did not improve from 32.65404
# Epoch 1825/3000
#  - 3s - loss: 29.6212 - decoder_loss: 29.4298 - predictor_loss: 0.0096 - val_loss: 33.4650 - val_decoder_loss: 33.2345 - val_predictor_loss: 0.0115
#
# Epoch 01825: val_loss did not improve from 32.65404
# Epoch 1826/3000
#  - 3s - loss: 29.3378 - decoder_loss: 29.1403 - predictor_loss: 0.0099 - val_loss: 33.3592 - val_decoder_loss: 33.0982 - val_predictor_loss: 0.0131
#
# Epoch 01826: val_loss did not improve from 32.65404
# Epoch 1827/3000
#  - 3s - loss: 29.1594 - decoder_loss: 28.9552 - predictor_loss: 0.0102 - val_loss: 33.8422 - val_decoder_loss: 33.6183 - val_predictor_loss: 0.0112
#
# Epoch 01827: val_loss did not improve from 32.65404
# Epoch 1828/3000
#  - 3s - loss: 29.1699 - decoder_loss: 28.9555 - predictor_loss: 0.0107 - val_loss: 33.7484 - val_decoder_loss: 33.4771 - val_predictor_loss: 0.0136
#
# Epoch 01828: val_loss did not improve from 32.65404
# Epoch 1829/3000
#  - 3s - loss: 29.6400 - decoder_loss: 29.4264 - predictor_loss: 0.0107 - val_loss: 32.8516 - val_decoder_loss: 32.6074 - val_predictor_loss: 0.0122
#
# Epoch 01829: val_loss did not improve from 32.65404
# Epoch 1830/3000
#  - 3s - loss: 29.4392 - decoder_loss: 29.2173 - predictor_loss: 0.0111 - val_loss: 33.2021 - val_decoder_loss: 32.9440 - val_predictor_loss: 0.0129
#
# Epoch 01830: val_loss did not improve from 32.65404
# Epoch 1831/3000
#  - 3s - loss: 29.2335 - decoder_loss: 29.0378 - predictor_loss: 0.0098 - val_loss: 33.0397 - val_decoder_loss: 32.7860 - val_predictor_loss: 0.0127
#
# Epoch 01831: val_loss did not improve from 32.65404
# Epoch 1832/3000
#  - 3s - loss: 29.3206 - decoder_loss: 29.1138 - predictor_loss: 0.0103 - val_loss: 33.2351 - val_decoder_loss: 32.9898 - val_predictor_loss: 0.0123
#
# Epoch 01832: val_loss did not improve from 32.65404
# Epoch 1833/3000
#  - 3s - loss: 29.5476 - decoder_loss: 29.3395 - predictor_loss: 0.0104 - val_loss: 33.8815 - val_decoder_loss: 33.5902 - val_predictor_loss: 0.0146
#
# Epoch 01833: val_loss did not improve from 32.65404
# Epoch 1834/3000
#  - 3s - loss: 29.2816 - decoder_loss: 29.0763 - predictor_loss: 0.0103 - val_loss: 33.9242 - val_decoder_loss: 33.6980 - val_predictor_loss: 0.0113
#
# Epoch 01834: val_loss did not improve from 32.65404
# Epoch 1835/3000
#  - 3s - loss: 29.3076 - decoder_loss: 29.1134 - predictor_loss: 0.0097 - val_loss: 34.0939 - val_decoder_loss: 33.8483 - val_predictor_loss: 0.0123
#
# Epoch 01835: val_loss did not improve from 32.65404
# Epoch 1836/3000
#  - 3s - loss: 29.3452 - decoder_loss: 29.1407 - predictor_loss: 0.0102 - val_loss: 33.7480 - val_decoder_loss: 33.4921 - val_predictor_loss: 0.0128
#
# Epoch 01836: val_loss did not improve from 32.65404
# Epoch 1837/3000
#  - 3s - loss: 29.3393 - decoder_loss: 29.1107 - predictor_loss: 0.0114 - val_loss: 33.7583 - val_decoder_loss: 33.5294 - val_predictor_loss: 0.0114
#
# Epoch 01837: val_loss did not improve from 32.65404
# Epoch 1838/3000
#  - 3s - loss: 29.2908 - decoder_loss: 29.0751 - predictor_loss: 0.0108 - val_loss: 33.6388 - val_decoder_loss: 33.3959 - val_predictor_loss: 0.0121
#
# Epoch 01838: val_loss did not improve from 32.65404
# Epoch 1839/3000
#  - 3s - loss: 29.5543 - decoder_loss: 29.3600 - predictor_loss: 0.0097 - val_loss: 33.6705 - val_decoder_loss: 33.4106 - val_predictor_loss: 0.0130
#
# Epoch 01839: val_loss did not improve from 32.65404
# Epoch 1840/3000
#  - 3s - loss: 29.1787 - decoder_loss: 28.9797 - predictor_loss: 0.0100 - val_loss: 33.4942 - val_decoder_loss: 33.2726 - val_predictor_loss: 0.0111
#
# Epoch 01840: val_loss did not improve from 32.65404
# Epoch 1841/3000
#  - 3s - loss: 29.0140 - decoder_loss: 28.8339 - predictor_loss: 0.0090 - val_loss: 33.5388 - val_decoder_loss: 33.2925 - val_predictor_loss: 0.0123
#
# Epoch 01841: val_loss did not improve from 32.65404
# Epoch 1842/3000
#  - 3s - loss: 29.3439 - decoder_loss: 29.1583 - predictor_loss: 0.0093 - val_loss: 33.5201 - val_decoder_loss: 33.2480 - val_predictor_loss: 0.0136
#
# Epoch 01842: val_loss did not improve from 32.65404
# Epoch 1843/3000
#  - 3s - loss: 29.0396 - decoder_loss: 28.8526 - predictor_loss: 0.0093 - val_loss: 32.7832 - val_decoder_loss: 32.5470 - val_predictor_loss: 0.0118
#
# Epoch 01843: val_loss did not improve from 32.65404
# Epoch 1844/3000
#  - 3s - loss: 29.3162 - decoder_loss: 29.1183 - predictor_loss: 0.0099 - val_loss: 33.4274 - val_decoder_loss: 33.1792 - val_predictor_loss: 0.0124
#
# Epoch 01844: val_loss did not improve from 32.65404
# Epoch 1845/3000
#  - 3s - loss: 29.3584 - decoder_loss: 29.1543 - predictor_loss: 0.0102 - val_loss: 33.2073 - val_decoder_loss: 32.9839 - val_predictor_loss: 0.0112
#
# Epoch 01845: val_loss did not improve from 32.65404
# Epoch 1846/3000
#  - 3s - loss: 29.3442 - decoder_loss: 29.1535 - predictor_loss: 0.0095 - val_loss: 33.4880 - val_decoder_loss: 33.2618 - val_predictor_loss: 0.0113
#
# Epoch 01846: val_loss did not improve from 32.65404
# Epoch 1847/3000
#  - 3s - loss: 29.2364 - decoder_loss: 29.0374 - predictor_loss: 0.0099 - val_loss: 33.5913 - val_decoder_loss: 33.3591 - val_predictor_loss: 0.0116
#
# Epoch 01847: val_loss did not improve from 32.65404
# Epoch 1848/3000
#  - 3s - loss: 29.4144 - decoder_loss: 29.2281 - predictor_loss: 0.0093 - val_loss: 33.5370 - val_decoder_loss: 33.3050 - val_predictor_loss: 0.0116
#
# Epoch 01848: val_loss did not improve from 32.65404
# Epoch 1849/3000
#  - 3s - loss: 29.4005 - decoder_loss: 29.1983 - predictor_loss: 0.0101 - val_loss: 33.1294 - val_decoder_loss: 32.8771 - val_predictor_loss: 0.0126
#
# Epoch 01849: val_loss did not improve from 32.65404
# Epoch 1850/3000
#  - 3s - loss: 29.3299 - decoder_loss: 29.1105 - predictor_loss: 0.0110 - val_loss: 33.5199 - val_decoder_loss: 33.2261 - val_predictor_loss: 0.0147
#
# Epoch 01850: val_loss did not improve from 32.65404
# Epoch 1851/3000
#  - 3s - loss: 29.2848 - decoder_loss: 29.0798 - predictor_loss: 0.0102 - val_loss: 32.8058 - val_decoder_loss: 32.5803 - val_predictor_loss: 0.0113
#
# Epoch 01851: val_loss did not improve from 32.65404
# Epoch 1852/3000
#  - 3s - loss: 29.2560 - decoder_loss: 29.0530 - predictor_loss: 0.0101 - val_loss: 33.4447 - val_decoder_loss: 33.1352 - val_predictor_loss: 0.0155
#
# Epoch 01852: val_loss did not improve from 32.65404
# Epoch 1853/3000
#  - 3s - loss: 29.4698 - decoder_loss: 29.2559 - predictor_loss: 0.0107 - val_loss: 33.1392 - val_decoder_loss: 32.8656 - val_predictor_loss: 0.0137
#
# Epoch 01853: val_loss did not improve from 32.65404
# Epoch 1854/3000
#  - 3s - loss: 29.3205 - decoder_loss: 29.1160 - predictor_loss: 0.0102 - val_loss: 33.6216 - val_decoder_loss: 33.3961 - val_predictor_loss: 0.0113
#
# Epoch 01854: val_loss did not improve from 32.65404
# Epoch 1855/3000
#  - 3s - loss: 29.2292 - decoder_loss: 29.0291 - predictor_loss: 0.0100 - val_loss: 33.7084 - val_decoder_loss: 33.4645 - val_predictor_loss: 0.0122
#
# Epoch 01855: val_loss did not improve from 32.65404
# Epoch 1856/3000
#  - 3s - loss: 29.2259 - decoder_loss: 29.0262 - predictor_loss: 0.0100 - val_loss: 33.4819 - val_decoder_loss: 33.2532 - val_predictor_loss: 0.0114
#
# Epoch 01856: val_loss did not improve from 32.65404
# Epoch 1857/3000
#  - 3s - loss: 29.3426 - decoder_loss: 29.1545 - predictor_loss: 0.0094 - val_loss: 33.2825 - val_decoder_loss: 33.0528 - val_predictor_loss: 0.0115
#
# Epoch 01857: val_loss did not improve from 32.65404
# Epoch 1858/3000
#  - 3s - loss: 29.4969 - decoder_loss: 29.3100 - predictor_loss: 0.0093 - val_loss: 33.1026 - val_decoder_loss: 32.8069 - val_predictor_loss: 0.0148
#
# Epoch 01858: val_loss did not improve from 32.65404
# Epoch 1859/3000
#  - 3s - loss: 29.2518 - decoder_loss: 29.0335 - predictor_loss: 0.0109 - val_loss: 32.7460 - val_decoder_loss: 32.4737 - val_predictor_loss: 0.0136
#
# Epoch 01859: val_loss did not improve from 32.65404
# Epoch 1860/3000
#  - 3s - loss: 29.2932 - decoder_loss: 29.0841 - predictor_loss: 0.0105 - val_loss: 33.3699 - val_decoder_loss: 33.1241 - val_predictor_loss: 0.0123
#
# Epoch 01860: val_loss did not improve from 32.65404
# Epoch 1861/3000
#  - 3s - loss: 29.3315 - decoder_loss: 29.1150 - predictor_loss: 0.0108 - val_loss: 33.2205 - val_decoder_loss: 33.0007 - val_predictor_loss: 0.0110
#
# Epoch 01861: val_loss did not improve from 32.65404
# Epoch 1862/3000
#  - 3s - loss: 29.2443 - decoder_loss: 29.0407 - predictor_loss: 0.0102 - val_loss: 32.9754 - val_decoder_loss: 32.7313 - val_predictor_loss: 0.0122
#
# Epoch 01862: val_loss did not improve from 32.65404
# Epoch 1863/3000
#  - 3s - loss: 29.0637 - decoder_loss: 28.8466 - predictor_loss: 0.0109 - val_loss: 33.3312 - val_decoder_loss: 33.0734 - val_predictor_loss: 0.0129
#
# Epoch 01863: val_loss did not improve from 32.65404
# Epoch 1864/3000
#  - 3s - loss: 29.2937 - decoder_loss: 29.0907 - predictor_loss: 0.0101 - val_loss: 33.2766 - val_decoder_loss: 33.0340 - val_predictor_loss: 0.0121
#
# Epoch 01864: val_loss did not improve from 32.65404
# Epoch 1865/3000
#  - 3s - loss: 29.0905 - decoder_loss: 28.8881 - predictor_loss: 0.0101 - val_loss: 33.3161 - val_decoder_loss: 33.0795 - val_predictor_loss: 0.0118
#
# Epoch 01865: val_loss did not improve from 32.65404
# Epoch 1866/3000
#  - 3s - loss: 29.1781 - decoder_loss: 28.9832 - predictor_loss: 0.0097 - val_loss: 33.6483 - val_decoder_loss: 33.4242 - val_predictor_loss: 0.0112
#
# Epoch 01866: val_loss did not improve from 32.65404
# Epoch 1867/3000
#  - 3s - loss: 29.3611 - decoder_loss: 29.1523 - predictor_loss: 0.0104 - val_loss: 33.7996 - val_decoder_loss: 33.5213 - val_predictor_loss: 0.0139
#
# Epoch 01867: val_loss did not improve from 32.65404
# Epoch 1868/3000
#  - 3s - loss: 29.2104 - decoder_loss: 29.0227 - predictor_loss: 0.0094 - val_loss: 33.5241 - val_decoder_loss: 33.2958 - val_predictor_loss: 0.0114
#
# Epoch 01868: val_loss did not improve from 32.65404
# Epoch 1869/3000
#  - 3s - loss: 29.5231 - decoder_loss: 29.3301 - predictor_loss: 0.0096 - val_loss: 33.3508 - val_decoder_loss: 33.0991 - val_predictor_loss: 0.0126
#
# Epoch 01869: val_loss did not improve from 32.65404
# Epoch 1870/3000
#  - 3s - loss: 29.3964 - decoder_loss: 29.1502 - predictor_loss: 0.0123 - val_loss: 33.3997 - val_decoder_loss: 33.1540 - val_predictor_loss: 0.0123
#
# Epoch 01870: val_loss did not improve from 32.65404
# Epoch 1871/3000
#  - 3s - loss: 29.2930 - decoder_loss: 29.0720 - predictor_loss: 0.0110 - val_loss: 33.6053 - val_decoder_loss: 33.2780 - val_predictor_loss: 0.0164
#
# Epoch 01871: val_loss did not improve from 32.65404
# Epoch 1872/3000
#  - 3s - loss: 29.2715 - decoder_loss: 29.0454 - predictor_loss: 0.0113 - val_loss: 34.1128 - val_decoder_loss: 33.8376 - val_predictor_loss: 0.0138
#
# Epoch 01872: val_loss did not improve from 32.65404
# Epoch 1873/3000
#  - 3s - loss: 29.4584 - decoder_loss: 29.2481 - predictor_loss: 0.0105 - val_loss: 34.2004 - val_decoder_loss: 33.9167 - val_predictor_loss: 0.0142
#
# Epoch 01873: val_loss did not improve from 32.65404
# Epoch 1874/3000
#  - 3s - loss: 29.8163 - decoder_loss: 29.5638 - predictor_loss: 0.0126 - val_loss: 33.5835 - val_decoder_loss: 33.3447 - val_predictor_loss: 0.0119
#
# Epoch 01874: val_loss did not improve from 32.65404
# Epoch 1875/3000
#  - 3s - loss: 29.7865 - decoder_loss: 29.5927 - predictor_loss: 0.0097 - val_loss: 33.0565 - val_decoder_loss: 32.8277 - val_predictor_loss: 0.0114
#
# Epoch 01875: val_loss did not improve from 32.65404
# Epoch 1876/3000
#  - 3s - loss: 29.4386 - decoder_loss: 29.2371 - predictor_loss: 0.0101 - val_loss: 34.3108 - val_decoder_loss: 34.0838 - val_predictor_loss: 0.0114
#
# Epoch 01876: val_loss did not improve from 32.65404
# Epoch 1877/3000
#  - 3s - loss: 29.3388 - decoder_loss: 29.1384 - predictor_loss: 0.0100 - val_loss: 33.1057 - val_decoder_loss: 32.8829 - val_predictor_loss: 0.0111
#
# Epoch 01877: val_loss did not improve from 32.65404
# Epoch 1878/3000
#  - 3s - loss: 29.1822 - decoder_loss: 28.9972 - predictor_loss: 0.0092 - val_loss: 33.4739 - val_decoder_loss: 33.2252 - val_predictor_loss: 0.0124
#
# Epoch 01878: val_loss did not improve from 32.65404
# Epoch 1879/3000
#  - 3s - loss: 29.0893 - decoder_loss: 28.8781 - predictor_loss: 0.0106 - val_loss: 33.1180 - val_decoder_loss: 32.8477 - val_predictor_loss: 0.0135
#
# Epoch 01879: val_loss did not improve from 32.65404
# Epoch 1880/3000
#  - 3s - loss: 29.2737 - decoder_loss: 29.0774 - predictor_loss: 0.0098 - val_loss: 32.8896 - val_decoder_loss: 32.6420 - val_predictor_loss: 0.0124
#
# Epoch 01880: val_loss did not improve from 32.65404
# Epoch 1881/3000
#  - 3s - loss: 28.8658 - decoder_loss: 28.6753 - predictor_loss: 0.0095 - val_loss: 33.3556 - val_decoder_loss: 33.1248 - val_predictor_loss: 0.0115
#
# Epoch 01881: val_loss did not improve from 32.65404
# Epoch 1882/3000
#  - 3s - loss: 29.3854 - decoder_loss: 29.1758 - predictor_loss: 0.0105 - val_loss: 33.7698 - val_decoder_loss: 33.5063 - val_predictor_loss: 0.0132
#
# Epoch 01882: val_loss did not improve from 32.65404
# Epoch 1883/3000
#  - 3s - loss: 29.1496 - decoder_loss: 28.9424 - predictor_loss: 0.0104 - val_loss: 33.3652 - val_decoder_loss: 33.1106 - val_predictor_loss: 0.0127
#
# Epoch 01883: val_loss did not improve from 32.65404
# Epoch 1884/3000
#  - 3s - loss: 29.2542 - decoder_loss: 29.0463 - predictor_loss: 0.0104 - val_loss: 33.4913 - val_decoder_loss: 33.2406 - val_predictor_loss: 0.0125
#
# Epoch 01884: val_loss did not improve from 32.65404
# Epoch 1885/3000
#  - 3s - loss: 29.1769 - decoder_loss: 28.9750 - predictor_loss: 0.0101 - val_loss: 34.1707 - val_decoder_loss: 33.9413 - val_predictor_loss: 0.0115
#
# Epoch 01885: val_loss did not improve from 32.65404
# Epoch 1886/3000
#  - 3s - loss: 29.6588 - decoder_loss: 29.4541 - predictor_loss: 0.0102 - val_loss: 33.7886 - val_decoder_loss: 33.5476 - val_predictor_loss: 0.0120
#
# Epoch 01886: val_loss did not improve from 32.65404
# Epoch 1887/3000
#  - 3s - loss: 29.2063 - decoder_loss: 29.0177 - predictor_loss: 0.0094 - val_loss: 33.6271 - val_decoder_loss: 33.4045 - val_predictor_loss: 0.0111
#
# Epoch 01887: val_loss did not improve from 32.65404
# Epoch 1888/3000
#  - 3s - loss: 29.2672 - decoder_loss: 29.0602 - predictor_loss: 0.0103 - val_loss: 33.6654 - val_decoder_loss: 33.3988 - val_predictor_loss: 0.0133
#
# Epoch 01888: val_loss did not improve from 32.65404
# Epoch 1889/3000
#  - 3s - loss: 29.4213 - decoder_loss: 29.1945 - predictor_loss: 0.0113 - val_loss: 33.4273 - val_decoder_loss: 33.1907 - val_predictor_loss: 0.0118
#
# Epoch 01889: val_loss did not improve from 32.65404
# Epoch 1890/3000
#  - 3s - loss: 29.4861 - decoder_loss: 29.2738 - predictor_loss: 0.0106 - val_loss: 33.2019 - val_decoder_loss: 32.9426 - val_predictor_loss: 0.0130
#
# Epoch 01890: val_loss did not improve from 32.65404
# Epoch 1891/3000
#  - 3s - loss: 29.3338 - decoder_loss: 29.1226 - predictor_loss: 0.0106 - val_loss: 33.9107 - val_decoder_loss: 33.6213 - val_predictor_loss: 0.0145
#
# Epoch 01891: val_loss did not improve from 32.65404
# Epoch 1892/3000
#  - 3s - loss: 29.4204 - decoder_loss: 29.1997 - predictor_loss: 0.0110 - val_loss: 33.7190 - val_decoder_loss: 33.4895 - val_predictor_loss: 0.0115
#
# Epoch 01892: val_loss did not improve from 32.65404
# Epoch 1893/3000
#  - 3s - loss: 29.2873 - decoder_loss: 29.0901 - predictor_loss: 0.0099 - val_loss: 33.4476 - val_decoder_loss: 33.1952 - val_predictor_loss: 0.0126
#
# Epoch 01893: val_loss did not improve from 32.65404
# Epoch 1894/3000
#  - 3s - loss: 29.2536 - decoder_loss: 29.0333 - predictor_loss: 0.0110 - val_loss: 33.1098 - val_decoder_loss: 32.8619 - val_predictor_loss: 0.0124
#
# Epoch 01894: val_loss did not improve from 32.65404
# Epoch 1895/3000
#  - 3s - loss: 29.2364 - decoder_loss: 29.0191 - predictor_loss: 0.0109 - val_loss: 33.6877 - val_decoder_loss: 33.4178 - val_predictor_loss: 0.0135
#
# Epoch 01895: val_loss did not improve from 32.65404
# Epoch 1896/3000
#  - 3s - loss: 29.3314 - decoder_loss: 29.1327 - predictor_loss: 0.0099 - val_loss: 32.9179 - val_decoder_loss: 32.6704 - val_predictor_loss: 0.0124
#
# Epoch 01896: val_loss did not improve from 32.65404
# Epoch 1897/3000
#  - 3s - loss: 29.0672 - decoder_loss: 28.8677 - predictor_loss: 0.0100 - val_loss: 34.1464 - val_decoder_loss: 33.9049 - val_predictor_loss: 0.0121
#
# Epoch 01897: val_loss did not improve from 32.65404
# Epoch 1898/3000
#  - 3s - loss: 29.5432 - decoder_loss: 29.3302 - predictor_loss: 0.0106 - val_loss: 33.3736 - val_decoder_loss: 33.1370 - val_predictor_loss: 0.0118
#
# Epoch 01898: val_loss did not improve from 32.65404
# Epoch 1899/3000
#  - 3s - loss: 29.1962 - decoder_loss: 29.0110 - predictor_loss: 0.0093 - val_loss: 33.2343 - val_decoder_loss: 33.0035 - val_predictor_loss: 0.0115
#
# Epoch 01899: val_loss did not improve from 32.65404
# Epoch 1900/3000
#  - 3s - loss: 29.2465 - decoder_loss: 29.0581 - predictor_loss: 0.0094 - val_loss: 33.4846 - val_decoder_loss: 33.2601 - val_predictor_loss: 0.0112
#
# Epoch 01900: val_loss did not improve from 32.65404
# Epoch 1901/3000
#  - 3s - loss: 29.1207 - decoder_loss: 28.9384 - predictor_loss: 0.0091 - val_loss: 33.9096 - val_decoder_loss: 33.6814 - val_predictor_loss: 0.0114
#
# Epoch 01901: val_loss did not improve from 32.65404
# Epoch 1902/3000
#  - 3s - loss: 29.1050 - decoder_loss: 28.9236 - predictor_loss: 0.0091 - val_loss: 32.8921 - val_decoder_loss: 32.6757 - val_predictor_loss: 0.0108
#
# Epoch 01902: val_loss did not improve from 32.65404
# Epoch 1903/3000
#  - 3s - loss: 29.2327 - decoder_loss: 29.0393 - predictor_loss: 0.0097 - val_loss: 32.9818 - val_decoder_loss: 32.7653 - val_predictor_loss: 0.0108
#
# Epoch 01903: val_loss did not improve from 32.65404
# Epoch 1904/3000
#  - 3s - loss: 29.3936 - decoder_loss: 29.2122 - predictor_loss: 0.0091 - val_loss: 33.4696 - val_decoder_loss: 33.2229 - val_predictor_loss: 0.0123
#
# Epoch 01904: val_loss did not improve from 32.65404
# Epoch 1905/3000
#  - 3s - loss: 29.8478 - decoder_loss: 29.6332 - predictor_loss: 0.0107 - val_loss: 34.2046 - val_decoder_loss: 33.9002 - val_predictor_loss: 0.0152
#
# Epoch 01905: val_loss did not improve from 32.65404
# Epoch 1906/3000
#  - 3s - loss: 29.6149 - decoder_loss: 29.4020 - predictor_loss: 0.0106 - val_loss: 33.4804 - val_decoder_loss: 33.2235 - val_predictor_loss: 0.0128
#
# Epoch 01906: val_loss did not improve from 32.65404
# Epoch 1907/3000
#  - 3s - loss: 29.2313 - decoder_loss: 29.0010 - predictor_loss: 0.0115 - val_loss: 33.0176 - val_decoder_loss: 32.7051 - val_predictor_loss: 0.0156
#
# Epoch 01907: val_loss did not improve from 32.65404
# Epoch 1908/3000
#  - 3s - loss: 29.3532 - decoder_loss: 29.1509 - predictor_loss: 0.0101 - val_loss: 33.1338 - val_decoder_loss: 32.9047 - val_predictor_loss: 0.0115
#
# Epoch 01908: val_loss did not improve from 32.65404
# Epoch 1909/3000
#  - 3s - loss: 29.3091 - decoder_loss: 29.1151 - predictor_loss: 0.0097 - val_loss: 33.6410 - val_decoder_loss: 33.4062 - val_predictor_loss: 0.0117
#
# Epoch 01909: val_loss did not improve from 32.65404
# Epoch 1910/3000
#  - 3s - loss: 29.2599 - decoder_loss: 29.0589 - predictor_loss: 0.0101 - val_loss: 33.4238 - val_decoder_loss: 33.2098 - val_predictor_loss: 0.0107
#
# Epoch 01910: val_loss did not improve from 32.65404
# Epoch 1911/3000
#  - 3s - loss: 29.0547 - decoder_loss: 28.8543 - predictor_loss: 0.0100 - val_loss: 33.5821 - val_decoder_loss: 33.3434 - val_predictor_loss: 0.0119
#
# Epoch 01911: val_loss did not improve from 32.65404
# Epoch 1912/3000
#  - 3s - loss: 29.4431 - decoder_loss: 29.2271 - predictor_loss: 0.0108 - val_loss: 33.0212 - val_decoder_loss: 32.7646 - val_predictor_loss: 0.0128
#
# Epoch 01912: val_loss did not improve from 32.65404
# Epoch 1913/3000
#  - 3s - loss: 29.4802 - decoder_loss: 29.2845 - predictor_loss: 0.0098 - val_loss: 33.0706 - val_decoder_loss: 32.8318 - val_predictor_loss: 0.0119
#
# Epoch 01913: val_loss did not improve from 32.65404
# Epoch 1914/3000
#  - 3s - loss: 29.2687 - decoder_loss: 29.0713 - predictor_loss: 0.0099 - val_loss: 33.1552 - val_decoder_loss: 32.8818 - val_predictor_loss: 0.0137
#
# Epoch 01914: val_loss did not improve from 32.65404
# Epoch 1915/3000
#  - 3s - loss: 28.9710 - decoder_loss: 28.7613 - predictor_loss: 0.0105 - val_loss: 33.2420 - val_decoder_loss: 33.0248 - val_predictor_loss: 0.0109
#
# Epoch 01915: val_loss did not improve from 32.65404
# Epoch 1916/3000
#  - 3s - loss: 29.2140 - decoder_loss: 29.0235 - predictor_loss: 0.0095 - val_loss: 32.8456 - val_decoder_loss: 32.6131 - val_predictor_loss: 0.0116
#
# Epoch 01916: val_loss did not improve from 32.65404
# Epoch 1917/3000
#  - 3s - loss: 29.2638 - decoder_loss: 29.0596 - predictor_loss: 0.0102 - val_loss: 33.2868 - val_decoder_loss: 33.0253 - val_predictor_loss: 0.0131
#
# Epoch 01917: val_loss did not improve from 32.65404
# Epoch 1918/3000
#  - 3s - loss: 28.9019 - decoder_loss: 28.7204 - predictor_loss: 0.0091 - val_loss: 33.4746 - val_decoder_loss: 33.2537 - val_predictor_loss: 0.0110
#
# Epoch 01918: val_loss did not improve from 32.65404
# Epoch 1919/3000
#  - 3s - loss: 29.0848 - decoder_loss: 28.9108 - predictor_loss: 0.0087 - val_loss: 33.5130 - val_decoder_loss: 33.2917 - val_predictor_loss: 0.0111
#
# Epoch 01919: val_loss did not improve from 32.65404
# Epoch 1920/3000
#  - 3s - loss: 29.0679 - decoder_loss: 28.8854 - predictor_loss: 0.0091 - val_loss: 32.9863 - val_decoder_loss: 32.7372 - val_predictor_loss: 0.0125
#
# Epoch 01920: val_loss did not improve from 32.65404
# Epoch 1921/3000
#  - 3s - loss: 29.0604 - decoder_loss: 28.8766 - predictor_loss: 0.0092 - val_loss: 32.8928 - val_decoder_loss: 32.6330 - val_predictor_loss: 0.0130
#
# Epoch 01921: val_loss did not improve from 32.65404
# Epoch 1922/3000
#  - 3s - loss: 29.2707 - decoder_loss: 29.0414 - predictor_loss: 0.0115 - val_loss: 33.6894 - val_decoder_loss: 33.4386 - val_predictor_loss: 0.0125
#
# Epoch 01922: val_loss did not improve from 32.65404
# Epoch 1923/3000
#  - 3s - loss: 29.3637 - decoder_loss: 29.1608 - predictor_loss: 0.0101 - val_loss: 32.9341 - val_decoder_loss: 32.6868 - val_predictor_loss: 0.0124
#
# Epoch 01923: val_loss did not improve from 32.65404
# Epoch 1924/3000
#  - 3s - loss: 29.0411 - decoder_loss: 28.8437 - predictor_loss: 0.0099 - val_loss: 33.2624 - val_decoder_loss: 32.9375 - val_predictor_loss: 0.0162
#
# Epoch 01924: val_loss did not improve from 32.65404
# Epoch 1925/3000
#  - 3s - loss: 29.4788 - decoder_loss: 29.2793 - predictor_loss: 0.0100 - val_loss: 33.1677 - val_decoder_loss: 32.9197 - val_predictor_loss: 0.0124
#
# Epoch 01925: val_loss did not improve from 32.65404
# Epoch 1926/3000
#  - 3s - loss: 29.3461 - decoder_loss: 29.1485 - predictor_loss: 0.0099 - val_loss: 33.5487 - val_decoder_loss: 33.3281 - val_predictor_loss: 0.0110
#
# Epoch 01926: val_loss did not improve from 32.65404
# Epoch 1927/3000
#  - 3s - loss: 29.1907 - decoder_loss: 29.0027 - predictor_loss: 0.0094 - val_loss: 33.0301 - val_decoder_loss: 32.7946 - val_predictor_loss: 0.0118
#
# Epoch 01927: val_loss did not improve from 32.65404
# Epoch 1928/3000
#  - 3s - loss: 28.9752 - decoder_loss: 28.7841 - predictor_loss: 0.0096 - val_loss: 33.1793 - val_decoder_loss: 32.9456 - val_predictor_loss: 0.0117
#
# Epoch 01928: val_loss did not improve from 32.65404
# Epoch 1929/3000
#  - 3s - loss: 29.2791 - decoder_loss: 29.0673 - predictor_loss: 0.0106 - val_loss: 33.5693 - val_decoder_loss: 33.3167 - val_predictor_loss: 0.0126
#
# Epoch 01929: val_loss did not improve from 32.65404
# Epoch 1930/3000
#  - 3s - loss: 29.1829 - decoder_loss: 28.9774 - predictor_loss: 0.0103 - val_loss: 32.8080 - val_decoder_loss: 32.5546 - val_predictor_loss: 0.0127
#
# Epoch 01930: val_loss did not improve from 32.65404
# Epoch 1931/3000
#  - 3s - loss: 29.2290 - decoder_loss: 29.0368 - predictor_loss: 0.0096 - val_loss: 33.5058 - val_decoder_loss: 33.2790 - val_predictor_loss: 0.0113
#
# Epoch 01931: val_loss did not improve from 32.65404
# Epoch 1932/3000
#  - 3s - loss: 29.6494 - decoder_loss: 29.4303 - predictor_loss: 0.0110 - val_loss: 33.5361 - val_decoder_loss: 33.2381 - val_predictor_loss: 0.0149
#
# Epoch 01932: val_loss did not improve from 32.65404
# Epoch 1933/3000
#  - 3s - loss: 29.5631 - decoder_loss: 29.3410 - predictor_loss: 0.0111 - val_loss: 33.1732 - val_decoder_loss: 32.9210 - val_predictor_loss: 0.0126
#
# Epoch 01933: val_loss did not improve from 32.65404
# Epoch 1934/3000
#  - 3s - loss: 29.3870 - decoder_loss: 29.1722 - predictor_loss: 0.0107 - val_loss: 33.0904 - val_decoder_loss: 32.8180 - val_predictor_loss: 0.0136
#
# Epoch 01934: val_loss did not improve from 32.65404
# Epoch 1935/3000
#  - 3s - loss: 29.3300 - decoder_loss: 29.1408 - predictor_loss: 0.0095 - val_loss: 33.3638 - val_decoder_loss: 33.1186 - val_predictor_loss: 0.0123
#
# Epoch 01935: val_loss did not improve from 32.65404
# Epoch 1936/3000
#  - 3s - loss: 28.9673 - decoder_loss: 28.7753 - predictor_loss: 0.0096 - val_loss: 32.8739 - val_decoder_loss: 32.6003 - val_predictor_loss: 0.0137
#
# Epoch 01936: val_loss did not improve from 32.65404
# Epoch 1937/3000
#  - 3s - loss: 29.4826 - decoder_loss: 29.2852 - predictor_loss: 0.0099 - val_loss: 33.6239 - val_decoder_loss: 33.3179 - val_predictor_loss: 0.0153
#
# Epoch 01937: val_loss did not improve from 32.65404
# Epoch 1938/3000
#  - 3s - loss: 29.0282 - decoder_loss: 28.8373 - predictor_loss: 0.0095 - val_loss: 33.5473 - val_decoder_loss: 33.2817 - val_predictor_loss: 0.0133
#
# Epoch 01938: val_loss did not improve from 32.65404
# Epoch 1939/3000
#  - 3s - loss: 29.2992 - decoder_loss: 29.0976 - predictor_loss: 0.0101 - val_loss: 33.4133 - val_decoder_loss: 33.1612 - val_predictor_loss: 0.0126
#
# Epoch 01939: val_loss did not improve from 32.65404
# Epoch 1940/3000
#  - 3s - loss: 29.3442 - decoder_loss: 29.1374 - predictor_loss: 0.0103 - val_loss: 33.6979 - val_decoder_loss: 33.4762 - val_predictor_loss: 0.0111
#
# Epoch 01940: val_loss did not improve from 32.65404
# Epoch 1941/3000
#  - 3s - loss: 29.2205 - decoder_loss: 29.0251 - predictor_loss: 0.0098 - val_loss: 33.3689 - val_decoder_loss: 33.1075 - val_predictor_loss: 0.0131
#
# Epoch 01941: val_loss did not improve from 32.65404
# Epoch 1942/3000
#  - 3s - loss: 28.9481 - decoder_loss: 28.7385 - predictor_loss: 0.0105 - val_loss: 33.4796 - val_decoder_loss: 33.2222 - val_predictor_loss: 0.0129
#
# Epoch 01942: val_loss did not improve from 32.65404
# Epoch 1943/3000
#  - 3s - loss: 29.0975 - decoder_loss: 28.8938 - predictor_loss: 0.0102 - val_loss: 32.9163 - val_decoder_loss: 32.6530 - val_predictor_loss: 0.0132
#
# Epoch 01943: val_loss did not improve from 32.65404
# Epoch 1944/3000
#  - 3s - loss: 29.2754 - decoder_loss: 29.0830 - predictor_loss: 0.0096 - val_loss: 33.7130 - val_decoder_loss: 33.4516 - val_predictor_loss: 0.0131
#
# Epoch 01944: val_loss did not improve from 32.65404
# Epoch 1945/3000
#  - 3s - loss: 29.7713 - decoder_loss: 29.5547 - predictor_loss: 0.0108 - val_loss: 33.5315 - val_decoder_loss: 33.2439 - val_predictor_loss: 0.0144
#
# Epoch 01945: val_loss did not improve from 32.65404
# Epoch 1946/3000
#  - 3s - loss: 29.3333 - decoder_loss: 29.1285 - predictor_loss: 0.0102 - val_loss: 33.3145 - val_decoder_loss: 33.0627 - val_predictor_loss: 0.0126
#
# Epoch 01946: val_loss did not improve from 32.65404
# Epoch 1947/3000
#  - 3s - loss: 28.9162 - decoder_loss: 28.7017 - predictor_loss: 0.0107 - val_loss: 33.3219 - val_decoder_loss: 33.0971 - val_predictor_loss: 0.0112
#
# Epoch 01947: val_loss did not improve from 32.65404
# Epoch 1948/3000
#  - 3s - loss: 29.2632 - decoder_loss: 29.0752 - predictor_loss: 0.0094 - val_loss: 33.3542 - val_decoder_loss: 33.0977 - val_predictor_loss: 0.0128
#
# Epoch 01948: val_loss did not improve from 32.65404
# Epoch 1949/3000
#  - 3s - loss: 28.9208 - decoder_loss: 28.7264 - predictor_loss: 0.0097 - val_loss: 33.3870 - val_decoder_loss: 33.1576 - val_predictor_loss: 0.0115
#
# Epoch 01949: val_loss did not improve from 32.65404
# Epoch 1950/3000
#  - 3s - loss: 29.1799 - decoder_loss: 28.9897 - predictor_loss: 0.0095 - val_loss: 32.9176 - val_decoder_loss: 32.7027 - val_predictor_loss: 0.0107
#
# Epoch 01950: val_loss did not improve from 32.65404
# Epoch 1951/3000
#  - 3s - loss: 29.3461 - decoder_loss: 29.1562 - predictor_loss: 0.0095 - val_loss: 33.4052 - val_decoder_loss: 33.1654 - val_predictor_loss: 0.0120
#
# Epoch 01951: val_loss did not improve from 32.65404
# Epoch 1952/3000
#  - 3s - loss: 29.3461 - decoder_loss: 29.1369 - predictor_loss: 0.0105 - val_loss: 33.3585 - val_decoder_loss: 33.1277 - val_predictor_loss: 0.0115
#
# Epoch 01952: val_loss did not improve from 32.65404
# Epoch 1953/3000
#  - 3s - loss: 29.5588 - decoder_loss: 29.3526 - predictor_loss: 0.0103 - val_loss: 33.1988 - val_decoder_loss: 32.9429 - val_predictor_loss: 0.0128
#
# Epoch 01953: val_loss did not improve from 32.65404
# Epoch 1954/3000
#  - 3s - loss: 29.1398 - decoder_loss: 28.9334 - predictor_loss: 0.0103 - val_loss: 33.1232 - val_decoder_loss: 32.8845 - val_predictor_loss: 0.0119
#
# Epoch 01954: val_loss did not improve from 32.65404
# Epoch 1955/3000
#  - 3s - loss: 29.1040 - decoder_loss: 28.9169 - predictor_loss: 0.0094 - val_loss: 33.4924 - val_decoder_loss: 33.2734 - val_predictor_loss: 0.0110
#
# Epoch 01955: val_loss did not improve from 32.65404
# Epoch 1956/3000
#  - 3s - loss: 29.4910 - decoder_loss: 29.2997 - predictor_loss: 0.0096 - val_loss: 32.7175 - val_decoder_loss: 32.4874 - val_predictor_loss: 0.0115
#
# Epoch 01956: val_loss did not improve from 32.65404
# Epoch 1957/3000
#  - 3s - loss: 29.2238 - decoder_loss: 29.0167 - predictor_loss: 0.0104 - val_loss: 33.1030 - val_decoder_loss: 32.8584 - val_predictor_loss: 0.0122
#
# Epoch 01957: val_loss did not improve from 32.65404
# Epoch 1958/3000
#  - 3s - loss: 29.1595 - decoder_loss: 28.9353 - predictor_loss: 0.0112 - val_loss: 33.1951 - val_decoder_loss: 32.9491 - val_predictor_loss: 0.0123
#
# Epoch 01958: val_loss did not improve from 32.65404
# Epoch 1959/3000
#  - 3s - loss: 29.3363 - decoder_loss: 29.1254 - predictor_loss: 0.0105 - val_loss: 34.2874 - val_decoder_loss: 34.0612 - val_predictor_loss: 0.0113
#
# Epoch 01959: val_loss did not improve from 32.65404
# Epoch 1960/3000
#  - 3s - loss: 29.3114 - decoder_loss: 29.1216 - predictor_loss: 0.0095 - val_loss: 32.8377 - val_decoder_loss: 32.5986 - val_predictor_loss: 0.0120
#
# Epoch 01960: val_loss did not improve from 32.65404
# Epoch 1961/3000
#  - 3s - loss: 29.0559 - decoder_loss: 28.8658 - predictor_loss: 0.0095 - val_loss: 33.5936 - val_decoder_loss: 33.3432 - val_predictor_loss: 0.0125
#
# Epoch 01961: val_loss did not improve from 32.65404
# Epoch 1962/3000
#  - 3s - loss: 28.9275 - decoder_loss: 28.7426 - predictor_loss: 0.0092 - val_loss: 32.7552 - val_decoder_loss: 32.4793 - val_predictor_loss: 0.0138
#
# Epoch 01962: val_loss did not improve from 32.65404
# Epoch 1963/3000
#  - 3s - loss: 29.2285 - decoder_loss: 29.0144 - predictor_loss: 0.0107 - val_loss: 32.7422 - val_decoder_loss: 32.5087 - val_predictor_loss: 0.0117
#
# Epoch 01963: val_loss did not improve from 32.65404
# Epoch 1964/3000
#  - 3s - loss: 29.3323 - decoder_loss: 29.1247 - predictor_loss: 0.0104 - val_loss: 33.1616 - val_decoder_loss: 32.8681 - val_predictor_loss: 0.0147
#
# Epoch 01964: val_loss did not improve from 32.65404
# Epoch 1965/3000
#  - 3s - loss: 29.3326 - decoder_loss: 29.1295 - predictor_loss: 0.0102 - val_loss: 33.6058 - val_decoder_loss: 33.3588 - val_predictor_loss: 0.0123
#
# Epoch 01965: val_loss did not improve from 32.65404
# Epoch 1966/3000
#  - 3s - loss: 29.3417 - decoder_loss: 29.1381 - predictor_loss: 0.0102 - val_loss: 33.2664 - val_decoder_loss: 33.0363 - val_predictor_loss: 0.0115
#
# Epoch 01966: val_loss did not improve from 32.65404
# Epoch 1967/3000
#  - 3s - loss: 29.2300 - decoder_loss: 29.0156 - predictor_loss: 0.0107 - val_loss: 33.2977 - val_decoder_loss: 33.0208 - val_predictor_loss: 0.0138
#
# Epoch 01967: val_loss did not improve from 32.65404
# Epoch 1968/3000
#  - 3s - loss: 29.1169 - decoder_loss: 28.9313 - predictor_loss: 0.0093 - val_loss: 33.3856 - val_decoder_loss: 33.1627 - val_predictor_loss: 0.0111
#
# Epoch 01968: val_loss did not improve from 32.65404
# Epoch 1969/3000
#  - 3s - loss: 29.4523 - decoder_loss: 29.2650 - predictor_loss: 0.0094 - val_loss: 32.9473 - val_decoder_loss: 32.7155 - val_predictor_loss: 0.0116
#
# Epoch 01969: val_loss did not improve from 32.65404
# Epoch 1970/3000
#  - 3s - loss: 29.2154 - decoder_loss: 29.0076 - predictor_loss: 0.0104 - val_loss: 33.3999 - val_decoder_loss: 33.1759 - val_predictor_loss: 0.0112
#
# Epoch 01970: val_loss did not improve from 32.65404
# Epoch 1971/3000
#  - 3s - loss: 29.0574 - decoder_loss: 28.8772 - predictor_loss: 0.0090 - val_loss: 33.4428 - val_decoder_loss: 33.1849 - val_predictor_loss: 0.0129
#
# ...
#
# Epoch 02927: val_loss did not improve from 32.13070
# Epoch 2928/3000
#  - 3s - loss: 28.6938 - decoder_loss: 28.5063 - predictor_loss: 0.0094 - val_loss: 32.8623 - val_decoder_loss: 32.6348 - val_predictor_loss: 0.0114
#
# Epoch 02928: val_loss did not improve from 32.13070
# Epoch 2929/3000
#  - 3s - loss: 28.8890 - decoder_loss: 28.6853 - predictor_loss: 0.0102 - val_loss: 33.1205 - val_decoder_loss: 32.8937 - val_predictor_loss: 0.0113
#
# Epoch 02929: val_loss did not improve from 32.13070
# Epoch 2930/3000
#  - 3s - loss: 28.9222 - decoder_loss: 28.7382 - predictor_loss: 0.0092 - val_loss: 33.2654 - val_decoder_loss: 33.0307 - val_predictor_loss: 0.0117
#
# Epoch 02930: val_loss did not improve from 32.13070
# Epoch 2931/3000
#  - 3s - loss: 28.5770 - decoder_loss: 28.3950 - predictor_loss: 0.0091 - val_loss: 32.6601 - val_decoder_loss: 32.4520 - val_predictor_loss: 0.0104
#
# Epoch 02931: val_loss did not improve from 32.13070
# Epoch 2932/3000
#  - 3s - loss: 29.0366 - decoder_loss: 28.8431 - predictor_loss: 0.0097 - val_loss: 33.1080 - val_decoder_loss: 32.8796 - val_predictor_loss: 0.0114
#
# Epoch 02932: val_loss did not improve from 32.13070
# Epoch 2933/3000
#  - 3s - loss: 28.7234 - decoder_loss: 28.5305 - predictor_loss: 0.0096 - val_loss: 32.4170 - val_decoder_loss: 32.2143 - val_predictor_loss: 0.0101
#
# Epoch 02933: val_loss did not improve from 32.13070
# Epoch 2934/3000
#  - 3s - loss: 28.8482 - decoder_loss: 28.6608 - predictor_loss: 0.0094 - val_loss: 32.7149 - val_decoder_loss: 32.4810 - val_predictor_loss: 0.0117
#
# Epoch 02934: val_loss did not improve from 32.13070
# Epoch 2935/3000
#  - 3s - loss: 29.0715 - decoder_loss: 28.8675 - predictor_loss: 0.0102 - val_loss: 33.3081 - val_decoder_loss: 33.0857 - val_predictor_loss: 0.0111
#
# Epoch 02935: val_loss did not improve from 32.13070
# Epoch 2936/3000
#  - 3s - loss: 28.5549 - decoder_loss: 28.3572 - predictor_loss: 0.0099 - val_loss: 32.9037 - val_decoder_loss: 32.6810 - val_predictor_loss: 0.0111
#
# Epoch 02936: val_loss did not improve from 32.13070
# Epoch 2937/3000
#  - 3s - loss: 29.1822 - decoder_loss: 28.9909 - predictor_loss: 0.0096 - val_loss: 33.5411 - val_decoder_loss: 33.2952 - val_predictor_loss: 0.0123
#
# Epoch 02937: val_loss did not improve from 32.13070
# Epoch 2938/3000
#  - 3s - loss: 29.1962 - decoder_loss: 28.9975 - predictor_loss: 0.0099 - val_loss: 32.5803 - val_decoder_loss: 32.3220 - val_predictor_loss: 0.0129
#
# Epoch 02938: val_loss did not improve from 32.13070
# Epoch 2939/3000
#  - 3s - loss: 28.8345 - decoder_loss: 28.6269 - predictor_loss: 0.0104 - val_loss: 33.2386 - val_decoder_loss: 32.9642 - val_predictor_loss: 0.0137
#
# Epoch 02939: val_loss did not improve from 32.13070
# Epoch 2940/3000
#  - 3s - loss: 28.9130 - decoder_loss: 28.7022 - predictor_loss: 0.0105 - val_loss: 33.0075 - val_decoder_loss: 32.7552 - val_predictor_loss: 0.0126
#
# Epoch 02940: val_loss did not improve from 32.13070
# Epoch 2941/3000
#  - 3s - loss: 28.6830 - decoder_loss: 28.4861 - predictor_loss: 0.0098 - val_loss: 33.4552 - val_decoder_loss: 33.2104 - val_predictor_loss: 0.0122
#
# Epoch 02941: val_loss did not improve from 32.13070
# Epoch 2942/3000
#  - 3s - loss: 28.7049 - decoder_loss: 28.5161 - predictor_loss: 0.0094 - val_loss: 32.7298 - val_decoder_loss: 32.4957 - val_predictor_loss: 0.0117
#
# Epoch 02942: val_loss did not improve from 32.13070
# Epoch 2943/3000
#  - 3s - loss: 28.5801 - decoder_loss: 28.3878 - predictor_loss: 0.0096 - val_loss: 32.2978 - val_decoder_loss: 32.0728 - val_predictor_loss: 0.0112
#
# Epoch 02943: val_loss did not improve from 32.13070
# Epoch 2944/3000
#  - 3s - loss: 28.6854 - decoder_loss: 28.5009 - predictor_loss: 0.0092 - val_loss: 32.9615 - val_decoder_loss: 32.7345 - val_predictor_loss: 0.0113
#
# Epoch 02944: val_loss did not improve from 32.13070
# Epoch 2945/3000
#  - 3s - loss: 29.0446 - decoder_loss: 28.8486 - predictor_loss: 0.0098 - val_loss: 33.3685 - val_decoder_loss: 33.1224 - val_predictor_loss: 0.0123
#
# Epoch 02945: val_loss did not improve from 32.13070
# Epoch 2946/3000
#  - 3s - loss: 28.8525 - decoder_loss: 28.6579 - predictor_loss: 0.0097 - val_loss: 32.9023 - val_decoder_loss: 32.6903 - val_predictor_loss: 0.0106
#
# Epoch 02946: val_loss did not improve from 32.13070
# Epoch 2947/3000
#  - 3s - loss: 28.7033 - decoder_loss: 28.5194 - predictor_loss: 0.0092 - val_loss: 32.4877 - val_decoder_loss: 32.2369 - val_predictor_loss: 0.0125
#
# Epoch 02947: val_loss did not improve from 32.13070
# Epoch 2948/3000
#  - 3s - loss: 29.0079 - decoder_loss: 28.8134 - predictor_loss: 0.0097 - val_loss: 32.9568 - val_decoder_loss: 32.6749 - val_predictor_loss: 0.0141
#
# Epoch 02948: val_loss did not improve from 32.13070
# Epoch 2949/3000
#  - 3s - loss: 28.8346 - decoder_loss: 28.6450 - predictor_loss: 0.0095 - val_loss: 33.2721 - val_decoder_loss: 33.0179 - val_predictor_loss: 0.0127
#
# Epoch 02949: val_loss did not improve from 32.13070
# Epoch 2950/3000
#  - 3s - loss: 28.7168 - decoder_loss: 28.5182 - predictor_loss: 0.0099 - val_loss: 32.6040 - val_decoder_loss: 32.3942 - val_predictor_loss: 0.0105
#
# Epoch 02950: val_loss did not improve from 32.13070
# Epoch 2951/3000
#  - 3s - loss: 28.8847 - decoder_loss: 28.6967 - predictor_loss: 0.0094 - val_loss: 32.9858 - val_decoder_loss: 32.7121 - val_predictor_loss: 0.0137
#
# Epoch 02951: val_loss did not improve from 32.13070
# Epoch 2952/3000
#  - 3s - loss: 28.9597 - decoder_loss: 28.7760 - predictor_loss: 0.0092 - val_loss: 32.8340 - val_decoder_loss: 32.6050 - val_predictor_loss: 0.0115
#
# Epoch 02952: val_loss did not improve from 32.13070
# Epoch 2953/3000
#  - 3s - loss: 28.9406 - decoder_loss: 28.7517 - predictor_loss: 0.0094 - val_loss: 33.3489 - val_decoder_loss: 33.1422 - val_predictor_loss: 0.0103
#
# Epoch 02953: val_loss did not improve from 32.13070
# Epoch 2954/3000
#  - 3s - loss: 28.6693 - decoder_loss: 28.4852 - predictor_loss: 0.0092 - val_loss: 33.8273 - val_decoder_loss: 33.6115 - val_predictor_loss: 0.0108
#
# Epoch 02954: val_loss did not improve from 32.13070
# Epoch 2955/3000
#  - 3s - loss: 28.9760 - decoder_loss: 28.8011 - predictor_loss: 0.0087 - val_loss: 32.5219 - val_decoder_loss: 32.3059 - val_predictor_loss: 0.0108
#
# Epoch 02955: val_loss did not improve from 32.13070
# Epoch 2956/3000
#  - 3s - loss: 28.7874 - decoder_loss: 28.6132 - predictor_loss: 0.0087 - val_loss: 33.0576 - val_decoder_loss: 32.8471 - val_predictor_loss: 0.0105
#
# Epoch 02956: val_loss did not improve from 32.13070
# Epoch 2957/3000
#  - 3s - loss: 28.6913 - decoder_loss: 28.5088 - predictor_loss: 0.0091 - val_loss: 32.5282 - val_decoder_loss: 32.2875 - val_predictor_loss: 0.0120
#
# Epoch 02957: val_loss did not improve from 32.13070
# Epoch 2958/3000
#  - 3s - loss: 28.8164 - decoder_loss: 28.6248 - predictor_loss: 0.0096 - val_loss: 32.9823 - val_decoder_loss: 32.7353 - val_predictor_loss: 0.0124
#
# Epoch 02958: val_loss did not improve from 32.13070
# Epoch 2959/3000
#  - 3s - loss: 28.7282 - decoder_loss: 28.5399 - predictor_loss: 0.0094 - val_loss: 32.4165 - val_decoder_loss: 32.1461 - val_predictor_loss: 0.0135
#
# Epoch 02959: val_loss did not improve from 32.13070
# Epoch 2960/3000
#  - 3s - loss: 28.6365 - decoder_loss: 28.4477 - predictor_loss: 0.0094 - val_loss: 32.9191 - val_decoder_loss: 32.6898 - val_predictor_loss: 0.0115
#
# Epoch 02960: val_loss did not improve from 32.13070
# Epoch 2961/3000
#  - 3s - loss: 29.0554 - decoder_loss: 28.8645 - predictor_loss: 0.0095 - val_loss: 32.9876 - val_decoder_loss: 32.7154 - val_predictor_loss: 0.0136
#
# Epoch 02961: val_loss did not improve from 32.13070
# Epoch 2962/3000
#  - 3s - loss: 28.8946 - decoder_loss: 28.6841 - predictor_loss: 0.0105 - val_loss: 32.6498 - val_decoder_loss: 32.4144 - val_predictor_loss: 0.0118
#
# Epoch 02962: val_loss did not improve from 32.13070
# Epoch 2963/3000
#  - 3s - loss: 28.8032 - decoder_loss: 28.6130 - predictor_loss: 0.0095 - val_loss: 32.6397 - val_decoder_loss: 32.4275 - val_predictor_loss: 0.0106
#
# Epoch 02963: val_loss did not improve from 32.13070
# Epoch 2964/3000
#  - 3s - loss: 28.8362 - decoder_loss: 28.6486 - predictor_loss: 0.0094 - val_loss: 32.8035 - val_decoder_loss: 32.5164 - val_predictor_loss: 0.0144
#
# Epoch 02964: val_loss did not improve from 32.13070
# Epoch 2965/3000
#  - 3s - loss: 28.8358 - decoder_loss: 28.6456 - predictor_loss: 0.0095 - val_loss: 31.8563 - val_decoder_loss: 31.6535 - val_predictor_loss: 0.0101
#
# Epoch 02965: val_loss improved from 32.13070 to 31.85628, saving model to VAE_Predictor2965.h5
# Epoch 2966/3000
#  - 3s - loss: 28.8467 - decoder_loss: 28.6669 - predictor_loss: 0.0090 - val_loss: 32.5759 - val_decoder_loss: 32.3336 - val_predictor_loss: 0.0121
#
# Epoch 02966: val_loss did not improve from 31.85628
# Epoch 2967/3000
#  - 3s - loss: 28.6957 - decoder_loss: 28.5049 - predictor_loss: 0.0095 - val_loss: 33.1240 - val_decoder_loss: 32.8644 - val_predictor_loss: 0.0130
#
# Epoch 02967: val_loss did not improve from 31.85628
# Epoch 2968/3000
#  - 3s - loss: 28.7195 - decoder_loss: 28.5230 - predictor_loss: 0.0098 - val_loss: 32.8000 - val_decoder_loss: 32.5918 - val_predictor_loss: 0.0104
#
# Epoch 02968: val_loss did not improve from 31.85628
# Epoch 2969/3000
#  - 3s - loss: 28.8883 - decoder_loss: 28.7070 - predictor_loss: 0.0091 - val_loss: 33.3163 - val_decoder_loss: 33.0806 - val_predictor_loss: 0.0118
#
# Epoch 02969: val_loss did not improve from 31.85628
# Epoch 2970/3000
#  - 3s - loss: 29.0673 - decoder_loss: 28.8629 - predictor_loss: 0.0102 - val_loss: 33.4225 - val_decoder_loss: 33.2002 - val_predictor_loss: 0.0111
#
# Epoch 02970: val_loss did not improve from 31.85628
# Epoch 2971/3000
#  - 3s - loss: 28.8417 - decoder_loss: 28.6295 - predictor_loss: 0.0106 - val_loss: 33.1321 - val_decoder_loss: 32.8533 - val_predictor_loss: 0.0139
#
# Epoch 02971: val_loss did not improve from 31.85628
# Epoch 2972/3000
#  - 3s - loss: 29.0309 - decoder_loss: 28.8232 - predictor_loss: 0.0104 - val_loss: 33.2389 - val_decoder_loss: 32.9967 - val_predictor_loss: 0.0121
#
# Epoch 02972: val_loss did not improve from 31.85628
# Epoch 2973/3000
#  - 3s - loss: 28.8324 - decoder_loss: 28.6301 - predictor_loss: 0.0101 - val_loss: 32.6828 - val_decoder_loss: 32.4706 - val_predictor_loss: 0.0106
#
# Epoch 02973: val_loss did not improve from 31.85628
# Epoch 2974/3000
#  - 3s - loss: 28.6361 - decoder_loss: 28.4538 - predictor_loss: 0.0091 - val_loss: 33.2616 - val_decoder_loss: 33.0529 - val_predictor_loss: 0.0104
#
# Epoch 02974: val_loss did not improve from 31.85628
# Epoch 2975/3000
#  - 3s - loss: 28.8278 - decoder_loss: 28.6500 - predictor_loss: 0.0089 - val_loss: 32.6232 - val_decoder_loss: 32.4208 - val_predictor_loss: 0.0101
#
# Epoch 02975: val_loss did not improve from 31.85628
# Epoch 2976/3000
#  - 3s - loss: 28.8311 - decoder_loss: 28.6338 - predictor_loss: 0.0099 - val_loss: 33.0130 - val_decoder_loss: 32.7765 - val_predictor_loss: 0.0118
#
# Epoch 02976: val_loss did not improve from 31.85628
# Epoch 2977/3000
#  - 3s - loss: 28.8581 - decoder_loss: 28.6747 - predictor_loss: 0.0092 - val_loss: 32.5435 - val_decoder_loss: 32.3098 - val_predictor_loss: 0.0117
#
# Epoch 02977: val_loss did not improve from 31.85628
# Epoch 2978/3000
#  - 3s - loss: 28.4951 - decoder_loss: 28.2993 - predictor_loss: 0.0098 - val_loss: 32.6803 - val_decoder_loss: 32.4387 - val_predictor_loss: 0.0121
#
# Epoch 02978: val_loss did not improve from 31.85628
# Epoch 2979/3000
#  - 3s - loss: 29.0266 - decoder_loss: 28.8424 - predictor_loss: 0.0092 - val_loss: 33.2347 - val_decoder_loss: 33.0169 - val_predictor_loss: 0.0109
#
# Epoch 02979: val_loss did not improve from 31.85628
# Epoch 2980/3000
#  - 3s - loss: 29.1564 - decoder_loss: 28.9610 - predictor_loss: 0.0098 - val_loss: 33.0640 - val_decoder_loss: 32.8268 - val_predictor_loss: 0.0119
#
# Epoch 02980: val_loss did not improve from 31.85628
# Epoch 2981/3000
#  - 3s - loss: 28.9000 - decoder_loss: 28.6923 - predictor_loss: 0.0104 - val_loss: 33.4361 - val_decoder_loss: 33.1925 - val_predictor_loss: 0.0122
#
# Epoch 02981: val_loss did not improve from 31.85628
# Epoch 2982/3000
#  - 3s - loss: 29.0690 - decoder_loss: 28.8673 - predictor_loss: 0.0101 - val_loss: 33.1902 - val_decoder_loss: 32.9376 - val_predictor_loss: 0.0126
#
# Epoch 02982: val_loss did not improve from 31.85628
# Epoch 2983/3000
#  - 3s - loss: 28.7039 - decoder_loss: 28.4785 - predictor_loss: 0.0113 - val_loss: 32.6306 - val_decoder_loss: 32.3326 - val_predictor_loss: 0.0149
#
# Epoch 02983: val_loss did not improve from 31.85628
# Epoch 2984/3000
#  - 3s - loss: 28.9609 - decoder_loss: 28.7450 - predictor_loss: 0.0108 - val_loss: 32.5292 - val_decoder_loss: 32.2787 - val_predictor_loss: 0.0125
#
# Epoch 02984: val_loss did not improve from 31.85628
# Epoch 2985/3000
#  - 3s - loss: 28.4972 - decoder_loss: 28.3002 - predictor_loss: 0.0098 - val_loss: 32.6224 - val_decoder_loss: 32.3906 - val_predictor_loss: 0.0116
#
# Epoch 02985: val_loss did not improve from 31.85628
# Epoch 2986/3000
#  - 3s - loss: 28.6946 - decoder_loss: 28.5024 - predictor_loss: 0.0096 - val_loss: 31.9329 - val_decoder_loss: 31.7195 - val_predictor_loss: 0.0107
#
# Epoch 02986: val_loss did not improve from 31.85628
# Epoch 2987/3000
#  - 3s - loss: 28.7887 - decoder_loss: 28.5883 - predictor_loss: 0.0100 - val_loss: 32.4681 - val_decoder_loss: 32.2437 - val_predictor_loss: 0.0112
#
# Epoch 02987: val_loss did not improve from 31.85628
# Epoch 2988/3000
#  - 3s - loss: 28.7988 - decoder_loss: 28.6025 - predictor_loss: 0.0098 - val_loss: 32.9089 - val_decoder_loss: 32.6841 - val_predictor_loss: 0.0112
#
# Epoch 02988: val_loss did not improve from 31.85628
# Epoch 2989/3000
#  - 3s - loss: 28.8009 - decoder_loss: 28.5978 - predictor_loss: 0.0102 - val_loss: 32.9938 - val_decoder_loss: 32.7375 - val_predictor_loss: 0.0128
#
# Epoch 02989: val_loss did not improve from 31.85628
# Epoch 2990/3000
#  - 3s - loss: 28.6114 - decoder_loss: 28.3964 - predictor_loss: 0.0107 - val_loss: 32.5626 - val_decoder_loss: 32.3080 - val_predictor_loss: 0.0127
#
# Epoch 02990: val_loss did not improve from 31.85628
# Epoch 2991/3000
#  - 3s - loss: 28.7775 - decoder_loss: 28.5791 - predictor_loss: 0.0099 - val_loss: 32.4913 - val_decoder_loss: 32.2650 - val_predictor_loss: 0.0113
#
# Epoch 02991: val_loss did not improve from 31.85628
# Epoch 2992/3000
#  - 3s - loss: 28.7401 - decoder_loss: 28.5500 - predictor_loss: 0.0095 - val_loss: 33.2993 - val_decoder_loss: 33.0846 - val_predictor_loss: 0.0107
#
# Epoch 02992: val_loss did not improve from 31.85628
# Epoch 2993/3000
#  - 3s - loss: 28.9083 - decoder_loss: 28.7163 - predictor_loss: 0.0096 - val_loss: 32.4666 - val_decoder_loss: 32.1912 - val_predictor_loss: 0.0138
#
# Epoch 02993: val_loss did not improve from 31.85628
# Epoch 2994/3000
#  - 3s - loss: 28.5939 - decoder_loss: 28.3957 - predictor_loss: 0.0099 - val_loss: 32.2951 - val_decoder_loss: 32.0885 - val_predictor_loss: 0.0103
#
# Epoch 02994: val_loss did not improve from 31.85628
# Epoch 2995/3000
#  - 3s - loss: 29.0215 - decoder_loss: 28.8291 - predictor_loss: 0.0096 - val_loss: 33.1392 - val_decoder_loss: 32.9297 - val_predictor_loss: 0.0105
#
# Epoch 02995: val_loss did not improve from 31.85628
# Epoch 2996/3000
#  - 3s - loss: 29.0841 - decoder_loss: 28.8787 - predictor_loss: 0.0103 - val_loss: 33.5949 - val_decoder_loss: 33.3732 - val_predictor_loss: 0.0111
#
# Epoch 02996: val_loss did not improve from 31.85628
# Epoch 2997/3000
#  - 3s - loss: 28.6530 - decoder_loss: 28.4574 - predictor_loss: 0.0098 - val_loss: 32.8934 - val_decoder_loss: 32.6604 - val_predictor_loss: 0.0116
#
# Epoch 02997: val_loss did not improve from 31.85628
# Epoch 2998/3000
#  - 3s - loss: 29.0568 - decoder_loss: 28.8702 - predictor_loss: 0.0093 - val_loss: 32.6649 - val_decoder_loss: 32.4145 - val_predictor_loss: 0.0125
#
# Epoch 02998: val_loss did not improve from 31.85628
# Epoch 2999/3000
#  - 3s - loss: 28.6080 - decoder_loss: 28.4188 - predictor_loss: 0.0095 - val_loss: 32.4027 - val_decoder_loss: 32.1960 - val_predictor_loss: 0.0103
#
# Epoch 02999: val_loss did not improve from 31.85628
# Epoch 3000/3000
#  - 3s - loss: 28.9858 - decoder_loss: 28.7983 - predictor_loss: 0.0094 - val_loss: 32.9086 - val_decoder_loss: 32.6692 - val_predictor_loss: 0.0120
#
# Epoch 03000: val_loss did not improve from 31.85628

# %%
vae_predictor.save('my_model.h5')
vae_predictor.save(checkpoint_path)
vae_predictor.save(new_check_path)

# %% [markdown]
# # **Latent Space Visualization**

# %%
# graph = tf.get_default_graph()

# %%
from scipy.stats import norm
# with graph.as_default():   # We are using this statement to reuse the last saved trained model
z_test = encoder.predict(X_test)

x = np.linspace(-3, 3, 300)

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(20):
    ax = fig.add_subplot(5, 10, i+1)
    ax.hist(z_test[:,i], density=True, bins = 20)
    ax.axis('on')
    ax.text(0.5, -0.35, str(i), fontsize=10, ha='center', transform=ax.transAxes)
    ax.plot(x,norm.pdf(x))

plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=logP_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('logP on test data')
plt.savefig(filename)
plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=qed_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('qed on test data')
plt.savefig(filename)
plt.show()

# %%
from sklearn.manifold import TSNE
z_mean = encoder.predict(X_test)
# print(z_mean)
model_name='VAESMILES_Latent'
os.makedirs(model_name, exist_ok=True)
filename = os.path.join(model_name, "smilesvae_mean.png")

z_embedded = TSNE(n_components=2).fit_transform(z_mean)
plt.figure(figsize=(7,7))
plt.scatter(z_embedded[:, 0], z_embedded[:, 1], c=SAS_test)
plt.colorbar()
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title('SAS on test data')
plt.savefig(filename)
plt.show()

# %% [markdown]
# # **Reconstruction**

# %%
# Calculating mean and standard deviation of all property values on test data

logp_mean_test, qed_mean_test,SAS_mean_test= np.mean(y_test_property, axis=0)
logp_std_test, qed_std_test,SAS_std_test = np.std(y_test_property, axis=0)

# %%
# encoded, decoded and predicted data on test dataset

encoded_xtest=encoder.predict(X_test)
predicted_xtest=predictor.predict(encoded_xtest)
decoded_xtest=decoder.predict(encoded_xtest)
print(encoded_xtest.shape)
print(predicted_xtest.shape)
print(decoded_xtest.shape)
# Out:
# (302, 20)
# (302, 3)
# (302, 4320)

# %%
# Reshaping the original and reconstructed test data
orig_test=X_test.reshape(len(X_test), mol_size_x, mol_size_y)
reconst_test = decoded_xtest.reshape(len(X_test), mol_size_x,mol_size_y)
print(orig_test.shape)
print(reconst_test.shape)
# Out:
# (302, 108, 40)
# (302, 108, 40)

# %% [markdown]
# ### **Reconstruction and Prediction on Original test data set**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
idx=1
print(predicted_xtest[idx])
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)


#Reconstruction

mol="".join([int_to_char[idx] for idx in np.argmax(orig_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [-0.08510791  0.6618125   2.0449011 ]
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# !CC1=C(C(=O)OC(C)C)[C@H](C)N=C1C(=O)Nc1ncc(C)s1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C(C(=O)OC(C)C)[C@H](C)N=C1C(=O)Nc1ncc(C)s1
#
# 47

# %% [markdown]
# ### **Reconstruction and Prediction of property on reconstructed test data**

# %%
# Going back from vectorized form back to a readable string on original test data

# Prediction 
print(predicted_xtest[idx])
print("mean of all properties on test data")
print(logp_mean_test, qed_mean_test,SAS_mean_test)
print("satndard deviation of all properties on test data")
print(logp_std_test, qed_std_test,SAS_std_test)

#Reconstruction
mol="".join([int_to_char[idx] for idx in np.argmax(reconst_test[idx,:,:], axis=1)])
print(mol)
print(len(mol))
mol = re.sub('!|E',"", mol)
print(mol)
print(len(mol))
m = Chem.MolFromSmiles(mol)
m
# Out:
# [-0.08510791  0.6618125   2.0449011 ]
# mean of all properties on test data
# 2.4771253642384106 0.7170151110408212 2.963516528736832
# satndard deviation of all properties on test data
# 1.4639469841537798 0.14166403787323872 0.811183384998689
# !CC1=C(C(=O)OC(C)C)[C@H](C)N=C1C(=O)Nc1ncc(C)s1
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 108
# CC1=C(C(=O)OC(C)C)[C@H](C)N=C1C(=O)Nc1ncc(C)s1
#
# 47

# %% [markdown]
# # **Generating New Samples from Normal Distribution**

# %%
prop_val={}
m=None
n_mol=10
i=0
latent_samples= np.random.normal(0,1,size=(n_mol,Z_DIM))
# print(latent_samples.shape)
predicted_prop_samples=predictor.predict(latent_samples)
# print(predicted_prop_samples.shape)

#Checking the property of molecule
for id, latent_mol in enumerate(latent_samples):
  a=predicted_prop_samples[id][0]<(logp_mean_test+logp_std_test)
  b=predicted_prop_samples[id][0]>=(logp_mean_test-logp_std_test)
  c=predicted_prop_samples[id][1]<(qed_mean_test+qed_std_test)
  d=predicted_prop_samples[id][1]>=(qed_mean_test-qed_std_test)
  e=predicted_prop_samples[id][2]<(SAS_mean_test+SAS_std_test)
  f=predicted_prop_samples[id][2]>=(SAS_mean_test-SAS_std_test)
  if ((a & b) & (c & d) & (e & f)):  #Checking if all of the property values matches
    prop_val[i]=1
    print("Mol {}, Property Validated".format(id+1))

    #Passing it to Decoder Now
    reconst_sample = decoder.predict(latent_samples[id:id+1])
    new_mol=reconst_sample.reshape(mol_size_x, mol_size_y) 
    mol="".join([int_to_char[idx] for idx in np.argmax(new_mol[:,:], axis=1)])
    mol = re.sub('!|E',"", mol)
    m = Chem.MolFromSmiles(mol, sanitize=False)
    if m is None:
      print('Mol {} {}, invalid SMILES'.format(id+1,m))
      continue                   
    else:
      try:
        m = Chem.SanitizeMol(m)
        print(m)
      except:
        print('Mol {}, invalid chemistry'.format(id+1)) 
    m
  else:    #No decoding happens here
    prop_val[i]=0
    print("Mol {}, Property Invalidated".format(id+1))
# Out:
# Mol 1, Property Validated
# Mol 1 None, invalid SMILES
# Mol 2, Property Invalidated
# Mol 3, Property Invalidated
# Mol 4, Property Invalidated
# Mol 5, Property Invalidated
# Mol 6, Property Validated
# Mol 6 None, invalid SMILES
# Mol 7, Property Invalidated
# Mol 8, Property Invalidated
# Mol 9, Property Invalidated
# Mol 10, Property Invalidated
# RDKit ERROR: [16:11:18] SMILES Parse Error: syntax error while parsing: Cc1ncc(C(c[C@CH]CCCC]CC(C)[C@(](ccCcccc1)C1
# RDKit ERROR:
# RDKit ERROR: [16:11:18] SMILES Parse Error: Failed parsing SMILES 'Cc1ncc(C(c[C@CH]CCCC]CC(C)[C@(](ccCcccc1)C1
# RDKit ERROR: ' for input: 'Cc1ncc(C(c[C@CH]CCCC]CC(C)[C@(](ccCcccc1)C1
# RDKit ERROR: '
# RDKit ERROR: [16:11:18] SMILES Parse Error: syntax error while parsing: CC(C)[C@=HC(Oc)cCCc(CC)111C)=Oc1cCcc(c)ccc12)CC1
# RDKit ERROR: [16:11:18] SMILES Parse Error: Failed parsing SMILES 'CC(C)[C@=HC(Oc)cCCc(CC)111C)=Oc1cCcc(c)ccc12)CC1' for input: 'CC(C)[C@=HC(Oc)cCCc(CC)111C)=Oc1cCcc(c)ccc12)CC1'
